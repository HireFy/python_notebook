# %%
import requests
from bs4 import BeautifulSoup
import queue
import threading
import re
import csv
import functools
import os
from time import time

# %%
class jobObject:
    'job描述对象'
    __slots__ = ('tag_href', 'job', 'company', 'address', 'salary', 'tag')

# %%
# 获取函数运行时间装饰器
def excute_time(func):
    @functools.wraps(func)
    def wrapper(*args, **kwargs):
        start = time()
        result = func(*args, **kwargs)
        spend = time() - start
        print('%s() 运行时间: %d' % (func.__name__, spend))
        thread_num = ''
        if 'thread_num' in kwargs:
            thread_num = kwargs['thread_num']
        
        # 运行时间写入文件
        headers = ['函数', '运行时间', '线程数']
        if os.path.isfile('运行时间统计.csv'):
            with open('运行时间统计.csv', 'a', newline='') as f:
                writer = csv.DictWriter(f, headers)
                data = {'函数':func.__name__, '运行时间':spend, '线程数':thread_num}
                writer.writerow(data)
        else:
            with open('运行时间统计.csv', 'a', newline='') as f:
                writer = csv.DictWriter(f, headers)
                writer.writeheader()
                data = {'函数':func.__name__, '运行时间':spend, '线程数':thread_num}
                writer.writerow(data)
            
        return result
    return wrapper

# %%
# 打印当前运行线程信息
def get_current_thread_info(func):
    @functools.wraps(func)
    def wrapper(*args, **kwargs):
        print('[%s()] %s processing!' % (func.__name__, threading.current_thread().name))
        #print('[%s()] processing!' % (func.__name__))
        return func(*args, **kwargs)
    return wrapper

# %%
# free-proxy-list.net上面的ip保存在本地ip_pool.txt文件
@excute_time
def ipToFile(file_name='ip_pool.txt'):
    url = 'https://free-proxy-list.net/'
    r = requests.get(url)
    html = r.text
    soup = BeautifulSoup(html, features='html5lib')
    div_tag = soup.find('div', 'table-responsive')
    tbody_list = div_tag.tbody.contents
    result = ''
    for tr in tbody_list:
        ip = tr.next_element.string
        port = tr.next_element.next_sibling.string
        result += ip + ':' + port + '\n'

    with open(file_name, 'w') as f:
        f.write(result)

# %%
# 从ip_pool读取ip信息
# 返回proxies(queue)
@excute_time
def getIPool(file_name='ip_pool.txt'):
    proxies = queue.Queue()

    with open(file_name, 'r') as f:
        ip_pool = f.read()

    ip_pool = ip_pool.split('\n')

    # 删除最后一个空值
    del ip_pool[-1]

    for ip in ip_pool:
        proxy = {'http': ip, 'https': ip}
        proxies.put(proxy)

    return proxies

# %%
# 获得清理过后的proxies
# 剔除不能连接网页的proxy
# 接收queue, 线程数
# 返回清洗之后的proxies(queue)
@excute_time
def getCleanProxies(proxies, **thread_num):
    #     url = 'http://www.baidu.com'
    url = 'https://jobs.51job.com/'

    # 有效的ip队列
    ok_proxies = queue.Queue()

    def check_proxy(thread_proxies):

        thread_proxies_size = thread_proxies.qsize()

        for i in range(thread_proxies_size):
            thread_proxies_size = thread_proxies.qsize()
            print('当前剩余处理的ip: ', thread_proxies_size)

            # 如果当前ip为0退出当前线程
            if (thread_proxies_size == 0):
                break

            proxy = thread_proxies.get()
            try:
                r = requests.get(url, proxies=proxy, timeout=5)
                print(threading.current_thread().name + ' is processing')
                print('r.status_code:', r.status_code)
                if (r.status_code != 200):
                    print('remove proxy:', proxy)
                else:
                    ok_proxies.put(proxy)

                print('-------------------------------------')

            except requests.Timeout as e:
                print(threading.current_thread().name + ' is processing')
                print(e)
                print('remove proxy:', proxy)
                print('-------------------------------------')
            except requests.ConnectionError as e:
                print(threading.current_thread().name + ' is processing')
                print(e)
                print('remove proxy:', proxy)
                print('-------------------------------------')
            except requests.InvalidHeader as e:
                print(threading.current_thread().name + ' is processing')
                print(e)
                print('remove proxy:', proxy)
                print('-------------------------------------')


    threads = []

    for i in range(thread_num.get('thread_num')):
        thread = threading.Thread(target=check_proxy, args=(proxies,))
        threads.append(thread)

    print('线程开始：')
    for thread in threads:
        print(thread.name + '开始运行')
        thread.start()

    # 每次在剩余处理ip为0之后，程序就会停住不动
    # 当当前线程检测到剩余ip为0后，调用join()方法
    print('线程开始停止运行：')
    for thread in threads:
        thread.join()
        print(thread.name + '已停止')

    return ok_proxies

# %%
# 获得指定链接中的jobObject
# 组装成jobObjectList
# 返回jobObjectList
##############################
# 要不要返回出来交给外面的函数处理？
# 还是就在内部处理？
# 在外面封装个函数吧还是
@excute_time
def get_jobObjectList(url, proxies):
    flag = True
    proxy = proxies.get()
    # TODO 查看信息
    print('get_jobObjectList()当前处理链接:', url))
    while flag:
        try:
            r = requests.get(url, proxies=proxy, timeout=5)
            # 报了异常的话捕捉了之后
            # 获得新的proxy之后就直接开始下次循环
        except requests.exceptions.Timeout as e:
            print(e)
            proxy = proxies.get()
            print('尝试新的proxy')
            #print('----------------------')
            continue
        except requests.exceptions.ProxyError as e:
            print(e)
            proxy = proxies.get()
            print('尝试新的proxy')
            #print('----------------------')
            continue
        except requests.exceptions.ConnectionError as e:
            print(e)
            proxy = proxies.get()
            print('尝试新的proxy')
            #print('----------------------')
            continue

    # 不报异常就取消循环
    flag = False
    
    r.encoding = 'gbk'
    html = r.text
    soup = BeautifulSoup(html, features='html5lib')
    # 找到了工作列表的开头
    title = soup.find('div', 'el title')
    # 找到每一个工作列，它们分别是一个div class='el'
    job_info_list = title.find_next_siblings('div', 'el')

    # 存放当前页jobObject对象到jobObjectList中
    jobObjectList = []
    for tag in job_info_list:
        object = jobObject()
        object.tag_href = tag.find('a').attrs['href']
        object.job = tag.find('a').attrs['title']

        infos = tag.find_all(class_=re.compile('t[2-4]'))
        object.company = infos[0].string
        object.address = infos[1].string
        object.salary = infos[2].string
        jobObjectList.append(object)
    
    print('get_jobObjectList处理完成!')

    return jobObjectList

# %%
# 获取一个jobObject的tag属性列表
# 获取一个详情页标签
# 接收详情页的链接， ip代理
# 返回一个包含有标签的list
# TODO 这个函数读取网页的tag时，耗费时间比较长
# @excute_time
@get_current_thread_info
def getTag(url, proxies):
    tag_url = url
    proxy = proxies.get()

    # 存储标签的List
    tag_list = []
    flag = True

    # TODO 查看信息
    print('getTag()当前处理链接:', tag_url)
    print('getTag()获得的ip:', proxy)
    while flag:
        #     headers = {'user-agent','Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/66.0.3359.181 Chrome/66.0.3359.181 Safari/537.36'}
        try:
            r_tag = requests.get(tag_url, timeout=5, proxies=proxy)

        # 报了异常的话捕捉了之后
        # 获得新的proxy之后就直接开始下次循环
        except requests.exceptions.Timeout as e:
            print(e)
            proxy = proxies.get()
            print('尝试新的proxy')
            #print('----------------------')
            continue
        except requests.exceptions.ProxyError as e:
            print(e)
            proxy = proxies.get()
            print('尝试新的proxy')
            #print('----------------------')
            continue
        except requests.exceptions.ConnectionError as e:
            print(e)
            proxy = proxies.get()
            print('尝试新的proxy')
            #print('----------------------')
            continue

    # 不报异常就取消循环
    flag = False

    r_tag.encoding = 'gbk'
    tag_html = r_tag.text
    tag_soup = BeautifulSoup(tag_html, features='html5lib')

    # 找到详情页第一行标签
    tag_1 = tag_soup.find_all('span', 'sp4')
    for i in tag_1:
        tag_list.append(i.contents[1])

    # 找到详情页第二行标签
    tag_2 = tag_soup.find('p', 't2')

    # 有些详情页没有第二行标签
    if tag_2 is None:
        print('getTag()中tag_list:', tag_list)
        print('----------------------')
        return tag_list

    ll = []
    for i in tag_2.strings:
        ll.append(i)

    # 清除ll中的空值
    def not_empty(s):
        return s and s.strip()

    for i in filter(not_empty, ll):
        tag_list.append(i)

    print('getTag()中tag_list:', tag_list)
    print('----------------------')

    return tag_list

# %%
# 组装jobObject的tag属性
@excute_time
def pack_tag(jobObjectList, proxies, **thread_num):
    # 用一个队列来存储特定的jobObject的详情链接
    #这里都可以不用写
    # tag_href_queue = queue.Queue()
    #
    # for i in jobObjectList:
    #     print(i.tag_href)
    #     tag_href_queue.put(i.tag_href)
    #
    # print('队列中的tag_href: ', tag_href_queue.qsize())
    
    # 用队列多线程来处理
    # 不在使用单线程取列表中一个值然后处理
    jobObject_queue = queue.Queue()
    
    for jobObject in jobObjectList:
        jobObject_queue.put(jobObject)
    
    def pack_object(jobObject_queue):
        flag = True
        while flag:
            jobObject = jobObject_queue.get()
            jobObject.tag = getTag(jobObject.tag_href, proxies)
            if jobObject_queue.qsize() == 0:
                flag = False
            
    
    threads = []
    
    print('thread_num.get(\'thread_num\'): ', thread_num.get('thread_num'))
    
    for i in range(thread_num.get('thread_num')):
        thread = threading.Thread(target=pack_object, args=(jobObject_queue,))
        threads.append(thread)
    
    for thread in threads:
        thread.start()
        
        
    for thread in threads:
        thread.join()
        print('%s 已停止' % thread.name)
    

    print('tag组装完成!')

# %%
# 写入csv
@excute_time
def save_to_csv(jobObjectList):
    headers = ['职位', '公司', '地址', '薪酬', '标签']
    datas = []

    for jobObject in jobObjectList:
        data = {headers[0]: jobObject.job,
                headers[1]: jobObject.company,
                headers[2]: jobObject.address,
                headers[3]: jobObject.salary,
                headers[4]: jobObject.tag}
        datas.append(data)
        
    if os.path.isfile('51job.csv'):
        with open('51job.csv', 'a', newline='') as f:
            writer = csv.DictWriter(f, headers)
            for row in datas:
                writer.writerow(row)
    else:
        with open('51job.csv', 'a', newline='') as f:
            writer = csv.DictWriter(f, headers)
            writer.writeheader()
            for row in datas:
                writer.writerow(row)

# %%
def handle_single(url, proxies):
#     # 先爬个10页看看
#     base_url = queue.Queue()
#     for i in range(10):
#         url_str = 'https://search.51job.com/list/000000,000000,0000,00,9,99,Java,2,{}.html?lang=c&stype=&postchannel=0000&workyear=99&cotype=99&degreefrom=99&jobterm=99&companysize=99&providesalary=99&lonlat=0%2C0&radius=-1&ord_field=0&confirmdate=9&fromType=&dibiaoid=0&address=&line=&specialarea=00&from=&welfare=' \
#             .format(i + 1)
#         base_url.put(url_str)

    # while base_url.not_empty:
    #     print(base_url.get())
    
    

#     print('当前队列中页链接数:', base_url.qsize())

    # 处理ip的代码应该放在其他地方，放在这里拉低了单页的处理速度
    #  获取可用的ip
#     ipToFile()
#     proxies = getIPool()
#     proxies = getCleanProxies(proxies, 25)
#     print('可用的ip: ', proxies.qsize())}
#     threads = []

#     proxy = proxies.get()
    jobObjectList = get_jobObjectList(url, proxies)
    pack_tag(jobObjectList, proxies, thread_num=20)
    save_to_csv(jobObjectList)

# %%
def main():
    url = 'https://search.51job.com/list/000000,000000,0000,00,9,99,Java,2,1.html?lang=c&stype=&postchannel=0000&workyear=99&cotype=99&degreefrom=99&jobterm=99&companysize=99&providesalary=99&lonlat=0%2C0&radius=-1&ord_field=0&confirmdate=9&fromType=&dibiaoid=0&address=&line=&specialarea=00&from=&welfare='
    # 获取ip 
    ipToFile()
    proxies = getIPool()
    proxies = getCleanProxies(proxies, thread_num=40)
    print('可用的ip: ', proxies.qsize())
    
    start_time = time()
    handle_single(url, proxies)
    end_time = time()
    finish_time = end_time - start_time
    print('完成写入单页jobObject!')
    print('完成时间: ', finish_time)
    
    # todo 分割运行时间统计
    with open('运行时间统计.csv', 'a', newline='') as f:
        headers = ['函数', '运行时间', '线程数']
        writer = csv.DictWriter(f, headers)
        data = {'函数':'', '运行时间':'', '线程数':''}
        writer.writerow(data)

main()
# Out:
# ipToFile() 运行时间: 1
# getIPool() 运行时间: 0
# 线程开始：
# Thread-179开始运行
# 当前剩余处理的ip: Thread-180开始运行
#  300
# 当前剩余处理的ip: Thread-181开始运行
#  299
# 当前剩余处理的ip: Thread-182开始运行
#  298
# 当前剩余处理的ip: Thread-183开始运行
#  297
# 当前剩余处理的ip: Thread-184开始运行
#  296
# 当前剩余处理的ip: Thread-185开始运行
#  295
# 当前剩余处理的ip: Thread-186开始运行
#  294
# 当前剩余处理的ip: Thread-187开始运行
#  293
# 当前剩余处理的ip: Thread-188开始运行
#  292
# 当前剩余处理的ip: Thread-189开始运行
#  291
# 当前剩余处理的ip: Thread-190开始运行
#  290
# 当前剩余处理的ip: Thread-191开始运行
#  289
# 当前剩余处理的ip: Thread-192开始运行
#  288
# 当前剩余处理的ip: Thread-193开始运行
#  287
# 当前剩余处理的ip: Thread-194开始运行
#  286
# 当前剩余处理的ip: Thread-195开始运行
#  285
# 当前剩余处理的ip: Thread-196开始运行
#  284
# 当前剩余处理的ip: Thread-197开始运行
#  283
# 当前剩余处理的ip: Thread-198开始运行
#  282
# 当前剩余处理的ip: Thread-199开始运行
#  281
# 当前剩余处理的ip: Thread-200开始运行
#  280
# 当前剩余处理的ip: Thread-201开始运行
#  279
# 当前剩余处理的ip: Thread-202开始运行
#  278
# 当前剩余处理的ip: Thread-203开始运行
#  277
# 当前剩余处理的ip: Thread-204开始运行
#  276
# 当前剩余处理的ip: Thread-205开始运行
#  275
# 当前剩余处理的ip: Thread-206开始运行
#  274
# 当前剩余处理的ip: Thread-207开始运行
#  273
# 当前剩余处理的ip: Thread-208开始运行
#  272
# 当前剩余处理的ip: Thread-209开始运行
#  271
# 当前剩余处理的ip:  270
# Thread-210开始运行
# 当前剩余处理的ip: Thread-211开始运行
#  269
# 当前剩余处理的ip: Thread-212开始运行
#  268
# 当前剩余处理的ip: Thread-213开始运行
#  267
# 当前剩余处理的ip: Thread-214开始运行
#  266
# 当前剩余处理的ip: Thread-215开始运行
#  265
# 当前剩余处理的ip: Thread-216开始运行
#  264
# 当前剩余处理的ip: Thread-217开始运行
#  263
# 当前剩余处理的ip: Thread-218开始运行
#  262
# 当前剩余处理的ip: 线程开始停止运行：
#  261
# Thread-182 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 503 Too many open connections',)))
# remove proxy: {'http': '45.35.55.81:8118', 'https': '45.35.55.81:8118'}
# -------------------------------------
# 当前剩余处理的ip:  260
# Thread-185 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 503 Too many open connections',)))
# remove proxy: {'http': '84.39.241.53:8118', 'https': '84.39.241.53:8118'}
# -------------------------------------
# 当前剩余处理的ip:  259
# Thread-179 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', ConnectionResetError(104, 'Connection reset by peer')))
# remove proxy: {'http': '31.172.191.32:41258', 'https': '31.172.191.32:41258'}
# -------------------------------------
# 当前剩余处理的ip:  258
# Thread-194 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response',)))
# remove proxy: {'http': '45.237.59.8:53281', 'https': '45.237.59.8:53281'}
# -------------------------------------
# 当前剩余处理的ip:  257
# Thread-181 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  256
# Thread-187 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  255
# Thread-180 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  254
# Thread-182 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  253
# Thread-197 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  252
# Thread-181 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', ConnectionResetError(104, 'Connection reset by peer')))
# remove proxy: {'http': '41.139.9.47:8080', 'https': '41.139.9.47:8080'}
# -------------------------------------
# 当前剩余处理的ip:  251
# Thread-200 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response',)))
# remove proxy: {'http': '154.72.48.240:53281', 'https': '154.72.48.240:53281'}
# -------------------------------------
# 当前剩余处理的ip:  250
# Thread-183 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fa39a277d30>, 'Connection to 176.118.49.102 timed out. (connect timeout=5)'))
# remove proxy: {'http': '176.118.49.102:53281', 'https': '176.118.49.102:53281'}
# -------------------------------------
# 当前剩余处理的ip:  249
# Thread-192 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fa39a257470>, 'Connection to 146.185.133.222 timed out. (connect timeout=5)'))
# remove proxy: {'http': '146.185.133.222:10080', 'https': '146.185.133.222:10080'}
# -------------------------------------
# 当前剩余处理的ip:  248
# Thread-205 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fa398151cc0>, 'Connection to 31.179.251.4 timed out. (connect timeout=5)'))
# remove proxy: {'http': '31.179.251.4:8080', 'https': '31.179.251.4:8080'}
# -------------------------------------
# 当前剩余处理的ip:  247
# Thread-215 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fa39bb71668>, 'Connection to 87.207.54.164 timed out. (connect timeout=5)'))
# remove proxy: {'http': '87.207.54.164:8080', 'https': '87.207.54.164:8080'}
# -------------------------------------
# 当前剩余处理的ip:  246
# Thread-190 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '192.241.135.49:8080', 'https': '192.241.135.49:8080'}
# -------------------------------------
# 当前剩余处理的ip:  245
# Thread-218 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fa3981b7e48>, 'Connection to 74.116.59.8 timed out. (connect timeout=5)'))
# remove proxy: {'http': '74.116.59.8:53281', 'https': '74.116.59.8:53281'}
# -------------------------------------
# 当前剩余处理的ip:  244
# Thread-212 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', ConnectionResetError(104, 'Connection reset by peer')))
# remove proxy: {'http': '93.91.154.195:8080', 'https': '93.91.154.195:8080'}
# -------------------------------------
# 当前剩余处理的ip:  243
# Thread-191 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '181.196.244.130:53281', 'https': '181.196.244.130:53281'}
# -------------------------------------
# 当前剩余处理的ip:  242
# Thread-188 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  241
# Thread-196 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '210.4.67.10:53281', 'https': '210.4.67.10:53281'}
# -------------------------------------
# 当前剩余处理的ip:  240
# Thread-195 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '138.122.30.14:53281', 'https': '138.122.30.14:53281'}
# -------------------------------------
# 当前剩余处理的ip:  239
# Thread-201 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '165.255.249.55:53281', 'https': '165.255.249.55:53281'}
# -------------------------------------
# 当前剩余处理的ip:  238
# Thread-202 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '181.113.27.99:80', 'https': '181.113.27.99:80'}
# -------------------------------------
# 当前剩余处理的ip:  237
# Thread-216 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '85.163.43.195:8080', 'https': '85.163.43.195:8080'}
# -------------------------------------
# 当前剩余处理的ip:  236
# Thread-200 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '178.62.251.66:8080', 'https': '178.62.251.66:8080'}
# -------------------------------------
# 当前剩余处理的ip:  235
# Thread-185 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '37.17.170.150:8080', 'https': '37.17.170.150:8080'}
# -------------------------------------
# 当前剩余处理的ip:  234
# Thread-195 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 404 Not Found',)))
# remove proxy: {'http': '198.1.122.29:80', 'https': '198.1.122.29:80'}
# -------------------------------------
# 当前剩余处理的ip:  233
# Thread-194 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  232
# Thread-189 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  231
# Thread-191 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 500 Internal Server Error',)))
# remove proxy: {'http': '37.59.80.69:8082', 'https': '37.59.80.69:8082'}
# -------------------------------------
# 当前剩余处理的ip:  230
# Thread-186 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '42.115.39.138:53281', 'https': '42.115.39.138:53281'}
# -------------------------------------
# 当前剩余处理的ip:  229
# Thread-211 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  228
# Thread-193 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '185.158.65.115:41258', 'https': '185.158.65.115:41258'}
# -------------------------------------
# 当前剩余处理的ip:  227
# Thread-204 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '82.117.204.14:53281', 'https': '82.117.204.14:53281'}
# -------------------------------------
# 当前剩余处理的ip:  226
# Thread-212 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  225
# Thread-204 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 400 Bad Request',)))
# remove proxy: {'http': '60.250.79.187:80', 'https': '60.250.79.187:80'}
# -------------------------------------
# 当前剩余处理的ip:  224
# Thread-179 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  223
# Thread-199 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '139.5.152.46:53281', 'https': '139.5.152.46:53281'}
# -------------------------------------
# 当前剩余处理的ip:  222
# Thread-207 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '77.242.183.220:41258', 'https': '77.242.183.220:41258'}
# -------------------------------------
# 当前剩余处理的ip:  221
# Thread-207 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 400 Bad Request',)))
# remove proxy: {'http': '185.8.238.188:8181', 'https': '185.8.238.188:8181'}
# -------------------------------------
# 当前剩余处理的ip:  220
# Thread-217 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '59.106.216.142:60088', 'https': '59.106.216.142:60088'}
# -------------------------------------
# 当前剩余处理的ip:  219
# Thread-206 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  218
# Thread-203 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  217
# Thread-197 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  216
# Thread-217 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '54.39.98.138:8080', 'https': '54.39.98.138:8080'}
# -------------------------------------
# 当前剩余处理的ip:  215
# Thread-198 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '83.219.143.157:41258', 'https': '83.219.143.157:41258'}
# -------------------------------------
# 当前剩余处理的ip:  214
# Thread-183 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  213
# Thread-196 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  212
# Thread-192 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  211
# Thread-218 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  210
# Thread-208 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '212.30.86.78:53281', 'https': '212.30.86.78:53281'}
# -------------------------------------
# 当前剩余处理的ip:  209
# Thread-182 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '192.111.151.233:80', 'https': '192.111.151.233:80'}
# -------------------------------------
# 当前剩余处理的ip:  208
# Thread-180 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '139.5.26.27:53281', 'https': '139.5.26.27:53281'}
# -------------------------------------
# 当前剩余处理的ip:  207
# Thread-214 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  206
# Thread-216 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  205
# Thread-210 is processingThread-184 is processing
# r.status_code: 200
#
# r.status_code:-------------------------------------
# 当前剩余处理的ip:  204
#  200
# -------------------------------------
# 当前剩余处理的ip:  203
# Thread-183 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 502 Bad Gateway',)))
# remove proxy: {'http': '95.189.123.70:8080', 'https': '95.189.123.70:8080'}
# -------------------------------------
# 当前剩余处理的ip:  202
# Thread-212 is processingThread-181 is processing
# r.status_code: 200
#
# -------------------------------------r.status_code: 200
#
# 当前剩余处理的ip: -------------------------------------
# 201当前剩余处理的ip:
#  201
# Thread-216 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '167.99.157.10:3128', 'https': '167.99.157.10:3128'}
# -------------------------------------
# 当前剩余处理的ip:  199
# Thread-187 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '37.235.70.145:41258', 'https': '37.235.70.145:41258'}
# -------------------------------------
# 当前剩余处理的ip:  198
# Thread-180 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response',)))
# remove proxy: {'http': '182.93.91.244:80', 'https': '182.93.91.244:80'}
# -------------------------------------
# 当前剩余处理的ip:  197
# Thread-188 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fa3a054cf28>, 'Connection to 23.180.0.25 timed out. (connect timeout=5)'))
# remove proxy: {'http': '23.180.0.25:8080', 'https': '23.180.0.25:8080'}
# -------------------------------------
# 当前剩余处理的ip:  196
# Thread-205 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLError("bad handshake: SysCallError(-1, 'Unexpected EOF')",),))
# remove proxy: {'http': '180.254.186.211:80', 'https': '180.254.186.211:80'}
# -------------------------------------
# 当前剩余处理的ip:  195
# Thread-191 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fa39a25e3c8>, 'Connection to 45.113.133.158 timed out. (connect timeout=5)'))
# remove proxy: {'http': '45.113.133.158:8080', 'https': '45.113.133.158:8080'}
# -------------------------------------
# 当前剩余处理的ip:  194
# Thread-207 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response',)))
# remove proxy: {'http': '188.191.124.103:80', 'https': '188.191.124.103:80'}
# -------------------------------------
# 当前剩余处理的ip:  193
# Thread-184 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', ConnectionResetError(104, 'Connection reset by peer')))
# remove proxy: {'http': '91.246.146.3:53281', 'https': '91.246.146.3:53281'}
# -------------------------------------
# 当前剩余处理的ip:  192
# Thread-202 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '62.176.114.225:8080', 'https': '62.176.114.225:8080'}
# -------------------------------------
# 当前剩余处理的ip:  191
# Thread-197 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  190
# Thread-203 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  189
# Thread-195 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  188
# Thread-185 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '95.140.195.154:8080', 'https': '95.140.195.154:8080'}
# -------------------------------------
# 当前剩余处理的ip:  187
# Thread-194 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '88.250.206.55:8080', 'https': '88.250.206.55:8080'}
# -------------------------------------
# 当前剩余处理的ip:  186
# Thread-204 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '78.186.111.31:8080', 'https': '78.186.111.31:8080'}
# -------------------------------------
# 当前剩余处理的ip:  185
# Thread-211 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  184
# Thread-193 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  183
# Thread-185 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7fa39bb30a20>: Failed to establish a new connection: [Errno 111] Connection refused',)))
# remove proxy: {'http': '179.164.195.200:8080', 'https': '179.164.195.200:8080'}
# -------------------------------------
# 当前剩余处理的ip:  182
# Thread-185 is processing
# ('Connection aborted.', BadStatusLine('<html>\r\n',))
# remove proxy: {'http': '118.193.26.18:8080', 'https': '118.193.26.18:8080'}
# -------------------------------------
# 当前剩余处理的ip:  181
# Thread-213 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Read timed out. (read timeout=5)
# remove proxy: {'http': '91.238.28.124:8080', 'https': '91.238.28.124:8080'}
# -------------------------------------
# 当前剩余处理的ip:  180
# Thread-206 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  179
# Thread-209 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  178
# Thread-182 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 500 Internal Server Error',)))
# remove proxy: {'http': '187.255.226.79:80', 'https': '187.255.226.79:80'}
# -------------------------------------
# 当前剩余处理的ip:  177
# Thread-206 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '159.65.45.64:8080', 'https': '159.65.45.64:8080'}
# -------------------------------------
# 当前剩余处理的ip:  176
# Thread-183 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  175
# Thread-200 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  174
# Thread-218 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '133.130.102.54:8181', 'https': '133.130.102.54:8181'}
# -------------------------------------
# 当前剩余处理的ip:  173
# Thread-181 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  172
# Thread-217 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '62.140.224.18:41258', 'https': '62.140.224.18:41258'}
# -------------------------------------
# 当前剩余处理的ip:  171
# Thread-192 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  170
# Thread-199 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  169
# Thread-181 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response',)))
# remove proxy: {'http': '202.84.40.104:53281', 'https': '202.84.40.104:53281'}
# -------------------------------------
# 当前剩余处理的ip:  168
# Thread-196 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '83.218.124.155:41258', 'https': '83.218.124.155:41258'}
# -------------------------------------
# 当前剩余处理的ip:  167
# Thread-207 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '186.230.39.194:80', 'https': '186.230.39.194:80'}
# -------------------------------------
# 当前剩余处理的ip:  166
# Thread-216 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fa3981afcf8>, 'Connection to 103.94.125.107 timed out. (connect timeout=5)'))
# remove proxy: {'http': '103.94.125.107:8080', 'https': '103.94.125.107:8080'}
# -------------------------------------
# 当前剩余处理的ip:  165
# Thread-211 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  164
# Thread-217 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 ',)))
# remove proxy: {'http': '190.94.102.4:8081', 'https': '190.94.102.4:8081'}
# -------------------------------------
# 当前剩余处理的ip:  163
# Thread-179 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '43.229.72.251:8080', 'https': '43.229.72.251:8080'}
# -------------------------------------
# 当前剩余处理的ip:  162
# Thread-188 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '95.179.133.104:8000', 'https': '95.179.133.104:8000'}
# -------------------------------------
# 当前剩余处理的ip:  161
# Thread-180 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '78.187.12.76:53281', 'https': '78.187.12.76:53281'}
# -------------------------------------
# 当前剩余处理的ip:  160
# Thread-204 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  159
# Thread-204 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7fa39bb30908>: Failed to establish a new connection: [Errno 111] Connection refused',)))
# remove proxy: {'http': '24.142.229.206:8080', 'https': '24.142.229.206:8080'}
# -------------------------------------
# 当前剩余处理的ip:  158
# Thread-187 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '182.253.32.132:8080', 'https': '182.253.32.132:8080'}
# -------------------------------------
# 当前剩余处理的ip:  157
# Thread-190 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '85.248.157.175:8080', 'https': '85.248.157.175:8080'}
# -------------------------------------
# 当前剩余处理的ip:  156
# Thread-202 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fa398171470>, 'Connection to 190.74.235.9 timed out. (connect timeout=5)'))
# remove proxy: {'http': '190.74.235.9:8080', 'https': '190.74.235.9:8080'}
# -------------------------------------
# 当前剩余处理的ip:  155
# Thread-197 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fa3981af048>, 'Connection to 45.65.227.42 timed out. (connect timeout=5)'))
# remove proxy: {'http': '45.65.227.42:8080', 'https': '45.65.227.42:8080'}
# -------------------------------------
# 当前剩余处理的ip:  154
# Thread-198 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  153
# Thread-194 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '81.91.49.36:8080', 'https': '81.91.49.36:8080'}
# -------------------------------------
# 当前剩余处理的ip:  152
# Thread-213 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  151
# Thread-184 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '36.81.89.16:8080', 'https': '36.81.89.16:8080'}
# -------------------------------------
# 当前剩余处理的ip:  150
# Thread-208 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  149
# Thread-182 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fa39a27bc88>, 'Connection to 36.65.37.129 timed out. (connect timeout=5)'))
# remove proxy: {'http': '36.65.37.129:8080', 'https': '36.65.37.129:8080'}
# -------------------------------------
# 当前剩余处理的ip:  148
# Thread-196 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  147
# Thread-187 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', ConnectionResetError(104, 'Connection reset by peer')))
# remove proxy: {'http': '103.73.224.194:8080', 'https': '103.73.224.194:8080'}
# -------------------------------------
# 当前剩余处理的ip:  146
# Thread-183 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  145
# Thread-191 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  144
# Thread-187 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 405 Method Not Allowed',)))
# remove proxy: {'http': '175.139.252.193:80', 'https': '175.139.252.193:80'}
# -------------------------------------
# 当前剩余处理的ip:  143
# Thread-212 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  142
# Thread-183 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '212.77.86.103:80', 'https': '212.77.86.103:80'}
# -------------------------------------
# 当前剩余处理的ip:  141
# Thread-183 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', ConnectionResetError(104, 'Connection reset by peer')))
# remove proxy: {'http': '223.19.41.6:8197', 'https': '223.19.41.6:8197'}
# -------------------------------------
# 当前剩余处理的ip:  140
# Thread-218 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '196.27.117.226:8080', 'https': '196.27.117.226:8080'}
# -------------------------------------
# 当前剩余处理的ip:  139
# Thread-206 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  138
# Thread-188 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  137
# Thread-192 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fa3981860b8>, 'Connection to 177.87.36.238 timed out. (connect timeout=5)'))
# remove proxy: {'http': '177.87.36.238:6666', 'https': '177.87.36.238:6666'}
# -------------------------------------
# 当前剩余处理的ip:  136
# Thread-210 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  135
# Thread-189 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  134
# Thread-217 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fa39bb71128>, 'Connection to 18.217.218.126 timed out. (connect timeout=5)'))
# remove proxy: {'http': '18.217.218.126:3128', 'https': '18.217.218.126:3128'}
# -------------------------------------
# 当前剩余处理的ip:  133
# Thread-179 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  132
# Thread-198 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  131
# Thread-190 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  130
# Thread-211 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  129
# Thread-186 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  128
# Thread-180 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fa3a0577048>, 'Connection to 109.248.236.59 timed out. (connect timeout=5)'))
# remove proxy: {'http': '109.248.236.59:8080', 'https': '109.248.236.59:8080'}
# -------------------------------------
# 当前剩余处理的ip:  127
# Thread-193 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  126
# Thread-187 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  125
# Thread-200 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '177.206.176.49:20183', 'https': '177.206.176.49:20183'}
# -------------------------------------
# 当前剩余处理的ip:  124
# Thread-201 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  123
# Thread-192 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  122
# Thread-194 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fa39a25c6a0>, 'Connection to 213.240.196.37 timed out. (connect timeout=5)'))
# remove proxy: {'http': '213.240.196.37:53281', 'https': '213.240.196.37:53281'}
# -------------------------------------
# 当前剩余处理的ip:  121
# Thread-209 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Read timed out. (read timeout=5)
# remove proxy: {'http': '114.134.187.162:53281', 'https': '114.134.187.162:53281'}
# -------------------------------------
# 当前剩余处理的ip:  120
# Thread-205 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Read timed out. (read timeout=5)
# remove proxy: {'http': '191.242.160.42:20183', 'https': '191.242.160.42:20183'}
# -------------------------------------
# 当前剩余处理的ip:  119
# Thread-195 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  118
# Thread-208 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fa39a25c208>, 'Connection to 187.49.192.26 timed out. (connect timeout=5)'))
# remove proxy: {'http': '187.49.192.26:41258', 'https': '187.49.192.26:41258'}
# -------------------------------------
# 当前剩余处理的ip:  117
# Thread-204 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  116
# Thread-184 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '169.239.166.80:53281', 'https': '169.239.166.80:53281'}
# -------------------------------------
# 当前剩余处理的ip:  115
# Thread-191 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fa3a056e550>, 'Connection to 85.175.99.103 timed out. (connect timeout=5)'))
# remove proxy: {'http': '85.175.99.103:8080', 'https': '85.175.99.103:8080'}
# -------------------------------------
# 当前剩余处理的ip:  114
# Thread-214 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  113
# Thread-180 is processingThread-188 is processingThread-203 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  112
#
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  111
#
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  110
# Thread-212 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '103.102.234.23:80', 'https': '103.102.234.23:80'}
# -------------------------------------
# 当前剩余处理的ip:  109
# Thread-183 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fa3981ae1d0>, 'Connection to 27.133.132.80 timed out. (connect timeout=5)'))
# remove proxy: {'http': '27.133.132.80:60088', 'https': '27.133.132.80:60088'}
# -------------------------------------
# 当前剩余处理的ip:  108
# Thread-218 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fa3a028fe10>, 'Connection to 41.90.113.226 timed out. (connect timeout=5)'))
# remove proxy: {'http': '41.90.113.226:8080', 'https': '41.90.113.226:8080'}
# -------------------------------------
# 当前剩余处理的ip:  107
# Thread-210 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '146.158.30.192:53281', 'https': '146.158.30.192:53281'}
# -------------------------------------
# 当前剩余处理的ip:  106
# Thread-190 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fa39a27b630>, 'Connection to 94.240.57.39 timed out. (connect timeout=5)'))
# remove proxy: {'http': '94.240.57.39:53281', 'https': '94.240.57.39:53281'}
# -------------------------------------
# 当前剩余处理的ip:  105
# Thread-202 is processingThread-190 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7fa3a0577dd8>: Failed to establish a new connection: [Errno 111] Connection refused',)))
# remove proxy: {'http': '94.180.248.159:8088', 'https': '94.180.248.159:8088'}
# -------------------------------------
# 当前剩余处理的ip:  104
#
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  103
# Thread-185 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '140.227.12.170:3129', 'https': '140.227.12.170:3129'}
# -------------------------------------
# 当前剩余处理的ip:  102
# Thread-213 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  101
# Thread-189 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  100
# Thread-181 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Read timed out. (read timeout=5)
# remove proxy: {'http': '36.89.182.57:8080', 'https': '36.89.182.57:8080'}
# -------------------------------------
# 当前剩余处理的ip:  99
# Thread-200 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  98
# Thread-179 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '31.25.141.46:53281', 'https': '31.25.141.46:53281'}
# -------------------------------------
# 当前剩余处理的ip:  97
# Thread-216 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '103.10.59.36:8080', 'https': '103.10.59.36:8080'}
# -------------------------------------
# 当前剩余处理的ip:  96
# Thread-187 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fa39a27aba8>, 'Connection to 87.244.181.115 timed out. (connect timeout=5)'))
# remove proxy: {'http': '87.244.181.115:8080', 'https': '87.244.181.115:8080'}
# -------------------------------------
# 当前剩余处理的ip:  95
# Thread-194 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  94
# Thread-198 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  93
# Thread-201 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fa39a5ad2b0>, 'Connection to 110.78.156.247 timed out. (connect timeout=5)'))
# remove proxy: {'http': '110.78.156.247:53281', 'https': '110.78.156.247:53281'}
# -------------------------------------
# 当前剩余处理的ip:  92
# Thread-209 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fa39bb4de48>, 'Connection to 103.246.3.85 timed out. (connect timeout=5)'))
# remove proxy: {'http': '103.246.3.85:8080', 'https': '103.246.3.85:8080'}
# -------------------------------------
# 当前剩余处理的ip:  91
# Thread-186 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  90
# Thread-204 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  89
# Thread-205 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '103.88.234.242:53281', 'https': '103.88.234.242:53281'}
# -------------------------------------
# 当前剩余处理的ip:  88
# Thread-184 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fa3a02b3a20>, 'Connection to 41.193.238.202 timed out. (connect timeout=5)'))
# remove proxy: {'http': '41.193.238.202:8080', 'https': '41.193.238.202:8080'}
# -------------------------------------
# 当前剩余处理的ip:  87
# Thread-217 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  86
# Thread-199 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  85
# Thread-208 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  84
# Thread-191 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '191.209.72.68:53281', 'https': '191.209.72.68:53281'}
# -------------------------------------
# 当前剩余处理的ip:  83
# Thread-217 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7fa3a0263080>: Failed to establish a new connection: [Errno 111] Connection refused',)))
# remove proxy: {'http': '82.76.40.4:443', 'https': '82.76.40.4:443'}
# -------------------------------------
# 当前剩余处理的ip:  82
# Thread-210 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  81
# Thread-197 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Read timed out.
# remove proxy: {'http': '176.120.210.168:41258', 'https': '176.120.210.168:41258'}
# -------------------------------------
# 当前剩余处理的ip:  80
# Thread-183 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fa39a5b72b0>, 'Connection to 103.249.241.246 timed out. (connect timeout=5)'))
# remove proxy: {'http': '103.249.241.246:8080', 'https': '103.249.241.246:8080'}
# -------------------------------------
# 当前剩余处理的ip:  79
# Thread-203 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  78
# Thread-180 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '103.205.177.44:53281', 'https': '103.205.177.44:53281'}
# -------------------------------------
# 当前剩余处理的ip:  77
# Thread-203 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '212.128.69.75:80', 'https': '212.128.69.75:80'}
# -------------------------------------
# 当前剩余处理的ip:  76
# Thread-213 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  75
# Thread-212 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  74
# Thread-196 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Read timed out. (read timeout=5)
# remove proxy: {'http': '103.55.48.154:53281', 'https': '103.55.48.154:53281'}
# -------------------------------------
# 当前剩余处理的ip:  73
# Thread-216 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  72
# Thread-192 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '79.143.120.38:8080', 'https': '79.143.120.38:8080'}
# -------------------------------------
# 当前剩余处理的ip:  71
# Thread-189 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '180.246.55.162:8080', 'https': '180.246.55.162:8080'}
# -------------------------------------
# 当前剩余处理的ip:  70
# Thread-200 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fa39816e400>, 'Connection to 134.35.60.245 timed out. (connect timeout=5)'))
# remove proxy: {'http': '134.35.60.245:8080', 'https': '134.35.60.245:8080'}
# ...
# -------------------------------------
# 当前剩余处理的ip:  24
# Thread-184 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '165.90.60.133:80', 'https': '165.90.60.133:80'}
# -------------------------------------
# 当前剩余处理的ip:  23
# Thread-191 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fa39a5a0e48>, 'Connection to 91.193.130.172 timed out. (connect timeout=5)'))
# remove proxy: {'http': '91.193.130.172:53281', 'https': '91.193.130.172:53281'}
# -------------------------------------
# 当前剩余处理的ip:  22
# Thread-197 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 400 Bad Request',)))
# remove proxy: {'http': '47.52.231.140:8080', 'https': '47.52.231.140:8080'}
# -------------------------------------
# 当前剩余处理的ip:  21
# Thread-204 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '212.237.7.173:8118', 'https': '212.237.7.173:8118'}
# -------------------------------------
# 当前剩余处理的ip:  20
# Thread-195 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  19
# Thread-180 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  18
# Thread-197 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '178.128.181.222:80', 'https': '178.128.181.222:80'}
# -------------------------------------
# 当前剩余处理的ip:  18
# Thread-201 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  16
# Thread-201 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 400 Bad Request',)))
# remove proxy: {'http': '52.163.120.142:8080', 'https': '52.163.120.142:8080'}
# -------------------------------------
# 当前剩余处理的ip:  15
# Thread-199 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  14
# Thread-180 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '138.197.200.119:3128', 'https': '138.197.200.119:3128'}
# -------------------------------------
# 当前剩余处理的ip:  13
# Thread-187 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  12
# Thread-183 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  11
# Thread-207 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  10
# Thread-208 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '109.232.137.45:41258', 'https': '109.232.137.45:41258'}
# -------------------------------------
# 当前剩余处理的ip:  9
# Thread-210 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  8
# Thread-187 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  7
# Thread-179 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fa39bb00c18>, 'Connection to 91.187.113.205 timed out. (connect timeout=5)'))
# remove proxy: {'http': '91.187.113.205:53281', 'https': '91.187.113.205:53281'}
# -------------------------------------
# 当前剩余处理的ip:  6
# Thread-208 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 400 Bad Request',)))
# remove proxy: {'http': '188.166.119.186:80', 'https': '188.166.119.186:80'}
# -------------------------------------
# 当前剩余处理的ip:  5
# Thread-188 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  4
# Thread-216 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fa39818ec50>, 'Connection to 140.227.10.47 timed out. (connect timeout=5)'))
# remove proxy: {'http': '140.227.10.47:3129', 'https': '140.227.10.47:3129'}
# -------------------------------------
# 当前剩余处理的ip:  3
# Thread-209 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', ConnectionResetError(104, 'Connection reset by peer')))
# remove proxy: {'http': '95.104.71.222:8080', 'https': '95.104.71.222:8080'}
# -------------------------------------
# 当前剩余处理的ip:  2
# Thread-206 is processing
# r.status_code: 200
# -------------------------------------Thread-216 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7fa39a0986d8>: Failed to establish a new connection: [Errno 111] Connection refused',)))
# remove proxy: {'http': '103.209.140.157:8080', 'https': '103.209.140.157:8080'}
# -------------------------------------
# 当前剩余处理的ip:  1
#
# 当前剩余处理的ip:  0
# Thread-207 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '189.98.44.9:8080', 'https': '189.98.44.9:8080'}
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-205 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fa39a257c50>, 'Connection to 187.84.222.153 timed out. (connect timeout=5)'))
# remove proxy: {'http': '187.84.222.153:80', 'https': '187.84.222.153:80'}
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-182 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-198 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-218 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fa3a054cc88>, 'Connection to 36.67.39.15 timed out. (connect timeout=5)'))
# remove proxy: {'http': '36.67.39.15:53281', 'https': '36.67.39.15:53281'}
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-189 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-185 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fa398152828>, 'Connection to 5.202.148.6 timed out. (connect timeout=5)'))
# remove proxy: {'http': '5.202.148.6:53281', 'https': '5.202.148.6:53281'}
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-197 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-184 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-180 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-194 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-190 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-191 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fa39a098160>, 'Connection to 192.244.99.217 timed out. (connect timeout=5)'))
# remove proxy: {'http': '192.244.99.217:3129', 'https': '192.244.99.217:3129'}
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-195 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-192 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '45.70.106.116:53281', 'https': '45.70.106.116:53281'}
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-213 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '45.127.222.140:53281', 'https': '45.127.222.140:53281'}
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-217 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Read timed out. (read timeout=5)
# remove proxy: {'http': '186.194.181.132:20183', 'https': '186.194.181.132:20183'}
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-201 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-209 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-200 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-179 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fa398195b38>, 'Connection to 125.20.96.215 timed out. (connect timeout=5)'))
# remove proxy: {'http': '125.20.96.215:80', 'https': '125.20.96.215:80'}
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-179已停止
# Thread-180已停止
# Thread-204 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-212 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-183 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '208.68.236.6:41258', 'https': '208.68.236.6:41258'}
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-188 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '95.170.220.162:53281', 'https': '95.170.220.162:53281'}
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-203 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Read timed out. (read timeout=5)
# remove proxy: {'http': '92.241.65.174:8080', 'https': '92.241.65.174:8080'}
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-202 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Read timed out. (read timeout=5)
# remove proxy: {'http': '190.214.1.26:52136', 'https': '190.214.1.26:52136'}
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-187 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '80.78.75.137:8080', 'https': '80.78.75.137:8080'}
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-193 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-216 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-199 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '103.108.157.218:53281', 'https': '103.108.157.218:53281'}
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-208 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '5.202.114.136:91', 'https': '5.202.114.136:91'}
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-214 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-181 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '185.231.210.211:41258', 'https': '185.231.210.211:41258'}
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-181已停止
# Thread-182已停止
# Thread-183已停止
# Thread-184已停止
# Thread-185已停止
# Thread-211 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-210 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '84.1.115.14:53281', 'https': '84.1.115.14:53281'}
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-196 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Read timed out.
# remove proxy: {'http': '85.70.10.251:53281', 'https': '85.70.10.251:53281'}
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-186 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-186已停止
# Thread-187已停止
# Thread-188已停止
# Thread-189已停止
# Thread-190已停止
# Thread-191已停止
# Thread-192已停止
# Thread-193已停止
# Thread-194已停止
# Thread-195已停止
# Thread-196已停止
# Thread-197已停止
# Thread-198已停止
# Thread-199已停止
# Thread-200已停止
# Thread-201已停止
# Thread-202已停止
# Thread-203已停止
# Thread-204已停止
# Thread-205已停止
# Thread-206已停止
# Thread-207已停止
# Thread-208已停止
# Thread-209已停止
# Thread-210已停止
# Thread-211已停止
# Thread-212已停止
# Thread-213已停止
# Thread-214已停止
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-76-a61c0972f111> in <module>()
#      21         writer.writerow(data)
#      22
# ---> 23 main()
#
# <ipython-input-76-a61c0972f111> in main()
#       4     ipToFile()
#       5     proxies = getIPool()
# ----> 6     proxies = getCleanProxies(proxies, thread_num=40)
#       7     print('可用的ip: ', proxies.qsize())
#       8
#
# <ipython-input-61-1b3a55337b52> in wrapper(*args, **kwargs)
#       4     def wrapper(*args, **kwargs):
#       5         start = time()
# ----> 6         result = func(*args, **kwargs)
#       7         spend = time() - start
#       8         print('%s() 运行时间: %d' % (func.__name__, spend))
#
# <ipython-input-65-e1e975338eb0> in getCleanProxies(proxies, **thread_num)
#      67     print('线程开始停止运行：')
#      68     for thread in threads:
# ---> 69         thread.join()
#      70         print(thread.name + '已停止')
#      71
#
# ~/anaconda3/lib/python3.6/threading.py in join(self, timeout)
#    1054
#    1055         if timeout is None:
# -> 1056             self._wait_for_tstate_lock()
#    1057         else:
#    1058             # the behavior of a negative timeout isn't documented, but
#
# ~/anaconda3/lib/python3.6/threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1070         if lock is None:  # already determined that the C code is done
#    1071             assert self._is_stopped
# -> 1072         elif lock.acquire(block, timeout):
#    1073             lock.release()
#    1074             self._stop()
#
# KeyboardInterrupt:

# %% [raw]
# 单页完成最多需要7分钟，200页需要连续爬23小时左右

# %% [markdown]
# - 装饰器查看每个函数处理的时间，具体优化
# - 清洗ip的函数的代码不应该放在处理单页数据的函数里面
# ----
# 现在想的是多线程来处理，一个线程调用一个handle_single()，就是
# 一个线程执行完成一个页面的所有操作，不知道这样速度是不是会提升
#
# 可以写一个模拟程序，来看看是不是会提升速度
#
# ----
#
# 最耗时的操作是pack_tag，98%的时间在这里被消耗!

# %% [raw]
# pack_tag的线程数为5的时候，消耗时间65秒,之前单线程时224秒左右，下降了70%左右的时间！

# %% [raw]
# pack_tag线程数为10，消耗时间46秒，相比之前下降30%左右！完成处理单页需要48b秒时间,

# %% [raw]
# 运行时间统计.csv第一行的数据情况是getCleanProxies()的线程数是25, pack_tag()的线程数是10
# 第二行情况是getCleanProxies的线程数30, pack_tag()的线程数是20
