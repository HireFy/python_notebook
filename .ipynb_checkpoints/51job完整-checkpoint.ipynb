# %%
import requests
from bs4 import BeautifulSoup
import threading

import queue
import re

# %%
# free-proxy-list.net上面的ip保存在本地ip_pool.txt文件
def ipToFile():
    url = 'https://free-proxy-list.net/'
    r = requests.get(url)
    html = r.text
    soup = BeautifulSoup(html, features='html5lib')
    div_tag = soup.find('div', 'table-responsive')
    tbody_list = div_tag.tbody.contents
    result = ''
    for tr in tbody_list:
        ip = tr.next_element.string
        port = tr.next_element.next_sibling.string
        result += ip + ':' + port + '\n'

    with open('ip_pool.txt', 'w') as f:
        f.write(result)

# %%
# 从ip_pool读取ip信息
# 返回queue
def getIPool():
    proxies = queue.Queue()
    
    with open('ip_pool.txt', 'r') as f:
        ip_pool = f.read()
        
    ip_pool = ip_pool.split('\n')

    # 删除最后一个空值
    del ip_pool[-1]

    for ip in ip_pool:
        proxy = {'http':ip, 'https':ip}
        proxies.put(proxy)
        
    return proxies

# %%
# 获得清理过后的proxies
# 剔除不能连接网页的proxy
# 接收queue, 线程数
# 返回queue
def getCleanProxies(proxies, thread_num):    
#     url = 'http://www.baidu.com'
    url = 'https://jobs.51job.com/'
    
    # 有效的ip队列
    ok_proxies = queue.Queue()
    
    
    def check_proxy(thread_proxies):
        
        thread_proxies_size = thread_proxies.qsize()
        
        for i in range(thread_proxies_size):
            thread_proxies_size = thread_proxies.qsize()
            print('当前剩余处理的ip: ', thread_proxies_size)
            
            # 如果当前ip为0退出当前线程
            if(thread_proxies_size == 0):
                break
                
            proxy = thread_proxies.get()
            try:
                r = requests.get(url, proxies=proxy, timeout=5)
                print(threading.current_thread().name + ' is processing')
                print('r.status_code:', r.status_code)
                if(r.status_code != 200):
                    print('remove proxy:', proxy)
                else:
                    ok_proxies.put(proxy)

                print('-------------------------------------')

            except requests.Timeout as e:
                print(threading.current_thread().name + ' is processing')
                print(e)
                print('remove proxy:', proxy)
                print('-------------------------------------')
            except requests.ConnectionError as e:
                print(threading.current_thread().name + ' is processing')
                print(e)
                print('remove proxy:', proxy)
                print('-------------------------------------')
            except requests.InvalidHeader as e:
                print(threading.current_thread().name + ' is processing')
                print(e)
                print('remove proxy:', proxy)
                print('-------------------------------------')
      
    
    threads = []
    
    for i in range(thread_num):
        thread = threading.Thread(target=check_proxy, args=(proxies,))
        threads.append(thread)
    
    print('线程开始：')
    for thread in threads:
        print(thread.name + '开始运行')
        thread.start()
    
    # 每次在剩余处理ip为0之后，程序就会停住不动
    # 当当前线程检测到剩余ip为0后，调用join()方法
    print('线程开始停止运行：')
    for thread in threads:
        thread.join()
        print(thread.name + '已停止')
        
    return ok_proxies

# %% [markdown]
# ----

# %%
#  获取可用的ip
ipToFile()
proxies = getIPool()
proxies = getCleanProxies(proxies, 25)
print('可用的ip: ', proxies.qsize())
# Out:
# 线程开始：
# Thread-4开始运行
# 当前剩余处理的ip: Thread-5开始运行
#  300
# 当前剩余处理的ip: Thread-6开始运行
#  299
# 当前剩余处理的ip: Thread-7开始运行
#  298
# 当前剩余处理的ip: Thread-8开始运行
#  297
# 当前剩余处理的ip: Thread-9开始运行
#  296
# 当前剩余处理的ip: Thread-10开始运行
#  295
# 当前剩余处理的ip: Thread-11开始运行
#  294
# 当前剩余处理的ip: Thread-12开始运行
#  293
# 当前剩余处理的ip: Thread-13开始运行
#  292
# 当前剩余处理的ip: Thread-14开始运行
#  291
# 当前剩余处理的ip: Thread-15开始运行
#  290
# 当前剩余处理的ip: Thread-16开始运行
#  289
# 当前剩余处理的ip: Thread-17开始运行
#  288
# 当前剩余处理的ip: Thread-18开始运行
#  287
# 当前剩余处理的ip: Thread-19开始运行
#  286
# 当前剩余处理的ip: Thread-20开始运行
#  285
# 当前剩余处理的ip: Thread-21开始运行
#  284
# 当前剩余处理的ip: Thread-22开始运行
#  283
# 当前剩余处理的ip: Thread-23开始运行
#  282
# 当前剩余处理的ip: Thread-24开始运行
#  281
# 当前剩余处理的ip: Thread-25开始运行
# Thread-21 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 400 Bad Request',)))
# remove proxy: {'http': '54.95.211.163:8080', 'https': '54.95.211.163:8080'}
# -------------------------------------
# 当前剩余处理的ip:  280
#  280
# 当前剩余处理的ip: Thread-26开始运行
#  278
# 当前剩余处理的ip: Thread-27开始运行
#  277
# 当前剩余处理的ip: Thread-28开始运行
#  276
# 当前剩余处理的ip: 线程开始停止运行：
#  275
# Thread-27 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 500 Internal Server Error',)))
# remove proxy: {'http': '108.61.186.207:8080', 'https': '108.61.186.207:8080'}
# -------------------------------------
# 当前剩余处理的ip:  274
# Thread-27 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '178.128.189.253:3128', 'https': '178.128.189.253:3128'}
# -------------------------------------
# 当前剩余处理的ip:  273
# Thread-5 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '66.70.190.244:8080', 'https': '66.70.190.244:8080'}
# -------------------------------------
# 当前剩余处理的ip:  272
# Thread-9 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response',)))
# remove proxy: {'http': '101.109.208.250:8080', 'https': '101.109.208.250:8080'}
# -------------------------------------
# 当前剩余处理的ip:  271
# Thread-10 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '89.40.119.252:80', 'https': '89.40.119.252:80'}
# -------------------------------------
# 当前剩余处理的ip:  270
# Thread-14 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 405 Method Not Allowed',)))
# remove proxy: {'http': '115.249.145.202:80', 'https': '115.249.145.202:80'}
# -------------------------------------
# 当前剩余处理的ip:  269
# Thread-17 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 500 Internal Server Error',)))
# remove proxy: {'http': '150.163.105.2:8080', 'https': '150.163.105.2:8080'}
# -------------------------------------
# 当前剩余处理的ip:  268
# Thread-19 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '178.62.251.66:8080', 'https': '178.62.251.66:8080'}
# -------------------------------------
# 当前剩余处理的ip:  267
# Thread-24 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 500 Internal Server Error',)))
# remove proxy: {'http': '178.49.139.13:80', 'https': '178.49.139.13:80'}
# -------------------------------------
# 当前剩余处理的ip:  266
# Thread-17 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 ',)))
# remove proxy: {'http': '170.82.228.42:8080', 'https': '170.82.228.42:8080'}
# -------------------------------------
# 当前剩余处理的ip:  265
# Thread-21 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  264
# Thread-10 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '179.164.232.117:20183', 'https': '179.164.232.117:20183'}
# -------------------------------------
# 当前剩余处理的ip:  263
# Thread-8 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response',)))
# remove proxy: {'http': '182.93.89.133:80', 'https': '182.93.89.133:80'}
# -------------------------------------
# 当前剩余处理的ip:  262
# Thread-20 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  261
# Thread-22 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  260
# Thread-20 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  259
# Thread-27 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  258
# Thread-20 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '159.89.229.66:8080', 'https': '159.89.229.66:8080'}
# -------------------------------------
# 当前剩余处理的ip:  257
# Thread-5 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  256
# Thread-11 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fb338f0ccf8>, 'Connection to 162.251.159.17 timed out. (connect timeout=5)'))
# remove proxy: {'http': '162.251.159.17:8080', 'https': '162.251.159.17:8080'}
# -------------------------------------
# 当前剩余处理的ip:  255
# Thread-18 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fb3386ba978>, 'Connection to 148.243.240.156 timed out. (connect timeout=5)'))
# remove proxy: {'http': '148.243.240.156:53281', 'https': '148.243.240.156:53281'}
# -------------------------------------
# 当前剩余处理的ip:  254
# Thread-15 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  253
# Thread-28 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  252
# Thread-13 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  251
# Thread-6 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  250
# Thread-23 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '194.28.169.235:41258', 'https': '194.28.169.235:41258'}
# -------------------------------------
# 当前剩余处理的ip:  249
# Thread-25 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  248
# Thread-16 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  247
# Thread-23 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '142.44.246.242:80', 'https': '142.44.246.242:80'}
# -------------------------------------
# 当前剩余处理的ip:  246
# Thread-9 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '188.120.226.223:80', 'https': '188.120.226.223:80'}
# -------------------------------------
# 当前剩余处理的ip:  245
# Thread-26 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  244
# Thread-26 is processing
# ('Connection aborted.', BadStatusLine('<html>\r\n',))
# remove proxy: {'http': '109.195.243.177:8197', 'https': '109.195.243.177:8197'}
# -------------------------------------
# 当前剩余处理的ip:  243
# Thread-19 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  242
# Thread-20 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  241
# Thread-19 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '178.128.146.110:80', 'https': '178.128.146.110:80'}
# -------------------------------------
# 当前剩余处理的ip:  240
# Thread-10 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fb3386adf60>, 'Connection to 176.120.208.242 timed out. (connect timeout=5)'))
# remove proxy: {'http': '176.120.208.242:41258', 'https': '176.120.208.242:41258'}
# -------------------------------------
# 当前剩余处理的ip:  239
# Thread-24 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '116.197.135.172:3128', 'https': '116.197.135.172:3128'}
# -------------------------------------
# 当前剩余处理的ip:  238
# Thread-21 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  237
# Thread-14 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  236
# Thread-14 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 400 Bad Request',)))
# remove proxy: {'http': '14.63.226.198:80', 'https': '14.63.226.198:80'}
# -------------------------------------
# 当前剩余处理的ip:  235
# Thread-17 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  234
# Thread-21 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '81.22.52.8:7744', 'https': '81.22.52.8:7744'}
# -------------------------------------
# 当前剩余处理的ip:  233
# Thread-25 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  232
# Thread-22 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '165.90.60.133:80', 'https': '165.90.60.133:80'}
# -------------------------------------
# 当前剩余处理的ip:  231
# Thread-7 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  230
# Thread-17 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  229
# Thread-11 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 500 Internal Server Error',)))
# remove proxy: {'http': '37.187.116.199:80', 'https': '37.187.116.199:80'}
# -------------------------------------
# 当前剩余处理的ip:  228
# Thread-6 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  227
# Thread-6 is processing
# ('Connection aborted.', BadStatusLine('<html>\r\n',))
# remove proxy: {'http': '113.253.113.90:8380', 'https': '113.253.113.90:8380'}
# -------------------------------------
# 当前剩余处理的ip:  226
# Thread-10 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  225
# Thread-18 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '36.68.50.249:8080', 'https': '36.68.50.249:8080'}
# -------------------------------------
# 当前剩余处理的ip:  224
# Thread-17 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response',)))
# remove proxy: {'http': '58.97.81.11:80', 'https': '58.97.81.11:80'}
# -------------------------------------
# 当前剩余处理的ip:  223
# Thread-17 is processing
# ('Connection aborted.', BadStatusLine('<html>\r\n',))
# remove proxy: {'http': '118.193.26.18:8080', 'https': '118.193.26.18:8080'}
# -------------------------------------
# 当前剩余处理的ip:  222
# Thread-27 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '46.174.10.18:8080', 'https': '46.174.10.18:8080'}
# -------------------------------------
# 当前剩余处理的ip:  221
# Thread-25 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '41.190.33.162:8080', 'https': '41.190.33.162:8080'}
# -------------------------------------
# 当前剩余处理的ip:  220
# Thread-18 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  219
# Thread-24 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response',)))
# remove proxy: {'http': '177.12.84.181:53281', 'https': '177.12.84.181:53281'}
# -------------------------------------
# 当前剩余处理的ip:  218
# Thread-24 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 400 Bad Request',)))
# remove proxy: {'http': '47.89.241.103:8080', 'https': '47.89.241.103:8080'}
# -------------------------------------
# 当前剩余处理的ip:  217
# Thread-15 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  216
# Thread-20 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  215
# Thread-12 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '95.143.108.195:41258', 'https': '95.143.108.195:41258'}
# -------------------------------------
# 当前剩余处理的ip:  214
# Thread-23 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLError("bad handshake: SysCallError(-1, 'Unexpected EOF')",),))
# remove proxy: {'http': '180.254.186.255:80', 'https': '180.254.186.255:80'}
# -------------------------------------
# 当前剩余处理的ip:  213
# Thread-22 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  212
# Thread-14 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLError("bad handshake: SysCallError(-1, 'Unexpected EOF')",),))
# remove proxy: {'http': '36.83.86.179:80', 'https': '36.83.86.179:80'}
# -------------------------------------
# 当前剩余处理的ip:  211
# Thread-11 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  210
# Thread-14 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 503 Service Unavailable',)))
# remove proxy: {'http': '171.97.67.166:3128', 'https': '171.97.67.166:3128'}
# -------------------------------------
# 当前剩余处理的ip:  209
# Thread-13 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  208
# Thread-6 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  207
# Thread-5 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  206
# Thread-26 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  205
# Thread-14 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 503 Service Temporarily Unavailable',)))
# remove proxy: {'http': '213.136.77.246:80', 'https': '213.136.77.246:80'}
# -------------------------------------
# 当前剩余处理的ip:  204
# Thread-7 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  203
# Thread-16 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  202
# Thread-21 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  201
# Thread-8 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  200
# Thread-18 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  199
# Thread-10 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '185.93.3.123:8080', 'https': '185.93.3.123:8080'}
# -------------------------------------
# 当前剩余处理的ip:  198
# Thread-25 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '216.104.200.183:53281', 'https': '216.104.200.183:53281'}
# -------------------------------------
# 当前剩余处理的ip:  197
# Thread-15 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fb3386a2f28>, 'Connection to 81.163.57.121 timed out. (connect timeout=5)'))
# remove proxy: {'http': '81.163.57.121:41258', 'https': '81.163.57.121:41258'}
# -------------------------------------
# 当前剩余处理的ip:  196
# Thread-16 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  195
# Thread-5 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  194
# Thread-13 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  193
# Thread-16 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7fb3386ad588>: Failed to establish a new connection: [Errno 111] Connection refused',)))
# remove proxy: {'http': '103.73.101.226:8080', 'https': '103.73.101.226:8080'}
# -------------------------------------
# 当前剩余处理的ip:  192
# Thread-5 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7fb338ee5780>: Failed to establish a new connection: [Errno 111] Connection refused',)))
# remove proxy: {'http': '177.61.51.253:8080', 'https': '177.61.51.253:8080'}
# -------------------------------------
# 当前剩余处理的ip:  191
# Thread-20 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  190
# Thread-22 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  189
# Thread-11 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fb33868d320>, 'Connection to 180.92.230.58 timed out. (connect timeout=5)'))
# remove proxy: {'http': '180.92.230.58:80', 'https': '180.92.230.58:80'}
# -------------------------------------
# 当前剩余处理的ip:  188
# Thread-16 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', ConnectionResetError(104, 'Connection reset by peer')))
# remove proxy: {'http': '178.141.249.246:8081', 'https': '178.141.249.246:8081'}
# -------------------------------------
# 当前剩余处理的ip:  187
# Thread-7 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  186
# Thread-11 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7fb3385d6668>: Failed to establish a new connection: [Errno 111] Connection refused',)))
# remove proxy: {'http': '179.107.53.90:80', 'https': '179.107.53.90:80'}
# -------------------------------------
# 当前剩余处理的ip:  185
# Thread-26 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  184
# Thread-24 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  183
# Thread-27 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  182
# Thread-23 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  181
# Thread-26 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# remove proxy: {'http': '211.222.0.95:8080', 'https': '211.222.0.95:8080'}
# -------------------------------------
# 当前剩余处理的ip:  180
# Thread-12 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '81.163.36.9:41258', 'https': '81.163.36.9:41258'}
# -------------------------------------
# 当前剩余处理的ip:  179
# Thread-17 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  178
# Thread-24 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '134.35.50.226:8080', 'https': '134.35.50.226:8080'}
# -------------------------------------
# 当前剩余处理的ip:  177
# Thread-8 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  176
# Thread-21 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  175
# Thread-19 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  174
# Thread-10 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  173
# Thread-14 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  172
# Thread-9 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Read timed out.
# remove proxy: {'http': '185.231.210.150:41258', 'https': '185.231.210.150:41258'}
# -------------------------------------
# 当前剩余处理的ip:  171
# Thread-15 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '109.106.136.6:8080', 'https': '109.106.136.6:8080'}
# -------------------------------------
# 当前剩余处理的ip:  170
# Thread-6 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '62.201.208.90:8080', 'https': '62.201.208.90:8080'}
# -------------------------------------
# 当前剩余处理的ip:  169
# Thread-13 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '197.231.179.61:53281', 'https': '197.231.179.61:53281'}
# -------------------------------------
# 当前剩余处理的ip:  168
# Thread-20 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fb3385ed0b8>, 'Connection to 190.64.135.122 timed out. (connect timeout=5)'))
# remove proxy: {'http': '190.64.135.122:53281', 'https': '190.64.135.122:53281'}
# -------------------------------------
# 当前剩余处理的ip:  167
# Thread-15 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response',)))
# remove proxy: {'http': '196.61.75.43:53281', 'https': '196.61.75.43:53281'}
# -------------------------------------
# 当前剩余处理的ip:  166
# Thread-5 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  165
# Thread-22 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '212.237.30.203:8888', 'https': '212.237.30.203:8888'}
# -------------------------------------
# 当前剩余处理的ip:  164
# Thread-7 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fb33860b828>, 'Connection to 103.85.64.212 timed out. (connect timeout=5)'))
# remove proxy: {'http': '103.85.64.212:53281', 'https': '103.85.64.212:53281'}
# -------------------------------------
# 当前剩余处理的ip:  163
# Thread-11 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fb338699fd0>, 'Connection to 134.35.110.251 timed out. (connect timeout=5)'))
# remove proxy: {'http': '134.35.110.251:8080', 'https': '134.35.110.251:8080'}
# -------------------------------------
# 当前剩余处理的ip:  162
# Thread-4 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  161
# Thread-26 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fb33868db38>, 'Connection to 89.234.199.22 timed out. (connect timeout=5)'))
# remove proxy: {'http': '89.234.199.22:41258', 'https': '89.234.199.22:41258'}
# -------------------------------------
# 当前剩余处理的ip:  160
# Thread-8 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  159
# Thread-12 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fb338699518>, 'Connection to 110.78.168.16 timed out. (connect timeout=5)'))
# remove proxy: {'http': '110.78.168.16:53281', 'https': '110.78.168.16:53281'}
# -------------------------------------
# 当前剩余处理的ip:  158
# Thread-27 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  157
# Thread-23 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '103.87.171.108:31773', 'https': '103.87.171.108:31773'}
# -------------------------------------
# 当前剩余处理的ip:  156
# Thread-28 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Read timed out.
# remove proxy: {'http': '185.155.32.112:41258', 'https': '185.155.32.112:41258'}
# -------------------------------------
# 当前剩余处理的ip:  155
# Thread-18 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  154
# Thread-17 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fb33868c358>, 'Connection to 49.48.8.119 timed out. (connect timeout=5)'))
# remove proxy: {'http': '49.48.8.119:8080', 'https': '49.48.8.119:8080'}
# -------------------------------------
# 当前剩余处理的ip:  153
# Thread-16 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  152
# Thread-21 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fb3385e1668>, 'Connection to 181.57.194.222 timed out. (connect timeout=5)'))
# remove proxy: {'http': '181.57.194.222:8080', 'https': '181.57.194.222:8080'}
# -------------------------------------
# 当前剩余处理的ip:  151
# Thread-19 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fb3386c7208>, 'Connection to 36.81.203.233 timed out. (connect timeout=5)'))
# remove proxy: {'http': '36.81.203.233:53281', 'https': '36.81.203.233:53281'}
# -------------------------------------
# 当前剩余处理的ip:  150
# Thread-26 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  149
# Thread-10 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '103.253.146.134:8080', 'https': '103.253.146.134:8080'}
# -------------------------------------
# 当前剩余处理的ip:  148
# Thread-10 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7fb338615e48>: Failed to establish a new connection: [Errno 111] Connection refused',)))
# remove proxy: {'http': '103.248.254.51:80', 'https': '103.248.254.51:80'}
# -------------------------------------
# 当前剩余处理的ip:  147
# Thread-5 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  146
# Thread-13 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fb338f00a90>, 'Connection to 83.219.142.227 timed out. (connect timeout=5)'))
# remove proxy: {'http': '83.219.142.227:41258', 'https': '83.219.142.227:41258'}
# -------------------------------------
# 当前剩余处理的ip:  145
# Thread-21 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response',)))
# remove proxy: {'http': '95.80.252.44:41258', 'https': '95.80.252.44:41258'}
# -------------------------------------
# 当前剩余处理的ip:  144
# Thread-6 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '5.160.243.113:8080', 'https': '5.160.243.113:8080'}
# -------------------------------------
# 当前剩余处理的ip:  143
# Thread-28 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  142
# Thread-22 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fb3386070f0>, 'Connection to 192.223.66.188 timed out. (connect timeout=5)'))
# remove proxy: {'http': '192.223.66.188:8080', 'https': '192.223.66.188:8080'}
# -------------------------------------
# 当前剩余处理的ip:  141
# Thread-24 is processingThread-11 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  140
#
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  139
# Thread-27 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  138
# Thread-4 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  137
# Thread-14 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  136
# Thread-12 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fb338edebe0>, 'Connection to 181.119.115.241 timed out. (connect timeout=5)'))
# remove proxy: {'http': '181.119.115.241:53281', 'https': '181.119.115.241:53281'}
# -------------------------------------
# 当前剩余处理的ip:  135
# Thread-7 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  134
# Thread-18 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fb33868c908>, 'Connection to 190.7.147.110 timed out. (connect timeout=5)'))
# remove proxy: {'http': '190.7.147.110:53281', 'https': '190.7.147.110:53281'}
# -------------------------------------
# 当前剩余处理的ip:  133
# Thread-17 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fb338677e10>, 'Connection to 31.40.116.14 timed out. (connect timeout=5)'))
# remove proxy: {'http': '31.40.116.14:53281', 'https': '31.40.116.14:53281'}
# -------------------------------------
# 当前剩余处理的ip:  132
# Thread-7 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 503 Service Temporarily Unavailable',)))
# remove proxy: {'http': '213.136.89.121:80', 'https': '213.136.89.121:80'}
# -------------------------------------
# 当前剩余处理的ip:  131
# Thread-8 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '103.4.66.238:8080', 'https': '103.4.66.238:8080'}
# -------------------------------------
# 当前剩余处理的ip:  130
# Thread-27 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  129
# Thread-24 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  128
# Thread-23 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  127
# Thread-23 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7fb338699c50>: Failed to establish a new connection: [Errno 111] Connection refused',)))
# remove proxy: {'http': '159.89.184.107:80', 'https': '159.89.184.107:80'}
# -------------------------------------
# 当前剩余处理的ip:  126
# Thread-19 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '139.255.43.82:53281', 'https': '139.255.43.82:53281'}
# -------------------------------------
# 当前剩余处理的ip:  125
# Thread-8 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 500 Internal Server Error',)))
# remove proxy: {'http': '195.178.207.241:80', 'https': '195.178.207.241:80'}
# -------------------------------------
# 当前剩余处理的ip:  124
# Thread-25 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Read timed out. (read timeout=5)
# remove proxy: {'http': '103.90.200.26:53281', 'https': '103.90.200.26:53281'}
# -------------------------------------
# 当前剩余处理的ip:  123
# Thread-6 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  122
# Thread-10 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '36.66.253.141:8080', 'https': '36.66.253.141:8080'}
# -------------------------------------
# 当前剩余处理的ip:  121
# Thread-5 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fb338684c18>, 'Connection to 168.194.152.77 timed out. (connect timeout=5)'))
# remove proxy: {'http': '168.194.152.77:53281', 'https': '168.194.152.77:53281'}
# -------------------------------------
# 当前剩余处理的ip:  120
# Thread-28 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  119
# Thread-21 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fb3386a24a8>, 'Connection to 41.220.229.10 timed out. (connect timeout=5)'))
# remove proxy: {'http': '41.220.229.10:53281', 'https': '41.220.229.10:53281'}
# -------------------------------------
# 当前剩余处理的ip:  118
# Thread-17 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  117
# Thread-4 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fb338ee5358>, 'Connection to 168.196.207.166 timed out. (connect timeout=5)'))
# remove proxy: {'http': '168.196.207.166:53281', 'https': '168.196.207.166:53281'}
# -------------------------------------
# 当前剩余处理的ip:  116
# Thread-11 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '41.193.238.249:8080', 'https': '41.193.238.249:8080'}
# -------------------------------------
# 当前剩余处理的ip:  115
# Thread-11 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '54.39.98.138:8080', 'https': '54.39.98.138:8080'}
# -------------------------------------
# 当前剩余处理的ip:  114
# Thread-7 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  113
# Thread-14 is processingThread-8 is processing
#
# r.status_code:r.status_code:  200200
#
# --------------------------------------------------------------------------
#
# 当前剩余处理的ip:  当前剩余处理的ip: 112
# 112
# Thread-9 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  110
# Thread-13 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  109
# Thread-24 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  108
# Thread-12 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  107
# Thread-6 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  106
# Thread-6 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 400 Bad Request',)))
# remove proxy: {'http': '218.50.2.102:8080', 'https': '218.50.2.102:8080'}
# -------------------------------------
# 当前剩余处理的ip:  105
# Thread-11 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 404 Not Found',)))
# remove proxy: {'http': '129.232.179.98:80', 'https': '129.232.179.98:80'}
# -------------------------------------
# 当前剩余处理的ip:  104
# Thread-6 is processing
# ('Connection aborted.', BadStatusLine('<html>\r\n',))
# remove proxy: {'http': '113.255.76.120:8380', 'https': '113.255.76.120:8380'}
# -------------------------------------
# 当前剩余处理的ip:  103
# Thread-25 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  102
# Thread-16 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  101
# Thread-23 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  100
# Thread-17 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  99
# Thread-25 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '80.211.181.37:3128', 'https': '80.211.181.37:3128'}
# -------------------------------------
# 当前剩余处理的ip:  98
# Thread-21 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  97
# Thread-25 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '206.189.26.105:8080', 'https': '206.189.26.105:8080'}
# -------------------------------------
# 当前剩余处理的ip:  96
# Thread-28 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fb3385fa710>, 'Connection to 54.86.154.239 timed out. (connect timeout=5)'))
# remove proxy: {'http': '54.86.154.239:80', 'https': '54.86.154.239:80'}
# -------------------------------------
# 当前剩余处理的ip:  95
# Thread-27 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  94
# Thread-27 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 400 Bad Request',)))
# remove proxy: {'http': '45.76.102.72:8088', 'https': '45.76.102.72:8088'}
# -------------------------------------
# 当前剩余处理的ip:  93
# Thread-25 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '159.203.33.72:3128', 'https': '159.203.33.72:3128'}
# -------------------------------------
# 当前剩余处理的ip:  92
# Thread-25 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 400 Bad Request',)))
# remove proxy: {'http': '47.89.41.164:80', 'https': '47.89.41.164:80'}
# -------------------------------------
# 当前剩余处理的ip:  91
# Thread-7 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  90
# Thread-8 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  89
# Thread-20 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Read timed out.
# remove proxy: {'http': '85.194.116.226:8080', 'https': '85.194.116.226:8080'}
# -------------------------------------
# 当前剩余处理的ip:  88
# Thread-18 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  87
# Thread-18 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7fb33868c710>: Failed to establish a new connection: [Errno 111] Connection refused',)))
# remove proxy: {'http': '35.184.109.90:3128', 'https': '35.184.109.90:3128'}
# -------------------------------------
# 当前剩余处理的ip:  86
# Thread-9 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  85
# Thread-4 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  84
# Thread-9 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '52.23.193.25:8080', 'https': '52.23.193.25:8080'}
# -------------------------------------
# 当前剩余处理的ip:  83
# Thread-5 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  82
# Thread-8 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  81
# Thread-11 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  80
# Thread-20 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  79
# Thread-11 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '159.89.145.94:8080', 'https': '159.89.145.94:8080'}
# -------------------------------------
# 当前剩余处理的ip:  78
# Thread-14 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  77
# Thread-8 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '201.16.212.134:80', 'https': '201.16.212.134:80'}
# -------------------------------------
# 当前剩余处理的ip:  76
# Thread-6 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fb3385c8c88>, 'Connection to 177.87.8.65 timed out. (connect timeout=5)'))
# remove proxy: {'http': '177.87.8.65:53281', 'https': '177.87.8.65:53281'}
# -------------------------------------
# 当前剩余处理的ip:  75
# Thread-14 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# remove proxy: {'http': '59.7.198.157:8080', 'https': '59.7.198.157:8080'}
# -------------------------------------
# 当前剩余处理的ip:  74
# Thread-22 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  73
# Thread-16 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '110.232.86.52:53281', 'https': '110.232.86.52:53281'}
# -------------------------------------
# 当前剩余处理的ip:  72
# Thread-14 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  71
# Thread-4 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  70
# Thread-19 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Read timed out. (read timeout=5)
# remove proxy: {'http': '45.6.102.238:53281', 'https': '45.6.102.238:53281'}
# -------------------------------------
# 当前剩余处理的ip:  69
# Thread-19 is processing
# ('Connection aborted.', BadStatusLine('<html>\r\n',))
# remove proxy: {'http': '113.255.29.133:80', 'https': '113.255.29.133:80'}
# -------------------------------------
# 当前剩余处理的ip:  68
# Thread-21 is processing
# r.status_code: 200
# -------------------------------------
# ...
# remove proxy: {'http': '81.24.88.99:41258', 'https': '81.24.88.99:41258'}
# -------------------------------------
# 当前剩余处理的ip:  42
# Thread-15 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  41
# Thread-26 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  40
# Thread-24 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Read timed out.
# remove proxy: {'http': '45.248.42.210:8080', 'https': '45.248.42.210:8080'}
# -------------------------------------
# 当前剩余处理的ip:  39
# Thread-6 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fb33857bb70>, 'Connection to 36.67.89.63 timed out. (connect timeout=5)'))
# remove proxy: {'http': '36.67.89.63:31773', 'https': '36.67.89.63:31773'}
# -------------------------------------
# 当前剩余处理的ip:  38
# Thread-23 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  37
# Thread-17 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '128.199.179.107:8080', 'https': '128.199.179.107:8080'}
# Thread-12 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fb338632be0>, 'Connection to 180.254.88.191 timed out. (connect timeout=5)'))
# remove proxy: {'http': '180.254.88.191:8080', 'https': '180.254.88.191:8080'}
# -------------------------------------
# 当前剩余处理的ip:  36
# -------------------------------------
# 当前剩余处理的ip:  35
# Thread-19 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  34
# Thread-19 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7fb3385cfc18>: Failed to establish a new connection: [Errno 111] Connection refused',)))
# remove proxy: {'http': '59.106.220.187:60088', 'https': '59.106.220.187:60088'}
# -------------------------------------
# 当前剩余处理的ip:  33
# Thread-22 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Read timed out. (read timeout=5)
# remove proxy: {'http': '91.207.185.25:8080', 'https': '91.207.185.25:8080'}
# -------------------------------------
# 当前剩余处理的ip:  32
# Thread-7 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  31
# Thread-5 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '185.137.250.244:8888', 'https': '185.137.250.244:8888'}
# -------------------------------------
# 当前剩余处理的ip:  30
# Thread-17 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', ConnectionResetError(104, 'Connection reset by peer')))
# remove proxy: {'http': '41.169.67.242:53281', 'https': '41.169.67.242:53281'}
# -------------------------------------
# 当前剩余处理的ip:  29
# Thread-4 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '189.50.51.100:31323', 'https': '189.50.51.100:31323'}
# -------------------------------------
# 当前剩余处理的ip:  28
# Thread-23 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  27
# Thread-8 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Read timed out. (read timeout=5)
# remove proxy: {'http': '177.74.127.15:53281', 'https': '177.74.127.15:53281'}
# -------------------------------------
# 当前剩余处理的ip:  26
# Thread-9 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fb33851a4e0>, 'Connection to 80.211.69.79 timed out. (connect timeout=5)'))
# remove proxy: {'http': '80.211.69.79:80', 'https': '80.211.69.79:80'}
# -------------------------------------
# 当前剩余处理的ip:  25
# Thread-25 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Read timed out. (read timeout=5)
# remove proxy: {'http': '183.89.178.142:8080', 'https': '183.89.178.142:8080'}
# -------------------------------------
# 当前剩余处理的ip:  24
# Thread-10 is processingThread-27 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '168.194.152.224:53281', 'https': '168.194.152.224:53281'}
# -------------------------------------
# 当前剩余处理的ip:  23
# Thread-15 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  22
#
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  21
# Thread-21 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '187.84.222.153:80', 'https': '187.84.222.153:80'}
# -------------------------------------
# 当前剩余处理的ip:  20
# Thread-28 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  19
# Thread-11 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  18
# Thread-24 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fb33868df28>, 'Connection to 148.102.57.122 timed out. (connect timeout=5)'))
# remove proxy: {'http': '148.102.57.122:8080', 'https': '148.102.57.122:8080'}
# -------------------------------------
# 当前剩余处理的ip:  17
# Thread-14 is processing
# Thread-19 is processingr.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  16
#
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  15
# Thread-14 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 503 Too many open connections',)))
# remove proxy: {'http': '117.18.65.202:8118', 'https': '117.18.65.202:8118'}
# -------------------------------------
# 当前剩余处理的ip:  14
# Thread-26 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  13
# Thread-12 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fb33857be48>, 'Connection to 103.85.235.235 timed out. (connect timeout=5)'))
# remove proxy: {'http': '103.85.235.235:53281', 'https': '103.85.235.235:53281'}
# -------------------------------------
# 当前剩余处理的ip:  12
# Thread-18 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  11
# Thread-20 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '74.210.184.16:53281', 'https': '74.210.184.16:53281'}
# -------------------------------------
# 当前剩余处理的ip:  10
# Thread-22 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '197.44.193.82:8090', 'https': '197.44.193.82:8090'}
# -------------------------------------
# 当前剩余处理的ip:  9
# Thread-6 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  8
# Thread-23 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fb338677908>, 'Connection to 103.209.140.156 timed out. (connect timeout=5)'))
# remove proxy: {'http': '103.209.140.156:8080', 'https': '103.209.140.156:8080'}
# -------------------------------------
# 当前剩余处理的ip:  7
# Thread-4 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  6
# Thread-8 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  5
# Thread-25 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fb33861b780>, 'Connection to 103.209.140.115 timed out. (connect timeout=5)'))
# remove proxy: {'http': '103.209.140.115:8080', 'https': '103.209.140.115:8080'}
# -------------------------------------
# 当前剩余处理的ip:  4
# Thread-13 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '118.101.102.125:8080', 'https': '118.101.102.125:8080'}
# -------------------------------------
# 当前剩余处理的ip:  3
# Thread-10 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fb338510ef0>, 'Connection to 185.103.165.137 timed out. (connect timeout=5)'))
# remove proxy: {'http': '185.103.165.137:41258', 'https': '185.103.165.137:41258'}
# -------------------------------------
# 当前剩余处理的ip:  2
# Thread-4 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7fb338559f60>: Failed to establish a new connection: [Errno 111] Connection refused',)))
# remove proxy: {'http': '185.86.203.237:41258', 'https': '185.86.203.237:41258'}
# -------------------------------------
# 当前剩余处理的ip:  1
# Thread-9 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fb33856e828>, 'Connection to 103.226.0.49 timed out. (connect timeout=5)'))
# remove proxy: {'http': '103.226.0.49:8080', 'https': '103.226.0.49:8080'}
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-21 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fb3385cf438>, 'Connection to 110.232.71.241 timed out. (connect timeout=5)'))
# remove proxy: {'http': '110.232.71.241:53281', 'https': '110.232.71.241:53281'}
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-17 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-19 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fb338615d68>, 'Connection to 111.67.65.5 timed out. (connect timeout=5)'))
# remove proxy: {'http': '111.67.65.5:8080', 'https': '111.67.65.5:8080'}
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-24 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '177.86.202.45:53281', 'https': '177.86.202.45:53281'}
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-18 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-26 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '190.207.63.211:8080', 'https': '190.207.63.211:8080'}
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-25 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-14 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-20 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-22 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fb338f40780>, 'Connection to 131.221.217.130 timed out. (connect timeout=5)'))
# remove proxy: {'http': '131.221.217.130:3128', 'https': '131.221.217.130:3128'}
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-12 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-5 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Read timed out. (read timeout=5)
# remove proxy: {'http': '103.23.239.195:53281', 'https': '103.23.239.195:53281'}
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-10 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fb33856e4a8>, 'Connection to 81.24.91.138 timed out. (connect timeout=5)'))
# remove proxy: {'http': '81.24.91.138:41258', 'https': '81.24.91.138:41258'}
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-16 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-23 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-8 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '103.59.213.29:8080', 'https': '103.59.213.29:8080'}
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-27 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-11 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Read timed out. (read timeout=5)
# remove proxy: {'http': '177.74.127.210:53281', 'https': '177.74.127.210:53281'}
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-6 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '103.220.24.34:8080', 'https': '103.220.24.34:8080'}
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-13 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-7 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-28 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Read timed out. (read timeout=5)
# remove proxy: {'http': '186.233.197.133:53281', 'https': '186.233.197.133:53281'}
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-4 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Read timed out.
# remove proxy: {'http': '185.93.205.194:41258', 'https': '185.93.205.194:41258'}
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-4已停止
# Thread-5已停止
# Thread-6已停止
# Thread-7已停止
# Thread-8已停止
# Thread-9已停止
# Thread-10已停止
# Thread-11已停止
# Thread-12已停止
# Thread-13已停止
# Thread-14已停止
# Thread-15 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Read timed out.
# remove proxy: {'http': '129.205.137.138:53281', 'https': '129.205.137.138:53281'}
# -------------------------------------
# 当前剩余处理的ip:  0
# Thread-15已停止
# Thread-16已停止
# Thread-17已停止
# Thread-18已停止
# Thread-19已停止
# Thread-20已停止
# Thread-21已停止
# Thread-22已停止
# Thread-23已停止
# Thread-24已停止
# Thread-25已停止
# Thread-26已停止
# Thread-27已停止
# Thread-28已停止
# 可用的ip:  140

# %%
# 爬取单页的数据
url = 'https://search.51job.com/list/000000,000000,0000,00,9,99,Java,2,1.html?lang=c&stype=&postchannel=0000&workyear=99&cotype=99&degreefrom=99&jobterm=99&companysize=99&providesalary=99&lonlat=0%2C0&radius=-1&ord_field=0&confirmdate=9&fromType=&dibiaoid=0&address=&line=&specialarea=00&from=&welfare='
proxy = proxies.get()
r = requests.get(url, proxies=proxy)
r.encoding = 'gbk'
html = r.text
soup = BeautifulSoup(html, features='html5lib')
#找到了工作列表的开头
title = soup.find('div', 'el title')
# 找到每一个工作列，它们分别是一个div class='el'
job_info_list = title.find_next_siblings('div', 'el')

# %%
class jobObject:
    'job描述对象'
    __slots__ = ('tag_href', 'job', 'company', 'address', 'salary', 'tag')

# %%
# 存放当前页jobObject对象
jobObjectList = []
for tag in job_info_list:
    object = jobObject()
    object.tag_href = tag.find('a').attrs['href']
    object.job = tag.find('a').attrs['title']
    
    infos = tag.find_all(class_=re.compile('t[2-4]'))
    object.company = infos[0].string
    object.address = infos[1].string
    object.salary = infos[2].string
    jobObjectList.append(object)

print('组装完毕')

print('共有', len(jobObjectList), '个工作')
# Out:
# 组装完毕
# 共有 50 个工作

# %%
num = 1
for i in jobObjectList:
    print(num)
    print(i.tag_href)
    print(i.job)
    print(i.company)
    print(i.address)
    print(i.salary)
    print()
    num += 1
# Out:
# 1
# https://jobs.51job.com/suzhou-xcq/86078730.html?s=01&t=0
# Java开发工程师
# 苏州白金汉爵大酒店有限公司
# 苏州-相城区
# 0.8-1.6万/月
#
# 2
# https://jobs.51job.com/jiaxing/98179674.html?s=01&t=0
# Java（资深）开发工程师
# 铠嘉电脑配件有限公司
# 嘉兴
# 0.5-1万/月
#
# 3
# https://jobs.51job.com/shenzhen-nsq/98131903.html?s=01&t=0
# 高级JAVA工程师
# 深圳爱影科技有限公司
# 深圳-南山区
# 1-1.5万/月
#
# 4
# https://jobs.51job.com/beijing-cyq/103551202.html?s=01&t=0
# Java开发工程师
# 北京悦畅科技有限公司
# 北京-朝阳区
# 1.5-2万/月
#
# 5
# https://jobs.51job.com/beijing-ftq/104516354.html?s=01&t=0
# Java开发工程师
# 北京信成未来科技有限公司
# 北京-丰台区
# 6-8千/月
#
# 6
# https://jobs.51job.com/xian-wyq/101639933.html?s=01&t=0
# 初级Java开发工程师+奖金绩效
# 西安大来电子科技有限公司
# 西安-未央区
# 3-5千/月
#
# 7
# https://jobs.51job.com/hangzhou-bjq/103813872.html?s=01&t=0
# Java转C语言开发（须懂日语）
# 咏创（杭州）科技有限公司
# 杭州-滨江区
# 3-8千/月
#
# 8
# https://jobs.51job.com/suzhou-gxq/104517663.html?s=01&t=0
# Java高级开发工程师
# 苏州诺赛网络科技有限公司
# 苏州-高新区
# 1-1.6万/月
#
# 9
# https://jobs.51job.com/chengdu-jjq/104517765.html?s=01&t=0
# Java开发工程师
# 成都鸿智金融科技有限公司
# 成都-锦江区
# 0.6-1.2万/月
#
# 10
# https://jobs.51job.com/jinan-gxq/104372013.html?s=01&t=0
# Java开发经理
# 济南卡巢网络科技有限公司
# 济南-高新区
# 1-1.5万/月
#
# 11
# https://jobs.51job.com/hangzhou-jgq/104514927.html?s=01&t=0
# Java开发工程师
# 杭州奕安济世生物药业有限公司
# 杭州-江干区
# 1-1.5万/月
#
# 12
# https://jobs.51job.com/nanjing-jyq/104514799.html?s=01&t=0
# Java开发经理
# 江苏微图信息科技有限公司
# 南京-建邺区
# 15-20万/年
#
# 13
# https://jobs.51job.com/wuhan-wcq/104512683.html?s=01&t=0
# 急聘4K双休+java开发助理
# 湖北众康空间体育产业孵化器有限公司
# 武汉-武昌区
# 4-6千/月
#
# 14
# https://jobs.51job.com/wuhan/104516824.html?s=01&t=0
# Java高级开发工程师
# 上海诺姆四达投资集团有限公司无锡...
# 武汉
# 1-2万/月
#
# 15
# https://jobs.51job.com/shanghai-pdxq/64520273.html?s=01&t=0
# Java软件工程师（上海）（金融业）
# 上海佳克计算机软件股份有限公司
# 上海-浦东新区
# 0.8-1.2万/月
#
# 16
# https://jobs.51job.com/zhengzhou/95480056.html?s=01&t=0
# Java开发工程师
# 河南信安通信技术股份有限公司
# 郑州
# 4-6千/月
#
# 17
# https://jobs.51job.com/beijing/71900339.html?s=01&t=0
# JAVA软件工程师（急招）
# 北京创思恒通科技有限公司
# 北京
# 0.6-1.5万/月
#
# 18
# https://jobs.51job.com/guangzhou/102189827.html?s=01&t=0
# java工程师（互联网政务）
# 广州华资软件技术有限公司
# 广州
# 0.8-1.5万/月
#
# 19
# https://jobs.51job.com/tianjin-hxq/104516179.html?s=01&t=0
# Java高级开发工程师
# 嘀嘀智慧城市运营管理（天津）有限...
# 天津-河西区
# 1-1.5万/月
#
# 20
# https://jobs.51job.com/shanghai-pdxq/104101732.html?s=01&t=0
# Java开发工程师（3年以上经验）
# 上海金指软件技术有限公司
# 上海-浦东新区
# 1.2-1.8万/月
#
# 21
# https://jobs.51job.com/qingdao/104515912.html?s=01&t=0
# Java工程师实训生
# 青岛迈科思软件有限责任公司
# 异地招聘
# 3-4.5千/月
#
# 22
# https://jobs.51job.com/zhengzhou-gxq/104514775.html?s=01&t=0
# Java高级开发工程师
# 河南省中教网盟科技有限公司
# 郑州-高新区
# 0.8-1万/月
#
# 23
# https://jobs.51job.com/nanjing-yhtq/61791476.html?s=01&t=0
# 高级JAVA软件工程师
# 上海艺赛旗软件股份有限公司
# 南京-雨花台区
# 1-1.5万/月
#
# 24
# https://jobs.51job.com/wuhan-hsq/103092588.html?s=01&t=0
# Java高级培训师/讲师
# 武汉尚云客网络技术有限公司
# 武汉-洪山区
# 1.2-1.6万/月
#
# 25
# https://jobs.51job.com/shanghai-ptq/102454749.html?s=01&t=0
# Java中级开发工程师
# 易批生鲜信息发展股份有限公司
# 上海-普陀区
# 1.5-2万/月
#
# 26
# https://jobs.51job.com/hefei-gxq/102962159.html?s=01&t=0
# Java开发工程师(合肥）
# 浙江网新恒天软件有限公司
# 合肥-高新区
# 0.7-1.4万/月
#
# 27
# https://jobs.51job.com/shanghai-xhq/70518516.html?s=01&t=0
# Java后台开发工程师
# 上海轻轻信息科技有限公司
# 上海-徐汇区
# 1.5-2.5万/月
#
# 28
# https://jobs.51job.com/wuhan-wcq/104512871.html?s=01&t=0
# Java软件开发实习生+五险一金
# 湖北国兴宏图体育场馆规划设计有限...
# 武汉-武昌区
# 4-6千/月
#
# 29
# https://jobs.51job.com/wuhan/98157540.html?s=01&t=0
# Java高级工程师
# 环球名车汽车服务湖北股份有限公司
# 武汉
# 8-9千/月
#
# 30
# https://jobs.51job.com/guangzhou-pyq/103561045.html?s=01&t=0
# Java高级开发工程师（智能机器人方向）
# 广州步云信息科技有限公司
# 广州-番禺区
# 1-1.5万/月
#
# 31
# https://jobs.51job.com/kunshan/104242248.html?s=01&t=0
# java后端高级开发工程师
# 途鸟科技（上海）有限公司
# 异地招聘
# 1.5-2万/月
#
# 32
# https://jobs.51job.com/shenzhen-nsq/98640418.html?s=01&t=0
# Java架构师（互联网电商方向）
# 深圳市远行科技股份有限公司
# 深圳-南山区
# 1.5-2.5万/月
#
# 33
# https://jobs.51job.com/xiamen/103321603.html?s=01&t=0
# Java开发工程师
# 易招标-互联网招投标的领导者
# 厦门
# 6-8千/月
#
# 34
# https://jobs.51job.com/foshan-sdq/103314270.html?s=01&t=0
# Java开发工程师
# 广东用心网络科技有限公司
# 异地招聘
# 7.5-10.5万/年
#
# 35
# https://jobs.51job.com/overseas/102123960.html?s=01&t=0
# 急聘java开发工程师（赴日）
# 大连鸿进科技有限公司
# 异地招聘
# 2-2.5万/月
#
# 36
# https://jobs.51job.com/xian-lhq/98477387.html?s=01&t=0
# Java开发经理
# 西安市城市规划信息中心
# 西安-莲湖区
# 5-7千/月
#
# 37
# https://jobs.51job.com/foshan/104512062.html?s=01&t=0
# 后端开发工程师（JAVA)
# 美的集团中央空调事业部
# 佛山
# 1-2万/月
#
# 38
# https://jobs.51job.com/beijing-hdq/104512186.html?s=01&t=0
# 资深JAVA开发工程师
# 易点租
# 北京-海淀区
# 2.5-4万/月
#
# 39
# https://jobs.51job.com/shijiazhuang/101545939.html?s=01&t=0
# 年底双薪+Java开发
# 石家庄明妄信息技术有限公司
# 石家庄
# 3-4.5千/月
#
# 40
# https://jobs.51job.com/hangzhou/90903625.html?s=01&t=0
# JAVA工程师
# 杭州云韦科技有限公司
# 杭州
# 1-1.5万/月
#
# 41
# https://jobs.51job.com/changsha-txq/99593709.html?s=01&t=0
# Java开发工程师
# 湖南微阵信息技术有限公司
# 长沙-天心区
# 0.8-1.2万/月
#
# 42
# https://jobs.51job.com/shanghai/51530702.html?s=01&t=0
# java开发工程师
# 上海福乐信息技术有限公司
# 上海
# 0.8-1万/月
#
# 43
# https://jobs.51job.com/guangzhou/104509592.html?s=01&t=0
# java微信工程师
# 广州信畅信息技术有限公司
# 广州
# 0.8-1.5万/月
#
# 44
# https://jobs.51job.com/shenzhen-nsq/104412480.html?s=01&t=0
# Java中高级开发工程师
# 深圳四方精创资讯股份有限公司
# 深圳-南山区
# 2-3万/月
#
# 45
# https://jobs.51job.com/shanghai-pdxq/104000963.html?s=01&t=0
# 高级java开发工程师
# 上海雪山金融信息服务有限公司
# 上海-浦东新区
# 1.5-2万/月
#
# 46
# https://jobs.51job.com/guangzhou-byq/103972417.html?s=01&t=0
# Java高级开发工程师
# 广东阿康药店连锁有限公司
# 广州-白云区
# 1-2万/月
#
# 47
# https://jobs.51job.com/shijiazhuang/104152551.html?s=01&t=0
# Java开发工程师
# 京津冀行知河北教育评估有限公司
# 石家庄
# 0.4-1万/月
#
# 48
# https://jobs.51job.com/shenzhen-nsq/104511166.html?s=01&t=0
# Java架构师
# 海能达通信股份有限公司
# 深圳-南山区
# 1.5-3万/月
#
# 49
# https://jobs.51job.com/shenzhen-nsq/104509392.html?s=01&t=0
# (急聘) java开发工程师
# 深圳讯腾软件技术有限公司
# 深圳-南山区
# 4.5-6千/月
#
# 50
# https://jobs.51job.com/shenzhen-lhq/84289946.html?s=01&t=0
# Java开发工程师/爬虫/采集
# 深圳市博览天下票务服务有限公司
# 深圳-罗湖区
# 0.8-1.5万/月

# %%
# 用一个队列来存储详情链接
tag_href_queue = queue.Queue()

for i in jobObjectList:
    print(i.tag_href)
    tag_href_queue.put(i.tag_href)

print('队列中的tag_href: ', tag_href_queue.qsize())
# Out:
# https://jobs.51job.com/suzhou-xcq/86078730.html?s=01&t=0
# https://jobs.51job.com/jiaxing/98179674.html?s=01&t=0
# https://jobs.51job.com/shenzhen-nsq/98131903.html?s=01&t=0
# https://jobs.51job.com/beijing-cyq/103551202.html?s=01&t=0
# https://jobs.51job.com/beijing-ftq/104516354.html?s=01&t=0
# https://jobs.51job.com/xian-wyq/101639933.html?s=01&t=0
# https://jobs.51job.com/hangzhou-bjq/103813872.html?s=01&t=0
# https://jobs.51job.com/suzhou-gxq/104517663.html?s=01&t=0
# https://jobs.51job.com/chengdu-jjq/104517765.html?s=01&t=0
# https://jobs.51job.com/jinan-gxq/104372013.html?s=01&t=0
# https://jobs.51job.com/hangzhou-jgq/104514927.html?s=01&t=0
# https://jobs.51job.com/nanjing-jyq/104514799.html?s=01&t=0
# https://jobs.51job.com/wuhan-wcq/104512683.html?s=01&t=0
# https://jobs.51job.com/wuhan/104516824.html?s=01&t=0
# https://jobs.51job.com/shanghai-pdxq/64520273.html?s=01&t=0
# https://jobs.51job.com/zhengzhou/95480056.html?s=01&t=0
# https://jobs.51job.com/beijing/71900339.html?s=01&t=0
# https://jobs.51job.com/guangzhou/102189827.html?s=01&t=0
# https://jobs.51job.com/tianjin-hxq/104516179.html?s=01&t=0
# https://jobs.51job.com/shanghai-pdxq/104101732.html?s=01&t=0
# https://jobs.51job.com/qingdao/104515912.html?s=01&t=0
# https://jobs.51job.com/zhengzhou-gxq/104514775.html?s=01&t=0
# https://jobs.51job.com/nanjing-yhtq/61791476.html?s=01&t=0
# https://jobs.51job.com/wuhan-hsq/103092588.html?s=01&t=0
# https://jobs.51job.com/shanghai-ptq/102454749.html?s=01&t=0
# https://jobs.51job.com/hefei-gxq/102962159.html?s=01&t=0
# https://jobs.51job.com/shanghai-xhq/70518516.html?s=01&t=0
# https://jobs.51job.com/wuhan-wcq/104512871.html?s=01&t=0
# https://jobs.51job.com/wuhan/98157540.html?s=01&t=0
# https://jobs.51job.com/guangzhou-pyq/103561045.html?s=01&t=0
# https://jobs.51job.com/kunshan/104242248.html?s=01&t=0
# https://jobs.51job.com/shenzhen-nsq/98640418.html?s=01&t=0
# https://jobs.51job.com/xiamen/103321603.html?s=01&t=0
# https://jobs.51job.com/foshan-sdq/103314270.html?s=01&t=0
# https://jobs.51job.com/overseas/102123960.html?s=01&t=0
# https://jobs.51job.com/xian-lhq/98477387.html?s=01&t=0
# https://jobs.51job.com/foshan/104512062.html?s=01&t=0
# https://jobs.51job.com/beijing-hdq/104512186.html?s=01&t=0
# https://jobs.51job.com/shijiazhuang/101545939.html?s=01&t=0
# https://jobs.51job.com/hangzhou/90903625.html?s=01&t=0
# https://jobs.51job.com/changsha-txq/99593709.html?s=01&t=0
# https://jobs.51job.com/shanghai/51530702.html?s=01&t=0
# https://jobs.51job.com/guangzhou/104509592.html?s=01&t=0
# https://jobs.51job.com/shenzhen-nsq/104412480.html?s=01&t=0
# https://jobs.51job.com/shanghai-pdxq/104000963.html?s=01&t=0
# https://jobs.51job.com/guangzhou-byq/103972417.html?s=01&t=0
# https://jobs.51job.com/shijiazhuang/104152551.html?s=01&t=0
# https://jobs.51job.com/shenzhen-nsq/104511166.html?s=01&t=0
# https://jobs.51job.com/shenzhen-nsq/104509392.html?s=01&t=0
# https://jobs.51job.com/shenzhen-lhq/84289946.html?s=01&t=0
# 队列中的tag_href:  50

# %%
# 获取详情页标签
# 返回一个包含有标签的list
# 传递详情页的链接， ip代理
def getTag(url, proxies):
    tag_url = url
    proxy = proxies.get()
    
    # 存储标签的List
    tag_list = []
    flag = True
    
    #TODO 查看信息
    print('getTag()当前处理链接:', tag_url)
    print('getTag()获得的ip:', proxy)
    while flag:
    #     headers = {'user-agent','Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/66.0.3359.181 Chrome/66.0.3359.181 Safari/537.36'}
        try:
            r_tag = requests.get(tag_url, timeout=5, proxies=proxy)
        
        # 报了异常的话捕捉了之后
        # 获得新的proxy之后就直接开始下次循环
        except requests.exceptions.Timeout as e:
            print(e)
            proxy = proxies.get()
            print('----------------------')
            continue
        except requests.exceptions.ProxyError as e:
            print(e)
            proxy = proxies.get()
            print('----------------------')
            continue
        except requests.exceptions.ConnectionError as e:
            print(e)
            proxy = proxies.get()
            print('----------------------')
            continue
        
        # 不报异常就取消循环
        flag = False
            
        r_tag.encoding = 'gbk'
        tag_html = r_tag.text
        tag_soup = BeautifulSoup(tag_html, features='html5lib')

        #找到详情页第一行标签
        tag_1 = tag_soup.find_all('span', 'sp4')
        for i in tag_1:
            tag_list.append(i.contents[1])

        #找到详情页第二行标签
        tag_2 = tag_soup.find('p', 't2')

        #有些详情页没有第二行标签
        if tag_2 is None:
            return tag_list

        ll = []
        for i in tag_2.strings:
            ll.append(i)

        #清除ll中的空值
        def not_empty(s):
            return s and s.strip()

        for i in filter(not_empty, ll):
            tag_list.append(i)
        
    print('getTag()中tag_list:', tag_list)
    print('----------------------')
    
    return tag_list

# %%
for i in range(tag_href_queue.qsize()):
    jobObjectList[i].tag = getTag(tag_href_queue.get(), proxies)
    
print('tag标签组装完成！')
# Out:
# getTag()当前处理链接: https://jobs.51job.com/suzhou-xcq/86078730.html?s=01&t=0
# getTag()获得的ip: {'http': '103.73.166.77:8080', 'https': '103.73.166.77:8080'}
# getTag()中tag_list: ['无工作经验', '本科', '招3人', '07-14发布', '餐饮补贴']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/jiaxing/98179674.html?s=01&t=0
# getTag()获得的ip: {'http': '81.91.49.36:8080', 'https': '81.91.49.36:8080'}
# getTag()中tag_list: ['无工作经验', '招2人', '07-14发布', '五险一金', '年终奖金', '绩效奖金', '专业培训']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/shenzhen-nsq/98131903.html?s=01&t=0
# getTag()获得的ip: {'http': '119.207.78.155:80', 'https': '119.207.78.155:80'}
# getTag()中tag_list: ['3-4年经验', '本科', '招1人', '07-14发布', '五险一金', '弹性工作', '绩效奖金', '年终奖金', '股票期权']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/beijing-cyq/103551202.html?s=01&t=0
# getTag()获得的ip: {'http': '103.194.88.141:8080', 'https': '103.194.88.141:8080'}
# getTag()中tag_list: ['无工作经验', '招2人', '07-14发布', '做五休二', '周末双休', '带薪年假', '绩效奖金', '专业培训', '五险一金', '节日福利']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/beijing-ftq/104516354.html?s=01&t=0
# getTag()获得的ip: {'http': '36.81.125.244:53281', 'https': '36.81.125.244:53281'}
# getTag()中tag_list: ['无工作经验', '本科', '招若干人', '07-14发布', '五险一金', '餐饮补贴', '绩效奖金', '股票期权', '弹性工作']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/xian-wyq/101639933.html?s=01&t=0
# getTag()获得的ip: {'http': '163.43.30.69:60088', 'https': '163.43.30.69:60088'}
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /xian-wyq/101639933.html?s=01&t=0 (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fb32fbc19b0>, 'Connection to 163.43.30.69 timed out. (connect timeout=5)'))
# ----------------------
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /xian-wyq/101639933.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# ----------------------
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /xian-wyq/101639933.html?s=01&t=0 (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fb32fd699b0>, 'Connection to 14.102.105.154 timed out. (connect timeout=5)'))
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/hangzhou-bjq/103813872.html?s=01&t=0
# getTag()获得的ip: {'http': '182.253.39.114:53281', 'https': '182.253.39.114:53281'}
# getTag()当前处理链接: https://jobs.51job.com/suzhou-gxq/104517663.html?s=01&t=0
# getTag()获得的ip: {'http': '140.227.80.50:3128', 'https': '140.227.80.50:3128'}
# getTag()中tag_list: ['3-4年经验', '大专', '招1人', '07-14发布', '周末双休', '带薪年假', '绩效奖金', '专业培训']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/chengdu-jjq/104517765.html?s=01&t=0
# getTag()获得的ip: {'http': '103.16.45.211:8080', 'https': '103.16.45.211:8080'}
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /chengdu-jjq/104517765.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# ----------------------
# getTag()中tag_list: ['3-4年经验', '大专', '招1人', '07-14发布', '通讯补贴', '弹性工作', '绩效奖金', '年终奖金', '餐饮补贴', '专业培训', '员工旅游', '五险一金']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/jinan-gxq/104372013.html?s=01&t=0
# getTag()获得的ip: {'http': '5.196.205.139:3128', 'https': '5.196.205.139:3128'}
# getTag()中tag_list: ['5-7年经验', '本科', '招1人', '07-14发布', '五险一金', '年终奖金', '股票期权', '弹性工作']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/hangzhou-jgq/104514927.html?s=01&t=0
# getTag()获得的ip: {'http': '177.96.220.66:8080', 'https': '177.96.220.66:8080'}
# getTag()中tag_list: ['3-4年经验', '招2人', '07-14发布', '五险一金', '弹性工作', '免费班车', '绩效奖金', '年终奖金', '专业培训', '团建活动', '节日福利', '做五休二', '带薪年假']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/nanjing-jyq/104514799.html?s=01&t=0
# getTag()获得的ip: {'http': '213.169.82.65:8081', 'https': '213.169.82.65:8081'}
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /nanjing-jyq/104514799.html?s=01&t=0 (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fb34c07c6d8>, 'Connection to 213.169.82.65 timed out. (connect timeout=5)'))
# ----------------------
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Read timed out. (read timeout=5)
# ----------------------
# getTag()中tag_list: ['5-7年经验', '本科', '招若干人', '07-14发布', '五险一金', '补充医疗保险', '免费班车', '员工旅游', '专业培训', '定期体检', '交通补贴']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/wuhan-wcq/104512683.html?s=01&t=0
# getTag()获得的ip: {'http': '186.83.66.5:63909', 'https': '186.83.66.5:63909'}
# getTag()当前处理链接: https://jobs.51job.com/wuhan/104516824.html?s=01&t=0
# getTag()获得的ip: {'http': '27.133.128.174:60088', 'https': '27.133.128.174:60088'}
# getTag()中tag_list: ['5-7年经验', '本科', '招2人', '07-14发布', '五险一金', '餐饮补贴', '通讯补贴', '专业培训', '绩效奖金', '年终奖金']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/shanghai-pdxq/64520273.html?s=01&t=0
# getTag()获得的ip: {'http': '140.227.71.66:3128', 'https': '140.227.71.66:3128'}
# getTag()当前处理链接: https://jobs.51job.com/zhengzhou/95480056.html?s=01&t=0
# getTag()获得的ip: {'http': '140.227.83.18:3129', 'https': '140.227.83.18:3129'}
# getTag()中tag_list: ['2年经验', '本科', '招1人', '07-14发布', '五险一金', '员工旅游', '交通补贴', '餐饮补贴', '通讯补贴', '绩效奖金', '年终奖金', '定期体检']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/beijing/71900339.html?s=01&t=0
# getTag()获得的ip: {'http': '61.220.65.151:8080', 'https': '61.220.65.151:8080'}
# getTag()中tag_list: ['1年经验', '本科', '招4人', '07-14发布', '五险一金', '餐饮补贴', '专业培训', '绩效奖金', '年终奖金', '半年加薪']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/guangzhou/102189827.html?s=01&t=0
# getTag()获得的ip: {'http': '167.99.224.142:8080', 'https': '167.99.224.142:8080'}
# getTag()中tag_list: ['1年经验', '招5人', '07-14发布', '五险一金', '补充医疗保险', '员工旅游', '年终奖金', '绩效奖金', '专业培训', '定期体检', '节日礼金', '14薪+']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/tianjin-hxq/104516179.html?s=01&t=0
# getTag()获得的ip: {'http': '88.99.149.188:31288', 'https': '88.99.149.188:31288'}
# getTag()中tag_list: ['3-4年经验', '本科', '招2人', '07-14发布', '五险一金', '交通补贴', '年终奖金']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/shanghai-pdxq/104101732.html?s=01&t=0
# getTag()获得的ip: {'http': '140.227.69.74:8080', 'https': '140.227.69.74:8080'}
# getTag()中tag_list: ['3-4年经验', '本科', '招10人', '07-14发布', '五险一金', '餐饮补贴', '交通补贴', '员工旅游', '免费班车', '专业培训', '通讯补贴', '定期体检', '年终奖金', '绩效奖金']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/qingdao/104515912.html?s=01&t=0
# getTag()获得的ip: {'http': '35.233.214.154:80', 'https': '35.233.214.154:80'}
# getTag()中tag_list: ['无工作经验', '大专', '招5人', '07-14发布', '带薪年假', '五险一金', '专业培训', '通讯补贴', '餐饮补贴', '全勤奖', '绩效奖金']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/zhengzhou-gxq/104514775.html?s=01&t=0
# getTag()获得的ip: {'http': '177.86.202.115:53281', 'https': '177.86.202.115:53281'}
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Read timed out.
# ----------------------
# getTag()中tag_list: ['5-7年经验', '大专', '招2人', '07-14发布', '带薪年假', '五险一金', '全勤奖', '节日福利', '餐饮补贴', '住房补贴', '员工旅游', '每年多次调薪']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/nanjing-yhtq/61791476.html?s=01&t=0
# getTag()获得的ip: {'http': '95.156.247.254:53281', 'https': '95.156.247.254:53281'}
# getTag()中tag_list: ['3-4年经验', '大专', '招5人', '07-14发布', '股票期权', '五险一金', '员工旅游', '交通补贴', '餐饮补贴', '通讯补贴', '绩效奖金', '年终奖金', '定期体检', '专业培训']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/wuhan-hsq/103092588.html?s=01&t=0
# getTag()获得的ip: {'http': '177.86.203.11:53281', 'https': '177.86.203.11:53281'}
# getTag()中tag_list: ['3-4年经验', '本科', '招2人', '07-14发布', '做五休二', '弹性工作', '带薪年假', '五险一金', '专业培训', '节日福利', '绩效奖金', '通讯补贴', '交通补贴', '餐饮补贴']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/shanghai-ptq/102454749.html?s=01&t=0
# getTag()获得的ip: {'http': '202.74.242.213:53281', 'https': '202.74.242.213:53281'}
# getTag()中tag_list: ['3-4年经验', '大专', '招1人', '07-14发布', '五险一金', '餐饮补贴', '定期体检', '交通补贴', '通讯补贴', '年终奖金', '绩效奖金', '员工旅游']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/hefei-gxq/102962159.html?s=01&t=0
# getTag()获得的ip: {'http': '49.236.220.6:8080', 'https': '49.236.220.6:8080'}
# getTag()中tag_list: ['3-4年经验', '本科', '招1人', '07-14发布', '五险一金', '交通补贴', '餐饮补贴', '弹性工作', '年终奖金']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/shanghai-xhq/70518516.html?s=01&t=0
# getTag()获得的ip: {'http': '95.105.115.88:8080', 'https': '95.105.115.88:8080'}
# getTag()中tag_list: ['3-4年经验', '本科', '招若干人', '07-14发布', '五险一金', '补充医疗保险', '弹性工作', '定期体检']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/wuhan-wcq/104512871.html?s=01&t=0
# getTag()获得的ip: {'http': '81.211.23.6:3128', 'https': '81.211.23.6:3128'}
# getTag()当前处理链接: https://jobs.51job.com/wuhan/98157540.html?s=01&t=0
# getTag()获得的ip: {'http': '103.21.163.74:53281', 'https': '103.21.163.74:53281'}
# getTag()当前处理链接: https://jobs.51job.com/guangzhou-pyq/103561045.html?s=01&t=0
# getTag()获得的ip: {'http': '42.115.96.17:53281', 'https': '42.115.96.17:53281'}
# getTag()当前处理链接: https://jobs.51job.com/kunshan/104242248.html?s=01&t=0
# getTag()获得的ip: {'http': '192.244.104.104:3129', 'https': '192.244.104.104:3129'}
# getTag()中tag_list: ['3-4年经验', '大专', '招3人', '07-14发布', '五险一金', '绩效奖金', '年终奖金', '弹性工作']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/shenzhen-nsq/98640418.html?s=01&t=0
# getTag()获得的ip: {'http': '62.176.18.197:44331', 'https': '62.176.18.197:44331'}
# getTag()中tag_list: ['5-7年经验', '本科', '招1人', '07-14发布', '五险一金', '交通补贴', '年底双薪', '年终奖金', '带薪年假', '节日福利', '生日福利', '员工旅游', '通讯补贴', '定期体检']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/xiamen/103321603.html?s=01&t=0
# getTag()获得的ip: {'http': '89.36.206.65:8080', 'https': '89.36.206.65:8080'}
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /xiamen/103321603.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# ----------------------
# getTag()中tag_list: ['1年经验', '本科', '招2人', '07-14发布', '五险一金', '节日福利', '餐饮补贴', '交通补贴', '弹性工作', '绩效奖金', '年终奖金']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/foshan-sdq/103314270.html?s=01&t=0
# getTag()获得的ip: {'http': '95.78.161.114:8080', 'https': '95.78.161.114:8080'}
# getTag()中tag_list: ['无工作经验', '招1人', '07-14发布', '每天7.5小时', '顺德社保', '国内外旅游', '年度调薪', '内部晋升制度', '商学院培训', '90后团队', '10分钟CBD']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/overseas/102123960.html?s=01&t=0
# getTag()获得的ip: {'http': '94.41.119.37:8080', 'https': '94.41.119.37:8080'}
# getTag()当前处理链接: https://jobs.51job.com/xian-lhq/98477387.html?s=01&t=0
# getTag()获得的ip: {'http': '41.78.216.82:53281', 'https': '41.78.216.82:53281'}
# getTag()当前处理链接: https://jobs.51job.com/foshan/104512062.html?s=01&t=0
# getTag()获得的ip: {'http': '190.121.231.243:53281', 'https': '190.121.231.243:53281'}
# getTag()中tag_list: ['无工作经验', '招1人', '07-14发布', '五险一金', '年终奖金', '专业培训', '餐饮补贴', '定期体检', '包住', '节日福利', '加班补贴']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/beijing-hdq/104512186.html?s=01&t=0
# getTag()获得的ip: {'http': '191.252.92.198:8080', 'https': '191.252.92.198:8080'}
# getTag()中tag_list: ['3-4年经验', '本科', '招1人', '07-14发布', '五险一金', '专业培训', '定期体检', '弹性工作', '年终奖金', '餐饮补贴']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/shijiazhuang/101545939.html?s=01&t=0
# getTag()获得的ip: {'http': '78.153.152.162:8080', 'https': '78.153.152.162:8080'}
# getTag()中tag_list: ['无工作经验', '高中', '招3人', '07-14发布', '五险一金', '补充医疗保险', '补充公积金', '年终奖金', '绩效奖金', '全勤奖', '带薪年假', '定期体检']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/hangzhou/90903625.html?s=01&t=0
# getTag()获得的ip: {'http': '150.129.52.75:6666', 'https': '150.129.52.75:6666'}
# getTag()中tag_list: ['2年经验', '大专', '招3人', '07-14发布', '五险一金', '股票期权', '员工旅游', '专业培训', '节日福利']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/changsha-txq/99593709.html?s=01&t=0
# getTag()获得的ip: {'http': '191.7.211.74:53281', 'https': '191.7.211.74:53281'}
# getTag()中tag_list: ['3-4年经验', '本科', '招1人', '07-14发布', '包住宿', '带薪年假', '五险一金', '餐饮补贴', '节日福利', '全勤奖', '专业培训', '加班补贴']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/shanghai/51530702.html?s=01&t=0
# getTag()获得的ip: {'http': '79.143.120.182:41258', 'https': '79.143.120.182:41258'}
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /shanghai/51530702.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/guangzhou/104509592.html?s=01&t=0
# getTag()获得的ip: {'http': '45.64.179.187:8080', 'https': '45.64.179.187:8080'}
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /guangzhou/104509592.html?s=01&t=0 (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fb32c607eb8>, 'Connection to 45.64.179.187 timed out. (connect timeout=5)'))
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/shenzhen-nsq/104412480.html?s=01&t=0
# getTag()获得的ip: {'http': '14.192.144.101:8080', 'https': '14.192.144.101:8080'}
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /shenzhen-nsq/104412480.html?s=01&t=0 (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fb32c60e208>, 'Connection to 14.192.144.101 timed out. (connect timeout=5)'))
# ----------------------
# getTag()中tag_list: ['3-4年经验', '本科', '招20人', '07-14发布', '做五休二', '周末双休', '带薪年假', '五险一金', '节日福利']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/shanghai-pdxq/104000963.html?s=01&t=0
# getTag()获得的ip: {'http': '191.5.187.224:53281', 'https': '191.5.187.224:53281'}
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /shanghai-pdxq/104000963.html?s=01&t=0 (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fb32c8d5b38>, 'Connection to 191.5.187.224 timed out. (connect timeout=5)'))
# ----------------------
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /shanghai-pdxq/104000963.html?s=01&t=0 (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fb32c292cf8>, 'Connection to 185.74.37.96 timed out. (connect timeout=5)'))
# ----------------------
# getTag()中tag_list: ['3-4年经验', '本科', '招1人', '07-14发布', '五险一金', '交通补贴', '餐饮补贴', '周末双休', '节日福利']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/guangzhou-byq/103972417.html?s=01&t=0
# getTag()获得的ip: {'http': '43.239.221.96:2018', 'https': '43.239.221.96:2018'}
# getTag()中tag_list: ['5-7年经验', '大专', '招1人', '07-14发布', '绩效奖金', '节日福利', '专业培训', '五险一金', '餐饮补贴']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/shijiazhuang/104152551.html?s=01&t=0
# getTag()获得的ip: {'http': '180.94.86.34:8080', 'https': '180.94.86.34:8080'}
# getTag()当前处理链接: https://jobs.51job.com/shenzhen-nsq/104511166.html?s=01&t=0
# getTag()获得的ip: {'http': '182.160.114.50:53281', 'https': '182.160.114.50:53281'}
# getTag()中tag_list: ['无工作经验', '本科', '招若干人', '07-14发布', '五险一金', '员工旅游', '通讯补贴', '专业培训', '绩效奖金', '年终奖金', '股票期权', '定期体检']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/shenzhen-nsq/104509392.html?s=01&t=0
# getTag()获得的ip: {'http': '186.208.112.202:8080', 'https': '186.208.112.202:8080'}
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /shenzhen-nsq/104509392.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# ----------------------
# getTag()中tag_list: ['无工作经验', '大专', '招2人', '07-14发布', '五险一金', '餐补补贴', '住房补贴', '专业培训', '绩效奖金', '年底双薪', '弹性工作', '员工旅游', '定期体检', '下午茶']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/shenzhen-lhq/84289946.html?s=01&t=0
# getTag()获得的ip: {'http': '108.187.45.85:41258', 'https': '108.187.45.85:41258'}
# getTag()中tag_list: ['3-4年经验', '招5人', '07-14发布', '绩效奖金', '五险', '员工旅游', '人性化管理']
# ----------------------
# tag标签组装完成！

# %%
num = 1
for i in jobObjectList:
    print(num)
    print(i.tag_href)
    print(i.job)
    print(i.company)
    print(i.address)
    print(i.salary)
    print(i.tag)
    num += 1
# Out:
# 1
# https://jobs.51job.com/suzhou-xcq/86078730.html?s=01&t=0
# Java开发工程师
# 苏州白金汉爵大酒店有限公司
# 苏州-相城区
# 0.8-1.6万/月
# ['无工作经验', '本科', '招3人', '07-14发布', '餐饮补贴']
# 2
# https://jobs.51job.com/jiaxing/98179674.html?s=01&t=0
# Java（资深）开发工程师
# 铠嘉电脑配件有限公司
# 嘉兴
# 0.5-1万/月
# ['无工作经验', '招2人', '07-14发布', '五险一金', '年终奖金', '绩效奖金', '专业培训']
# 3
# https://jobs.51job.com/shenzhen-nsq/98131903.html?s=01&t=0
# 高级JAVA工程师
# 深圳爱影科技有限公司
# 深圳-南山区
# 1-1.5万/月
# ['3-4年经验', '本科', '招1人', '07-14发布', '五险一金', '弹性工作', '绩效奖金', '年终奖金', '股票期权']
# 4
# https://jobs.51job.com/beijing-cyq/103551202.html?s=01&t=0
# Java开发工程师
# 北京悦畅科技有限公司
# 北京-朝阳区
# 1.5-2万/月
# ['无工作经验', '招2人', '07-14发布', '做五休二', '周末双休', '带薪年假', '绩效奖金', '专业培训', '五险一金', '节日福利']
# 5
# https://jobs.51job.com/beijing-ftq/104516354.html?s=01&t=0
# Java开发工程师
# 北京信成未来科技有限公司
# 北京-丰台区
# 6-8千/月
# ['无工作经验', '本科', '招若干人', '07-14发布', '五险一金', '餐饮补贴', '绩效奖金', '股票期权', '弹性工作']
# 6
# https://jobs.51job.com/xian-wyq/101639933.html?s=01&t=0
# 初级Java开发工程师+奖金绩效
# 西安大来电子科技有限公司
# 西安-未央区
# 3-5千/月
# ['无工作经验', '大专', '招5人', '07-14发布']
# 7
# https://jobs.51job.com/hangzhou-bjq/103813872.html?s=01&t=0
# Java转C语言开发（须懂日语）
# 咏创（杭州）科技有限公司
# 杭州-滨江区
# 3-8千/月
# ['无工作经验', '大专', '招5人', '07-14发布']
# 8
# https://jobs.51job.com/suzhou-gxq/104517663.html?s=01&t=0
# Java高级开发工程师
# 苏州诺赛网络科技有限公司
# 苏州-高新区
# 1-1.6万/月
# ['3-4年经验', '大专', '招1人', '07-14发布', '周末双休', '带薪年假', '绩效奖金', '专业培训']
# 9
# https://jobs.51job.com/chengdu-jjq/104517765.html?s=01&t=0
# Java开发工程师
# 成都鸿智金融科技有限公司
# 成都-锦江区
# 0.6-1.2万/月
# ['3-4年经验', '大专', '招1人', '07-14发布', '通讯补贴', '弹性工作', '绩效奖金', '年终奖金', '餐饮补贴', '专业培训', '员工旅游', '五险一金']
# 10
# https://jobs.51job.com/jinan-gxq/104372013.html?s=01&t=0
# Java开发经理
# 济南卡巢网络科技有限公司
# 济南-高新区
# 1-1.5万/月
# ['5-7年经验', '本科', '招1人', '07-14发布', '五险一金', '年终奖金', '股票期权', '弹性工作']
# 11
# https://jobs.51job.com/hangzhou-jgq/104514927.html?s=01&t=0
# Java开发工程师
# 杭州奕安济世生物药业有限公司
# 杭州-江干区
# 1-1.5万/月
# ['3-4年经验', '招2人', '07-14发布', '五险一金', '弹性工作', '免费班车', '绩效奖金', '年终奖金', '专业培训', '团建活动', '节日福利', '做五休二', '带薪年假']
# 12
# https://jobs.51job.com/nanjing-jyq/104514799.html?s=01&t=0
# Java开发经理
# 江苏微图信息科技有限公司
# 南京-建邺区
# 15-20万/年
# ['5-7年经验', '本科', '招若干人', '07-14发布', '五险一金', '补充医疗保险', '免费班车', '员工旅游', '专业培训', '定期体检', '交通补贴']
# 13
# https://jobs.51job.com/wuhan-wcq/104512683.html?s=01&t=0
# 急聘4K双休+java开发助理
# 湖北众康空间体育产业孵化器有限公司
# 武汉-武昌区
# 4-6千/月
# ['无工作经验', '大专', '招4人', '07-14发布']
# 14
# https://jobs.51job.com/wuhan/104516824.html?s=01&t=0
# Java高级开发工程师
# 上海诺姆四达投资集团有限公司无锡...
# 武汉
# 1-2万/月
# ['5-7年经验', '本科', '招2人', '07-14发布', '五险一金', '餐饮补贴', '通讯补贴', '专业培训', '绩效奖金', '年终奖金']
# 15
# https://jobs.51job.com/shanghai-pdxq/64520273.html?s=01&t=0
# Java软件工程师（上海）（金融业）
# 上海佳克计算机软件股份有限公司
# 上海-浦东新区
# 0.8-1.2万/月
# ['2年经验', '本科', '招2人', '07-14发布']
# 16
# https://jobs.51job.com/zhengzhou/95480056.html?s=01&t=0
# Java开发工程师
# 河南信安通信技术股份有限公司
# 郑州
# 4-6千/月
# ['2年经验', '本科', '招1人', '07-14发布', '五险一金', '员工旅游', '交通补贴', '餐饮补贴', '通讯补贴', '绩效奖金', '年终奖金', '定期体检']
# 17
# https://jobs.51job.com/beijing/71900339.html?s=01&t=0
# JAVA软件工程师（急招）
# 北京创思恒通科技有限公司
# 北京
# 0.6-1.5万/月
# ['1年经验', '本科', '招4人', '07-14发布', '五险一金', '餐饮补贴', '专业培训', '绩效奖金', '年终奖金', '半年加薪']
# 18
# https://jobs.51job.com/guangzhou/102189827.html?s=01&t=0
# java工程师（互联网政务）
# 广州华资软件技术有限公司
# 广州
# 0.8-1.5万/月
# ['1年经验', '招5人', '07-14发布', '五险一金', '补充医疗保险', '员工旅游', '年终奖金', '绩效奖金', '专业培训', '定期体检', '节日礼金', '14薪+']
# 19
# https://jobs.51job.com/tianjin-hxq/104516179.html?s=01&t=0
# Java高级开发工程师
# 嘀嘀智慧城市运营管理（天津）有限...
# 天津-河西区
# 1-1.5万/月
# ['3-4年经验', '本科', '招2人', '07-14发布', '五险一金', '交通补贴', '年终奖金']
# 20
# https://jobs.51job.com/shanghai-pdxq/104101732.html?s=01&t=0
# Java开发工程师（3年以上经验）
# 上海金指软件技术有限公司
# 上海-浦东新区
# 1.2-1.8万/月
# ['3-4年经验', '本科', '招10人', '07-14发布', '五险一金', '餐饮补贴', '交通补贴', '员工旅游', '免费班车', '专业培训', '通讯补贴', '定期体检', '年终奖金', '绩效奖金']
# 21
# https://jobs.51job.com/qingdao/104515912.html?s=01&t=0
# Java工程师实训生
# 青岛迈科思软件有限责任公司
# 异地招聘
# 3-4.5千/月
# ['无工作经验', '大专', '招5人', '07-14发布', '带薪年假', '五险一金', '专业培训', '通讯补贴', '餐饮补贴', '全勤奖', '绩效奖金']
# 22
# https://jobs.51job.com/zhengzhou-gxq/104514775.html?s=01&t=0
# Java高级开发工程师
# 河南省中教网盟科技有限公司
# 郑州-高新区
# 0.8-1万/月
# ['5-7年经验', '大专', '招2人', '07-14发布', '带薪年假', '五险一金', '全勤奖', '节日福利', '餐饮补贴', '住房补贴', '员工旅游', '每年多次调薪']
# 23
# https://jobs.51job.com/nanjing-yhtq/61791476.html?s=01&t=0
# 高级JAVA软件工程师
# 上海艺赛旗软件股份有限公司
# 南京-雨花台区
# 1-1.5万/月
# ['3-4年经验', '大专', '招5人', '07-14发布', '股票期权', '五险一金', '员工旅游', '交通补贴', '餐饮补贴', '通讯补贴', '绩效奖金', '年终奖金', '定期体检', '专业培训']
# 24
# https://jobs.51job.com/wuhan-hsq/103092588.html?s=01&t=0
# Java高级培训师/讲师
# 武汉尚云客网络技术有限公司
# 武汉-洪山区
# 1.2-1.6万/月
# ['3-4年经验', '本科', '招2人', '07-14发布', '做五休二', '弹性工作', '带薪年假', '五险一金', '专业培训', '节日福利', '绩效奖金', '通讯补贴', '交通补贴', '餐饮补贴']
# 25
# https://jobs.51job.com/shanghai-ptq/102454749.html?s=01&t=0
# Java中级开发工程师
# 易批生鲜信息发展股份有限公司
# 上海-普陀区
# 1.5-2万/月
# ['3-4年经验', '大专', '招1人', '07-14发布', '五险一金', '餐饮补贴', '定期体检', '交通补贴', '通讯补贴', '年终奖金', '绩效奖金', '员工旅游']
# 26
# https://jobs.51job.com/hefei-gxq/102962159.html?s=01&t=0
# Java开发工程师(合肥）
# 浙江网新恒天软件有限公司
# 合肥-高新区
# 0.7-1.4万/月
# ['3-4年经验', '本科', '招1人', '07-14发布', '五险一金', '交通补贴', '餐饮补贴', '弹性工作', '年终奖金']
# 27
# https://jobs.51job.com/shanghai-xhq/70518516.html?s=01&t=0
# Java后台开发工程师
# 上海轻轻信息科技有限公司
# 上海-徐汇区
# 1.5-2.5万/月
# ['3-4年经验', '本科', '招若干人', '07-14发布', '五险一金', '补充医疗保险', '弹性工作', '定期体检']
# 28
# https://jobs.51job.com/wuhan-wcq/104512871.html?s=01&t=0
# Java软件开发实习生+五险一金
# 湖北国兴宏图体育场馆规划设计有限...
# 武汉-武昌区
# 4-6千/月
# ['无工作经验', '大专', '招5人', '07-14发布']
# 29
# https://jobs.51job.com/wuhan/98157540.html?s=01&t=0
# Java高级工程师
# 环球名车汽车服务湖北股份有限公司
# 武汉
# 8-9千/月
# ['无工作经验', '本科', '招3人', '07-14发布']
# 30
# https://jobs.51job.com/guangzhou-pyq/103561045.html?s=01&t=0
# Java高级开发工程师（智能机器人方向）
# 广州步云信息科技有限公司
# 广州-番禺区
# 1-1.5万/月
# ['无工作经验', '招5人', '07-14发布']
# 31
# https://jobs.51job.com/kunshan/104242248.html?s=01&t=0
# java后端高级开发工程师
# 途鸟科技（上海）有限公司
# 异地招聘
# 1.5-2万/月
# ['3-4年经验', '大专', '招3人', '07-14发布', '五险一金', '绩效奖金', '年终奖金', '弹性工作']
# 32
# https://jobs.51job.com/shenzhen-nsq/98640418.html?s=01&t=0
# Java架构师（互联网电商方向）
# 深圳市远行科技股份有限公司
# 深圳-南山区
# 1.5-2.5万/月
# ['5-7年经验', '本科', '招1人', '07-14发布', '五险一金', '交通补贴', '年底双薪', '年终奖金', '带薪年假', '节日福利', '生日福利', '员工旅游', '通讯补贴', '定期体检']
# 33
# https://jobs.51job.com/xiamen/103321603.html?s=01&t=0
# Java开发工程师
# 易招标-互联网招投标的领导者
# 厦门
# 6-8千/月
# ['1年经验', '本科', '招2人', '07-14发布', '五险一金', '节日福利', '餐饮补贴', '交通补贴', '弹性工作', '绩效奖金', '年终奖金']
# 34
# https://jobs.51job.com/foshan-sdq/103314270.html?s=01&t=0
# Java开发工程师
# 广东用心网络科技有限公司
# 异地招聘
# 7.5-10.5万/年
# ['无工作经验', '招1人', '07-14发布', '每天7.5小时', '顺德社保', '国内外旅游', '年度调薪', '内部晋升制度', '商学院培训', '90后团队', '10分钟CBD']
# 35
# https://jobs.51job.com/overseas/102123960.html?s=01&t=0
# 急聘java开发工程师（赴日）
# 大连鸿进科技有限公司
# 异地招聘
# 2-2.5万/月
# ['无工作经验', '招若干人', '07-14发布']
# 36
# https://jobs.51job.com/xian-lhq/98477387.html?s=01&t=0
# Java开发经理
# 西安市城市规划信息中心
# 西安-莲湖区
# 5-7千/月
# ['3-4年经验', '本科', '招若干人', '07-14发布']
# 37
# https://jobs.51job.com/foshan/104512062.html?s=01&t=0
# 后端开发工程师（JAVA)
# 美的集团中央空调事业部
# 佛山
# 1-2万/月
# ['无工作经验', '招1人', '07-14发布', '五险一金', '年终奖金', '专业培训', '餐饮补贴', '定期体检', '包住', '节日福利', '加班补贴']
# 38
# https://jobs.51job.com/beijing-hdq/104512186.html?s=01&t=0
# 资深JAVA开发工程师
# 易点租
# 北京-海淀区
# 2.5-4万/月
# ['3-4年经验', '本科', '招1人', '07-14发布', '五险一金', '专业培训', '定期体检', '弹性工作', '年终奖金', '餐饮补贴']
# 39
# https://jobs.51job.com/shijiazhuang/101545939.html?s=01&t=0
# 年底双薪+Java开发
# 石家庄明妄信息技术有限公司
# 石家庄
# 3-4.5千/月
# ['无工作经验', '高中', '招3人', '07-14发布', '五险一金', '补充医疗保险', '补充公积金', '年终奖金', '绩效奖金', '全勤奖', '带薪年假', '定期体检']
# 40
# https://jobs.51job.com/hangzhou/90903625.html?s=01&t=0
# JAVA工程师
# 杭州云韦科技有限公司
# 杭州
# 1-1.5万/月
# ['2年经验', '大专', '招3人', '07-14发布', '五险一金', '股票期权', '员工旅游', '专业培训', '节日福利']
# 41
# https://jobs.51job.com/changsha-txq/99593709.html?s=01&t=0
# Java开发工程师
# 湖南微阵信息技术有限公司
# 长沙-天心区
# 0.8-1.2万/月
# ['3-4年经验', '本科', '招1人', '07-14发布', '包住宿', '带薪年假', '五险一金', '餐饮补贴', '节日福利', '全勤奖', '专业培训', '加班补贴']
# 42
# https://jobs.51job.com/shanghai/51530702.html?s=01&t=0
# java开发工程师
# 上海福乐信息技术有限公司
# 上海
# 0.8-1万/月
# ['3-4年经验', '大专', '招2人', '07-14发布']
# 43
# https://jobs.51job.com/guangzhou/104509592.html?s=01&t=0
# java微信工程师
# 广州信畅信息技术有限公司
# 广州
# 0.8-1.5万/月
# ['无工作经验', '招2人', '07-14发布']
# 44
# https://jobs.51job.com/shenzhen-nsq/104412480.html?s=01&t=0
# Java中高级开发工程师
# 深圳四方精创资讯股份有限公司
# 深圳-南山区
# 2-3万/月
# ['3-4年经验', '本科', '招20人', '07-14发布', '做五休二', '周末双休', '带薪年假', '五险一金', '节日福利']
# 45
# https://jobs.51job.com/shanghai-pdxq/104000963.html?s=01&t=0
# 高级java开发工程师
# 上海雪山金融信息服务有限公司
# 上海-浦东新区
# 1.5-2万/月
# ['3-4年经验', '本科', '招1人', '07-14发布', '五险一金', '交通补贴', '餐饮补贴', '周末双休', '节日福利']
# 46
# https://jobs.51job.com/guangzhou-byq/103972417.html?s=01&t=0
# Java高级开发工程师
# 广东阿康药店连锁有限公司
# 广州-白云区
# 1-2万/月
# ['5-7年经验', '大专', '招1人', '07-14发布', '绩效奖金', '节日福利', '专业培训', '五险一金', '餐饮补贴']
# 47
# https://jobs.51job.com/shijiazhuang/104152551.html?s=01&t=0
# Java开发工程师
# 京津冀行知河北教育评估有限公司
# 石家庄
# 0.4-1万/月
# ['1年经验', '本科', '招3人', '07-14发布']
# 48
# https://jobs.51job.com/shenzhen-nsq/104511166.html?s=01&t=0
# Java架构师
# 海能达通信股份有限公司
# 深圳-南山区
# 1.5-3万/月
# ['无工作经验', '本科', '招若干人', '07-14发布', '五险一金', '员工旅游', '通讯补贴', '专业培训', '绩效奖金', '年终奖金', '股票期权', '定期体检']
# 49
# https://jobs.51job.com/shenzhen-nsq/104509392.html?s=01&t=0
# (急聘) java开发工程师
# 深圳讯腾软件技术有限公司
# 深圳-南山区
# 4.5-6千/月
# ['无工作经验', '大专', '招2人', '07-14发布', '五险一金', '餐补补贴', '住房补贴', '专业培训', '绩效奖金', '年底双薪', '弹性工作', '员工旅游', '定期体检', '下午茶']
# 50
# https://jobs.51job.com/shenzhen-lhq/84289946.html?s=01&t=0
# Java开发工程师/爬虫/采集
# 深圳市博览天下票务服务有限公司
# 深圳-罗湖区
# 0.8-1.5万/月
# ['3-4年经验', '招5人', '07-14发布', '绩效奖金', '五险', '员工旅游', '人性化管理']
