# %%
import requests
from bs4 import BeautifulSoup
import queue
import threading
import re
import csv
import functools
import os
from time import time

# %%
class jobObject:
    'job描述对象'
    __slots__ = ('tag_href', 'job', 'company', 'address', 'salary', 'tag')

# %%
def ipToQueue():
    q = queue.Queue()
    url = 'https://free-proxy-list.net/'
    r = requests.get(url)
    html = r.text
    soup = BeautifulSoup(html, features='html5lib')
    div_tag = soup.find('div', 'table-responsive')
    tbody_list = div_tag.tbody.contents
    result = ''
    for tr in tbody_list:
        ip = tr.next_element.string
        port = tr.next_element.next_sibling.string
        result = ip + ':' + port
        q.put(result)

    return q

# %%
# q = ipToQueue()
# print(q.qsize())

# while q.qsize()!=0:
#     print(q.get())

# %%
def getIPool(ip_queue):
    proxies = queue.Queue()

    flag = True
    while flag:
        ip = ip_queue.get()
        proxy = {'http': ip, 'https': ip}
        proxies.put(proxy)
        if ip_queue.qsize()==0:
            flag = False

    return proxies

# %%
def getCleanProxies(proxies, **thread_num):
    #     url = 'http://www.baidu.com'
    url = 'https://jobs.51job.com/'

    # 有效的ip队列
    ok_proxies = queue.Queue()

    def check_proxy(thread_proxies):

        thread_proxies_size = thread_proxies.qsize()

        for i in range(thread_proxies_size):
            thread_proxies_size = thread_proxies.qsize()
            print('%s : 当前剩余处理的ip: %d' % (threading.current_thread().name, thread_proxies_size))

            # 如果当前ip为0退出当前线程
            if (thread_proxies_size == 0):
                break

            proxy = thread_proxies.get()
            try:
                r = requests.get(url, proxies=proxy, timeout=5)
                print(threading.current_thread().name + ' is processing')
                print('r.status_code:', r.status_code)
                if (r.status_code != 200):
                    print('remove proxy:', proxy)
                else:
                    ok_proxies.put(proxy)

                print('-------------------------------------')

            except requests.Timeout as e:
                print(threading.current_thread().name + ' is processing')
                print(e)
                print('remove proxy:', proxy)
                print('-------------------------------------')
            except requests.ConnectionError as e:
                print(threading.current_thread().name + ' is processing')
                print(e)
                print('remove proxy:', proxy)
                print('-------------------------------------')
            except requests.InvalidHeader as e:
                print(threading.current_thread().name + ' is processing')
                print(e)
                print('remove proxy:', proxy)
                print('-------------------------------------')


    threads = []

    for i in range(thread_num.get('thread_num')):
        thread = threading.Thread(target=check_proxy, args=(proxies,))
        threads.append(thread)

    print('线程开始：')
    for thread in threads:
        print(thread.name + '开始运行')
        thread.start()

    # 每次在剩余处理ip为0之后，程序就会停住不动
    # 当当前线程检测到剩余ip为0后，调用join()方法
    print('线程开始停止运行：')
    for thread in threads:
        thread.join()
        print(thread.name + '已停止')

    return ok_proxies

# %%
def get_jobObjectList(url, proxies):
    flag = True
    proxy = proxies.get()
    # TODO 查看信息
    print('get_jobObjectList()当前处理链接:', url)
    while flag:
        try:
            r = requests.get(url, proxies=proxy, timeout=5)
            # 报了异常的话捕捉了之后
            # 获得新的proxy之后就直接开始下次循环
        except requests.exceptions.Timeout as e:
            print(e)
            proxy = proxies.get()
            print('尝试新的proxy')
            #print('----------------------')
            continue
        except requests.exceptions.ProxyError as e:
            print(e)
            proxy = proxies.get()
            print('尝试新的proxy')
            #print('----------------------')
            continue
        except requests.exceptions.ConnectionError as e:
            print(e)
            proxy = proxies.get()
            print('尝试新的proxy')
            #print('----------------------')
            continue
        
        # 不报异常就取消循环
        flag = False

    
    
    r.encoding = 'gbk'
    html = r.text
    soup = BeautifulSoup(html, features='html5lib')
    # 找到了工作列表的开头
    title = soup.find('div', 'el title')
    # 找到每一个工作列，它们分别是一个div class='el'
    job_info_list = title.find_next_siblings('div', 'el')

    # 存放当前页jobObject对象到jobObjectList中
    jobObjectList = []
    for tag in job_info_list:
        object = jobObject()
        object.tag_href = tag.find('a').attrs['href']
        object.job = tag.find('a').attrs['title']

        infos = tag.find_all(class_=re.compile('t[2-4]'))
        object.company = infos[0].string
        object.address = infos[1].string
        object.salary = infos[2].string
        jobObjectList.append(object)
    
    print('get_jobObjectList处理完成!')

    return jobObjectList

# %%
def getTag(url, proxies):
    tag_url = url
    proxy = proxies.get()

    # 存储标签的List
    tag_list = []
    flag = True

    # TODO 查看信息
    print('getTag()当前处理链接:', tag_url)
    print('getTag()获得的ip:', proxy)
    while flag:
        #     headers = {'user-agent','Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/66.0.3359.181 Chrome/66.0.3359.181 Safari/537.36'}
        try:
            r_tag = requests.get(tag_url, timeout=5, proxies=proxy)

        # 报了异常的话捕捉了之后
        # 获得新的proxy之后就直接开始下次循环
        except requests.exceptions.Timeout as e:
            print(e)
            proxy = proxies.get()
            print('尝试新的proxy')
            #print('----------------------')
            continue
        except requests.exceptions.ProxyError as e:
            print(e)
            proxy = proxies.get()
            print('尝试新的proxy')
            #print('----------------------')
            continue
        except requests.exceptions.ConnectionError as e:
            print(e)
            proxy = proxies.get()
            print('尝试新的proxy')
            #print('----------------------')
            continue
        # 不报异常就取消循环
        flag = False

    r_tag.encoding = 'gbk'
    tag_html = r_tag.text
    tag_soup = BeautifulSoup(tag_html, features='html5lib')

    # 找到详情页第一行标签
    tag_1 = tag_soup.find_all('span', 'sp4')
    for i in tag_1:
        tag_list.append(i.contents[1])

    # 找到详情页第二行标签
    tag_2 = tag_soup.find('p', 't2')

    # 有些详情页没有第二行标签
    if tag_2 is None:
        print('getTag()中tag_list:', tag_list)
        print('----------------------')
        return tag_list

    ll = []
    for i in tag_2.strings:
        ll.append(i)

    # 清除ll中的空值
    def not_empty(s):
        return s and s.strip()

    for i in filter(not_empty, ll):
        tag_list.append(i)

    print('getTag()中tag_list:', tag_list)
    print('----------------------')

    return tag_list

# %%
def pack_tag(jobObjectList, proxies, **thread_num):
    jobObject_queue = queue.Queue()
    
    for jobObject in jobObjectList:
        jobObject_queue.put(jobObject)
    
    def pack_object(jobObject_queue):
        flag = True
        while flag:
            jobObject = jobObject_queue.get()
            jobObject.tag = getTag(jobObject.tag_href, proxies)
            if jobObject_queue.qsize() == 0:
                flag = False
            
    
    threads = []
    
#     print('thread_num.get(\'thread_num\'): ', thread_num.get('thread_num'))
    
    for i in range(thread_num.get('thread_num')):
        thread = threading.Thread(target=pack_object, args=(jobObject_queue,))
        threads.append(thread)
    
    for thread in threads:
        thread.start()
        
        
    for thread in threads:
        thread.join()
        print('%s 已停止' % thread.name)
    

    print('tag组装完成!')

# %%
def save_to_csv(jobObjectList):
    headers = ['职位', '公司', '地址', '薪酬', '标签']
    datas = []

    for jobObject in jobObjectList:
        data = {headers[0]: jobObject.job,
                headers[1]: jobObject.company,
                headers[2]: jobObject.address,
                headers[3]: jobObject.salary,
                headers[4]: jobObject.tag}
        datas.append(data)
        
    if os.path.isfile('51job.csv'):
        with open('51job.csv', 'a', newline='') as f:
            writer = csv.DictWriter(f, headers)
            for row in datas:
                writer.writerow(row)
    else:
        with open('51job.csv', 'a', newline='') as f:
            writer = csv.DictWriter(f, headers)
            writer.writeheader()
            for row in datas:
                writer.writerow(row)

# %%
def handle_single(url, proxies):
    jobObjectList = get_jobObjectList(url, proxies)
    pack_tag(jobObjectList, proxies, thread_num=20)
    save_to_csv(jobObjectList)

# %%
# 获取proxy
# 当队列中的proxy用完了的时候在获取新的proxies
# 不是每次线程启动就获取新的proxies
# 当一个proxy不能用了才能获取新的proxy
def getProxy():
    # 多线程的话，就不保存在本地文件
            # 应该保存在各自线程的queue里面s
    ip_start = time()
            ip_queue = ipToQueue()
            proxies = getIPool(ip_queue)
            proxies = getCleanProxies(proxies, thread_num=45)
            ip_result = time() - ip_start
            print('可用的ip: ', proxies.qsize())
            print('%s清洗ip的时间: %d' % (threading.current_thread().name, ip_result))

# %%
def main():
    url_queue = queue.Queue()
    pages = 5
    thread_nums = 3
    
    for i in range(pages):
        url = 'https://search.51job.com/list/000000,000000,0000,00,9,99,Java,2,{}.html?lang=c&stype=&postchannel=0000&workyear=99&cotype=99&degreefrom=99&jobterm=99&companysize=99&providesalary=99&lonlat=0%2C0&radius=-1&ord_field=0&confirmdate=9&fromType=&dibiaoid=0&address=&line=&specialarea=00&from=&welfare='\
        .format(i+1)
        url_queue.put(url)
    
#     flag = True
#     while flag:

    def go(url_queue):
        flag = True
        while flag:
            
            
            
            url = url_queue.get()
            
            start = time()
            handle_single(url, proxies)
            result = time() - start
            print('%s完成单页的时间: %d' % (threading.current_thread().name, result))
            
            if url_queue.qsize()==0:
                flag = False
            
    
    threads = []
    
    for i in range(thread_nums):
        thread = threading.Thread(target=go, args=(url_queue,))
        threads.append(thread)
    
    start = time()
    for thread in threads:
        thread.start()
        print('主线程%s开始' % thread.name)
        
    for thread in threads:
        thread.join()
        print('主线程%s停止' % thread.name)
    
    result = time()-start
    print('爬取时间:',result)

# %%
main()
# Out:
# 主线程Thread-656开始
# 主线程Thread-657开始
# 主线程Thread-658开始
# 线程开始：
# Thread-659开始运行
# Thread-659 : 当前剩余处理的ip: 300Thread-660开始运行
#
# Thread-660 : 当前剩余处理的ip: 299线程开始：Thread-661开始运行
#
# 线程开始：
# Thread-749开始运行
#
# Thread-704开始运行
# Thread-661 : 当前剩余处理的ip: 298Thread-662开始运行
# Thread-749 : 当前剩余处理的ip: 300Thread-750开始运行
# Thread-704 : 当前剩余处理的ip: 300Thread-705开始运行
#
#
#
# Thread-705 : 当前剩余处理的ip: 299Thread-706开始运行
# Thread-750 : 当前剩余处理的ip: 299Thread-751开始运行
# Thread-662 : 当前剩余处理的ip: 297Thread-663开始运行
#
#
#
# Thread-663 : 当前剩余处理的ip: 296Thread-664开始运行
# Thread-751 : 当前剩余处理的ip: 298Thread-752开始运行
# Thread-706 : 当前剩余处理的ip: 298Thread-707开始运行
#
#
#
# Thread-707 : 当前剩余处理的ip: 297Thread-708开始运行
# Thread-752 : 当前剩余处理的ip: 297Thread-753开始运行
# Thread-664 : 当前剩余处理的ip: 295Thread-665开始运行
#
#
#
# Thread-665 : 当前剩余处理的ip: 294Thread-666开始运行
# Thread-708 : 当前剩余处理的ip: 296Thread-709开始运行
# Thread-753 : 当前剩余处理的ip: 296Thread-754开始运行
#
#
#
# Thread-709 : 当前剩余处理的ip: 295Thread-710开始运行
#
# Thread-754 : 当前剩余处理的ip: 295Thread-755开始运行
#
# Thread-666 : 当前剩余处理的ip: 293
# Thread-667开始运行
# Thread-710 : 当前剩余处理的ip: 294Thread-711开始运行
# Thread-755 : 当前剩余处理的ip: 294Thread-756开始运行
# Thread-667 : 当前剩余处理的ip: 292Thread-668开始运行
#
#
#
# Thread-668 : 当前剩余处理的ip: 291Thread-669开始运行
# Thread-756 : 当前剩余处理的ip: 293Thread-757开始运行
# Thread-711 : 当前剩余处理的ip: 293Thread-712开始运行
#
#
# Thread-712 : 当前剩余处理的ip: 293
# Thread-713开始运行
#
# Thread-757 : 当前剩余处理的ip: 292Thread-758开始运行
# Thread-669 : 当前剩余处理的ip: 290Thread-670开始运行
#
#
# Thread-713 : 当前剩余处理的ip: 291Thread-714开始运行
# Thread-670 : 当前剩余处理的ip: 289Thread-671开始运行
# Thread-758 : 当前剩余处理的ip: 291Thread-759开始运行
#
#
#
# Thread-759 : 当前剩余处理的ip: 290
# Thread-760开始运行
# Thread-671 : 当前剩余处理的ip: 288
# Thread-672开始运行
# Thread-714 : 当前剩余处理的ip: 290
# Thread-715开始运行
# Thread-760 : 当前剩余处理的ip: 289Thread-761开始运行
# Thread-715 : 当前剩余处理的ip: 289Thread-716开始运行
# Thread-672 : 当前剩余处理的ip: 287Thread-673开始运行
#
#
# Thread-671 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 400 Bad Request',)))
# remove proxy: {'http': '54.238.250.77:80', 'https': '54.238.250.77:80'}
# -------------------------------------
# Thread-671 : 当前剩余处理的ip: 286
#
# Thread-673 : 当前剩余处理的ip: 285Thread-674开始运行
#
# Thread-716 : 当前剩余处理的ip: 288Thread-717开始运行
#
# Thread-761 : 当前剩余处理的ip: 288Thread-762开始运行
#
# Thread-717 : 当前剩余处理的ip: 287Thread-718开始运行
# Thread-762 : 当前剩余处理的ip: 287Thread-763开始运行
#
# Thread-674 : 当前剩余处理的ip: 284
# Thread-675开始运行
#
# Thread-672 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 400 Bad Request',)))
# remove proxy: {'http': '13.115.179.194:80', 'https': '13.115.179.194:80'}
# -------------------------------------
# Thread-672 : 当前剩余处理的ip: 283
# Thread-763 : 当前剩余处理的ip: 286
# Thread-764开始运行
# Thread-718 : 当前剩余处理的ip: 286
# Thread-719开始运行
# Thread-716 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 400 Bad Request',)))
# remove proxy: {'http': '54.238.250.77:80', 'https': '54.238.250.77:80'}
# -------------------------------------
# Thread-716 : 当前剩余处理的ip: 285
# Thread-675 : 当前剩余处理的ip: 282Thread-676开始运行
#
# Thread-761 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 400 Bad Request',)))
# remove proxy: {'http': '54.238.250.77:80', 'https': '54.238.250.77:80'}
# -------------------------------------
# Thread-761 : 当前剩余处理的ip: 285
# Thread-762 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 400 Bad Request',)))
# remove proxy: {'http': '13.115.179.194:80', 'https': '13.115.179.194:80'}
# -------------------------------------
# Thread-762 : 当前剩余处理的ip: 284
# Thread-717 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 400 Bad Request',)))
# remove proxy: {'http': '13.115.179.194:80', 'https': '13.115.179.194:80'}
# -------------------------------------
# Thread-717 : 当前剩余处理的ip: 284
# Thread-676 : 当前剩余处理的ip: 281
# Thread-677开始运行
# Thread-719 : 当前剩余处理的ip: 283
# Thread-764 : 当前剩余处理的ip: 283
# Thread-765开始运行
# Thread-720开始运行
# Thread-765 : 当前剩余处理的ip: 282Thread-766开始运行
# Thread-720 : 当前剩余处理的ip: 282Thread-721开始运行
# Thread-677 : 当前剩余处理的ip: 280Thread-678开始运行
#
#
#
# Thread-678 : 当前剩余处理的ip: 279
# Thread-679开始运行
# Thread-721 : 当前剩余处理的ip: 281
# Thread-722开始运行
# Thread-672 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 500 Internal Server Error',)))
# remove proxy: {'http': '13.125.85.229:9000', 'https': '13.125.85.229:9000'}
# -------------------------------------
# Thread-672 : 当前剩余处理的ip: 278
# Thread-766 : 当前剩余处理的ip: 281
# Thread-767开始运行
# Thread-722 : 当前剩余处理的ip: 280Thread-723开始运行
# Thread-679 : 当前剩余处理的ip: 277Thread-680开始运行
#
#
# Thread-764 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 500 Internal Server Error',)))
# remove proxy: {'http': '13.125.85.229:9000', 'https': '13.125.85.229:9000'}
# -------------------------------------
# Thread-764 : 当前剩余处理的ip: 280
# Thread-661 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '159.89.229.66:8080', 'https': '159.89.229.66:8080'}
# -------------------------------------
# Thread-661 : 当前剩余处理的ip: 276
# Thread-660 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '66.70.190.244:8080', 'https': '66.70.190.244:8080'}
# -------------------------------------
# Thread-660 : 当前剩余处理的ip: 275
# Thread-750 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '66.70.190.244:8080', 'https': '66.70.190.244:8080'}
# -------------------------------------
# Thread-750 : 当前剩余处理的ip: 279
# Thread-751 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '159.89.229.66:8080', 'https': '159.89.229.66:8080'}
# -------------------------------------
# Thread-751 : 当前剩余处理的ip: 278
# Thread-680 : 当前剩余处理的ip: 274
# Thread-723 : 当前剩余处理的ip: 279
# Thread-724开始运行
# Thread-767 : 当前剩余处理的ip: 277
# Thread-768开始运行
# Thread-706 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '159.89.229.66:8080', 'https': '159.89.229.66:8080'}
# -------------------------------------
# Thread-706 : 当前剩余处理的ip: 278
# Thread-719 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 500 Internal Server Error',)))
# remove proxy: {'http': '13.125.85.229:9000', 'https': '13.125.85.229:9000'}
# -------------------------------------
# Thread-719 : 当前剩余处理的ip: 277
# Thread-681开始运行
# Thread-705 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '66.70.190.244:8080', 'https': '66.70.190.244:8080'}
# -------------------------------------
# Thread-705 : 当前剩余处理的ip: 276
# Thread-724 : 当前剩余处理的ip: 275
# Thread-768 : 当前剩余处理的ip: 276
# Thread-725开始运行
# Thread-769开始运行
# Thread-681 : 当前剩余处理的ip: 273
# Thread-682开始运行
# Thread-753 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '52.23.193.25:8080', 'https': '52.23.193.25:8080'}
# -------------------------------------
# Thread-753 : 当前剩余处理的ip: 275
# Thread-663 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '52.23.193.25:8080', 'https': '52.23.193.25:8080'}
# -------------------------------------
# Thread-663 : 当前剩余处理的ip: 272
# Thread-725 : 当前剩余处理的ip: 274
# Thread-726开始运行
# Thread-769 : 当前剩余处理的ip: 274
# Thread-770开始运行
# Thread-708 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '52.23.193.25:8080', 'https': '52.23.193.25:8080'}
# -------------------------------------
# Thread-708 : 当前剩余处理的ip: 273
# Thread-670 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '167.99.153.225:3128', 'https': '167.99.153.225:3128'}
# -------------------------------------
# Thread-670 : 当前剩余处理的ip: 271
# Thread-682 : 当前剩余处理的ip: 270
# Thread-683开始运行
# Thread-770 : 当前剩余处理的ip: 273
# Thread-771开始运行
# Thread-726 : 当前剩余处理的ip: 272
# Thread-727开始运行
# Thread-760 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '167.99.153.225:3128', 'https': '167.99.153.225:3128'}
# -------------------------------------
# Thread-760 : 当前剩余处理的ip: 272
# Thread-715 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '167.99.153.225:3128', 'https': '167.99.153.225:3128'}
# -------------------------------------
# Thread-715 : 当前剩余处理的ip: 271
# Thread-683 : 当前剩余处理的ip: 269Thread-684开始运行
# Thread-727 : 当前剩余处理的ip: 270Thread-728开始运行
# Thread-771 : 当前剩余处理的ip: 271Thread-772开始运行
#
#
#
# Thread-772 : 当前剩余处理的ip: 270
# Thread-728 : 当前剩余处理的ip: 269
# Thread-729开始运行
# Thread-773开始运行
# Thread-684 : 当前剩余处理的ip: 268
# Thread-685开始运行
# Thread-729 : 当前剩余处理的ip: 268Thread-730开始运行
# Thread-773 : 当前剩余处理的ip: 269Thread-774开始运行
#
#
# Thread-774 : 当前剩余处理的ip: 268Thread-775开始运行
# Thread-730 : 当前剩余处理的ip: 267Thread-731开始运行
#
#
# Thread-685 : 当前剩余处理的ip: 267
# Thread-686开始运行
# Thread-731 : 当前剩余处理的ip: 266Thread-732开始运行
# Thread-775 : 当前剩余处理的ip: 267Thread-776开始运行
#
#
# Thread-776 : 当前剩余处理的ip: 266Thread-777开始运行
# Thread-732 : 当前剩余处理的ip: 265Thread-733开始运行
#
# Thread-686 : 当前剩余处理的ip: 266Thread-687开始运行
#
#
# Thread-733 : 当前剩余处理的ip: 264Thread-734开始运行
# Thread-687 : 当前剩余处理的ip: 265Thread-688开始运行
# Thread-777 : 当前剩余处理的ip: 265Thread-778开始运行
# Thread-675 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 500 Internal Server Error',)))
# remove proxy: {'http': '52.23.176.214:80', 'https': '52.23.176.214:80'}
# -------------------------------------
# Thread-675 : 当前剩余处理的ip: 265
#
#
#
# Thread-778 : 当前剩余处理的ip: 264Thread-779开始运行
# Thread-688 : 当前剩余处理的ip: 263Thread-689开始运行
# Thread-668 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 503 Service Temporarily Unavailable',)))
# remove proxy: {'http': '213.136.89.121:80', 'https': '213.136.89.121:80'}
# -------------------------------------
# Thread-668 : 当前剩余处理的ip: 263
# Thread-734 : 当前剩余处理的ip: 263Thread-735开始运行
#
#
#
# Thread-735 : 当前剩余处理的ip: 262Thread-736开始运行
#
# Thread-689 : 当前剩余处理的ip: 261Thread-690开始运行
#
# Thread-678 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '159.65.45.64:8080', 'https': '159.65.45.64:8080'}
# -------------------------------------
# Thread-678 : 当前剩余处理的ip: 260
# Thread-779 : 当前剩余处理的ip: 263Thread-780开始运行
#
# Thread-758 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 503 Service Temporarily Unavailable',)))
# remove proxy: {'http': '213.136.89.121:80', 'https': '213.136.89.121:80'}
# -------------------------------------
# Thread-758 : 当前剩余处理的ip: 262
# Thread-720 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 500 Internal Server Error',)))
# remove proxy: {'http': '52.23.176.214:80', 'https': '52.23.176.214:80'}
# -------------------------------------
# Thread-720 : 当前剩余处理的ip: 261
# Thread-690 : 当前剩余处理的ip: 259Thread-691开始运行
# Thread-780 : 当前剩余处理的ip: 261Thread-781开始运行
#
# Thread-736 : 当前剩余处理的ip: 260
# Thread-713 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 503 Service Temporarily Unavailable',)))
# remove proxy: {'http': '213.136.89.121:80', 'https': '213.136.89.121:80'}
# -------------------------------------
# Thread-713 : 当前剩余处理的ip: 259
#
# Thread-737开始运行
# Thread-781 : 当前剩余处理的ip: 260Thread-782开始运行
# Thread-691 : 当前剩余处理的ip: 258Thread-692开始运行
#
#
# Thread-660 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '159.203.172.125:8080', 'https': '159.203.172.125:8080'}
# -------------------------------------
# Thread-660 : 当前剩余处理的ip: 257
# Thread-765 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 500 Internal Server Error',)))
# remove proxy: {'http': '52.23.176.214:80', 'https': '52.23.176.214:80'}
# -------------------------------------
# Thread-765 : 当前剩余处理的ip: 259
# Thread-673 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '177.67.83.134:80', 'https': '177.67.83.134:80'}
# -------------------------------------
# Thread-673 : 当前剩余处理的ip: 256
# Thread-750 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '159.65.45.64:8080', 'https': '159.65.45.64:8080'}
# -------------------------------------
# Thread-750 : 当前剩余处理的ip: 258
# Thread-692 : 当前剩余处理的ip: 255Thread-693开始运行
#
# Thread-782 : 当前剩余处理的ip: 257Thread-783开始运行
#
# Thread-737 : 当前剩余处理的ip: 258
# Thread-738开始运行
# Thread-693 : 当前剩余处理的ip: 254Thread-694开始运行
#
# Thread-783 : 当前剩余处理的ip: 256Thread-784开始运行
#
# Thread-716 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '177.67.83.134:80', 'https': '177.67.83.134:80'}
# -------------------------------------
# Thread-716 : 当前剩余处理的ip: 257
# Thread-761 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '177.67.83.134:80', 'https': '177.67.83.134:80'}
# -------------------------------------
# Thread-761 : 当前剩余处理的ip: 255
# Thread-724 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '159.203.172.125:8080', 'https': '159.203.172.125:8080'}
# -------------------------------------
# Thread-724 : 当前剩余处理的ip: 256
# Thread-784 : 当前剩余处理的ip: 254
# Thread-785开始运行
# Thread-694 : 当前剩余处理的ip: 253
# Thread-695开始运行
# Thread-723 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '159.65.45.64:8080', 'https': '159.65.45.64:8080'}
# -------------------------------------
# Thread-723 : 当前剩余处理的ip: 255
# Thread-738 : 当前剩余处理的ip: 254
# Thread-739开始运行
# Thread-753 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '159.203.172.125:8080', 'https': '159.203.172.125:8080'}
# -------------------------------------
# Thread-753 : 当前剩余处理的ip: 253
# Thread-680 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 ',)))
# remove proxy: {'http': '190.94.102.4:8081', 'https': '190.94.102.4:8081'}
# -------------------------------------
# Thread-680 : 当前剩余处理的ip: 252
# Thread-769 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 ',)))
# remove proxy: {'http': '190.94.102.4:8081', 'https': '190.94.102.4:8081'}
# -------------------------------------
# Thread-769 : 当前剩余处理的ip: 252
# Thread-695 : 当前剩余处理的ip: 251
# Thread-696开始运行
# Thread-725 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 ',)))
# remove proxy: {'http': '190.94.102.4:8081', 'https': '190.94.102.4:8081'}
# -------------------------------------
# Thread-725 : 当前剩余处理的ip: 253
# Thread-739 : 当前剩余处理的ip: 252
# Thread-740开始运行
# Thread-785 : 当前剩余处理的ip: 251
# Thread-786开始运行
# Thread-696 : 当前剩余处理的ip: 250
# Thread-740 : 当前剩余处理的ip: 251
# Thread-741开始运行
# Thread-786 : 当前剩余处理的ip: 250
# Thread-787开始运行
# Thread-697开始运行
# Thread-787 : 当前剩余处理的ip: 249
# Thread-788开始运行
# Thread-697 : 当前剩余处理的ip: 249
# Thread-698开始运行
# Thread-741 : 当前剩余处理的ip: 250
# Thread-742开始运行
# Thread-709 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response',)))
# remove proxy: {'http': '91.205.239.120:8080', 'https': '91.205.239.120:8080'}
# -------------------------------------
# Thread-709 : 当前剩余处理的ip: 249
# Thread-754 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response',)))
# remove proxy: {'http': '91.205.239.120:8080', 'https': '91.205.239.120:8080'}
# -------------------------------------
# Thread-754 : 当前剩余处理的ip: 248
# Thread-698 : 当前剩余处理的ip: 248Thread-699开始运行
#
# Thread-742 : 当前剩余处理的ip: 248Thread-743开始运行
#
# Thread-788 : 当前剩余处理的ip: 247Thread-789开始运行
#
# Thread-699 : 当前剩余处理的ip: 247Thread-700开始运行
#
# Thread-743 : 当前剩余处理的ip: 247Thread-744开始运行
#
# Thread-789 : 当前剩余处理的ip: 246
# Thread-790开始运行
# Thread-700 : 当前剩余处理的ip: 246Thread-701开始运行
#
# Thread-744 : 当前剩余处理的ip: 246Thread-745开始运行
#
# Thread-728 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '212.128.69.75:80', 'https': '212.128.69.75:80'}
# -------------------------------------
# Thread-728 : 当前剩余处理的ip: 245
# Thread-683 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '212.128.69.75:80', 'https': '212.128.69.75:80'}
# -------------------------------------
# Thread-683 : 当前剩余处理的ip: 245
# Thread-773 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '212.128.69.75:80', 'https': '212.128.69.75:80'}
# -------------------------------------
# Thread-773 : 当前剩余处理的ip: 245
# Thread-790 : 当前剩余处理的ip: 244Thread-791开始运行
# Thread-745 : 当前剩余处理的ip: 244Thread-746开始运行
#
# Thread-701 : 当前剩余处理的ip: 244Thread-702开始运行
# Thread-664 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response',)))
# remove proxy: {'http': '91.205.239.120:8080', 'https': '91.205.239.120:8080'}
# -------------------------------------
# Thread-664 : 当前剩余处理的ip: 244
#
#
# Thread-791 : 当前剩余处理的ip: 243
# Thread-792开始运行
# Thread-672 is processing
# r.status_code: 200
# -------------------------------------
# Thread-672 : 当前剩余处理的ip: 242
# Thread-746 : 当前剩余处理的ip: 243
# Thread-747开始运行
# Thread-702 : 当前剩余处理的ip: 241
# Thread-703开始运行
# Thread-706 is processing
# r.status_code: 200
# -------------------------------------Thread-792 : 当前剩余处理的ip: 242
# Thread-703 : 当前剩余处理的ip: 240
# Thread-747 : 当前剩余处理的ip: 242
# Thread-748开始运行
# Thread-751 is processing
# r.status_code: 200
# -------------------------------------
# Thread-751 : 当前剩余处理的ip: 241
# Thread-793开始运行
# 线程开始停止运行：
# Thread-767 is processing
# r.status_code: 200
# -------------------------------------
# Thread-767 : 当前剩余处理的ip: 240
# Thread-679 is processing
# r.status_code: 200
# -------------------------------------
# Thread-679 : 当前剩余处理的ip: 239
# Thread-793 : 当前剩余处理的ip: 239
#
# Thread-706 : 当前剩余处理的ip: 241
# Thread-719 is processing
# r.status_code: 200
# -------------------------------------
# Thread-719 : 当前剩余处理的ip: 240
# 线程开始停止运行：
# Thread-748 : 当前剩余处理的ip: 239
# 线程开始停止运行：
# Thread-694 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# remove proxy: {'http': '118.70.79.123:8080', 'https': '118.70.79.123:8080'}
# -------------------------------------
# Thread-753 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# remove proxy: {'http': '118.70.79.123:8080', 'https': '118.70.79.123:8080'}
# -------------------------------------
# Thread-694 : 当前剩余处理的ip: 238
# Thread-753 : 当前剩余处理的ip: 238
# Thread-725 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# remove proxy: {'http': '118.70.79.123:8080', 'https': '118.70.79.123:8080'}
# -------------------------------------
# Thread-725 : 当前剩余处理的ip: 238
# Thread-722 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 502 Bad Gateway',)))
# remove proxy: {'http': '93.180.7.246:8080', 'https': '93.180.7.246:8080'}
# -------------------------------------
# Thread-722 : 当前剩余处理的ip: 237
# Thread-764 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 502 Bad Gateway',)))
# remove proxy: {'http': '93.180.7.246:8080', 'https': '93.180.7.246:8080'}
# -------------------------------------
# Thread-764 : 当前剩余处理的ip: 237
# Thread-677 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 502 Bad Gateway',)))
# remove proxy: {'http': '93.180.7.246:8080', 'https': '93.180.7.246:8080'}
# -------------------------------------
# Thread-677 : 当前剩余处理的ip: 237
# Thread-788 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response',)))
# remove proxy: {'http': '41.79.198.35:53281', 'https': '41.79.198.35:53281'}
# -------------------------------------
# Thread-788 : 当前剩余处理的ip: 236
# Thread-682 is processing
# r.status_code: 200
# -------------------------------------
# Thread-682 : 当前剩余处理的ip: 236
# Thread-701 is processing
# r.status_code: 200
# -------------------------------------
# Thread-701 : 当前剩余处理的ip: 235
# Thread-772 is processing
# r.status_code: 200
# -------------------------------------Thread-727 is processing
# Thread-772 : 当前剩余处理的ip: 235
#
# r.status_code: 200
# -------------------------------------
# Thread-727 : 当前剩余处理的ip: 236
# Thread-746 is processing
# r.status_code: 200
# -------------------------------------
# Thread-746 : 当前剩余处理的ip: 235
# Thread-717 is processing
# r.status_code: 200
# -------------------------------------
# Thread-717 : 当前剩余处理的ip: 234
# Thread-674 is processing
# r.status_code: 200
# -------------------------------------
# Thread-674 : 当前剩余处理的ip: 234
# Thread-689 is processing
# r.status_code: 200
# -------------------------------------
# Thread-689 : 当前剩余处理的ip: 233
# Thread-762 is processing
# r.status_code: 200
# -------------------------------------
# Thread-762 : 当前剩余处理的ip: 234
# Thread-780 is processing
# r.status_code: 200
# -------------------------------------
# Thread-780 : 当前剩余处理的ip: 233
# Thread-715 is processing
# r.status_code: 200
# -------------------------------------
# Thread-715 : 当前剩余处理的ip: 233
# Thread-791 is processing
# r.status_code: 200
# -------------------------------------
# Thread-791 : 当前剩余处理的ip: 232
# Thread-698 is processing
# r.status_code: 200
# -------------------------------------
# Thread-698 : 当前剩余处理的ip: 232
# Thread-705 is processing
# r.status_code: 200
# -------------------------------------
# Thread-705 : 当前剩余处理的ip: 232
# Thread-666 is processing
# r.status_code: 200
# -------------------------------------
# Thread-666 : 当前剩余处理的ip: 231
# Thread-768 is processingThread-661 is processing
# r.status_code: 200
# -------------------------------------
# Thread-661 : 当前剩余处理的ip: 230
#
# r.status_code: 200
# -------------------------------------
# Thread-768 : 当前剩余处理的ip: 231
# Thread-712 is processing
# r.status_code: 200
# -------------------------------------
# Thread-712 : 当前剩余处理的ip: 231
# Thread-785 is processingThread-695 is processingThread-756 is processing
# r.status_code: 200
# -------------------------------------
# Thread-756 : 当前剩余处理的ip: 230
#
# r.status_code: 200
# -------------------------------------
# Thread-695 : 当前剩余处理的ip: 229
#
# r.status_code: 200
# -------------------------------------
# Thread-785 : 当前剩余处理的ip: 229
# Thread-742 is processing
# r.status_code: 200
# -------------------------------------
# Thread-742 : 当前剩余处理的ip: 230
# Thread-776 is processing
# r.status_code: 200
# -------------------------------------
# Thread-776 : 当前剩余处理的ip: 228
# Thread-686 is processing
# r.status_code: 200
# -------------------------------------
# Thread-686 : 当前剩余处理的ip: 228
# Thread-731 is processing
# r.status_code: 200
# -------------------------------------
# Thread-731 : 当前剩余处理的ip: 229
# Thread-704 is processing
# r.status_code: 200
# -------------------------------------
# Thread-704 : 当前剩余处理的ip: 228
# Thread-754 is processing
# r.status_code: 200
# -------------------------------------
# Thread-754 : 当前剩余处理的ip: 227
# Thread-680 is processingThread-769 is processingThread-659 is processingThread-784 is processingThread-738 is processing
#
# r.status_code: 200
# -------------------------------------
# Thread-680 : 当前剩余处理的ip: 227
#
# r.status_code: 200
# -------------------------------------
# Thread-769 : 当前剩余处理的ip: 226
#
# r.status_code: 200
# -------------------------------------Thread-739 is processing
# r.status_code: 200
# -------------------------------------
# Thread-739 : 当前剩余处理的ip: 227
#
# r.status_code: 200
# -------------------------------------
# Thread-659 : 当前剩余处理的ip: 226
#
# Thread-784 : 当前剩余处理的ip: 225
# r.status_code: 200
# -------------------------------------
# Thread-738 : 当前剩余处理的ip: 226
# Thread-700 is processing
# r.status_code:Thread-790 is processing
# r.status_code: 200
# -------------------------------------
# Thread-790 : 当前剩余处理的ip: 224
# Thread-662 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '114.202.2.185:80', 'https': '114.202.2.185:80'}
# -------------------------------------
# Thread-662 : 当前剩余处理的ip: 225
# Thread-749 is processing
# r.status_code: 200
# -------------------------------------
# Thread-749 : 当前剩余处理的ip: 223
# Thread-707 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '114.202.2.185:80', 'https': '114.202.2.185:80'}
# -------------------------------------
# Thread-707 : 当前剩余处理的ip: 225
# Thread-752 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '114.202.2.185:80', 'https': '114.202.2.185:80'}
# -------------------------------------
# Thread-752 : 当前剩余处理的ip: 222
# Thread-744 is processing
# r.status_code: 200
# -------------------------------------
# Thread-744 : 当前剩余处理的ip: 224
#  200
# -------------------------------------
# Thread-700 : 当前剩余处理的ip: 224
# Thread-789 is processing
# r.status_code: 200
# -------------------------------------
# Thread-789 : 当前剩余处理的ip: 221
# Thread-714 is processing
# r.status_code: 200
# -------------------------------------
# Thread-714 : 当前剩余处理的ip: 223
# Thread-787 is processing
# r.status_code: 200
# -------------------------------------
# Thread-787 : 当前剩余处理的ip: 220
# Thread-697 is processing
# r.status_code: 200
# -------------------------------------
# Thread-697 : 当前剩余处理的ip: 223
# Thread-709 is processing
# r.status_code: 200
# -------------------------------------
# Thread-709 : 当前剩余处理的ip: 222
# Thread-665 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '5.135.186.183:3128', 'https': '5.135.186.183:3128'}
# -------------------------------------
# Thread-665 : 当前剩余处理的ip: 222
# Thread-755 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '5.135.186.183:3128', 'https': '5.135.186.183:3128'}
# -------------------------------------
# Thread-755 : 当前剩余处理的ip: 219
# Thread-710 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '5.135.186.183:3128', 'https': '5.135.186.183:3128'}
# -------------------------------------
# Thread-710 : 当前剩余处理的ip: 221
# Thread-778 is processing
# r.status_code: 200
# -------------------------------------
# Thread-778 : 当前剩余处理的ip: 218
# Thread-667 is processing
# r.status_code: 200
# -------------------------------------
# Thread-667 : 当前剩余处理的ip: 221
# Thread-687 is processing
# r.status_code: 200
# -------------------------------------
# Thread-687 : 当前剩余处理的ip: 220
# Thread-690 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f5c3651a8d0>, 'Connection to 92.241.65.174 timed out. (connect timeout=5)'))
# remove proxy: {'http': '92.241.65.174:8080', 'https': '92.241.65.174:8080'}
# -------------------------------------
# Thread-690 : 当前剩余处理的ip: 219
# Thread-683 is processing
# r.status_code: 200
# -------------------------------------
# Thread-683 : 当前剩余处理的ip: 218
# Thread-693 is processing
# r.status_code: 200
# -------------------------------------
# Thread-693 : 当前剩余处理的ip: 217
# Thread-667 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response',)))
# remove proxy: {'http': '95.78.161.114:8080', 'https': '95.78.161.114:8080'}
# -------------------------------------
# Thread-667 : 当前剩余处理的ip: 216
# Thread-760 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '185.93.3.123:8080', 'https': '185.93.3.123:8080'}
# -------------------------------------
# Thread-760 : 当前剩余处理的ip: 217
# Thread-726 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '185.93.3.123:8080', 'https': '185.93.3.123:8080'}
# -------------------------------------
# Thread-726 : 当前剩余处理的ip: 220
# Thread-708 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '58.97.81.11:80', 'https': '58.97.81.11:80'}
# -------------------------------------
# Thread-708 : 当前剩余处理的ip: 219
# Thread-713 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f5c43cc5780>, 'Connection to 92.241.65.174 timed out. (connect timeout=5)'))
# remove proxy: {'http': '92.241.65.174:8080', 'https': '92.241.65.174:8080'}
# -------------------------------------
# Thread-713 : 当前剩余处理的ip: 218
# Thread-663 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '185.93.3.123:8080', 'https': '185.93.3.123:8080'}
# -------------------------------------
# Thread-663 : 当前剩余处理的ip: 215
# Thread-681 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '58.97.81.11:80', 'https': '58.97.81.11:80'}
# -------------------------------------
# Thread-681 : 当前剩余处理的ip: 214
# Thread-773 is processingThread-770 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '58.97.81.11:80', 'https': '58.97.81.11:80'}
# -------------------------------------
# Thread-770 : 当前剩余处理的ip: 216
# Thread-764 is processing
# r.status_code: 200
# -------------------------------------
# Thread-764 : 当前剩余处理的ip: 215
# Thread-710 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response',)))
# remove proxy: {'http': '95.78.161.114:8080', 'https': '95.78.161.114:8080'}
# -------------------------------------
# Thread-710 : 当前剩余处理的ip: 217
# Thread-765 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f5c4e1de0b8>, 'Connection to 92.241.65.174 timed out. (connect timeout=5)'))
# remove proxy: {'http': '92.241.65.174:8080', 'https': '92.241.65.174:8080'}
# -------------------------------------
# Thread-765 : 当前剩余处理的ip: 214
# Thread-728 is processingThread-723 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '188.120.230.172:80', 'https': '188.120.230.172:80'}
# -------------------------------------
# Thread-779 is processingThread-734 is processing
# r.status_code: 200
# -------------------------------------
# Thread-734 : 当前剩余处理的ip: 216
# Thread-748 is processing
# r.status_code: 200
# -------------------------------------
# Thread-748 : 当前剩余处理的ip: 215
# Thread-755 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response',)))
# remove proxy: {'http': '150.242.109.120:53281', 'https': '150.242.109.120:53281'}
# -------------------------------------
# Thread-755 : 当前剩余处理的ip: 213
#
# r.status_code: 200
# -------------------------------------
# Thread-728 : 当前剩余处理的ip: 214
# Thread-761 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLError("bad handshake: SysCallError(-1, 'Unexpected EOF')",),))
# remove proxy: {'http': '188.120.230.172:80', 'https': '188.120.230.172:80'}
# -------------------------------------
# Thread-761 : 当前剩余处理的ip: 212
# Thread-737 is processing
# r.status_code: 200
# -------------------------------------
# Thread-737 : 当前剩余处理的ip: 213
# Thread-723 : 当前剩余处理的ip: 212
#
# r.status_code: 200
# -------------------------------------
# Thread-779 : 当前剩余处理的ip: 211
# Thread-793 is processing
# r.status_code: 200
# -------------------------------------
# Thread-793 : 当前剩余处理的ip: 210
# Thread-782 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '188.120.226.223:80', 'https': '188.120.226.223:80'}
# -------------------------------------
# Thread-782 : 当前剩余处理的ip: 209
# Thread-676 is processing
# r.status_code: 200
# -------------------------------------
# Thread-676 : 当前剩余处理的ip: 213
# Thread-684 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '103.230.63.215:8080', 'https': '103.230.63.215:8080'}
# -------------------------------------
# Thread-684 : 当前剩余处理的ip: 212Thread-692 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '188.120.230.172:80', 'https': '188.120.230.172:80'}
# -------------------------------------
# Thread-692 : 当前剩余处理的ip: 212
# Thread-743 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '41.79.198.35:53281', 'https': '41.79.198.35:53281'}
# -------------------------------------
# Thread-743 : 当前剩余处理的ip: 211
# Thread-709 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response',)))
# remove proxy: {'http': '138.185.255.74:53281', 'https': '138.185.255.74:53281'}
# -------------------------------------
# Thread-709 : 当前剩余处理的ip: 210
#
# r.status_code: 200
# -------------------------------------
# Thread-773 : 当前剩余处理的ip: 208
# Thread-691 is processing
# r.status_code: 200
# -------------------------------------
# Thread-691 : 当前剩余处理的ip: 211
# Thread-789 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response',)))
# remove proxy: {'http': '95.78.161.114:8080', 'https': '95.78.161.114:8080'}
# -------------------------------------
# Thread-789 : 当前剩余处理的ip: 207
# Thread-693 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response',)))
# remove proxy: {'http': '190.196.90.174:53281', 'https': '190.196.90.174:53281'}
# -------------------------------------
# Thread-693 : 当前剩余处理的ip: 210
#
# Thread-750 is processing
# r.status_code: 200
# -------------------------------------
# Thread-750 : 当前剩余处理的ip: 206
# Thread-668 is processing
# r.status_code: 200
# -------------------------------------
# Thread-668 : 当前剩余处理的ip: 208
# Thread-716 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '188.120.226.223:80', 'https': '188.120.226.223:80'}
# -------------------------------------
# Thread-716 : 当前剩余处理的ip: 209
# Thread-678 is processing
# r.status_code: Thread-675 is processing
# r.status_code: 200
# -------------------------------------
# Thread-675 : 当前剩余处理的ip: 207
# Thread-660 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '188.120.226.223:80', 'https': '188.120.226.223:80'}
# -------------------------------------
# Thread-660 : 当前剩余处理的ip: 206
# 200
# -------------------------------------
# Thread-678 : 当前剩余处理的ip: 205
# Thread-711 is processing
# r.status_code: 200
# -------------------------------------
# Thread-711 : 当前剩余处理的ip: 208
# Thread-758 is processing
# r.status_code: 200
# -------------------------------------
# Thread-758 : 当前剩余处理的ip: 205
# Thread-679 is processing
# r.status_code: 200
# -------------------------------------
# Thread-679 : 当前剩余处理的ip: 204
# Thread-670 is processing
# r.status_code: 200
# -------------------------------------
# Thread-670 : 当前剩余处理的ip: 203
# Thread-724 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '103.73.166.77:8080', 'https': '103.73.166.77:8080'}
# -------------------------------------
# Thread-724 : 当前剩余处理的ip: 207
# Thread-720 is processing
# r.status_code: 200
# -------------------------------------
# Thread-720 : 当前剩余处理的ip: 206
# Thread-740 is processing
# r.status_code: 200
# -------------------------------------
# Thread-740 : 当前剩余处理的ip: 205
# Thread-771 is processing
# r.status_code: 200
# -------------------------------------
# Thread-771 : 当前剩余处理的ip: 204
# Thread-768 is processing
# r.status_code: 200
# -------------------------------------
# Thread-768 : 当前剩余处理的ip: 203
# Thread-688 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Read timed out.
# remove proxy: {'http': '140.227.69.54:3128', 'https': '140.227.69.54:3128'}
# -------------------------------------
# Thread-688 : 当前剩余处理的ip: 202
# Thread-732 is processing
# r.status_code: 200
# -------------------------------------
# Thread-732 : 当前剩余处理的ip: 204
# Thread-669 is processing
# r.status_code: 200
# -------------------------------------
# Thread-669 : 当前剩余处理的ip: 201
# Thread-733 is processing
# r.status_code: 200
# -------------------------------------
# Thread-733 : 当前剩余处理的ip: 203
# Thread-696 is processing
# r.status_code: 200
# -------------------------------------
# Thread-696 : 当前剩余处理的ip: 200
# Thread-780 is processing
# r.status_code: 200
# -------------------------------------
# Thread-780 : 当前剩余处理的ip: 202
# Thread-689 is processing
# r.status_code: 200
# -------------------------------------
# Thread-689 : 当前剩余处理的ip: 199
# Thread-682 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f5c544671d0>, 'Connection to 103.87.104.87 timed out. (connect timeout=5)'))
# remove proxy: {'http': '103.87.104.87:8080', 'https': '103.87.104.87:8080'}
# -------------------------------------
# Thread-682 : 当前剩余处理的ip: 198
# Thread-764 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', ConnectionResetError(104, 'Connection reset by peer')))
# remove proxy: {'http': '193.178.187.136:53281', 'https': '193.178.187.136:53281'}
# -------------------------------------
# Thread-764 : 当前剩余处理的ip: 201
# Thread-663 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', ConnectionResetError(104, 'Connection reset by peer')))
# remove proxy: {'http': '193.178.187.136:53281', 'https': '193.178.187.136:53281'}
# -------------------------------------
# Thread-663 : 当前剩余处理的ip: 197
# Thread-727 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f5c544722e8>, 'Connection to 103.87.104.87 timed out. (connect timeout=5)'))
# remove proxy: {'http': '103.87.104.87:8080', 'https': '103.87.104.87:8080'}
# -------------------------------------
# Thread-727 : 当前剩余处理的ip: 202
# Thread-777 is processing
# r.status_code: 200
# -------------------------------------
# Thread-777 : 当前剩余处理的ip: 200
# Thread-671 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '93.58.124.32:80', 'https': '93.58.124.32:80'}
# -------------------------------------
# Thread-671 : 当前剩余处理的ip: 196
# Thread-718 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '93.58.124.32:80', 'https': '93.58.124.32:80'}
# -------------------------------------
# Thread-718 : 当前剩余处理的ip: 201
# Thread-763 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '93.58.124.32:80', 'https': '93.58.124.32:80'}
# -------------------------------------
# Thread-763 : 当前剩余处理的ip: 199
# Thread-677 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '140.227.70.51:3128', 'https': '140.227.70.51:3128'}
# -------------------------------------
# Thread-677 : 当前剩余处理的ip: 195
# Thread-683 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '109.121.163.75:53282', 'https': '109.121.163.75:53282'}
# -------------------------------------
# Thread-683 : 当前剩余处理的ip: 194
# Thread-674 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f5c54469588>, 'Connection to 200.37.7.75 timed out. (connect timeout=5)'))
# remove proxy: {'http': '200.37.7.75:53281', 'https': '200.37.7.75:53281'}
# ...
# ----------------------
# Thread-795 已停止
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /beijing/94483910.html?s=01&t=0 (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f5c54e27b00>, 'Connection to 89.22.150.70 timed out. (connect timeout=5)'))
# 尝试新的proxy
# getTag()中tag_list: ['5-7年经验', '本科', '招5人', '07-16发布', '五险一金', '补充医疗保险', '绩效奖金', '年终奖金', '带薪年假', '加班补助', '驻场补助', '团队氛围好', '领导好', '帅哥美女多多']
# ----------------------
# Thread-796 已停止
# Thread-797 已停止
# Thread-798 已停止
# getTag()中tag_list:getTag()中tag_list: ['1年经验', '招1人', '07-16发布']
# ----------------------
# getTag()当前处理链接:HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /tianjin-xqq/104554438.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# 尝试新的proxy
#  https://jobs.51job.com/wuxi-wxxq/87498739.html?s=01&t=0
# getTag()获得的ip: {'http': '140.227.69.54:3128', 'https': '140.227.69.54:3128'}
#  ['3-4年经验', '大专', '招5人', '07-16发布', '五险一金', '员工旅游', '交通补贴', '年终奖金', '弹性工作', '加班补贴']
# ----------------------
# getTag()中tag_list:getTag()中tag_list: ['3-4年经验', '本科', '招10人', '07-16发布', '五险一金', '年终奖金', '定期体检']
# ----------------------
# getTag()中tag_list: ['2年经验', '本科', '招若干人', '07-16发布', '五险一金', '餐饮补贴', '通讯补贴', '定期体检']
# ----------------------
#  ['3-4年经验', '本科', '招1人', '07-16发布', '五险一金', '年终奖金', '定期体检', '员工旅游', '专业培训', '餐饮补贴']
# ----------------------
# getTag()中tag_list: ['1年经验', '本科', '招若干人', '07-16发布', '五险一金', '补充医疗保险', '员工旅游', '交通补贴', '餐饮补贴', '通讯补贴', '绩效奖金', '年终奖金', '定期体检']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/shenzhen-nsq/93916006.html?s=01&t=0
# getTag()获得的ip: {'http': '187.44.155.229:53281', 'https': '187.44.155.229:53281'}
# getTag()中tag_list:getTag()中tag_list: ['2年经验', '大专', '招5人', '07-16发布', '五险一金', '员工旅游', '餐饮补贴', '专业培训', '绩效奖金', '年终奖金']
# ----------------------
#  ['2年经验', '本科', '招5人', '07-16发布', '五险一金', '交通补贴', '餐饮补贴', '通讯补贴', '绩效奖金', '年终奖金', '员工旅游']
# ----------------------
# Thread-799 已停止
# getTag()中tag_list: ['无工作经验', '大专', '招1人', '07-16发布', '五险一金', '餐饮补贴', '交通补贴', '绩效奖金', '年终奖金', '通讯补贴']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/shanghai-mhq/98080318.html?s=01&t=0
# getTag()获得的ip: {'http': '78.83.113.81:8080', 'https': '78.83.113.81:8080'}
# getTag()中tag_list: ['3-4年经验', '本科', '招5人', '07-16发布', '五险一金', '弹性工作', '通讯补贴', '绩效奖金', '员工旅游', '年终奖金', '餐饮补贴']
# ----------------------
# getTag()中tag_list: ['2年经验', '大专', '招2人', '07-16发布', '五险一金', '免费班车', '餐饮补贴', '专业培训', '意外险']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/guangzhou-thq/98885570.html?s=01&t=0
# getTag()获得的ip: {'http': '200.37.7.75:53281', 'https': '200.37.7.75:53281'}
# getTag()中tag_list: ['2年经验', '本科', '招若干人', '07-16发布', '五险一金', '员工旅游', '餐饮补贴', '通讯补贴', '定期体检', '年终奖金']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/guangzhou-pyq/90968811.html?s=01&t=0
# getTag()获得的ip: {'http': '195.46.163.247:8080', 'https': '195.46.163.247:8080'}
# getTag()中tag_list: ['2年经验', '大专', '招2人', '07-16发布', '五险一金', '补充医疗保险', '补充公积金', '员工旅游', '专业培训', '绩效奖金', '年终奖金', '项目奖金']
# ----------------------
# getTag()中tag_list: ['3-4年经验', '大专', '招1人', '07-16发布', '五险一金', '全勤奖', '节日福利', '绩效奖金', '周末双休', '专业培训', '补充公积金']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/guangzhou-thq/103564951.html?s=01&t=0
# getTag()获得的ip: {'http': '140.227.80.50:3128', 'https': '140.227.80.50:3128'}
# getTag()中tag_list:getTag()中tag_list: ['无工作经验', '招2人', '07-16发布', '五险一金', '补充医疗保险', '年终奖金', '定期体检']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/fuzhou/87939686.html?s=01&t=0
# getTag()获得的ip: {'http': '202.93.128.98:3128', 'https': '202.93.128.98:3128'}
#  ['2年经验', '本科', '招若干人', '07-16发布', '五险一金', '员工旅游', '年终奖金', '弹性工作', '专业培训', '周末双休', '每年多次调薪', '扁平化管理', '行业领先', '建筑二次革命']
# ----------------------
# getTag()中tag_list:HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /guangzhou-thq/98885570.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response',)))
# 尝试新的proxy
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /guangzhou-pyq/90968811.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response',)))
# 尝试新的proxy
# getTag()中tag_list: ['3-4年经验', '本科', '招1人', '07-16发布', '五险一金', '交通补贴', '餐饮补贴', '弹性工作', '年终奖金']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/guangzhou-thq/85738794.html?s=01&t=0
# getTag()获得的ip: {'http': '140.227.83.18:3129', 'https': '140.227.83.18:3129'}
# getTag()中tag_list:getTag()中tag_list: ['3-4年经验', '本科', '招1人', '07-16发布', '五险一金', '年终奖金', '餐饮补贴', '定期体检', '弹性工作', '专业培训', '员工旅游', '节日福利', '专业导师', '绩效奖金']
# ----------------------
#  ['1年经验', '大专', '招2人', '07-16发布', '五险一金', '员工旅游', '绩效奖金', '年终奖金', '定期体检', '弹性工作', '通讯补贴', '做五休二', '交通补贴', '全勤奖']
# ----------------------
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Read timed out. (read timeout=5)
# 尝试新的proxy
# Thread-800 已停止
# getTag()中tag_list:getTag()中tag_list:getTag()中tag_list: ['无工作经验', '本科', '招2人', '07-16发布', '五险一金', '交通补贴', '餐饮补贴', '通讯补贴', '弹性工作']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/shanghai-pdxq/103177488.html?s=01&t=0
# getTag()获得的ip: {'http': '190.196.90.174:53281', 'https': '190.196.90.174:53281'}
#  ['无工作经验', '招6人', '07-16发布', '五险一金', '补充公积金', '员工旅游', '专业培训', '通讯补贴', '绩效奖金', '年终奖金', '定期体检']
# ----------------------
#  ['2年经验', '本科', '招若干人', '07-16发布', '五险一金', '弹性工作']
# ----------------------
# getTag()中tag_list: ['无工作经验', '招5人', '07-16发布', '五险一金', '绩效奖金', '年终奖金', '餐饮补贴']
# ----------------------
#  ['5-7年经验', '大专', '招若干人', '07-16发布', '五险一金', '员工旅游', '定期体检', '餐饮补贴', '结婚礼金', '年度调薪', '生子礼金', '生日礼物']
# ----------------------
# getTag()中tag_list: ['3-4年经验', '大专', '招2人', '07-16发布', '五险一金', '补充医疗保险', '专业培训', '绩效奖金', '员工旅游', '餐饮补贴', '弹性工作']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/shenzhen-nsq/103168560.html?s=01&t=0
# getTag()获得的ip: {'http': '140.227.71.55:3128', 'https': '140.227.71.55:3128'}
# getTag()中tag_list:Thread-815 已停止
# getTag()中tag_list: ['3-4年经验', '本科', '招若干人', '07-16发布']
# ----------------------
#  ['无工作经验', '本科', '招若干人', '07-16发布', '五险一金', '带薪年假', '周末双休', '节日福利', '员工旅游', '餐饮补贴', '通讯补贴', '专业培训', '定期体检']
# ----------------------
# Thread-801 已停止
# Thread-802 已停止
# Thread-803 已停止
# Thread-804 已停止
# Thread-805 已停止
# Thread-806 已停止
# getTag()当前处理链接: https://jobs.51job.com/hangzhou-gsq/104568615.html?s=01&t=0
# getTag()获得的ip: {'http': '83.234.163.46:8080', 'https': '83.234.163.46:8080'}
# getTag()中tag_list:getTag()中tag_list: ['3-4年经验', '本科', '招2人', '07-16发布', '舒适环境', '丰富下午茶', '带薪年假', '过节福利']
# ----------------------
# getTag()当前处理链接:getTag()中tag_list: ['3-4年经验', '大专', '招1人', '07-16发布', '五险一金', '股票期权', '周末双休', '扁平架构', '做五休二']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/suzhou-gyyq/103693630.html?s=01&t=0
# getTag()获得的ip: {'http': '91.246.214.143:53281', 'https': '91.246.214.143:53281'}
#  https://jobs.51job.com/beijing/104246683.html?s=01&t=0
# getTag()获得的ip: {'http': '140.227.69.74:8080', 'https': '140.227.69.74:8080'}
#  ['3-4年经验', '本科', '招2人', '07-16发布', '五险一金', '通讯补贴', '交通补贴', '年终奖金']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/wuhan-wcq/104569003.html?s=01&t=0
# getTag()获得的ip: {'http': '92.255.182.151:8080', 'https': '92.255.182.151:8080'}
# getTag()中tag_list:getTag()中tag_list: ['5-7年经验', '本科', '招3人', '07-16发布', '五险一金', '免费班车']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/nanjing/102563639.html?s=01&t=0
#  ['3-4年经验', '大专', '招若干人', '07-16发布', '绩效奖金', '年终奖金', '股票期权', '员工旅游', '周末双休', '带薪年假', '节日福利', '下午茶', '结婚礼金', '五险一金']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/suzhou-gyyq/102933787.html?s=01&t=0
# getTag()获得的ip: {'http': '186.68.85.26:53281', 'https': '186.68.85.26:53281'}
# getTag()获得的ip: {'http': '47.35.216.156:53281', 'https': '47.35.216.156:53281'}
# getTag()中tag_list:HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /guangzhou-thq/98885570.html?s=01&t=0 (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f5c41760e10>, 'Connection to 81.15.175.208 timed out. (connect timeout=5)'))
# 尝试新的proxy
#  ['无工作经验', '招8人', '07-16发布']
# ----------------------
# getTag()中tag_list:getTag()中tag_list:HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /guangzhou-thq/85738794.html?s=01&t=0 (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f5c41638240>, 'Connection to 140.227.83.18 timed out. (connect timeout=5)'))
# 尝试新的proxy
#  ['1年经验', '大专', '招3人', '07-16发布']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/beijing-hdq/104568783.html?s=01&t=0
# getTag()获得的ip: {'http': '202.159.48.202:65205', 'https': '202.159.48.202:65205'}
# getTag()中tag_list: ['2年经验', '大专', '招2人', '07-16发布', '全勤奖', '节日福利', '五险一金', '周末双休']
# ----------------------
# Thread-816 已停止
# Thread-817 已停止
# Thread-818 已停止
# Thread-819 已停止
# Thread-820 已停止
# Thread-821 已停止
# Thread-822 已停止
# Thread-823 已停止
# Thread-824 已停止
# Thread-825 已停止
# Thread-826 已停止
# Thread-827 已停止
# Thread-828 已停止
# Thread-829 已停止
# Thread-830 已停止
# Thread-831 已停止
# Thread-832 已停止
# Thread-833 已停止
# tag组装完成!
#  ['无工作经验', '大专', '招5人', '07-16发布', '交通补贴', '年终奖金', '弹性工作']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/guangzhou-byq/104276976.html?s=01&t=0
# getTag()获得的ip: {'http': '185.103.166.249:41258', 'https': '185.103.166.249:41258'}
# Thread-658完成单页的时间: 62
# getTag()中tag_list:getTag()中tag_list: ['无工作经验', '大专', '招3人', '07-16发布']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/beijing/104176386.html?s=01&t=0
# getTag()获得的ip: {'http': '95.220.130.102:44331', 'https': '95.220.130.102:44331'}
# getTag()中tag_list:getTag()中tag_list: ['无工作经验', '大专', '招5人', '07-16发布']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/zhuhai/104562193.html?s=01&t=0
# getTag()获得的ip: {'http': '189.115.92.71:80', 'https': '189.115.92.71:80'}
#  ['5-7年经验', '本科', '招2人', '07-16发布', '五险一金', '员工旅游', '年终奖金', '绩效奖金', '定期体检', '股票期权']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/jinan/99919610.html?s=01&t=0
# getTag()获得的ip: {'http': '41.60.237.85:8080', 'https': '41.60.237.85:8080'}
#  ['无工作经验', '招5人', '07-16发布']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/yantai/104567879.html?s=01&t=0
# getTag()获得的ip: {'http': '129.205.136.183:53281', 'https': '129.205.136.183:53281'}
# getTag()中tag_list: ['2年经验', '招4人', '07-16发布', '五险一金', '弹性工作', '专业培训']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/shanghai-mhq/104288105.html?s=01&t=0
# getTag()获得的ip: {'http': '200.89.98.38:42619', 'https': '200.89.98.38:42619'}
# getTag()中tag_list: ['3-4年经验', '大专', '招2人', '07-16发布', '做五休二', '全勤奖', '通讯补贴', '住房补贴', '节日福利', '提供住宿', '五险一金']
# ----------------------
# getTag()中tag_list:Thread-807 已停止
# Thread-808 已停止
# Thread-809 已停止
# Thread-810 已停止
# Thread-811 已停止
# Thread-812 已停止
# Thread-813 已停止
# tag组装完成!
# Thread-656完成单页的时间: 63
#  ['2年经验', '本科', '招3人', '07-16发布', '五险一金', '年终奖金']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/guangzhou-thq/103767475.html?s=01&t=0
# getTag()获得的ip: {'http': '217.175.1.245:7777', 'https': '217.175.1.245:7777'}
# getTag()中tag_list: ['3-4年经验', '本科', '招5人', '07-16发布', '做五休二', '周末双休', '弹性工作', '带薪年假', '五险一金', '绩效奖金', '节日福利', '专业培训']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/shanghai-pdxq/104568429.html?s=01&t=0
# getTag()获得的ip: {'http': '109.188.92.18:8080', 'https': '109.188.92.18:8080'}
# getTag()中tag_list: ['5-7年经验', '大专', '招5人', '07-16发布']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/shanghai-bsq/101161858.html?s=01&t=0
# getTag()获得的ip: {'http': '37.60.212.172:44331', 'https': '37.60.212.172:44331'}
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /nanjing/102563639.html?s=01&t=0 (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f5c4509a780>, 'Connection to 47.35.216.156 timed out. (connect timeout=5)'))
# 尝试新的proxy
# getTag()中tag_list:HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /beijing-hdq/104568783.html?s=01&t=0 (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f5c46bda278>, 'Connection to 202.159.48.202 timed out. (connect timeout=5)'))
# 尝试新的proxy
#  ['5-7年经验', '本科', '招1人', '07-16发布']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/guangzhou-thq/104568314.html?s=01&t=0
# getTag()获得的ip: {'http': '46.0.199.23:3128', 'https': '46.0.199.23:3128'}
# getTag()中tag_list:HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /shanghai-mhq/104288105.html?s=01&t=0 (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f5c4539b080>, 'Connection to 200.89.98.38 timed out. (connect timeout=5)'))
# 尝试新的proxy
# getTag()中tag_list: ['1年经验', '硕士', '招1人', '07-16发布', '五险一金', '餐饮补贴', '绩效奖金', '年终奖金', '股票期权', '弹性工作']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/wuhan-hyq/68196361.html?s=01&t=0
# getTag()获得的ip: {'http': '103.111.3.1:53281', 'https': '103.111.3.1:53281'}
#  HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /beijing/104176386.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# 尝试新的proxy
# ['3-4年经验', '本科', '招若干人', '07-16发布', '五险一金', '补充医疗保险', '员工旅游', '餐饮补贴', '专业培训', '绩效奖金', '年终奖金', '股票期权', '定期体检']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/hangzhou-jgq/104561496.html?s=01&t=0
# getTag()获得的ip: {'http': '178.57.50.95:44331', 'https': '178.57.50.95:44331'}
# getTag()中tag_list: ['3-4年经验', '大专', '招5人', '07-16发布', '五险一金', '补充医疗保险', '专业培训', '绩效奖金', '周末双休', '年终奖金']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/guangzhou-hzq/84053068.html?s=01&t=0
# getTag()获得的ip: {'http': '59.106.213.54:60088', 'https': '59.106.213.54:60088'}
# 线程开始：HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /shanghai-pdxq/104568429.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# Thread-854开始运行
# Thread-854 : 当前剩余处理的ip: 300
# Thread-855开始运行尝试新的proxy
#
# Thread-855 : 当前剩余处理的ip: 300
# Thread-856开始运行
#
# Thread-856 : 当前剩余处理的ip: 298Thread-857开始运行
# Thread-858开始运行Thread-857 : 当前剩余处理的ip: 298
#
#
# Thread-855 is processing
# Thread-857 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
#
# remove proxy: {'http': '66.70.190.244:8080', 'https': '66.70.190.244:8080'}
# -------------------------------------
# Thread-855 : 当前剩余处理的ip: 296
# remove proxy: {'http': '159.89.229.66:8080', 'https': '159.89.229.66:8080'}
# -------------------------------------
# Thread-857 : 当前剩余处理的ip: 295
# 线程开始：
# Thread-899开始运行
# Thread-899 : 当前剩余处理的ip: 300Thread-900开始运行
#
# 主线程Thread-656停止
# Thread-856 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '114.202.2.185:80', 'https': '114.202.2.185:80'}
# -------------------------------------
# Thread-856 : 当前剩余处理的ip: 294
# Thread-855 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy:Thread-857 is processing {'http': '52.23.193.25:8080', 'https': '52.23.193.25:8080'}
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response',)))
# -------------------------------------

# %% [raw]
# 一个最影响速度的地方就是每个线程在开始运行handle_single前要进行ip清洗的操作

# %% [raw]
# 10页2线程
# getCleanProxy()45
# pack_tag()20
# ---
# 主线程Thread-4停止
# 主线程Thread-5停止
# 爬取时间: 540.9446504116058
