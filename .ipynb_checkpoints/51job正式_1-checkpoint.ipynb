# %%
import requests
from bs4 import BeautifulSoup
import queue
import threading
import re
import csv
import functools
import os
from time import time

# %%
lock = threading.Lock()

# %%
# 获取函数运行时间装饰器
def excute_time(func):
    @functools.wraps(func)
    def wrapper(*args, **kwargs):
        start = time()
        result = func(*args, **kwargs)
        spend = time() - start
        print('%s() 运行时间: %d' % (func.__name__, spend))
        thread_num = ''
        if 'thread_num' in kwargs:
            thread_num = kwargs['thread_num']
        
        # 运行时间写入文件
        headers = ['函数', '运行时间', '线程数']
        if os.path.isfile('运行时间统计.csv'):
            with open('运行时间统计.csv', 'a', newline='') as f:
                writer = csv.DictWriter(f, headers)
                data = {'函数':func.__name__, '运行时间':spend, '线程数':thread_num}
                writer.writerow(data)
        else:
            with open('运行时间统计.csv', 'a', newline='') as f:
                writer = csv.DictWriter(f, headers)
                writer.writeheader()
                data = {'函数':func.__name__, '运行时间':spend, '线程数':thread_num}
                writer.writerow(data)
            
        return result
    return wrapper

# %%
class jobObject:
    'job描述对象'
    __slots__ = ('tag_href', 'job', 'company', 'address', 'salary', 'tag')

# %%
def ipToQueue():
    q = queue.Queue()
    url = 'https://free-proxy-list.net/'
    r = requests.get(url)
    html = r.text
    soup = BeautifulSoup(html, features='html5lib')
    div_tag = soup.find('div', 'table-responsive')
    tbody_list = div_tag.tbody.contents
    result = ''
    for tr in tbody_list:
        ip = tr.next_element.string
        port = tr.next_element.next_sibling.string
        result = ip + ':' + port
        q.put(result)

    return q

# %%
def getIPool(ip_queue):
    proxies = queue.Queue()

    flag = True
    while flag:
        ip = ip_queue.get()
        proxy = {'http': ip, 'https': ip}
        proxies.put(proxy)
        if ip_queue.qsize()==0:
            flag = False

    return proxies

# %%
def getCleanProxies(proxies, **thread_num):
    #     url = 'http://www.baidu.com'
    url = 'https://jobs.51job.com/'

    # 有效的ip队列
    ok_proxies = queue.Queue()

    def check_proxy(thread_proxies):

        thread_proxies_size = thread_proxies.qsize()

        for i in range(thread_proxies_size):
            thread_proxies_size = thread_proxies.qsize()
            print('%s : 当前剩余处理的ip: %d' % (threading.current_thread().name, thread_proxies_size))

            # 如果当前ip为0退出当前线程
            if (thread_proxies_size == 0):
                break

            proxy = thread_proxies.get()
            try:
                r = requests.get(url, proxies=proxy, timeout=5)
                print(threading.current_thread().name + ' is processing')
                print('r.status_code:', r.status_code)
                if (r.status_code != 200):
                    print('remove proxy:', proxy)
                else:
                    ok_proxies.put(proxy)

                print('-------------------------------------')

            except requests.Timeout as e:
                print(threading.current_thread().name + ' is processing')
                print(e)
                print('remove proxy:', proxy)
                print('-------------------------------------')
            except requests.ConnectionError as e:
                print(threading.current_thread().name + ' is processing')
                print(e)
                print('remove proxy:', proxy)
                print('-------------------------------------')
            except requests.InvalidHeader as e:
                print(threading.current_thread().name + ' is processing')
                print(e)
                print('remove proxy:', proxy)
                print('-------------------------------------')


    threads = []

    for i in range(thread_num.get('thread_num')):
        thread = threading.Thread(target=check_proxy, args=(proxies,))
        threads.append(thread)

    print('线程开始：')
    for thread in threads:
        print(thread.name + '开始运行')
        thread.start()

    # 每次在剩余处理ip为0之后，程序就会停住不动
    # 当当前线程检测到剩余ip为0后，调用join()方法
    print('线程开始停止运行：')
    for thread in threads:
        thread.join()
        print(thread.name + '已停止')

    return ok_proxies

# %%
@excute_time
def get_jobObjectList(url):
    global proxy
    
    flag = True
    
    # TODO 查看信息
    print('get_jobObjectList()当前处理链接:', url)
    while flag:
        try:
            r = requests.get(url, proxies=proxy, timeout=5)
            # 报了异常的话捕捉了之后
            # 获得新的proxy之后就直接开始下次循环
        except requests.exceptions.Timeout as e:
            print(e)
            proxy = getProxy()
            print('尝试新的proxy')
            #print('----------------------')
            continue
        except requests.exceptions.ProxyError as e:
            print(e)
            proxy = getProxy()
            print('尝试新的proxy')
            #print('----------------------')
            continue
        except requests.exceptions.ConnectionError as e:
            print(e)
            proxy = getProxy()
            print('尝试新的proxy')
            #print('----------------------')
            continue
        
        # 不报异常就取消循环
        flag = False

    
    
    r.encoding = 'gbk'
    html = r.text
    soup = BeautifulSoup(html, features='html5lib')
    # 找到了工作列表的开头
    title = soup.find('div', 'el title')
    # 找到每一个工作列，它们分别是一个div class='el'
    job_info_list = title.find_next_siblings('div', 'el')

    # 存放当前页jobObject对象到jobObjectList中
    jobObjectList = []
    for tag in job_info_list:
        object = jobObject()
        object.tag_href = tag.find('a').attrs['href']
        object.job = tag.find('a').attrs['title']

        infos = tag.find_all(class_=re.compile('t[2-4]'))
        object.company = infos[0].string
        object.address = infos[1].string
        object.salary = infos[2].string
        jobObjectList.append(object)
    
    print('get_jobObjectList处理完成!')

    return jobObjectList

# %%
@excute_time
def getTag(url):
    tag_url = url
    global proxy
    
    # 存储标签的List
    tag_list = []
    flag = True

    # TODO 查看信息
    print('getTag()当前处理链接:', tag_url)
    print('getTag()获得的ip:', proxy)
    while flag:
        #     headers = {'user-agent','Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/66.0.3359.181 Chrome/66.0.3359.181 Safari/537.36'}
        try:
            r_tag = requests.get(tag_url, timeout=5, proxies=proxy)

        # 报了异常的话捕捉了之后
        # 获得新的proxy之后就直接开始下次循环
        except requests.exceptions.Timeout as e:
            print(e)
            proxy = getProxy()
            print('尝试新的proxy')
            #print('----------------------')
            continue
        except requests.exceptions.ProxyError as e:
            print(e)
            proxy = getProxy()
            print('尝试新的proxy')
            #print('----------------------')
            continue
        except requests.exceptions.ConnectionError as e:
            print(e)
            proxy = getProxy()
            print('尝试新的proxy')
            #print('----------------------')
            continue
        # 不报异常就取消循环
        flag = False

    r_tag.encoding = 'gbk'
    tag_html = r_tag.text
    tag_soup = BeautifulSoup(tag_html, features='html5lib')

    # 找到详情页第一行标签
    tag_1 = tag_soup.find_all('span', 'sp4')
    for i in tag_1:
        tag_list.append(i.contents[1])

    # 找到详情页第二行标签
    tag_2 = tag_soup.find('p', 't2')

    # 有些详情页没有第二行标签
    if tag_2 is None:
        print('getTag()中tag_list:', tag_list)
        print('----------------------')
        return tag_list

    ll = []
    for i in tag_2.strings:
        ll.append(i)

    # 清除ll中的空值
    def not_empty(s):
        return s and s.strip()

    for i in filter(not_empty, ll):
        tag_list.append(i)

    print('getTag()中tag_list:', tag_list)
    print('----------------------')

    return tag_list

# %%
@excute_time
def pack_tag(jobObjectList, **thread_num):
    jobObject_queue = queue.Queue()
    
    for jobObject in jobObjectList:
        jobObject_queue.put(jobObject)
    
    def pack_object(jobObject_queue):
        flag = True
        while flag:
            jobObject = jobObject_queue.get()
            jobObject.tag = getTag(jobObject.tag_href)
            if jobObject_queue.qsize() == 0:
                flag = False
            
    
    threads = []
    
#     print('thread_num.get(\'thread_num\'): ', thread_num.get('thread_num'))
    
    for i in range(thread_num.get('thread_num')):
        thread = threading.Thread(target=pack_object, args=(jobObject_queue,))
        threads.append(thread)
    
    for thread in threads:
        thread.start()
        
        
    for thread in threads:
        thread.join()
        print('%s 已停止' % thread.name)
    

    print('tag组装完成!')

# %%
def save_to_csv(jobObjectList):
    headers = ['职位', '公司', '地址', '薪酬', '标签']
    datas = []

    for jobObject in jobObjectList:
        data = {headers[0]: jobObject.job,
                headers[1]: jobObject.company,
                headers[2]: jobObject.address,
                headers[3]: jobObject.salary,
                headers[4]: jobObject.tag}
        datas.append(data)
        
    if os.path.isfile('51job.csv'):
        with open('51job.csv', 'a', newline='') as f:
            writer = csv.DictWriter(f, headers)
            for row in datas:
                writer.writerow(row)
    else:
        with open('51job.csv', 'a', newline='') as f:
            writer = csv.DictWriter(f, headers)
            writer.writeheader()
            for row in datas:
                writer.writerow(row)

# %%
def handle_single(url, proxy):
    jobObjectList = get_jobObjectList(url)
    pack_tag(jobObjectList, thread_num=20)
    save_to_csv(jobObjectList)

# %%
# 获取proxy
# 当队列中的proxy用完了的时候在获取新的proxies
# 不是每次线程启动就获取新的proxies
# 当一个proxy不能用了才能获取新的proxy
def getProxy():
    global proxies
    
    lock.acquire()
    if proxies.qsize()==0:
        proxies = getProxies()
    lock.release()
        
    proxy = proxies.get()
    print('###当前proxies的ip数: ', proxies.qsize())
    return proxy
    

def getProxies():
    # 多线程的话，就不保存在本地文件
    # 应该保存在各自线程的queue里面s
    ip_start = time()
    ip_queue = ipToQueue()
    proxies = getIPool(ip_queue)
    proxies = getCleanProxies(proxies, thread_num=45)
    ip_result = time() - ip_start
    print('可用的ip: ', proxies.qsize())
    print('%s清洗ip的时间: %d' % (threading.current_thread().name, ip_result))
    return proxies

# %%
# 全局变量
proxies = getProxies()
proxy= getProxy()
# Out:
# 线程开始：
# Thread-4开始运行
# Thread-4 : 当前剩余处理的ip: 300Thread-5开始运行
#
# Thread-5 : 当前剩余处理的ip: 299Thread-6开始运行
#
# Thread-6 : 当前剩余处理的ip: 298Thread-7开始运行
#
# Thread-7 : 当前剩余处理的ip: 297Thread-8开始运行
#
# Thread-8 : 当前剩余处理的ip: 296Thread-9开始运行
#
# Thread-9 : 当前剩余处理的ip: 295Thread-10开始运行
#
# Thread-10 : 当前剩余处理的ip: 294Thread-11开始运行
#
# Thread-11 : 当前剩余处理的ip: 293Thread-12开始运行
#
# Thread-12 : 当前剩余处理的ip: 292Thread-13开始运行
#
# Thread-13 : 当前剩余处理的ip: 291Thread-14开始运行
#
# Thread-14 : 当前剩余处理的ip: 290Thread-15开始运行
#
# Thread-15 : 当前剩余处理的ip: 289Thread-16开始运行
#
# Thread-16 : 当前剩余处理的ip: 288Thread-17开始运行
#
# Thread-17 : 当前剩余处理的ip: 287Thread-18开始运行
#
# Thread-18 : 当前剩余处理的ip: 286Thread-19开始运行
#
# Thread-19 : 当前剩余处理的ip: 285Thread-20开始运行
#
# Thread-20 : 当前剩余处理的ip: 284Thread-21开始运行
#
# Thread-21 : 当前剩余处理的ip: 283Thread-22开始运行
#
# Thread-22 : 当前剩余处理的ip: 282Thread-23开始运行
#
# Thread-23 : 当前剩余处理的ip: 281Thread-24开始运行
#
# Thread-24 : 当前剩余处理的ip: 280Thread-25开始运行
#
# Thread-25 : 当前剩余处理的ip: 279Thread-26开始运行
#
# Thread-26 : 当前剩余处理的ip: 278Thread-27开始运行
#
# Thread-27 : 当前剩余处理的ip: 277Thread-28开始运行
#
# Thread-28 : 当前剩余处理的ip: 276Thread-29开始运行
#
# Thread-29 : 当前剩余处理的ip: 275Thread-30开始运行
#
# Thread-30 : 当前剩余处理的ip: 274Thread-31开始运行
#
# Thread-31 : 当前剩余处理的ip: 273Thread-32开始运行
#
# Thread-32 : 当前剩余处理的ip: 272Thread-33开始运行
#
# Thread-33 : 当前剩余处理的ip: 271Thread-34开始运行
#
# Thread-34 : 当前剩余处理的ip: 270Thread-35开始运行
#
# Thread-35 : 当前剩余处理的ip: 269Thread-36开始运行
#
# Thread-36 : 当前剩余处理的ip: 268Thread-37开始运行
#
# Thread-37 : 当前剩余处理的ip: 267Thread-38开始运行
#
# Thread-38 : 当前剩余处理的ip: 266Thread-39开始运行
#
# Thread-39 : 当前剩余处理的ip: 265Thread-40开始运行
#
# Thread-40 : 当前剩余处理的ip: 264Thread-41开始运行
#
# Thread-41 : 当前剩余处理的ip: 263Thread-42开始运行
#
# Thread-42 : 当前剩余处理的ip: 262Thread-43开始运行
#
# Thread-43 : 当前剩余处理的ip: 261Thread-44开始运行
#
# Thread-44 : 当前剩余处理的ip: 260Thread-45开始运行
#
# Thread-45 : 当前剩余处理的ip: 259Thread-46开始运行
#
# Thread-46 : 当前剩余处理的ip: 258Thread-47开始运行
#
# Thread-47 : 当前剩余处理的ip: 257Thread-48开始运行
#
# Thread-48 : 当前剩余处理的ip: 256线程开始停止运行：
#
# Thread-30 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response',)))
# remove proxy: {'http': '122.102.39.9:53281', 'https': '122.102.39.9:53281'}
# -------------------------------------
# Thread-30 : 当前剩余处理的ip: 255
# Thread-21 is processing
# r.status_code: 200
# -------------------------------------
# Thread-21 : 当前剩余处理的ip: 254
# Thread-20 is processing
# r.status_code: 200
# -------------------------------------
# Thread-20 : 当前剩余处理的ip: 253
# Thread-44 is processing
# r.status_code: 200
# -------------------------------------
# Thread-44 : 当前剩余处理的ip: 252
# Thread-45 is processing
# r.status_code: 200
# -------------------------------------
# Thread-45 : 当前剩余处理的ip: 251
# Thread-19 is processing
# r.status_code: 200
# -------------------------------------
# Thread-19 : 当前剩余处理的ip: 250
# Thread-48 is processingThread-41 is processing
# r.status_code:
#  r.status_code:200
#  -------------------------------------200
# -------------------------------------
# Thread-48 : 当前剩余处理的ip: 249
# Thread-41 : 当前剩余处理的ip: 249
#
# Thread-33 is processing
# r.status_code: 200
# -------------------------------------
# Thread-33 : 当前剩余处理的ip: 247
# Thread-23 is processing
# r.status_code: 200
# -------------------------------------
# Thread-23 : 当前剩余处理的ip: 246
# Thread-10 is processing
# r.status_code: 200
# -------------------------------------
# Thread-10 : 当前剩余处理的ip: 245
# Thread-18 is processing
# r.status_code: 200
# -------------------------------------
# Thread-18 : 当前剩余处理的ip: 244
# Thread-8 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f398c566198>, 'Connection to 95.174.206.18 timed out. (connect timeout=5)'))
# remove proxy: {'http': '95.174.206.18:8080', 'https': '95.174.206.18:8080'}
# -------------------------------------
# Thread-8 : 当前剩余处理的ip: 243
# Thread-13 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f398c57ca20>, 'Connection to 68.7.138.66 timed out. (connect timeout=5)'))
# remove proxy: {'http': '68.7.138.66:8080', 'https': '68.7.138.66:8080'}
# -------------------------------------
# Thread-13 : 当前剩余处理的ip: 242
# Thread-11 is processing
# r.status_code: 200
# -------------------------------------
# Thread-11 : 当前剩余处理的ip: 241
# Thread-16 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f398c51a438>, 'Connection to 91.225.56.117 timed out. (connect timeout=5)'))
# remove proxy: {'http': '91.225.56.117:31222', 'https': '91.225.56.117:31222'}
# -------------------------------------
# Thread-16 : 当前剩余处理的ip: 240
# Thread-32 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f398c4fc668>, 'Connection to 27.116.51.106 timed out. (connect timeout=5)'))
# remove proxy: {'http': '27.116.51.106:6666', 'https': '27.116.51.106:6666'}
# -------------------------------------
# Thread-32 : 当前剩余处理的ip: 239
# Thread-17 is processing
# r.status_code: 200
# -------------------------------------
# Thread-17 : 当前剩余处理的ip: 238
# Thread-46 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f398c457be0>, 'Connection to 77.85.169.25 timed out. (connect timeout=5)'))
# remove proxy: {'http': '77.85.169.25:8080', 'https': '77.85.169.25:8080'}
# -------------------------------------
# Thread-46 : 当前剩余处理的ip: 237
# Thread-47 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f398c463470>, 'Connection to 103.206.201.18 timed out. (connect timeout=5)'))
# remove proxy: {'http': '103.206.201.18:8080', 'https': '103.206.201.18:8080'}
# -------------------------------------
# Thread-47 : 当前剩余处理的ip: 236
# Thread-32 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 400 Bad Request',)))
# remove proxy: {'http': '47.75.160.192:80', 'https': '47.75.160.192:80'}
# -------------------------------------
# Thread-32 : 当前剩余处理的ip: 235
# Thread-8 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response',)))
# remove proxy: {'http': '113.53.151.228:8080', 'https': '113.53.151.228:8080'}
# -------------------------------------
# Thread-8 : 当前剩余处理的ip: 234
# Thread-7 is processingThread-27 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '177.86.203.61:53281', 'https': '177.86.203.61:53281'}
# -------------------------------------
# Thread-27 : 当前剩余处理的ip: 233
#
# r.status_code: 200
# -------------------------------------
# Thread-7 : 当前剩余处理的ip: 232
# Thread-27 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 400 Bad Request',)))
# remove proxy: {'http': '13.115.179.194:80', 'https': '13.115.179.194:80'}
# -------------------------------------
# Thread-27 : 当前剩余处理的ip: 231
# Thread-32 is processing
# ('Connection aborted.', BadStatusLine('<html>\r\n',))
# remove proxy: {'http': '50.93.200.237:2018', 'https': '50.93.200.237:2018'}
# -------------------------------------
# Thread-32 : 当前剩余处理的ip: 230
# Thread-24 is processing
# r.status_code: 200
# -------------------------------------
# Thread-24 : 当前剩余处理的ip: 229
# Thread-42 is processing
# r.status_code: 200
# -------------------------------------
# Thread-42 : 当前剩余处理的ip: 228
# Thread-34 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '168.194.155.19:53281', 'https': '168.194.155.19:53281'}
# -------------------------------------
# Thread-34 : 当前剩余处理的ip: 227
# Thread-43 is processing
# r.status_code: 200
# -------------------------------------
# Thread-43 : 当前剩余处理的ip: 226
# Thread-5 is processing
# r.status_code: 200
# -------------------------------------
# Thread-5 : 当前剩余处理的ip: 225
# Thread-28 is processing
# r.status_code: 200
# -------------------------------------
# Thread-28 : 当前剩余处理的ip: 224
# Thread-26 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '24.247.62.169:53281', 'https': '24.247.62.169:53281'}
# -------------------------------------
# Thread-26 : 当前剩余处理的ip: 223
# Thread-13 is processing
# r.status_code: 200
# -------------------------------------
# Thread-13 : 当前剩余处理的ip: 222
# Thread-22 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '41.204.242.174:8080', 'https': '41.204.242.174:8080'}
# -------------------------------------
# Thread-22 : 当前剩余处理的ip: 221
# Thread-17 is processing
# r.status_code: 200
# -------------------------------------
# Thread-17 : 当前剩余处理的ip: 220
# Thread-31 is processing
# r.status_code: 200
# -------------------------------------
# Thread-31 : 当前剩余处理的ip: 219
# Thread-15 is processing
# r.status_code: 200
# -------------------------------------
# Thread-15 : 当前剩余处理的ip: 218
# Thread-24 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '159.65.45.64:8080', 'https': '159.65.45.64:8080'}
# -------------------------------------
# Thread-24 : 当前剩余处理的ip: 217
# Thread-14 is processing
# r.status_code: 200
# -------------------------------------
# Thread-14 : 当前剩余处理的ip: 216
# Thread-4 is processing
# r.status_code: 200
# -------------------------------------
# Thread-4 : 当前剩余处理的ip: 215
# Thread-35 is processingThread-34 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '174.138.5.199:8080', 'https': '174.138.5.199:8080'}
# -------------------------------------
# Thread-34 : 当前剩余处理的ip: 214
#
# r.status_code: 200
# -------------------------------------
# Thread-35 : 当前剩余处理的ip: 213
# Thread-42 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '80.211.181.37:3128', 'https': '80.211.181.37:3128'}
# -------------------------------------
# Thread-42 : 当前剩余处理的ip: 212
# Thread-25 is processing
# r.status_code: 200
# -------------------------------------
# Thread-25 : 当前剩余处理的ip: 211
# Thread-6 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '79.190.126.186:8080', 'https': '79.190.126.186:8080'}
# -------------------------------------
# Thread-6 : 当前剩余处理的ip: 210
# Thread-35 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f398c58b048>: Failed to establish a new connection: [Errno 111] Connection refused',)))
# remove proxy: {'http': '159.89.184.107:80', 'https': '159.89.184.107:80'}
# -------------------------------------
# Thread-35 : 当前剩余处理的ip: 209
# Thread-15 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 ',)))
# remove proxy: {'http': '190.94.102.4:8081', 'https': '190.94.102.4:8081'}
# -------------------------------------
# Thread-15 : 当前剩余处理的ip: 208
# Thread-38 is processing
# r.status_code: 200
# -------------------------------------
# Thread-38 : 当前剩余处理的ip: 207
# Thread-5 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 500 Internal Server Error',)))
# remove proxy: {'http': '37.187.116.199:80', 'https': '37.187.116.199:80'}
# -------------------------------------
# Thread-5 : 当前剩余处理的ip: 206
# Thread-25 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '66.70.190.244:8080', 'https': '66.70.190.244:8080'}
# -------------------------------------
# Thread-25 : 当前剩余处理的ip: 205
# Thread-6 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '159.203.172.125:8080', 'https': '159.203.172.125:8080'}
# -------------------------------------
# Thread-6 : 当前剩余处理的ip: 204
# Thread-29 is processing
# r.status_code: 200
# -------------------------------------
# Thread-29 : 当前剩余处理的ip: 203
# Thread-6 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f398d5ccdd8>: Failed to establish a new connection: [Errno 111] Connection refused',)))
# remove proxy: {'http': '87.255.27.163:3128', 'https': '87.255.27.163:3128'}
# -------------------------------------
# Thread-6 : 当前剩余处理的ip: 202
# Thread-18 is processing
# r.status_code: 200
# -------------------------------------
# Thread-18 : 当前剩余处理的ip: 201
# Thread-31 is processing
# r.status_code: 200
# -------------------------------------
# Thread-31 : 当前剩余处理的ip: 200
# Thread-38 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# remove proxy: {'http': '182.72.74.51:3128', 'https': '182.72.74.51:3128'}
# -------------------------------------
# Thread-38 : 当前剩余处理的ip: 199
# Thread-21 is processing
# r.status_code: 200
# -------------------------------------
# Thread-21 : 当前剩余处理的ip: 198
# Thread-44 is processing
# r.status_code: 200
# -------------------------------------
# Thread-44 : 当前剩余处理的ip: 197
# Thread-13 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 502 Bad Gateway',)))
# remove proxy: {'http': '109.70.186.247:8080', 'https': '109.70.186.247:8080'}
# -------------------------------------
# Thread-13 : 当前剩余处理的ip: 196
# Thread-30 is processing
# r.status_code: 200
# -------------------------------------
# Thread-30 : 当前剩余处理的ip: 195
# Thread-32 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 500 Internal Server Error',)))
# remove proxy: {'http': '195.201.138.167:80', 'https': '195.201.138.167:80'}
# -------------------------------------
# Thread-32 : 当前剩余处理的ip: 194
# Thread-16 is processing
# r.status_code: 200
# -------------------------------------
# Thread-16 : 当前剩余处理的ip: 193
# Thread-16 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f398c3c7a58>: Failed to establish a new connection: [Errno 111] Connection refused',)))
# remove proxy: {'http': '183.88.106.12:8080', 'https': '183.88.106.12:8080'}
# -------------------------------------
# Thread-16 : 当前剩余处理的ip: 192
# Thread-36 is processing
# r.status_code: 200
# -------------------------------------
# Thread-36 : 当前剩余处理的ip: 191
# Thread-17 is processing
# r.status_code: 200
# -------------------------------------
# Thread-17 : 当前剩余处理的ip: 190
# Thread-26 is processing
# r.status_code: 200
# -------------------------------------
# Thread-26 : 当前剩余处理的ip: 189
# Thread-46 is processing
# r.status_code: 200
# -------------------------------------
# Thread-46 : 当前剩余处理的ip: 188
# Thread-31 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 502 Bad Gateway',)))
# remove proxy: {'http': '95.167.177.19:8080', 'https': '95.167.177.19:8080'}
# -------------------------------------
# Thread-31 : 当前剩余处理的ip: 187
# Thread-45 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f398c4412e8>, 'Connection to 46.0.203.186 timed out. (connect timeout=5)'))
# remove proxy: {'http': '46.0.203.186:8080', 'https': '46.0.203.186:8080'}
# -------------------------------------
# Thread-45 : 当前剩余处理的ip: 186
# Thread-19 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f398c441550>, 'Connection to 83.221.215.205 timed out. (connect timeout=5)'))
# remove proxy: {'http': '83.221.215.205:8080', 'https': '83.221.215.205:8080'}
# -------------------------------------
# Thread-19 : 当前剩余处理的ip: 185
# Thread-41 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f398c472860>, 'Connection to 46.164.158.166 timed out. (connect timeout=5)'))
# remove proxy: {'http': '46.164.158.166:8080', 'https': '46.164.158.166:8080'}
# -------------------------------------
# Thread-41 : 当前剩余处理的ip: 184
# Thread-43 is processing
# r.status_code: 200
# -------------------------------------
# Thread-43 : 当前剩余处理的ip: 183
# Thread-20 is processing
# r.status_code:Thread-48 is processing 200
# -------------------------------------
# Thread-20 : 当前剩余处理的ip: 182
#
# r.status_code: 200
# -------------------------------------
# Thread-48 : 当前剩余处理的ip: 181
# Thread-18 is processing
# r.status_code: 200
# -------------------------------------
# Thread-18 : 当前剩余处理的ip: 180
# Thread-20 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f398c463908>: Failed to establish a new connection: [Errno 113] No route to host',)))
# remove proxy: {'http': '87.252.107.84:41258', 'https': '87.252.107.84:41258'}
# -------------------------------------
# Thread-20 : 当前剩余处理的ip: 179
# Thread-11 is processing
# r.status_code: 200
# -------------------------------------
# Thread-11 : 当前剩余处理的ip: 178
# Thread-9 is processing
# r.status_code: 200
# -------------------------------------
# Thread-9 : 当前剩余处理的ip: 177
# Thread-8 is processing
# r.status_code: 200
# -------------------------------------
# Thread-8 : 当前剩余处理的ip: 176
# Thread-45 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 404 Not Found',)))
# remove proxy: {'http': '92.51.201.118:8080', 'https': '92.51.201.118:8080'}
# -------------------------------------
# Thread-45 : 当前剩余处理的ip: 175
# Thread-25 is processing
# r.status_code: 200
# -------------------------------------
# Thread-25 : 当前剩余处理的ip: 174
# Thread-23 is processing
# r.status_code: 200
# -------------------------------------
# Thread-23 : 当前剩余处理的ip: 173
# Thread-24 is processing
# r.status_code: 200
# -------------------------------------
# Thread-24 : 当前剩余处理的ip: 172
# Thread-15 is processing
# r.status_code: 200
# -------------------------------------
# Thread-15 : 当前剩余处理的ip: 171
# Thread-8 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f398c424dd8>: Failed to establish a new connection: [Errno 113] No route to host',)))
# remove proxy: {'http': '103.41.147.235:8080', 'https': '103.41.147.235:8080'}
# -------------------------------------
# Thread-8 : 当前剩余处理的ip: 170
# Thread-12 is processing
# r.status_code: 200
# -------------------------------------
# Thread-12 : 当前剩余处理的ip: 169
# Thread-7 is processing
# r.status_code: 200
# -------------------------------------
# Thread-7 : 当前剩余处理的ip: 168
# Thread-28 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '113.161.90.156:3128', 'https': '113.161.90.156:3128'}
# -------------------------------------
# Thread-28 : 当前剩余处理的ip: 167
# Thread-22 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f398c53e358>, 'Connection to 187.44.136.226 timed out. (connect timeout=5)'))
# remove proxy: {'http': '187.44.136.226:53281', 'https': '187.44.136.226:53281'}
# -------------------------------------
# Thread-22 : 当前剩余处理的ip: 166
# Thread-40 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Read timed out.
# remove proxy: {'http': '103.73.166.77:8080', 'https': '103.73.166.77:8080'}
# -------------------------------------
# Thread-40 : 当前剩余处理的ip: 165
# Thread-47 is processing
# r.status_code: 200
# -------------------------------------
# Thread-47 : 当前剩余处理的ip: 164
# Thread-10 is processing
# r.status_code: 200
# -------------------------------------
# Thread-10 : 当前剩余处理的ip: 163
# Thread-39 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '81.211.23.6:3128', 'https': '81.211.23.6:3128'}
# -------------------------------------
# Thread-39 : 当前剩余处理的ip: 162
# Thread-21 is processing
# r.status_code: 200
# -------------------------------------
# Thread-21 : 当前剩余处理的ip: 161
# Thread-26 is processing
# r.status_code: 200
# -------------------------------------
# Thread-26 : 当前剩余处理的ip: 160
# Thread-34 is processing
# r.status_code: 200
# -------------------------------------
# Thread-34 : 当前剩余处理的ip: 159
# Thread-29 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '185.93.3.70:8080', 'https': '185.93.3.70:8080'}
# -------------------------------------
# Thread-29 : 当前剩余处理的ip: 158
# Thread-6 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '192.111.151.233:80', 'https': '192.111.151.233:80'}
# -------------------------------------
# Thread-6 : 当前剩余处理的ip: 157
# Thread-27 is processing
# r.status_code: 200
# -------------------------------------
# Thread-27 : 当前剩余处理的ip: 156
# Thread-45 is processing
# r.status_code: 200
# -------------------------------------
# Thread-45 : 当前剩余处理的ip: 155
# Thread-20 is processing
# r.status_code: 200
# -------------------------------------
# Thread-20 : 当前剩余处理的ip: 154
# Thread-44 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '150.129.207.74:6666', 'https': '150.129.207.74:6666'}
# -------------------------------------
# Thread-44 : 当前剩余处理的ip: 153
# Thread-35 is processing
# r.status_code: 200
# -------------------------------------
# Thread-35 : 当前剩余处理的ip: 152
# Thread-7 is processing
# r.status_code: 200
# -------------------------------------
# Thread-7 : 当前剩余处理的ip: 151
# Thread-16 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f398c3f05f8>, 'Connection to 176.108.233.88 timed out. (connect timeout=5)'))
# remove proxy: {'http': '176.108.233.88:53281', 'https': '176.108.233.88:53281'}
# -------------------------------------
# Thread-16 : 当前剩余处理的ip: 150
# Thread-7 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f398c40e208>: Failed to establish a new connection: [Errno 111] Connection refused',)))
# remove proxy: {'http': '35.184.109.90:3128', 'https': '35.184.109.90:3128'}
# -------------------------------------
# Thread-7 : 当前剩余处理的ip: 149
# Thread-12 is processing
# r.status_code: 200
# -------------------------------------
# Thread-12 : 当前剩余处理的ip: 148
# Thread-42 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Read timed out. (read timeout=5)
# remove proxy: {'http': '185.155.66.1:53281', 'https': '185.155.66.1:53281'}
# -------------------------------------
# Thread-42 : 当前剩余处理的ip: 147
# Thread-46 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f398c35b278>, 'Connection to 79.165.22.225 timed out. (connect timeout=5)'))
# remove proxy: {'http': '79.165.22.225:53281', 'https': '79.165.22.225:53281'}
# -------------------------------------
# Thread-46 : 当前剩余处理的ip: 146
# Thread-31 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f398c39fb38>, 'Connection to 191.242.173.64 timed out. (connect timeout=5)'))
# remove proxy: {'http': '191.242.173.64:20183', 'https': '191.242.173.64:20183'}
# -------------------------------------
# Thread-31 : 当前剩余处理的ip: 145
# Thread-13 is processing
# r.status_code: 200
# -------------------------------------
# Thread-13 : 当前剩余处理的ip: 144
# Thread-8 is processing
# r.status_code: 200
# -------------------------------------
# Thread-8 : 当前剩余处理的ip: 143
# Thread-43 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '54.39.20.31:3128', 'https': '54.39.20.31:3128'}
# -------------------------------------
# Thread-43 : 当前剩余处理的ip: 142
# Thread-48 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f398c436160>, 'Connection to 185.155.32.112 timed out. (connect timeout=5)'))
# remove proxy: {'http': '185.155.32.112:41258', 'https': '185.155.32.112:41258'}
# -------------------------------------
# Thread-48 : 当前剩余处理的ip: 141
# Thread-43 is processing
# ('Connection aborted.', BadStatusLine('<html>\r\n',))
# remove proxy: {'http': '47.90.87.225:88', 'https': '47.90.87.225:88'}
# -------------------------------------
# Thread-43 : 当前剩余处理的ip: 140
# Thread-11 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f398c3b5390>, 'Connection to 83.164.222.177 timed out. (connect timeout=5)'))
# remove proxy: {'http': '83.164.222.177:8080', 'https': '83.164.222.177:8080'}
# -------------------------------------
# Thread-11 : 当前剩余处理的ip: 139
# Thread-25 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f398c4fc860>, 'Connection to 41.58.188.122 timed out. (connect timeout=5)'))
# remove proxy: {'http': '41.58.188.122:8080', 'https': '41.58.188.122:8080'}
# -------------------------------------
# Thread-25 : 当前剩余处理的ip: 138
# Thread-48 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 400 Bad Request',)))
# remove proxy: {'http': '54.38.56.252:80', 'https': '54.38.56.252:80'}
# -------------------------------------
# Thread-48 : 当前剩余处理的ip: 137
# Thread-23 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f398c53e9b0>, 'Connection to 103.77.252.97 timed out. (connect timeout=5)'))
# remove proxy: {'http': '103.77.252.97:8080', 'https': '103.77.252.97:8080'}
# -------------------------------------
# Thread-23 : 当前剩余处理的ip: 136
# Thread-4 is processing
# r.status_code: 200
# -------------------------------------
# Thread-4 : 当前剩余处理的ip: 135
# Thread-24 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f398c40e8d0>, 'Connection to 84.27.174.183 timed out. (connect timeout=5)'))
# remove proxy: {'http': '84.27.174.183:8080', 'https': '84.27.174.183:8080'}
# -------------------------------------
# Thread-24 : 当前剩余处理的ip: 134
# Thread-23 is processing
# ('Connection aborted.', BadStatusLine('<html>\r\n',))
# remove proxy: {'http': '113.254.114.24:80', 'https': '113.254.114.24:80'}
# -------------------------------------
# Thread-23 : 当前剩余处理的ip: 133
# Thread-21 is processing
# r.status_code: 200
# -------------------------------------
# Thread-21 : 当前剩余处理的ip: 132
# Thread-43 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '191.252.100.125:80', 'https': '191.252.100.125:80'}
# -------------------------------------
# Thread-43 : 当前剩余处理的ip: 131
# Thread-5 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '45.115.60.7:8080', 'https': '45.115.60.7:8080'}
# -------------------------------------
# Thread-5 : 当前剩余处理的ip: 130
# Thread-14 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '41.169.3.51:8080', 'https': '41.169.3.51:8080'}
# -------------------------------------
# Thread-14 : 当前剩余处理的ip: 129
# Thread-28 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f398c39af28>, 'Connection to 14.102.81.195 timed out. (connect timeout=5)'))
# remove proxy: {'http': '14.102.81.195:53281', 'https': '14.102.81.195:53281'}
# -------------------------------------
# Thread-28 : 当前剩余处理的ip: 128
# Thread-9 is processing
# r.status_code: 200
# -------------------------------------
# Thread-9 : 当前剩余处理的ip: 127
# Thread-28 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 400 Bad Request',)))
# remove proxy: {'http': '47.89.241.103:8080', 'https': '47.89.241.103:8080'}
# -------------------------------------
# Thread-28 : 当前剩余处理的ip: 126
# Thread-5 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '159.203.33.72:3128', 'https': '159.203.33.72:3128'}
# -------------------------------------
# Thread-5 : 当前剩余处理的ip: 125
# Thread-20 is processing
# r.status_code: 200
# -------------------------------------
# Thread-20 : 当前剩余处理的ip: 124
# Thread-46 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 502 Bad Gateway',)))
# remove proxy: {'http': '217.119.82.14:8080', 'https': '217.119.82.14:8080'}
# -------------------------------------
# Thread-46 : 当前剩余处理的ip: 123
# Thread-47 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f398c46e2e8>, 'Connection to 190.52.130.32 timed out. (connect timeout=5)'))
# remove proxy: {'http': '190.52.130.32:8080', 'https': '190.52.130.32:8080'}
# -------------------------------------
# Thread-47 : 当前剩余处理的ip: 122
# Thread-32 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '186.42.172.50:53281', 'https': '186.42.172.50:53281'}
# -------------------------------------
# Thread-32 : 当前剩余处理的ip: 121
# Thread-30 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '109.105.208.152:53281', 'https': '109.105.208.152:53281'}
# -------------------------------------
# Thread-30 : 当前剩余处理的ip: 120
# Thread-5 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', ConnectionResetError(104, 'Connection reset by peer')))
# remove proxy: {'http': '80.48.119.28:8080', 'https': '80.48.119.28:8080'}
# -------------------------------------
# Thread-5 : 当前剩余处理的ip: 119
# Thread-29 is processing
# r.status_code: 200
# -------------------------------------
# Thread-29 : 当前剩余处理的ip: 118
# Thread-13 is processing
# r.status_code: 200
# -------------------------------------
# Thread-13 : 当前剩余处理的ip: 117
# Thread-33 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '41.79.197.150:8080', 'https': '41.79.197.150:8080'}
# -------------------------------------
# Thread-33 : 当前剩余处理的ip: 116
# Thread-38 is processing
# r.status_code: 200
# -------------------------------------
# Thread-38 : 当前剩余处理的ip: 115
# Thread-38 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 500 Internal Server Error',)))
# remove proxy: {'http': '108.61.186.207:8080', 'https': '108.61.186.207:8080'}
# -------------------------------------
# Thread-38 : 当前剩余处理的ip: 114
# Thread-30 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '89.40.119.252:80', 'https': '89.40.119.252:80'}
# -------------------------------------
# Thread-30 : 当前剩余处理的ip: 113
# Thread-17 is processing
# r.status_code: 200
# -------------------------------------
# Thread-17 : 当前剩余处理的ip: 112
# Thread-42 is processing
# r.status_code: 200
# -------------------------------------
# Thread-42 : 当前剩余处理的ip: 111
# Thread-34 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '27.147.151.134:53281', 'https': '27.147.151.134:53281'}
# -------------------------------------
# Thread-34 : 当前剩余处理的ip: 110
# Thread-31 is processing
# r.status_code: 200
# -------------------------------------
# Thread-31 : 当前剩余处理的ip: 109
# Thread-12 is processingThread-16 is processingThread-45 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '206.81.5.117:3128', 'https': '206.81.5.117:3128'}
# -------------------------------------
# Thread-45 : 当前剩余处理的ip: 108
#
# r.status_code: 200
# -------------------------------------
# Thread-16 : 当前剩余处理的ip: 107
#
# r.status_code: 200
# -------------------------------------
# Thread-12 : 当前剩余处理的ip: 106
# Thread-23 is processing
# r.status_code: 200
# -------------------------------------
# Thread-23 : 当前剩余处理的ip: 105
# Thread-10 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '78.83.113.81:8080', 'https': '78.83.113.81:8080'}
# -------------------------------------
# Thread-10 : 当前剩余处理的ip: 104
# Thread-20 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 500 Internal Server Error',)))
# remove proxy: {'http': '197.155.158.22:80', 'https': '197.155.158.22:80'}
# -------------------------------------
# Thread-20 : 当前剩余处理的ip: 103
# Thread-32 is processing
# r.status_code: 200
# -------------------------------------
# Thread-32 : 当前剩余处理的ip: 102
# Thread-32 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f399c033400>: Failed to establish a new connection: [Errno 111] Connection refused',)))
# remove proxy: {'http': '202.74.242.248:31773', 'https': '202.74.242.248:31773'}
# -------------------------------------
# Thread-32 : 当前剩余处理的ip: 101
# Thread-27 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '95.143.109.136:41258', 'https': '95.143.109.136:41258'}
# -------------------------------------
# Thread-27 : 当前剩余处理的ip: 100
# Thread-11 is processing
# r.status_code: 200
# -------------------------------------
# Thread-11 : 当前剩余处理的ip: 99
# Thread-6 is processing
# r.status_code: 200
# -------------------------------------
# Thread-6 : 当前剩余处理的ip: 98
# Thread-32 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '54.39.98.138:8080', 'https': '54.39.98.138:8080'}
# -------------------------------------
# Thread-32 : 当前剩余处理的ip: 97
# Thread-41 is processing
# r.status_code: 200
# -------------------------------------
# Thread-41 : 当前剩余处理的ip: 96
# Thread-7 is processing
# r.status_code: 200
# -------------------------------------
# Thread-7 : 当前剩余处理的ip: 95
# Thread-21 is processing
# r.status_code: 200
# -------------------------------------
# Thread-21 : 当前剩余处理的ip: 94
# Thread-29 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 502 Bad Gateway',)))
# remove proxy: {'http': '78.25.98.114:8080', 'https': '78.25.98.114:8080'}
# -------------------------------------
# Thread-29 : 当前剩余处理的ip: 93
# Thread-6 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '159.89.229.66:8080', 'https': '159.89.229.66:8080'}
# -------------------------------------
# Thread-6 : 当前剩余处理的ip: 92
# Thread-4 is processing
# r.status_code: 200
# -------------------------------------
# Thread-4 : 当前剩余处理的ip: 91
# Thread-25 is processing
# r.status_code: 200
# -------------------------------------
# Thread-25 : 当前剩余处理的ip: 90
# Thread-43 is processing
# r.status_code: 200
# -------------------------------------
# Thread-43 : 当前剩余处理的ip: 89
# Thread-31 is processing
# r.status_code: 200
# -------------------------------------
# Thread-31 : 当前剩余处理的ip: 88
# Thread-35 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '41.169.155.98:8080', 'https': '41.169.155.98:8080'}
# -------------------------------------
# Thread-35 : 当前剩余处理的ip: 87
# Thread-16 is processing
# r.status_code: 200
# -------------------------------------
# Thread-16 : 当前剩余处理的ip: 86
# Thread-35 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f398c39ae10>: Failed to establish a new connection: [Errno 111] Connection refused',)))
# remove proxy: {'http': '203.154.82.61:8080', 'https': '203.154.82.61:8080'}
# -------------------------------------
# Thread-35 : 当前剩余处理的ip: 85
# Thread-23 is processing
# r.status_code: 200
# -------------------------------------
# Thread-23 : 当前剩余处理的ip: 84
# Thread-36 is processingThread-38 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 502 Bad Gateway',)))
# remove proxy: {'http': '88.147.142.25:8080', 'https': '88.147.142.25:8080'}
# -------------------------------------
# Thread-38 : 当前剩余处理的ip: 83
#
# r.status_code: 200
# -------------------------------------
# Thread-36 : 当前剩余处理的ip: 82
# Thread-47 is processing
# r.status_code: 200
# -------------------------------------
# Thread-47 : 当前剩余处理的ip: 81
# Thread-19 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '197.149.90.162:53281', 'https': '197.149.90.162:53281'}
# -------------------------------------
# Thread-19 : 当前剩余处理的ip: 80
# Thread-33 is processing
# r.status_code: 200
# -------------------------------------
# Thread-33 : 当前剩余处理的ip: 79
# Thread-22 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '103.254.185.26:80', 'https': '103.254.185.26:80'}
# -------------------------------------
# Thread-22 : 当前剩余处理的ip: 78
# Thread-9 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f398c5666d8>, 'Connection to 77.237.15.225 timed out. (connect timeout=5)'))
# remove proxy: {'http': '77.237.15.225:8080', 'https': '77.237.15.225:8080'}
# -------------------------------------
# Thread-9 : 当前剩余处理的ip: 77
# Thread-28 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f398c3a8e48>, 'Connection to 05.197.183.222 timed out. (connect timeout=5)'))
# remove proxy: {'http': '05.197.183.222:8080', 'https': '05.197.183.222:8080'}
# -------------------------------------
# Thread-28 : 当前剩余处理的ip: 76
# Thread-8 is processing
# r.status_code: 200
# -------------------------------------
# Thread-8 : 当前剩余处理的ip: 75
# Thread-10 is processing
# r.status_code: 200
# -------------------------------------
# Thread-10 : 当前剩余处理的ip: 74
# Thread-12 is processing
# r.status_code: 200
# -------------------------------------
# Thread-12 : 当前剩余处理的ip: 73
# Thread-45 is processing
# r.status_code: 200
# -------------------------------------
# Thread-45 : 当前剩余处理的ip: 72
# Thread-48 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '94.141.142.40:8080', 'https': '94.141.142.40:8080'}
# -------------------------------------
# Thread-48 : 当前剩余处理的ip: 71
# Thread-34 is processing
# r.status_code: 200
# -------------------------------------
# Thread-34 : 当前剩余处理的ip: 70
# Thread-48 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f398c3e60f0>: Failed to establish a new connection: [Errno 111] Connection refused',)))
# remove proxy: {'http': '138.118.85.56:53281', 'https': '138.118.85.56:53281'}
# -------------------------------------
# Thread-48 : 当前剩余处理的ip: 69
# Thread-46 is processing
# r.status_code: 200
# -------------------------------------
# Thread-46 : 当前剩余处理的ip: 68
# Thread-42 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '74.209.243.116:3128', 'https': '74.209.243.116:3128'}
# -------------------------------------
# Thread-42 : 当前剩余处理的ip: 67
# Thread-27 is processing
# r.status_code: 200
# -------------------------------------
# Thread-27 : 当前剩余处理的ip: 66
# Thread-5 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '46.238.242.126:8080', 'https': '46.238.242.126:8080'}
# -------------------------------------
# Thread-5 : 当前剩余处理的ip: 65
# Thread-18 is processing
# r.status_code: 200
# -------------------------------------
# Thread-18 : 当前剩余处理的ip: 64
# Thread-18 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f398c3b5e10>: Failed to establish a new connection: [Errno 111] Connection refused',)))
# remove proxy: {'http': '118.96.170.233:8080', 'https': '118.96.170.233:8080'}
# -------------------------------------
# Thread-18 : 当前剩余处理的ip: 63
# Thread-16 is processing
# r.status_code: 200
# -------------------------------------
# Thread-16 : 当前剩余处理的ip: 62
# Thread-20 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f398c35b908>, 'Connection to 173.212.202.65 timed out. (connect timeout=5)'))
# remove proxy: {'http': '173.212.202.65:443', 'https': '173.212.202.65:443'}
# -------------------------------------
# Thread-20 : 当前剩余处理的ip: 61
# Thread-42 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 501 Not Implemented',)))
# remove proxy: {'http': '87.198.31.62:8080', 'https': '87.198.31.62:8080'}
# -------------------------------------
# Thread-42 : 当前剩余处理的ip: 60
# Thread-7 is processing
# r.status_code: 200
# -------------------------------------
# Thread-7 : 当前剩余处理的ip: 59
# Thread-6 is processing
# r.status_code: 200
# -------------------------------------
# Thread-6 : 当前剩余处理的ip: 58
# Thread-45 is processing
# r.status_code: 200
# -------------------------------------
# Thread-45 : 当前剩余处理的ip: 57
# Thread-40 is processing
# ...
# remove proxy: {'http': '91.215.104.124:8080', 'https': '91.215.104.124:8080'}
# -------------------------------------
# Thread-33 : 当前剩余处理的ip: 25
# Thread-25 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '36.81.48.70:8080', 'https': '36.81.48.70:8080'}
# -------------------------------------
# Thread-25 : 当前剩余处理的ip: 24
# Thread-27 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '110.136.42.54:80', 'https': '110.136.42.54:80'}
# -------------------------------------
# Thread-27 : 当前剩余处理的ip: 23
# Thread-24 is processing
# r.status_code: 200
# -------------------------------------
# Thread-24 : 当前剩余处理的ip: 22
# Thread-33 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '159.203.77.130:8080', 'https': '159.203.77.130:8080'}
# -------------------------------------
# Thread-33 : 当前剩余处理的ip: 21
# Thread-24 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 404 Not Found',)))
# remove proxy: {'http': '198.1.122.29:80', 'https': '198.1.122.29:80'}
# -------------------------------------
# Thread-24 : 当前剩余处理的ip: 20
# Thread-13 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '117.196.233.28:53281', 'https': '117.196.233.28:53281'}
# -------------------------------------
# Thread-13 : 当前剩余处理的ip: 19
# Thread-14 is processing
# r.status_code: 200
# -------------------------------------
# Thread-14 : 当前剩余处理的ip: 18
# Thread-43 is processing
# r.status_code: 200
# -------------------------------------
# Thread-43 : 当前剩余处理的ip: 17
# Thread-7 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f399c0332e8>, 'Connection to 191.5.183.247 timed out. (connect timeout=5)'))
# remove proxy: {'http': '191.5.183.247:20183', 'https': '191.5.183.247:20183'}
# -------------------------------------
# Thread-7 : 当前剩余处理的ip: 16
# Thread-16 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '94.141.142.108:41258', 'https': '94.141.142.108:41258'}
# -------------------------------------
# Thread-16 : 当前剩余处理的ip: 15
# Thread-28 is processing
# r.status_code: 200
# -------------------------------------
# Thread-28 : 当前剩余处理的ip: 14
# Thread-21 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f398c3bca58>, 'Connection to 177.12.178.194 timed out. (connect timeout=5)'))
# remove proxy: {'http': '177.12.178.194:6666', 'https': '177.12.178.194:6666'}
# -------------------------------------
# Thread-21 : 当前剩余处理的ip: 13
# Thread-33 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '201.16.148.145:80', 'https': '201.16.148.145:80'}
# -------------------------------------
# Thread-33 : 当前剩余处理的ip: 12
# Thread-14 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '52.23.193.25:8080', 'https': '52.23.193.25:8080'}
# -------------------------------------
# Thread-14 : 当前剩余处理的ip: 11
# Thread-41 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f398c3b5f60>, 'Connection to 104.237.252.30 timed out. (connect timeout=5)'))
# remove proxy: {'http': '104.237.252.30:8181', 'https': '104.237.252.30:8181'}
# -------------------------------------
# Thread-41 : 当前剩余处理的ip: 10
# Thread-14 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '159.89.145.94:8080', 'https': '159.89.145.94:8080'}
# -------------------------------------
# Thread-14 : 当前剩余处理的ip: 9
# Thread-10 is processing
# r.status_code: 200
# -------------------------------------
# Thread-10 : 当前剩余处理的ip: 8
# Thread-4 is processing
# r.status_code: 200
# -------------------------------------
# Thread-4 : 当前剩余处理的ip: 7
# Thread-41 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '142.44.246.242:80', 'https': '142.44.246.242:80'}
# -------------------------------------
# Thread-41 : 当前剩余处理的ip: 6
# Thread-5 is processing
# r.status_code: 200
# -------------------------------------
# Thread-5 : 当前剩余处理的ip: 5
# Thread-31 is processing
# r.status_code: 200
# -------------------------------------
# Thread-31 : 当前剩余处理的ip: 4
# Thread-21 is processing
# r.status_code: 200
# -------------------------------------
# Thread-21 : 当前剩余处理的ip: 3
# Thread-7 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 502 Bad Gateway',)))
# remove proxy: {'http': '185.190.40.75:8080', 'https': '185.190.40.75:8080'}
# -------------------------------------
# Thread-7 : 当前剩余处理的ip: 2
# Thread-32 is processing
# r.status_code: 200
# -------------------------------------
# Thread-32 : 当前剩余处理的ip: 1
# Thread-34 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '144.76.7.248:8080', 'https': '144.76.7.248:8080'}
# -------------------------------------
# Thread-34 : 当前剩余处理的ip: 0
# Thread-11 is processing
# r.status_code: 200
# -------------------------------------
# Thread-11 : 当前剩余处理的ip: 0
# Thread-5 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 503 Service Temporarily Unavailable',)))
# remove proxy: {'http': '213.136.77.246:80', 'https': '213.136.77.246:80'}
# -------------------------------------
# Thread-5 : 当前剩余处理的ip: 0
# Thread-17 is processing
# r.status_code: 200
# -------------------------------------
# Thread-17 : 当前剩余处理的ip: 0
# Thread-28 is processing
# r.status_code: 200
# Thread-23 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '177.1.25.242:8080', 'https': '177.1.25.242:8080'}
# -------------------------------------
# Thread-23 : 当前剩余处理的ip: 0
# -------------------------------------
# Thread-28 : 当前剩余处理的ip: 0
# Thread-29 is processing
# r.status_code: 200
# -------------------------------------
# Thread-29 : 当前剩余处理的ip: 0
# Thread-25 is processing
# r.status_code: 200
# -------------------------------------
# Thread-25 : 当前剩余处理的ip: 0
# Thread-30 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Read timed out.
# remove proxy: {'http': '201.23.192.173:53281', 'https': '201.23.192.173:53281'}
# -------------------------------------
# Thread-30 : 当前剩余处理的ip: 0
# Thread-26 is processingThread-24 is processing
# r.status_code: 200
# -------------------------------------
# Thread-26 : 当前剩余处理的ip: 0
#
# r.status_code: 200
# -------------------------------------
# Thread-24 : 当前剩余处理的ip: 0
# Thread-37 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f398c472080>, 'Connection to 92.243.104.244 timed out. (connect timeout=5)'))
# remove proxy: {'http': '92.243.104.244:8080', 'https': '92.243.104.244:8080'}
# -------------------------------------
# Thread-37 : 当前剩余处理的ip: 0
# Thread-20 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '95.107.6.63:8080', 'https': '95.107.6.63:8080'}
# -------------------------------------
# Thread-20 : 当前剩余处理的ip: 0
# Thread-8 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f398c441eb8>, 'Connection to 193.106.58.174 timed out. (connect timeout=5)'))
# remove proxy: {'http': '193.106.58.174:8080', 'https': '193.106.58.174:8080'}
# -------------------------------------
# Thread-8 : 当前剩余处理的ip: 0
# Thread-45 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '52.89.117.198:80', 'https': '52.89.117.198:80'}
# -------------------------------------
# Thread-45 : 当前剩余处理的ip: 0
# Thread-33 is processing
# r.status_code: 200
# -------------------------------------
# Thread-33 : 当前剩余处理的ip: 0
# Thread-48 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f398c4d6160>, 'Connection to 188.120.227.20 timed out. (connect timeout=5)'))
# remove proxy: {'http': '188.120.227.20:80', 'https': '188.120.227.20:80'}
# -------------------------------------
# Thread-48 : 当前剩余处理的ip: 0
# Thread-40 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '190.214.20.10:53281', 'https': '190.214.20.10:53281'}
# -------------------------------------
# Thread-40 : 当前剩余处理的ip: 0
# Thread-42 is processing
# r.status_code: 200
# -------------------------------------
# Thread-42 : 当前剩余处理的ip: 0
# Thread-16 is processing
# r.status_code: 200
# -------------------------------------
# Thread-16 : 当前剩余处理的ip: 0
# Thread-22 is processing
# r.status_code: 200
# -------------------------------------
# Thread-22 : 当前剩余处理的ip: 0
# Thread-41 is processing
# r.status_code: 200
# -------------------------------------
# Thread-41 : 当前剩余处理的ip: 0
# Thread-12 is processing
# r.status_code: 200
# -------------------------------------
# Thread-12 : 当前剩余处理的ip: 0
# Thread-13 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '195.208.172.70:8080', 'https': '195.208.172.70:8080'}
# -------------------------------------
# Thread-13 : 当前剩余处理的ip: 0
# Thread-19 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '41.169.16.120:8080', 'https': '41.169.16.120:8080'}
# -------------------------------------
# Thread-19 : 当前剩余处理的ip: 0
# Thread-18 is processing
# r.status_code: 200
# -------------------------------------
# Thread-18 : 当前剩余处理的ip: 0
# Thread-38 is processing
# r.status_code: 200
# -------------------------------------
# Thread-38 : 当前剩余处理的ip: 0
# Thread-44 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Read timed out.
# remove proxy: {'http': '177.204.85.203:80', 'https': '177.204.85.203:80'}
# -------------------------------------
# Thread-44 : 当前剩余处理的ip: 0
# Thread-31 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f399c033da0>, 'Connection to 178.213.13.136 timed out. (connect timeout=5)'))
# remove proxy: {'http': '178.213.13.136:53281', 'https': '178.213.13.136:53281'}
# -------------------------------------
# Thread-31 : 当前剩余处理的ip: 0
# Thread-32 is processing
# r.status_code: 200
# -------------------------------------
# Thread-32 : 当前剩余处理的ip: 0
# Thread-4 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '165.90.60.133:80', 'https': '165.90.60.133:80'}
# -------------------------------------
# Thread-4 : 当前剩余处理的ip: 0
# Thread-4已停止
# Thread-5已停止
# Thread-39 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Read timed out.
# remove proxy: {'http': '31.132.69.165:8080', 'https': '31.132.69.165:8080'}
# -------------------------------------
# Thread-39 : 当前剩余处理的ip: 0
# Thread-7 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '185.231.208.196:41258', 'https': '185.231.208.196:41258'}
# -------------------------------------
# Thread-7 : 当前剩余处理的ip: 0
# Thread-36 is processing
# r.status_code: 200
# -------------------------------------
# Thread-36 : 当前剩余处理的ip: 0
# Thread-15 is processing
# r.status_code: 200
# -------------------------------------
# Thread-15 : 当前剩余处理的ip: 0
# Thread-14 is processing
# r.status_code: 200
# -------------------------------------
# Thread-14 : 当前剩余处理的ip: 0
# Thread-46 is processing
# r.status_code: 200
# -------------------------------------
# Thread-46 : 当前剩余处理的ip: 0
# Thread-21 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '41.169.67.242:53281', 'https': '41.169.67.242:53281'}
# -------------------------------------
# Thread-21 : 当前剩余处理的ip: 0
# Thread-6 is processing
# r.status_code: 200
# -------------------------------------
# Thread-6 : 当前剩余处理的ip: 0
# Thread-6已停止
# Thread-7已停止
# Thread-8已停止
# Thread-10 is processing
# r.status_code: 200
# -------------------------------------
# Thread-10 : 当前剩余处理的ip: 0
# Thread-27 is processing
# r.status_code: 200
# -------------------------------------
# Thread-27 : 当前剩余处理的ip: 0
# Thread-47 is processing
# r.status_code: 200
# -------------------------------------
# Thread-47 : 当前剩余处理的ip: 0
# Thread-9 is processing
# r.status_code: 200
# -------------------------------------
# Thread-9 : 当前剩余处理的ip: 0
# Thread-9已停止
# Thread-10已停止
# Thread-11已停止
# Thread-12已停止
# Thread-13已停止
# Thread-14已停止
# Thread-15已停止
# Thread-16已停止
# Thread-17已停止
# Thread-18已停止
# Thread-19已停止
# Thread-20已停止
# Thread-21已停止
# Thread-22已停止
# Thread-23已停止
# Thread-24已停止
# Thread-25已停止
# Thread-26已停止
# Thread-27已停止
# Thread-28已停止
# Thread-29已停止
# Thread-30已停止
# Thread-31已停止
# Thread-32已停止
# Thread-33已停止
# Thread-34已停止
# Thread-43 is processing
# r.status_code: 200
# -------------------------------------
# Thread-43 : 当前剩余处理的ip: 0
# Thread-35 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Read timed out.
# remove proxy: {'http': '170.245.173.234:53281', 'https': '170.245.173.234:53281'}
# -------------------------------------
# Thread-35 : 当前剩余处理的ip: 0
# Thread-35已停止
# Thread-36已停止
# Thread-37已停止
# Thread-38已停止
# Thread-39已停止
# Thread-40已停止
# Thread-41已停止
# Thread-42已停止
# Thread-43已停止
# Thread-44已停止
# Thread-45已停止
# Thread-46已停止
# Thread-47已停止
# Thread-48已停止
# 可用的ip:  151
# MainThread清洗ip的时间: 52
# ###当前proxies的ip数:  150

# %%
def main():
    url_queue = queue.Queue()
    pages = 10
    thread_nums = 5
    
    for i in range(pages):
        url = 'https://search.51job.com/list/000000,000000,0000,00,9,99,Java,2,{}.html?lang=c&stype=&postchannel=0000&workyear=99&cotype=99&degreefrom=99&jobterm=99&companysize=99&providesalary=99&lonlat=0%2C0&radius=-1&ord_field=0&confirmdate=9&fromType=&dibiaoid=0&address=&line=&specialarea=00&from=&welfare='\
        .format(i+1)
        url_queue.put(url)
    
#     flag = True
#     while flag:
 
    def go(url_queue, proxy):
        flag = True
        while flag:   
            url = url_queue.get()
            start = time()
            handle_single(url, proxy)
            result = time() - start
            print('%s完成单页的时间: %d' % (threading.current_thread().name, result))
            
            if url_queue.qsize()==0:
                flag = False
            
    
    threads = []
    
    for i in range(thread_nums):
        thread = threading.Thread(target=go, args=(url_queue,proxy))
        threads.append(thread)
    
    start = time()
    for thread in threads:
        thread.start()
        print('主线程%s开始' % thread.name)
        
    for thread in threads:
        thread.join()
        print('主线程%s停止' % thread.name)
    
    result = time()-start
    print('爬取时间:',result)

# %%
main()
# Out:
# get_jobObjectList()当前处理链接:主线程Thread-49开始
#  https://search.51job.com/list/000000,000000,0000,00,9,99,Java,2,1.html?lang=c&stype=&postchannel=0000&workyear=99&cotype=99&degreefrom=99&jobterm=99&companysize=99&providesalary=99&lonlat=0%2C0&radius=-1&ord_field=0&confirmdate=9&fromType=&dibiaoid=0&address=&line=&specialarea=00&from=&welfare=
# get_jobObjectList()当前处理链接:主线程Thread-50开始
#  https://search.51job.com/list/000000,000000,0000,00,9,99,Java,2,2.html?lang=c&stype=&postchannel=0000&workyear=99&cotype=99&degreefrom=99&jobterm=99&companysize=99&providesalary=99&lonlat=0%2C0&radius=-1&ord_field=0&confirmdate=9&fromType=&dibiaoid=0&address=&line=&specialarea=00&from=&welfare=
# get_jobObjectList()当前处理链接:主线程Thread-51开始
#  https://search.51job.com/list/000000,000000,0000,00,9,99,Java,2,3.html?lang=c&stype=&postchannel=0000&workyear=99&cotype=99&degreefrom=99&jobterm=99&companysize=99&providesalary=99&lonlat=0%2C0&radius=-1&ord_field=0&confirmdate=9&fromType=&dibiaoid=0&address=&line=&specialarea=00&from=&welfare=
# get_jobObjectList()当前处理链接:主线程Thread-52开始
#  https://search.51job.com/list/000000,000000,0000,00,9,99,Java,2,4.html?lang=c&stype=&postchannel=0000&workyear=99&cotype=99&degreefrom=99&jobterm=99&companysize=99&providesalary=99&lonlat=0%2C0&radius=-1&ord_field=0&confirmdate=9&fromType=&dibiaoid=0&address=&line=&specialarea=00&from=&welfare=
# get_jobObjectList()当前处理链接:主线程Thread-53开始
#  https://search.51job.com/list/000000,000000,0000,00,9,99,Java,2,5.html?lang=c&stype=&postchannel=0000&workyear=99&cotype=99&degreefrom=99&jobterm=99&companysize=99&providesalary=99&lonlat=0%2C0&radius=-1&ord_field=0&confirmdate=9&fromType=&dibiaoid=0&address=&line=&specialarea=00&from=&welfare=
# get_jobObjectList处理完成!
# get_jobObjectList() 运行时间: 6
# getTag()当前处理链接: https://jobs.51job.com/beijing-hdq/104653540.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/guangzhou-thq/104431940.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/shanghai-ptq/55987012.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/hangzhou-bjq/99555111.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/shenzhen-lhxq/69207758.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/beijing-xcq/104666223.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/jinan/104654491.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/wuhan/71957463.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/shanghai-pdxq/79898586.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/chongqing-ybq/104664060.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/hefei-ssq/103038173.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/shanghai-hpq/104664775.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/guangzhou-hzq/101299889.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/shenyang/104092281.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/shenzhen-nsq/104664943.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/beijing-cyq/104217935.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# get_jobObjectList处理完成!
# get_jobObjectList() 运行时间: 7
# getTag()当前处理链接: https://jobs.51job.com/beijing/104036201.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/beijing-cyq/104346282.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/fuzhou/101301127.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/changsha-ylq/104665101.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/guangzhou/104665182.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/beijing-cyq/104658971.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/beijing-hdq/104665187.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/hangzhou-xhq/104662029.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/wuhan-jxq/84864546.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/taiyuan/104662396.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/hangzhou/104662473.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/foshan-sdq/104662016.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/beijing-xcq/104662813.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/shanghai-pdxq/94947255.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/guangzhou/85890853.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/guangzhou-pyq/101634260.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/guangzhou-thq/101713518.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/xian-ytq/104662286.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/shanghai-ypq/104662725.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/shanghai-xhq/101939176.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/xian-ytq/98535631.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/xiamen/104631915.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/beijing-cpq/104544566.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/shanghai-pdxq/104659904.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# get_jobObjectList处理完成!
# get_jobObjectList() 运行时间: 9
# getTag()当前处理链接: https://jobs.51job.com/guangzhou-lwq/77808060.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/beijing/66860407.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/beijing-cyq/104641061.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/nanjing-glq/104656222.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/shanghai-jaq/81852102.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/chongqing-spbq/102510815.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/hangzhou-xhq/104650102.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/taiyuan/69008091.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/guangzhou/75125783.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/foshan/104654946.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/fuzhou/103045419.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/shenzhen/98608625.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/fuzhou/83340502.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/shanghai-xhq/85523985.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/dalian-zsq/104179970.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/wuhan/104652316.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/shanghai-jaq/102347991.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/wuxi/102755451.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/guangzhou-hpq/102281572.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/suzhou-gxq/102316056.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# get_jobObjectList处理完成!
# get_jobObjectList() 运行时间: 11
# getTag()当前处理链接: https://jobs.51job.com/guangzhou-hzq/103060760.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/shanghai-sjq/104648258.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/guangzhou-thq/99884782.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/beijing-cyq/104629280.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/xian/83460921.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/guangzhou-yxq/65304377.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/chengdu-gxq/87320816.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/kunming/82173662.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()中tag_list: ['3-4年经验', '大专', '招1人', '07-18发布', '绩效奖金', '全勤奖', '节日福利', '加班补贴', '五险一金', '补充公积金', '弹性工作']
# ----------------------
# getTag() 运行时间: 4
# getTag()当前处理链接: https://jobs.51job.com/shanghai-ypq/86663060.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()中tag_list: ['3-4年经验', '大专', '招1人', '07-18发布', '五险一金', '餐饮补贴', '通讯补贴', '绩效奖金']
# ----------------------
# getTag() 运行时间: 5
# getTag()当前处理链接: https://jobs.51job.com/jinan-gxq/83482991.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/hangzhou-xcq/104658938.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()当前处理链接: https://jobs.51job.com/jinan-gxq/104647779.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# getTag()中tag_list:getTag()当前处理链接: https://jobs.51job.com/hangzhou-xcq/104659227.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
#  ['2年经验', '本科', '招若干人', '07-18发布', '五险一金', '专业培训', '免费班车', '年终奖金', '绩效奖金', '员工旅游', '股票期权']
# ----------------------
# getTag() 运行时间: 5
# getTag()当前处理链接: https://jobs.51job.com/shenzhen/104167314.html?s=01&t=0
# getTag()获得的ip: {'http': '69.43.44.210:53281', 'https': '69.43.44.210:53281'}
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /shenzhen-lhxq/69207758.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# ###当前proxies的ip数:  149
# 尝试新的proxy
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /guangzhou/104665182.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# ###当前proxies的ip数:  148
# 尝试新的proxy
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /chongqing-ybq/104664060.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# ###当前proxies的ip数:  147
# 尝试新的proxy
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /hangzhou-xhq/104662029.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# ###当前proxies的ip数:  146
# 尝试新的proxy
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /beijing-xcq/104662813.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# ###当前proxies的ip数:  145
# 尝试新的proxy
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /guangzhou-thq/101713518.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# ###当前proxies的ip数:  144
# 尝试新的proxy
# getTag()当前处理链接: https://jobs.51job.com/shanghai/98049537.html?s=01&t=0
# getTag()获得的ip: {'http': '176.120.212.23:41258', 'https': '176.120.212.23:41258'}
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /xian-ytq/98535631.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# ###当前proxies的ip数:  143
# 尝试新的proxy
# getTag()当前处理链接: https://jobs.51job.com/zhongshan/104658664.html?s=01&t=0
# getTag()获得的ip: {'http': '178.210.130.71:53281', 'https': '178.210.130.71:53281'}
# getTag()当前处理链接: https://jobs.51job.com/chengdu-jjq/103126467.html?s=01&t=0
# getTag()获得的ip: {'http': '178.210.130.71:53281', 'https': '178.210.130.71:53281'}
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Read timed out. (read timeout=5)
# ###当前proxies的ip数:  142
# 尝试新的proxy
# getTag()中tag_list:HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /beijing-xcq/104662813.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response',)))
# ###当前proxies的ip数:  141
# 尝试新的proxy
#  ['无工作经验', '大专', '招5人', '07-18发布', '五险一金', '绩效奖金', '年终奖金', '员工旅游']
# ----------------------
# getTag() 运行时间: 6
# getTag()当前处理链接: http://lachapelle.51job.com/show_job_detail.php?jobid=104650705
# getTag()获得的ip: {'http': '93.91.157.141:8080', 'https': '93.91.157.141:8080'}
# getTag()当前处理链接: https://jobs.51job.com/chongqing-jlpq/104658706.html?s=01&t=0
# getTag()获得的ip: {'http': '93.91.157.141:8080', 'https': '93.91.157.141:8080'}
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /shanghai-hpq/104664775.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# ###当前proxies的ip数:  140
# 尝试新的proxy
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /dalian-zsq/104179970.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# ###当前proxies的ip数:  139
# 尝试新的proxy
# getTag()当前处理链接: https://jobs.51job.com/shanghai/104646086.html?s=01&t=0
# getTag()获得的ip: {'http': '92.255.182.151:8080', 'https': '92.255.182.151:8080'}
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /chongqing-spbq/102510815.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# ###当前proxies的ip数:  138
# 尝试新的proxy
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /shanghai-jaq/102347991.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# ###当前proxies的ip数:  137
# 尝试新的proxy
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /foshan-sdq/104662016.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# ###当前proxies的ip数:  136
# 尝试新的proxy
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /fuzhou/83340502.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# ###当前proxies的ip数:  135
# 尝试新的proxy
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /shanghai-hpq/104664775.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response',)))
# ###当前proxies的ip数:  134
# 尝试新的proxy
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /guangzhou-lwq/77808060.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# ###当前proxies的ip数:  133
# 尝试新的proxy
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /xiamen/104631915.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# ###当前proxies的ip数:  132
# 尝试新的proxy
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /guangzhou-hpq/102281572.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# ###当前proxies的ip数:  131
# 尝试新的proxy
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Read timed out. (read timeout=5)
# ###当前proxies的ip数:  130
# 尝试新的proxy
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Read timed out. (read timeout=5)
# ###当前proxies的ip数:  129
# 尝试新的proxy
# getTag()中tag_list:getTag()当前处理链接: https://jobs.51job.com/chengdu-whq/102125473.html?s=01&t=0
# getTag()获得的ip: {'http': '89.248.247.247:8080', 'https': '89.248.247.247:8080'}
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /shanghai-jaq/81852102.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# ###当前proxies的ip数:  128
# 尝试新的proxy
#  ['3-4年经验', '本科', '招2人', '07-18发布', '五险一金', '定期体检', '交通补贴', '通讯补贴', '员工旅游', '专业培训', '弹性工作', '年终奖金', '绩效奖金']
# ----------------------
# getTag() 运行时间: 10
# getTag()当前处理链接: https://jobs.51job.com/shanghai-jaq/104653243.html?s=01&t=0
# getTag()获得的ip: {'http': '118.172.34.129:3128', 'https': '118.172.34.129:3128'}
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Read timed out. (read timeout=5)
# ###当前proxies的ip数:  127
# 尝试新的proxy
# getTag()中tag_list:HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /changsha-ylq/104665101.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# ###当前proxies的ip数:  126
# 尝试新的proxy
# getTag()当前处理链接: https://jobs.51job.com/nanjing/104647163.html?s=01&t=0
# getTag()获得的ip: {'http': '95.24.148.239:53281', 'https': '95.24.148.239:53281'}
#  ['3-4年经验', '本科', '招若干人', '07-18发布', '五险一金', '定期体检', '通讯补贴', '十三薪']
# ----------------------
# getTag() 运行时间: 11
# getTag()当前处理链接: https://jobs.51job.com/nanjing-yhtq/104629917.html?s=01&t=0
# getTag()获得的ip: {'http': '95.24.148.239:53281', 'https': '95.24.148.239:53281'}
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /guangzhou-thq/101713518.html?s=01&t=0 (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f395cf21400>, 'Connection to 176.120.212.23 timed out. (connect timeout=5)'))
# ###当前proxies的ip数:  125
# 尝试新的proxy
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /foshan-sdq/104662016.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response',)))
# ###当前proxies的ip数:  124
# 尝试新的proxy
# getTag()中tag_list: ['3-4年经验', '大专', '招若干人', '07-18发布', '五险一金', '交通补贴', '员工旅游', '餐饮补贴', '出国机会', '弹性工作', '定期体检', '周末双休']
# ----------------------getTag()当前处理链接: https://jobs.51job.com/beijing/102571871.html?s=01&t=0
# getTag()获得的ip: {'http': '36.89.228.201:53281', 'https': '36.89.228.201:53281'}
#
# getTag() 运行时间: 12
# getTag()当前处理链接: https://jobs.51job.com/kunshan/104242248.html?s=01&t=0
# getTag()获得的ip: {'http': '36.89.228.201:53281', 'https': '36.89.228.201:53281'}
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Read timed out. (read timeout=5)
# ###当前proxies的ip数:  123
# 尝试新的proxy
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /guangzhou-yxq/65304377.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# ###当前proxies的ip数:  122
# 尝试新的proxy
# getTag()中tag_list:HTTPSConnectionPool(host='jobs.51job.com', port=443): Read timed out. (read timeout=5)
# ###当前proxies的ip数:  121
# 尝试新的proxy
# getTag()中tag_list: ['2年经验', '本科', '招1人', '07-18发布', '五险一金', '绩效奖金', '定期体检', '员工旅游']
# ----------------------
# getTag() 运行时间: 11
# getTag()当前处理链接: https://jobs.51job.com/xian-gxjs/104643369.html?s=01&t=0
# getTag()获得的ip: {'http': '198.98.86.111:53281', 'https': '198.98.86.111:53281'}
#  ['1年经验', '大专', '招1人', '07-18发布', '五险一金', '餐饮补贴', '绩效奖金', '定期体检']
# ----------------------
# getTag() 运行时间: 13
# getTag()当前处理链接: https://jobs.51job.com/shenzhen-nsq/104661064.html?s=01&t=0
# getTag()获得的ip: {'http': '198.98.86.111:53281', 'https': '198.98.86.111:53281'}
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /shanghai/98049537.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# ###当前proxies的ip数:  120
# 尝试新的proxy
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Read timed out. (read timeout=5)
# ###当前proxies的ip数:  119
# 尝试新的proxy
# getTag()当前处理链接: https://jobs.51job.com/nanjing/79329032.html?s=01&t=0
# getTag()获得的ip: {'http': '189.84.64.2:53281', 'https': '189.84.64.2:53281'}
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /fuzhou/83340502.html?s=01&t=0 (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f3959d767f0>, 'Connection to 103.85.243.90 timed out. (connect timeout=5)'))
# ###当前proxies的ip数:  118
# 尝试新的proxy
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /hangzhou-xcq/104659227.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# ###当前proxies的ip数:  117
# 尝试新的proxy
# getTag()中tag_list: HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /shanghai-jaq/102347991.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# ###当前proxies的ip数:  116
# 尝试新的proxy
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /shanghai-jaq/104653243.html?s=01&t=0 (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f3958f720f0>, 'Connection to 118.172.34.129 timed out. (connect timeout=5)'))
# ###当前proxies的ip数:  115
# 尝试新的proxy
# getTag()中tag_list:getTag()中tag_list:getTag()中tag_list: ['3-4年经验', '本科', '招1人', '07-18发布', '周末双休', '带薪年假', '专业培训', '全勤奖', '六险']
# ----------------------
# getTag() 运行时间: 16
# getTag()当前处理链接: https://jobs.51job.com/hangzhou-scq/104663959.html?s=01&t=0
# getTag()获得的ip: {'http': '194.50.158.1:41258', 'https': '194.50.158.1:41258'}
#  ['3-4年经验', '本科', '招2人', '07-18发布']
# ----------------------
# getTag() 运行时间: 16
# getTag()当前处理链接: https://jobs.51job.com/guangzhou-thq/100021622.html?s=01&t=0
# getTag()获得的ip: {'http': '194.50.158.1:41258', 'https': '194.50.158.1:41258'}
#  []
# ----------------------
# getTag() 运行时间: 9
# getTag()当前处理链接: https://jobs.51job.com/shenzhen/93924157.html?s=01&t=0
# getTag()获得的ip: {'http': '194.50.158.1:41258', 'https': '194.50.158.1:41258'}
# ['3-4年经验', '大专', '招若干人', '07-18发布']
# ----------------------
# getTag() 运行时间: 17
# getTag()当前处理链接: https://jobs.51job.com/changsha-kfq/104661540.html?s=01&t=0
# getTag()获得的ip: {'http': '194.50.158.1:41258', 'https': '194.50.158.1:41258'}
# getTag()中tag_list:getTag()中tag_list: ['2年经验', '大专', '招3人', '07-18发布', '五险一金', '补充医疗保险', '餐饮补贴', '绩效奖金', '年终奖金', '股票期权', '弹性工作', '定期体检']
# ----------------------
# getTag() 运行时间: 15
# getTag()当前处理链接: https://jobs.51job.com/guangzhou-byq/95207623.html?s=01&t=0
# getTag()获得的ip: {'http': '194.50.158.1:41258', 'https': '194.50.158.1:41258'}
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /beijing/102571871.html?s=01&t=0 (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f3984691c18>, 'Connection to 36.89.228.201 timed out. (connect timeout=5)'))
# ###当前proxies的ip数:  114
# 尝试新的proxy
# getTag()中tag_list:HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /guangzhou-yxq/65304377.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response',)))
# ###当前proxies的ip数:  113
# 尝试新的proxy
#  ['5-7年经验', '本科', '招1人', '07-18发布', '五险一金', '交通补贴', '餐饮补贴', '通讯补贴', '绩效奖金', '带薪年假', '节日福利', '补充医疗保险', '定期体检']
# ----------------------
# getTag() 运行时间: 18
# getTag()当前处理链接: https://jobs.51job.com/shenyang-hpq/104664405.html?s=01&t=0
# getTag()获得的ip: {'http': '204.52.206.65:8080', 'https': '204.52.206.65:8080'}
#  ['3-4年经验', '本科', '招2人', '07-18发布', '五险一金', '员工旅游', '出国机会', '专业培训', '绩效奖金', '年终奖金', '弹性工作', '定期体检']
# ----------------------
# getTag() 运行时间: 16
# getTag()当前处理链接: https://jobs.51job.com/shanghai-hpq/104140347.html?s=01&t=0
# getTag()获得的ip: {'http': '204.52.206.65:8080', 'https': '204.52.206.65:8080'}
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /foshan-sdq/104662016.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# ###当前proxies的ip数:  112
# 尝试新的proxy
# getTag()中tag_list:HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /shanghai-ypq/104662725.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# ###当前proxies的ip数:  111
# 尝试新的proxy
#  ['3-4年经验', '大专', '招2人', '07-18发布', '五险一金', '免费班车', '员工旅游', '餐饮补贴', '定期体检', '业绩提成', '住房补贴']
# ----------------------
# getTag() 运行时间: 13
# getTag()当前处理链接: https://jobs.51job.com/fuzhou/87433764.html?s=01&t=0
# getTag()获得的ip: {'http': '45.6.216.79:80', 'https': '45.6.216.79:80'}
# getTag()中tag_list: ['1年经验', '大专', '招1人', '07-18发布', '五险一金', '专业培训', '绩效奖金', '年终奖金']
# ----------------------
# getTag() 运行时间: 19
# getTag()当前处理链接: https://jobs.51job.com/hangzhou-bjq/104387500.html?s=01&t=0
# getTag()获得的ip: {'http': '45.6.216.79:80', 'https': '45.6.216.79:80'}
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /kunshan/104242248.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# ###当前proxies的ip数:  110
# 尝试新的proxy
# getTag()中tag_list: ['3-4年经验', '本科', '招1人', '07-18发布', '五险一金', '餐饮补贴', '年终奖金', '员工旅游']
# ----------------------
# getTag() 运行时间: 19
# getTag()当前处理链接: https://jobs.51job.com/chengdu-gxq/82699083.html?s=01&t=0
# getTag()获得的ip: {'http': '201.166.181.8:53281', 'https': '201.166.181.8:53281'}
# getTag()中tag_list:getTag()中tag_list: ['2年经验', '本科', '招1人', '07-18发布', '五险一金', '员工旅游', '年终奖金', '绩效奖金', '股票期权', '专业培训']
# ----------------------
# getTag() 运行时间: 18
# getTag()当前处理链接: https://jobs.51job.com/guangzhou/81493978.html?s=01&t=0
# getTag()获得的ip: {'http': '201.166.181.8:53281', 'https': '201.166.181.8:53281'}
#  ['3-4年经验', '大专', '招3人', '07-18发布', '五险一金', '员工旅游', '绩效奖金', '年终奖金', '全勤奖', '带薪休假', '升迁机会']
# ----------------------
# getTag() 运行时间: 21
# getTag()当前处理链接: https://jobs.51job.com/xian/104661453.html?s=01&t=0
# getTag()获得的ip: {'http': '201.166.181.8:53281', 'https': '201.166.181.8:53281'}
# getTag()中tag_list:getTag()中tag_list: ['2年经验', '本科', '招若干人', '07-18发布', '五险一金', '绩效奖金', '年终奖金']
# ----------------------
# getTag() 运行时间: 21
#  ['3-4年经验', '本科', '招7人', '07-18发布']
# ----------------------
# getTag() 运行时间: 21
# getTag()当前处理链接: https://jobs.51job.com/shanghai-cnq/91019348.html?s=01&t=0
# getTag()获得的ip: {'http': '201.166.181.8:53281', 'https': '201.166.181.8:53281'}
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /shenzhen/93924157.html?s=01&t=0 (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f395707f400>, 'Connection to 194.50.158.1 timed out. (connect timeout=5)'))
# ###当前proxies的ip数:  109
# 尝试新的proxy
# getTag()当前处理链接: https://jobs.51job.com/beijing-hdq/104661368.html?s=01&t=0
# getTag()获得的ip: {'http': '78.156.49.26:41258', 'https': '78.156.49.26:41258'}
# getTag()中tag_list: ['无工作经验', '招1人', '07-18发布', '五险一金', '年终奖金', '专业培训', '餐饮补贴', '定期体检', '节日福利', '加班补贴']
# ----------------------
# getTag() 运行时间: 20HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /kunshan/104242248.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response',)))
# ###当前proxies的ip数:  108
# 尝试新的proxy
# getTag()中tag_list:
# getTag()当前处理链接: http://tojoy.51job.com/sc/show_job_detail.php?jobid=104651467
# getTag()获得的ip: {'http': '46.164.240.180:53281', 'https': '46.164.240.180:53281'}
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /changsha-kfq/104661540.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# ###当前proxies的ip数:  107
# 尝试新的proxy
# getTag()中tag_list:HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /shanghai-jaq/104653243.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# ###当前proxies的ip数:  106
# 尝试新的proxy
#  ['1年经验', '大专', '招若干人', '07-18发布', '五险一金', '周末双休', '免费班车', '通讯补贴', '年终奖金', '定期体检', '带薪假期', '节日福利', '全勤奖']
# ----------------------
# getTag() 运行时间: 22
# getTag()当前处理链接: https://jobs.51job.com/chengdu-gxq/104635630.html?s=01&t=0
# getTag()获得的ip: {'http': '195.46.162.83:8080', 'https': '195.46.162.83:8080'}
# getTag()中tag_list: ['3-4年经验', '大专', '招3人', '07-18发布', '五险一金', '餐饮补贴', '通讯补贴', '绩效奖金', '年终奖金', '股票期权', '员工旅游']
# ----------------------
# getTag() 运行时间: 22
# getTag()中tag_list:getTag()中tag_list:HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /shenyang-hpq/104664405.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# ###当前proxies的ip数:  105
# 尝试新的proxy
#  ['3-4年经验', '大专', '招1人', '07-18发布', '五险一金', '通讯补贴', '交通补贴', '年终奖金', '绩效奖金', '专业培训', '出国机会', '员工旅游', '定期体检', '补充公积金']
# ----------------------
# getTag() 运行时间: 24
# getTag()当前处理链接: https://jobs.51job.com/nanjing-yhtq/104654345.html?s=01&t=0
# getTag()获得的ip: {'http': '81.24.82.118:8080', 'https': '81.24.82.118:8080'}
# getTag()当前处理链接: https://jobs.51job.com/changsha-yhq/101910379.html?s=01&t=0
# getTag()获得的ip: {'http': '81.24.82.118:8080', 'https': '81.24.82.118:8080'}
# getTag()中tag_list: ['无工作经验', '大专', '招若干人', '07-18发布', '五险一金', '绩效奖金', '餐饮补贴', '专业培训', '年终奖金', '定期体检', '员工旅游', '交通补贴']
# ----------------------
# getTag() 运行时间: 24
#  ['5-7年经验', '本科', '招2人', '07-18发布', '五险一金', '定期体检', '年终奖金', '补充医疗保险', '交通补贴', '餐饮补贴', '绩效奖金']
# ----------------------
# getTag() 运行时间: 25
# getTag()中tag_list:getTag()当前处理链接: https://jobs.51job.com/beijing/104654640.html?s=01&t=0
# getTag()获得的ip: {'http': '81.24.82.118:8080', 'https': '81.24.82.118:8080'}
#  ['3-4年经验', '本科', '招10人', '07-18发布', '五险一金', '餐饮补贴', '定期体检', '专业培训', '免费班车', '员工旅游', '交通补贴', '年终奖金', '股票期权', '绩效奖金']
# ----------------------
# getTag() 运行时间: 27
# getTag()当前处理链接: https://jobs.51job.com/longyan/104646905.html?s=01&t=0
# getTag()获得的ip: {'http': '81.24.82.118:8080', 'https': '81.24.82.118:8080'}
# getTag()中tag_list:getTag()中tag_list:getTag()中tag_list: ['3-4年经验', '本科', '招若干人', '07-18发布', '周末双休', '五险一金', '绩效奖金', '销售业绩奖', '员工福利齐全']
# ----------------------
# getTag() 运行时间: 24
# getTag()当前处理链接: https://jobs.51job.com/shenzhen-nsq/87645456.html?s=01&t=0
# getTag()获得的ip: {'http': '81.24.82.118:8080', 'https': '81.24.82.118:8080'}
#  ['2年经验', '大专', '招3人', '07-18发布', '五险一金', '餐饮补贴', '通讯补贴', '意外险']
# ----------------------
# getTag() 运行时间: 27
# getTag()当前处理链接: https://jobs.51job.com/hangzhou-bjq/104647757.html?s=01&t=0
# getTag()获得的ip: {'http': '81.24.82.118:8080', 'https': '81.24.82.118:8080'}
#  ['3-4年经验', '本科', '招1人', '07-18发布', '周末双休', '五险一金', '通讯补贴', '餐饮补贴', '节日福利', '做五休二', '年终奖金', '电脑补贴']
# ----------------------
# getTag() 运行时间: 23
# getTag()当前处理链接: https://jobs.51job.com/shanghai-pdxq/65983613.html?s=01&t=0
# getTag()获得的ip: {'http': '81.24.82.118:8080', 'https': '81.24.82.118:8080'}
# getTag()当前处理链接: https://jobs.51job.com/jinan/103579680.html?s=01&t=0
# getTag()获得的ip: {'http': '81.24.82.118:8080', 'https': '81.24.82.118:8080'}
# getTag()中tag_list:getTag()中tag_list:HTTPSConnectionPool(host='jobs.51job.com', port=443): Read timed out. (read timeout=5)
# ###当前proxies的ip数:  104
# 尝试新的proxy
#  ['2年经验', '大专', '招3人', '07-18发布', '五险一金', '补充医疗保险', '员工旅游', '餐饮补贴', '通讯补贴', '专业培训', '绩效奖金', '年终奖金', '定期体检']
# ----------------------
# getTag() 运行时间: 25
# getTag()当前处理链接: https://jobs.51job.com/nanjing-glq/104404591.html?s=01&t=0
# getTag()获得的ip: {'http': '46.235.67.172:53281', 'https': '46.235.67.172:53281'}
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /chengdu-gxq/104635630.html?s=01&t=0 (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f39557972e8>, 'Connection to 195.46.162.83 timed out. (connect timeout=5)'))
# ###当前proxies的ip数:  103
# 尝试新的proxy
#  ['5-7年经验', '招若干人', '07-18发布']
# ----------------------
# getTag() 运行时间: 25
# getTag()当前处理链接:HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /shanghai-jaq/104653243.html?s=01&t=0 (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f3955977780>, 'Connection to 195.46.162.83 timed out. (connect timeout=5)'))
# ###当前proxies的ip数:  102
# 尝试新的proxy
#  https://jobs.51job.com/xian-ytq/104657587.html?s=01&t=0
# getTag()获得的ip: {'http': '62.152.34.166:3128', 'https': '62.152.34.166:3128'}
#  ['3-4年经验', '本科', '招1人', '07-18发布', '五险一金', '免费班车', '员工旅游', '绩效奖金', '专业培训', '周末双休']
# ----------------------
# getTag() 运行时间: 30
# getTag()当前处理链接: https://jobs.51job.com/hangzhou-scq/104658405.html?s=01&t=0
# getTag()获得的ip: {'http': '62.152.34.166:3128', 'https': '62.152.34.166:3128'}
# getTag()中tag_list: ['3-4年经验', '本科', '招1人', '07-18发布', '五险一金', '员工旅游', '年终奖金', '弹性工作', '定期体检']
# ----------------------
# getTag() 运行时间: 31
# getTag()当前处理链接: https://jobs.51job.com/zhenjiang/90979006.html?s=01&t=0
# getTag()获得的ip: {'http': '62.152.34.166:3128', 'https': '62.152.34.166:3128'}
# getTag()中tag_list:HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /nanjing-yhtq/104654345.html?s=01&t=0 (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f3954e5a9b0>, 'Connection to 81.24.82.118 timed out. (connect timeout=5)'))
# ###当前proxies的ip数:  101
# 尝试新的proxy
# getTag()中tag_list:getTag()中tag_list: []
# ----------------------
# getTag() 运行时间: 9
# getTag()当前处理链接: https://jobs.51job.com/shenzhen-ftq/104654488.html?s=01&t=0
# getTag()获得的ip: {'http': '89.249.240.170:8080', 'https': '89.249.240.170:8080'}
#  ['无工作经验', '高中', '招6人', '07-18发布', '五险一金', '员工旅游', '交通补贴', '餐饮补贴', '专业培训', '出国机会', '绩效奖金', '年终奖金', '弹性工作', '定期体检']
# ----------------------
# getTag() 运行时间: 33
# getTag()当前处理链接: https://jobs.51job.com/guangzhou/102671035.html?s=01&t=0
# getTag()获得的ip: {'http': '89.249.240.170:8080', 'https': '89.249.240.170:8080'}
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /chengdu-gxq/104635630.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response',)))
# ###当前proxies的ip数:  100
# 尝试新的proxy
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /shenyang-hpq/104664405.html?s=01&t=0 (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f395529e390>, 'Connection to 81.24.82.118 timed out. (connect timeout=5)'))
# ###当前proxies的ip数:  99
# 尝试新的proxy
# getTag()中tag_list:getTag()中tag_list:getTag()中tag_list: ['1年经验', '大专', '招2人', '07-18发布']
# ----------------------
# getTag() 运行时间: 28
# getTag()当前处理链接: https://jobs.51job.com/dalian-shkq/103225681.html?s=01&t=0
# getTag()获得的ip: {'http': '92.55.27.216:8080', 'https': '92.55.27.216:8080'}
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /shenzhen-ftq/104654488.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response',)))
# ###当前proxies的ip数:  98
# 尝试新的proxy
#  ['3-4年经验', '本科', '招5人', '07-18发布', '五险一金', '交通补贴', '餐饮补贴', '绩效奖金', '年终奖金', '定期体检', '节日福利']
# ----------------------
# getTag() 运行时间: 35
# getTag()当前处理链接: https://jobs.51job.com/jinan-gxq/84583149.html?s=01&t=0
# getTag()获得的ip: {'http': '83.167.103.103:41258', 'https': '83.167.103.103:41258'}
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /jinan/103579680.html?s=01&t=0 (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f3954616f98>, 'Connection to 81.24.82.118 timed out. (connect timeout=5)'))
# ###当前proxies的ip数:  97
# 尝试新的proxy
# getTag()中tag_list: ['3-4年经验', '大专', '招5人', '07-18发布', '周末双休', '弹性工作', '带薪年假', '包吃', '五险一金', '节日福利']
# ----------------------
# getTag() 运行时间: 36
# getTag()当前处理链接: https://jobs.51job.com/xian-gxjs/99503159.html?s=01&t=0
# getTag()获得的ip: {'http': '103.194.89.161:8080', 'https': '103.194.89.161:8080'}
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /jinan-gxq/84583149.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response',)))
# ###当前proxies的ip数:  96
# 尝试新的proxy
# getTag()中tag_list:getTag()中tag_list: ['无工作经验', '本科', '招3人', '07-18发布', '五险一金', '餐饮补贴', '通讯补贴', '定期体检', '补充公积金', '员工旅游', '专业培训', '年终奖金', '绩效奖金', '商业保险']
# ----------------------
# getTag() 运行时间: 25
# getTag()当前处理链接: https://jobs.51job.com/beijing-hdq/101751141.html?s=01&t=0
# getTag()获得的ip: {'http': '95.87.19.16:8080', 'https': '95.87.19.16:8080'}
# getTag()中tag_list:getTag()中tag_list:getTag()中tag_list: ['5-7年经验', '本科', '招3人', '07-18发布', '五险一金', '采暖补贴', '高温补贴', '餐饮补贴', '定期体检', '绩效奖金', '专业培训']
# ----------------------
# getTag() 运行时间: 37
# getTag()当前处理链接: https://jobs.51job.com/ningbo/103846149.html?s=01&t=0
# getTag()获得的ip: {'http': '95.87.19.16:8080', 'https': '95.87.19.16:8080'}
#  ['5-7年经验', '大专', '招2人', '07-18发布', '周末双休', '弹性工作', '带薪年假', '五险一金', '全勤奖', '节日福利', '专业培训', '餐饮补贴', '交通补贴', '通讯补贴']
# ----------------------
# getTag() 运行时间: 29
# getTag()当前处理链接: https://jobs.51job.com/wuhan-hsq/104658137.html?s=01&t=0
# getTag()获得的ip: {'http': '95.87.19.16:8080', 'https': '95.87.19.16:8080'}
# getTag()中tag_list:getTag()中tag_list: ['2年经验', '本科', '招2人', '07-18发布']
# ----------------------
# getTag() 运行时间: 35
# getTag()当前处理链接: https://jobs.51job.com/beijing-syq/98608688.html?s=01&t=0
# getTag()获得的ip: {'http': '95.87.19.16:8080', 'https': '95.87.19.16:8080'}
# getTag()中tag_list: ['无工作经验', '硕士', '招若干人', '07-18发布', '五险一金', '交通补贴', '餐饮补贴', '通讯补贴', '年终奖金', '专业培训', '节假日福利', '住房补贴', '工龄补贴']
# ----------------------
# getTag() 运行时间: 32
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /hangzhou-bjq/104647757.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', ConnectionResetError(104, 'Connection reset by peer')))
# ###当前proxies的ip数:  95
# 尝试新的proxy
# getTag()中tag_list:getTag()当前处理链接: https://jobs.51job.com/xiaogan/51449297.html?s=01&t=0
# getTag()获得的ip: {'http': '118.97.87.186:8080', 'https': '118.97.87.186:8080'}
#  ['1年经验', '大专', '招4人', '07-18发布', '五险一金', '免费班车', '年终奖金', '绩效奖金', '周末双休', '员工旅游']
# ----------------------
# getTag() 运行时间: 36
# getTag()当前处理链接: https://jobs.51job.com/beijing/101904701.html?s=01&t=0
# getTag()获得的ip: {'http': '118.97.87.186:8080', 'https': '118.97.87.186:8080'}
#  ['2年经验', '本科', '招10人', '07-18发布', '餐饮补贴', '五险一金', '年终奖金', '定期体检', '绩效奖金']
# ----------------------
# getTag() 运行时间: 38
# getTag()当前处理链接: https://jobs.51job.com/shanghai-pdxq/77514369.html?s=01&t=0
# getTag()获得的ip: {'http': '118.97.87.186:8080', 'https': '118.97.87.186:8080'}
# getTag()中tag_list: ['无工作经验', '本科', '招5人', '07-18发布', '五险一金', '绩效奖金', '定期体检']
# ----------------------
# getTag() 运行时间: 25
# getTag()当前处理链接: https://jobs.51job.com/harbin/92496223.html?s=01&t=0
# getTag()获得的ip: {'http': '118.97.87.186:8080', 'https': '118.97.87.186:8080'}
#  ['1年经验', '大专', '招1人', '07-18发布', '五险一金', '员工旅游', '定期体检', '绩效奖金', '年终奖金']
# ----------------------
# getTag() 运行时间: 38
# getTag()当前处理链接: https://jobs.51job.com/kunming/78909643.html?s=01&t=0
# getTag()获得的ip: {'http': '118.97.87.186:8080', 'https': '118.97.87.186:8080'}
# getTag()中tag_list: ['3-4年经验', '大专', '招6人', '07-18发布', '五险一金', '补充医疗保险', '员工旅游', '专业培训', '定期体检', '12天带薪年假']
# ----------------------
# getTag() 运行时间: 34
#  ['3-4年经验', '本科', '招3人', '07-18发布', '五险一金', '补充医疗保险', '餐饮补贴', '专业培训', '出国机会', '弹性工作', '定期体检', '双休', '带薪年假']
# ----------------------
# getTag() 运行时间: 34
# getTag()当前处理链接: https://jobs.51job.com/shenzhen/104662912.html?s=01&t=0
# getTag()获得的ip: {'http': '118.97.87.186:8080', 'https': '118.97.87.186:8080'}
#  ['3-4年经验', '本科', '招5人', '07-18发布', '餐饮补贴', '周末双休', '带薪年假', '五险一金']
# ----------------------
# getTag() 运行时间: 39
# getTag()当前处理链接: https://jobs.51job.com/beijing-cyq/104663042.html?s=01&t=0
# getTag()获得的ip: {'http': '118.97.87.186:8080', 'https': '118.97.87.186:8080'}
# getTag()中tag_list:HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /beijing-syq/98608688.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response',)))
# ###当前proxies的ip数:  94
# 尝试新的proxy
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /ningbo/103846149.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response',)))
# ###当前proxies的ip数:  93
# 尝试新的proxy
# getTag()当前处理链接: https://jobs.51job.com/fuzhou/88629127.html?s=01&t=0
# getTag()获得的ip: {'http': '41.193.222.58:3128', 'https': '41.193.222.58:3128'}
# getTag()中tag_list:getTag()中tag_list: ['无工作经验', '招4人', '07-18发布', '五险一金', '补充医疗保险', '年终奖金', '定期体检']
# ----------------------
# getTag() 运行时间: 33
# getTag()当前处理链接: https://jobs.51job.com/chengdu-gxq/104656772.html?s=01&t=0
# getTag()获得的ip: {'http': '41.193.222.58:3128', 'https': '41.193.222.58:3128'}
#  ['无工作经验', '本科', '招若干人', '07-18发布', '五险一金', '员工旅游', '餐饮补贴', '绩效奖金', '年终奖金', '弹性工作', '定期体检']
# ----------------------
# getTag() 运行时间: 20
# getTag()当前处理链接: https://jobs.51job.com/wuhan-wcq/103293973.html?s=01&t=0
# getTag()获得的ip: {'http': '41.193.222.58:3128', 'https': '41.193.222.58:3128'}
#  ['3-4年经验', '本科', '招若干人', '07-18发布', '餐饮补贴', '专业培训', '绩效奖金', '弹性工作', '年终奖金']
# ----------------------
# getTag() 运行时间: 39
# getTag()当前处理链接: https://jobs.51job.com/nanchang-hgt/93483016.html?s=01&t=0
# getTag()获得的ip: {'http': '41.193.222.58:3128', 'https': '41.193.222.58:3128'}
# getTag()中tag_list:getTag()中tag_list: ['3-4年经验', '大专', '招1人', '07-18发布', '专业培训', '餐饮补贴', '通讯补贴', '员工旅游', '绩效奖金', '年终奖金', '定期体检']
# ----------------------
# getTag() 运行时间: 37
# getTag()当前处理链接: https://jobs.51job.com/zhongyuanqu/81026870.html?s=01&t=0
# getTag()获得的ip: {'http': '41.193.222.58:3128', 'https': '41.193.222.58:3128'}
#  ['5-7年经验', '本科', '招若干人', '07-18发布', '五险一金', '补充医疗保险', '补充公积金', '员工旅游', '餐饮补贴', '通讯补贴', '专业培训', '绩效奖金', '年终奖金', '弹性工作']
# ----------------------
# getTag() 运行时间: 39
# getTag()当前处理链接: https://jobs.51job.com/zhengzhou-gxq/102708479.html?s=01&t=0
# getTag()获得的ip: {'http': '41.193.222.58:3128', 'https': '41.193.222.58:3128'}
#  ['无工作经验', '招8人', '07-18发布']
# ----------------------
# getTag() 运行时间: 34
# getTag()当前处理链接: https://jobs.51job.com/wuhan-dxhq/101602394.html?s=01&t=0
# getTag()获得的ip: {'http': '41.193.222.58:3128', 'https': '41.193.222.58:3128'}
# getTag()中tag_list: ['3-4年经验', '大专', '招1人', '07-18发布', '五险一金', '补充医疗保险', '绩效奖金', '年终奖金', '定期体检', '五天八小时']
# ----------------------
# getTag() 运行时间: 40
# getTag()当前处理链接: https://jobs.51job.com/chengdu/98821196.html?s=01&t=0
# getTag()获得的ip: {'http': '41.193.222.58:3128', 'https': '41.193.222.58:3128'}
# getTag()中tag_list:getTag()中tag_list: ['3-4年经验', '本科', '招2人', '07-18发布', '五险一金', '年终奖金', '餐饮补贴', '交通补贴', '绩效奖金']
# ----------------------
# getTag() 运行时间: 39
# getTag()当前处理链接: https://jobs.51job.com/beijing-dcq/103685008.html?s=01&t=0
# getTag()获得的ip: {'http': '41.193.222.58:3128', 'https': '41.193.222.58:3128'}
# getTag()中tag_list: ['1年经验', '大专', '招3人', '07-18发布', '五险一金', '员工旅游', '交通补贴', '年终奖金', '补充商业险', '生日礼物', '带薪年假', '周末双休', '节日福利', '团队聚餐']
# ----------------------
# getTag() 运行时间: 43
# getTag()当前处理链接: https://jobs.51job.com/shenzhen-lhq/67648701.html?s=01&t=0
# getTag()获得的ip: {'http': '41.193.222.58:3128', 'https': '41.193.222.58:3128'}
#  ['3-4年经验', '招2人', '07-18发布', '做五休二', '五险一金', '周末双休', '全勤奖', '绩效奖金', '专业培训']
# ----------------------
# getTag() 运行时间: 44
# getTag()当前处理链接: https://jobs.51job.com/changsha/52369819.html?s=01&t=0
# getTag()获得的ip: {'http': '41.193.222.58:3128', 'https': '41.193.222.58:3128'}
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /chengdu-gxq/104635630.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# ###当前proxies的ip数:  92
# 尝试新的proxy
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /xiaogan/51449297.html?s=01&t=0 (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f3952db89b0>, 'Connection to 118.97.87.186 timed out. (connect timeout=5)'))
# ###当前proxies的ip数:  91
# 尝试新的proxy
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /shenzhen/104662912.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response',)))
# ###当前proxies的ip数:  90
# 尝试新的proxy
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /kunming/78909643.html?s=01&t=0 (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f3952d13358>, 'Connection to 118.97.87.186 timed out. (connect timeout=5)'))
# ###当前proxies的ip数:  89
# 尝试新的proxy
# getTag()中tag_list:HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /shanghai-pdxq/77514369.html?s=01&t=0 (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f3952d0d470>, 'Connection to 118.97.87.186 timed out. (connect timeout=5)'))
# ###当前proxies的ip数:  88
# 尝试新的proxy
#  ['2年经验', '本科', '招若干人', '07-18发布', '五险一金', '绩效奖金', '定期体检', '交通补贴', '项目工作奖', '弹性工作', '股票期权']
# ----------------------
# getTag() 运行时间: 36
# getTag()当前处理链接: https://jobs.51job.com/xian/104047476.html?s=01&t=0
# getTag()获得的ip: {'http': '90.154.25.104:8080', 'https': '90.154.25.104:8080'}
# getTag()中tag_list: ['无工作经验', '招若干人', '07-18发布']
# ...
#  ['无工作经验', '本科', '招3人', '07-18发布', '五险一金', '专业培训', '年终奖金', '提供住宿']
# ----------------------
# getTag() 运行时间: 39
# getTag()当前处理链接: https://jobs.51job.com/wuhan-hsq/103250384.html?s=01&t=0
# getTag()获得的ip: {'http': '90.154.25.104:8080', 'https': '90.154.25.104:8080'}
# getTag()中tag_list:getTag()中tag_list: ['3-4年经验', '招2人', '07-18发布', '股票期权', '年终奖金', '弹性工作', '员工旅游', '出国机会']
# ----------------------
# getTag() 运行时间: 22
# getTag()中tag_list: ['3-4年经验', '本科', '招1人', '07-18发布']
# ----------------------
# getTag() 运行时间: 53 ['3-4年经验', '大专', '招5人', '07-18发布', '五险一金', '补充医疗保险', '年终奖金', '定期体检']
# ----------------------
# getTag() 运行时间: 79
# getTag()当前处理链接: https://jobs.51job.com/shanghai-xhq/64477698.html?s=01&t=0
# getTag()获得的ip: {'http': '90.154.25.104:8080', 'https': '90.154.25.104:8080'}
# Thread-54 已停止
# getTag()中tag_list: ['3-4年经验', '大专', '招2人', '07-18发布']
# ----------------------
# getTag() 运行时间: 78
# getTag()中tag_list: ['2年经验', '大专', '招2人', '07-18发布', '五险一金', '年终奖金', '股票期权']
# ----------------------
# getTag() 运行时间: 27
#
#  ['3-4年经验', '本科', '招5人', '07-18发布', '绩效奖金', '专业培训', '项目奖金', '社保五险', '周末双休', '节日福利']
# ----------------------
# getTag() 运行时间: 36
# getTag()中tag_list:getTag()中tag_list:getTag()中tag_list: ['3-4年经验', '本科', '招1人', '07-18发布', '五险一金', '免费班车', '交通补贴', '通讯补贴', '专业培训', '定期体检', '餐饮补贴', '员工旅游', '股票期权', '弹性工作']
# ----------------------
# getTag() 运行时间: 39
# getTag()当前处理链接: https://jobs.51job.com/shanghai-hpq/98060865.html?s=01&t=0
# getTag()获得的ip: {'http': '90.154.25.104:8080', 'https': '90.154.25.104:8080'}
#  ['3-4年经验', '本科', '招3人', '07-18发布', '五险一金', '员工旅游', '弹性工作', '年终奖金']
# ----------------------
# getTag() 运行时间: 38
# getTag()中tag_list:getTag()中tag_list: ['无工作经验', '大专', '招2人', '07-18发布', '周末双休', '五险一金', '绩效奖金', '年终奖金', '餐饮补贴', '定期体检', '员工旅游']
# ----------------------
# getTag() 运行时间: 45
# getTag()当前处理链接: https://jobs.51job.com/beijing-cyq/104651385.html?s=01&t=0
# getTag()获得的ip: {'http': '90.154.25.104:8080', 'https': '90.154.25.104:8080'}
#  ['1年经验', '大专', '招2人', '07-18发布', '五险一金', '年终奖金', '绩效奖金', '节日福利', '带薪年假', '年底双薪']
# ----------------------
# getTag() 运行时间: 59
#  ['5-7年经验', '大专', '招1人', '07-18发布', '五险一金', '包吃', '绩效奖金', '年终奖金', '定期体检', '高温补贴', '节日福利', '带薪年假', '员工旅游', '股票期权']
# ----------------------
# getTag() 运行时间: 34
# getTag()中tag_list: ['3-4年经验', '本科', '招5人', '07-18发布', '五险一金', '补充医疗保险', '餐饮补贴', '专业培训', '绩效奖金', '定期体检']
# ----------------------
# getTag() 运行时间: 39
# getTag()当前处理链接: https://jobs.51job.com/shanghai/104656331.html?s=01&t=0
# getTag()获得的ip: {'http': '90.154.25.104:8080', 'https': '90.154.25.104:8080'}
# getTag()中tag_list:getTag()中tag_list:getTag()中tag_list: ['2年经验', '本科', '招5人', '07-18发布', '五险一金', '专业培训', '绩效奖金']
# ----------------------
# getTag() 运行时间: 50
# getTag()中tag_list: ['2年经验', '大专', '招2人', '07-18发布', '五险一金', '餐饮补贴', '弹性工作', '专业培训', '绩效奖金', '年终奖金', '员工旅游']
# ----------------------
# getTag() 运行时间: 76
# getTag()中tag_list:get_jobObjectList处理完成!getTag()中tag_list: ['3-4年经验', '大专', '招3人', '07-18发布']
# ----------------------
# getTag() 运行时间: 53
# getTag()中tag_list:getTag()中tag_list: ['3-4年经验', '本科', '招1人', '07-18发布', '五险一金', '员工旅游', '餐饮补贴', '专业培训', '年终奖金', '绩效奖金']
# ----------------------
# getTag() 运行时间: 31
# getTag()中tag_list:getTag()中tag_list: ['无工作经验', '大专', '招4人', '07-18发布']
# ----------------------
# getTag() 运行时间: 32
# getTag()中tag_list: ['2年经验', '本科', '招8人', '07-18发布', '带薪年假', '五险一金', '节日福利', '定期体检', '专业培训']
# ----------------------
# getTag() 运行时间: 41
# getTag()中tag_list: ['3-4年经验', '本科', '招1人', '07-18发布', '五险一金', '交通补贴', '绩效奖金', '年终奖金', '周末双休']
# ----------------------
# getTag() 运行时间: 40
#  ['3-4年经验', '本科', '招1人', '07-18发布', '节日福利', '专业培训', '加班补贴', '餐饮补贴', '五险一金', '弹性工作']
# ----------------------
# getTag() 运行时间: 34
#
# get_jobObjectList() 运行时间: 97
# Thread-114 已停止
# getTag()中tag_list:getTag()中tag_list: ['5-7年经验', '本科', '招2人', '07-18发布', '五险一金', '通讯补贴', '交通补贴', '年终奖金']
# ----------------------
# getTag() 运行时间: 39
#  ['5-7年经验', '大专', '招1人', '07-18发布', '六险一金', '包吃', '员工旅游', '绩效奖金', '年终奖金', '弹性工作']
# ----------------------
# getTag() 运行时间: 46
#  ['1年经验', '本科', '招2人', '07-18发布']
# ----------------------
# getTag() 运行时间: 38
#  ['5-7年经验', '本科', '招4人', '07-18发布', '五险一金', '员工旅游', '餐饮补贴', '通讯补贴', '专业培训', '绩效奖金', '年终奖金', '定期体检']
# ----------------------
# getTag() 运行时间: 88
# getTag()中tag_list:getTag()中tag_list: ['无工作经验', '招5人', '07-18发布', '五险一金', '餐饮补贴', '交通补贴', '员工旅游', '弹性工作', '年终奖金']
# ----------------------
# getTag() 运行时间: 55
# getTag()中tag_list:getTag()当前处理链接: ['无工作经验', '本科', '招3人', '07-18发布', '五险一金', '补充医疗保险', '补充公积金', '免费班车', '员工旅游', '交通补贴', '绩效奖金', '通讯补贴', '餐饮补贴', '定期体检']
# ----------------------
# getTag() 运行时间: 51
#  ['无工作经验', '大专', '招5人', '07-18发布', '五险一金', '年终奖金', '节日福利', '带薪年假', '绩效奖金', '餐饮补贴']
# ----------------------
# getTag() 运行时间: 40
#  https://jobs.51job.com/shanghai/104669671.html?s=01&t=0
# getTag()获得的ip: {'http': '90.154.25.104:8080', 'https': '90.154.25.104:8080'}
# getTag()中tag_list:getTag()中tag_list:getTag()中tag_list:getTag()中tag_list: ['3-4年经验', '本科', '招10人', '07-18发布', '五险一金', '餐饮补贴', '专业培训', '定期体检', '通讯补贴', '年终奖金']
# ----------------------
# getTag() 运行时间: 54
# Thread-74 已停止
#  ['2年经验', '本科', '招若干人', '07-18发布']
# ----------------------
# getTag() 运行时间: 43
#  ['2年经验', '大专', '招若干人', '07-18发布', '五险一金', '通讯补贴', '绩效奖金', '股票期权', '餐饮补贴', '弹性工作', '专业培训', '员工旅游']
# ----------------------
# getTag() 运行时间: 50
#  ['无工作经验', '高中', '招3人', '07-18发布', '五险一金', '定期体检', '年终奖金', '绩效奖金', '补充医疗保险']
# ----------------------
# getTag() 运行时间: 60
#  ['无工作经验', '本科', '招1人', '07-18发布', '五险一金', '交通补贴', '通讯补贴', '餐饮补贴', '专业培训', '绩效奖金', '定期体检']
# ----------------------
# getTag() 运行时间: 40
# getTag()中tag_list: ['2年经验', '招3人', '07-18发布', '五险一金', '餐饮补贴', '通讯补贴', '专业培训', '出国机会', '绩效奖金', '年终奖金', '交通补贴', '股票期权']
# ----------------------
# getTag() 运行时间: 40
#  ['2年经验', '本科', '招1人', '07-18发布', '五险一金', '补充医疗保险', '免费班车', '员工旅游', '通讯补贴', '专业培训', '绩效奖金', '年终奖金', '定期体检', '带薪年假']
# ----------------------
# getTag() 运行时间: 91
# getTag()中tag_list: ['5-7年经验', '本科', '招1人', '07-18发布', '五险一金', '补充医疗保险', '定期体检', '员工旅游', '专业培训', '年终奖金', '周末双休']getTag()中tag_list:getTag()当前处理链接: https://jobs.51job.com/guangzhou/104669725.html?s=01&t=0
# getTag()获得的ip: {'http': '90.154.25.104:8080', 'https': '90.154.25.104:8080'}
# getTag()中tag_list:getTag()中tag_list:getTag()中tag_list:getTag()中tag_list: ['无工作经验', '招2人', '07-18发布']
# ----------------------
# getTag() 运行时间: 33
#
# ----------------------
# getTag() 运行时间: 59
# getTag()当前处理链接: https://jobs.51job.com/shanghai-xhq/104669750.html?s=01&t=0
# getTag()获得的ip: {'http': '90.154.25.104:8080', 'https': '90.154.25.104:8080'}
#  ['3-4年经验', '本科', '招1人', '07-18发布', '五险一金', '定期体检', '专业培训', '绩效奖金', '员工旅游', '年终奖金', '包三餐', '免费班车']
# ----------------------
# getTag() 运行时间: 32
#  ['2年经验', '本科', '招1人', '07-18发布', '五险一金', '补充医疗保险', '通讯补贴', '绩效奖金', '定期体检']
# ----------------------
# getTag() 运行时间: 43
# getTag()中tag_list: ['3-4年经验', '本科', '招3人', '07-18发布', '五险一金', '员工旅游', '年终奖金', '定期体检']
# ----------------------
# getTag() 运行时间: 64getTag()中tag_list: ['无工作经验', '本科', '招1人', '07-18发布', '五险一金', '补充医疗保险', '员工旅游', '交通补贴', '年终奖金', '绩效奖金', '通讯补贴', '定期体检']
# ----------------------
# getTag() 运行时间: 54
# getTag()中tag_list:getTag()当前处理链接: https://jobs.51job.com/guangdongsheng/104669608.html?s=01&t=0
# getTag()获得的ip: {'http': '90.154.25.104:8080', 'https': '90.154.25.104:8080'}
#  ['3-4年经验', '大专', '招2人', '07-18发布', '带薪年假', '五险一金', '节日福利', '绩效奖金', '交通补贴', '餐饮补贴', '通讯补贴', '全勤奖']
# ----------------------
# getTag() 运行时间: 26
# getTag()中tag_list: ['2年经验', '大专', '招2人', '07-18发布']
# ----------------------
# getTag() 运行时间: 20
#  ['1年经验', '大专', '招2人', '07-18发布', '五险一金', '年终奖金', '年底分红']
# ----------------------
# getTag() 运行时间: 25
# getTag()当前处理链接: https://jobs.51job.com/changsha-yhq/85500057.html?s=01&t=0
# getTag()获得的ip: {'http': '90.154.25.104:8080', 'https': '90.154.25.104:8080'}
# getTag()中tag_list:
# getTag()中tag_list: getTag()中tag_list:['1年经验', '大专', '招3人', '07-18发布', '五险一金', '绩效奖金', '员工旅游', '股票期权']
# ----------------------
# getTag() 运行时间: 56
#  ['3-4年经验', '本科', '招2人', '07-18发布', '五险一金', '绩效奖金', '定期体检', '员工旅游']
# ----------------------
# getTag() 运行时间: 55
#  ['无工作经验', '招10人', '07-18发布', '五险一金', '免费班车', '员工旅游', '出国机会', '定期体检', '专业培训', '餐饮补贴', '交通补贴', '年终奖金', '股票期权']
# ----------------------
# getTag() 运行时间: 42
#  ['无工作经验', '大专', '招若干人', '07-18发布']
# ----------------------
# getTag() 运行时间: 20
# getTag()中tag_list: ['3-4年经验', '大专', '招1人', '07-18发布', '五险一金', '员工旅游', '专业培训', '绩效奖金']
# ----------------------
# getTag() 运行时间: 20
# getTag()中tag_list: getTag()中tag_list:getTag()中tag_list:['3-4年经验', '大专', '招10人', '07-18发布', '员工旅游', '餐饮补贴', '通讯补贴', '专业培训', '绩效奖金', '年终奖金', '定期体检', '股票期权'] ['1年经验', '大专', '招若干人', '07-18发布', '交通补贴', '餐饮补贴', '通讯补贴', '专业培训', '年终奖金', '弹性工作', '定期体检', '员工旅游', '绩效奖金']
# ----------------------
# getTag() 运行时间: 40
#  ['无工作经验', '本科', '招5人', '07-18发布', '五险一金', '交通补贴', '餐饮补贴', '年终奖金']
# ----------------------
# getTag() 运行时间: 26
#
# ----------------------
# getTag() 运行时间: 32
# getTag()当前处理链接: https://jobs.51job.com/shanghai-pdxq/104669337.html?s=01&t=0
# getTag()获得的ip: {'http': '90.154.25.104:8080', 'https': '90.154.25.104:8080'}
# Thread-75 已停止
# Thread-76 已停止
# Thread-77 已停止
# Thread-78 已停止
# Thread-79 已停止
# Thread-80 已停止
# getTag()中tag_list: getTag()中tag_list:getTag()中tag_list:getTag()中tag_list:getTag()中tag_list: ['3-4年经验', '大专', '招2人', '07-18发布'] ['5-7年经验', '大专', '招5人', '07-18发布', '五险一金', '通讯补贴', '专业培训', '绩效奖金', '周末双休', '节日福利', '交通补贴', '补充保险', '不定期加薪', '带薪假期']
# ----------------------
# getTag() 运行时间: 24
#  ['2年经验', '本科', '招2人', '07-18发布', '五险一金', '补充医疗保险', '年终奖金', '定期体检', '餐饮补贴', '通讯补贴']
# ----------------------
# getTag() 运行时间: 35
#  ['无工作经验', '本科', '招2人', '07-18发布', '做五休二', '五险一金', '绩效奖金', '高温补贴', '节日福利', '通讯补贴']
# ----------------------
# getTag() 运行时间: 93
# getTag()当前处理链接:['3-4年经验', '大专', '招若干人', '07-18发布', '五险一金', '周末双休', '节日福利', '股票期权']
# getTag()当前处理链接:
#  https://jobs.51job.com/chengdu/104664832.html?s=01&t=0
# getTag()获得的ip: {'http': '90.154.25.104:8080', 'https': '90.154.25.104:8080'}
# ----------------------
#  https://jobs.51job.com/shanghai-hpq/95060609.html?s=01&t=0
# getTag()获得的ip: {'http': '90.154.25.104:8080', 'https': '90.154.25.104:8080'}
# getTag()中tag_list: ['3-4年经验', '本科', '招6人', '07-18发布', '五险一金', '餐饮补贴', '绩效奖金', '年终奖金']
# ----------------------
# getTag() 运行时间: 21
# getTag() 运行时间: 54
# getTag()当前处理链接:----------------------
# getTag() 运行时间: 29
#  https://jobs.51job.com/shenzhen-nsq/104362337.html?s=01&t=0
# getTag()获得的ip: {'http': '90.154.25.104:8080', 'https': '90.154.25.104:8080'}
# getTag()中tag_list:getTag()当前处理链接: https://jobs.51job.com/shanghai-pdxq/101468790.html?s=01&t=0 getTag()当前处理链接:getTag()当前处理链接:getTag()当前处理链接: https://jobs.51job.com/shenzhen-baq/103526714.html?s=01&t=0
# getTag()获得的ip: {'http': '90.154.25.104:8080', 'https': '90.154.25.104:8080'}
#
# getTag()获得的ip: {'http': '90.154.25.104:8080', 'https': '90.154.25.104:8080'}
# getTag()当前处理链接:getTag()中tag_list: ['无工作经验', '大专', '招2人', '07-18发布', '五险一金', '员工旅游', '通讯补贴', '年终奖金', '高温补贴', '弹性工作']
# ----------------------
# getTag() 运行时间: 31
# getTag()中tag_list:  ['3-4年经验', '大专', '招1人', '07-18发布', '五险一金', '弹性工作', '补充公积金', '餐饮补贴']
# ----------------------
#  https://jobs.51job.com/guangzhou-thq/95935316.html?s=01&t=0
# getTag()获得的ip: {'http': '90.154.25.104:8080', 'https': '90.154.25.104:8080'}
# ['3-4年经验', '本科', '招2人', '07-18发布', '五险一金', '年终奖金', '绩效奖金', '交通补贴', '餐饮补贴', '通讯补贴']
# ----------------------
# getTag() 运行时间: 23
#  https://jobs.51job.com/xian-wyq/88542509.html?s=01&t=0
# getTag()获得的ip: {'http': '90.154.25.104:8080', 'https': '90.154.25.104:8080'}getTag() 运行时间: 37
# https://jobs.51job.com/hangzhou-xsq/86940183.html?s=01&t=0
# getTag()获得的ip: {'http': '90.154.25.104:8080', 'https': '90.154.25.104:8080'}
# Thread-94 已停止
# Thread-95 已停止
# Thread-96 已停止
# Thread-97 已停止
# Thread-98 已停止
# Thread-99 已停止
# getTag()当前处理链接:
# getTag()中tag_list: ['3-4年经验', '本科', '招2人', '07-18发布', '做五休二', '节日福利', '五险一金', '带薪年假', '弹性工作', '周末双休', '专业培训', '通讯补贴']
# ----------------------
# getTag() 运行时间: 71
# getTag()当前处理链接: getTag()当前处理链接:getTag()中tag_list: ['3-4年经验', '大专', '招1人', '07-18发布', '五险一金', '员工旅游', '绩效奖金', '定期体检', '餐饮补贴', '年终奖金']getTag()中tag_list: ['3-4年经验', '本科', '招2人', '07-18发布', '员工旅游', '绩效奖金', '年终奖金', '专业培训', '股票期权', '弹性工作', '定期体检', '出国机会', '五险一金']
# ----------------------
# https://jobs.51job.com/guangzhou-thq/86164623.html?s=01&t=0
# getTag()获得的ip: {'http': '90.154.25.104:8080', 'https': '90.154.25.104:8080'}
# getTag()当前处理链接:getTag() 运行时间: 32
# getTag()中tag_list:getTag()当前处理链接: https://jobs.51job.com/hangzhou/101814920.html?s=01&t=0
# getTag()获得的ip: {'http': '90.154.25.104:8080', 'https': '90.154.25.104:8080'}
#
# ----------------------
# getTag() 运行时间: 59
#  https://jobs.51job.com/hangzhou-yhq/93389759.html?s=01&t=0
# getTag()获得的ip: getTag()当前处理链接: https://jobs.51job.com/yantai/83985791.html?s=01&t=0
# getTag()获得的ip: {'http': '90.154.25.104:8080', 'https': '90.154.25.104:8080'}
#  https://jobs.51job.com/tianjin/104668949.html?s=01&t=0
# getTag()获得的ip: {'http': '90.154.25.104:8080', 'https': '90.154.25.104:8080'}
#  https://jobs.51job.com/shenzhen/94323275.html?s=01&t=0
# getTag()获得的ip: {'http': '90.154.25.104:8080', 'https': '90.154.25.104:8080'}
# {'http': '90.154.25.104:8080', 'https': '90.154.25.104:8080'} ['无工作经验', '本科', '招2人', '07-18发布']getTag()中tag_list:
#  ['无工作经验', '本科', '招若干人', '07-18发布', '五险一金', '专业培训', '年终奖金', '绩效奖金']
# ----------------------
# getTag() 运行时间: 19
#
# ----------------------
# getTag() 运行时间: 41
# getTag()中tag_list: Thread-55 已停止
# getTag()中tag_list:Thread-56 已停止
# Thread-57 已停止
#  ['3-4年经验', '本科', '招若干人', '07-18发布', '五险一金', '补充医疗保险', '专业培训', '定期体检', '16天年假', '补充养老保险', '不强制加班', '弹性工作']
# ----------------------
# getTag() 运行时间: 25
# getTag()中tag_list: ['2年经验', '本科', '招2人', '07-18发布']['无工作经验', '招1人', '07-18发布', '五险一金']
# ----------------------
# getTag() 运行时间: 28
#
# ----------------------
# getTag() 运行时间: 45
# Thread-100 已停止
# Thread-101 已停止
# Thread-102 已停止
# Thread-103 已停止
# Thread-104 已停止
# Thread-105 已停止
# Thread-106 已停止
# Thread-107 已停止
# Thread-108 已停止
# Thread-109 已停止
# Thread-110 已停止
# Thread-111 已停止
# Thread-112 已停止
# getTag()中tag_list: ['5-7年经验', '大专', '招5人', '07-18发布', '五险一金', '免费班车', '员工旅游', '弹性工作', '绩效奖金', '年终奖金']
# ----------------------
# Thread-113 已停止
# tag组装完成!
# pack_tag() 运行时间: 104
# getTag() 运行时间: 37
# getTag()中tag_list:getTag()中tag_list: ['2年经验', '本科', '招6人', '07-18发布', '五险一金', '员工旅游', '交通补贴', '年终奖金', '绩效奖金', '餐饮补贴', '通讯补贴', '专业培训', '股票期权']
# ----------------------
# getTag() 运行时间: 27
# Thread-58 已停止
# Thread-59 已停止
# Thread-60 已停止
# Thread-61 已停止
# Thread-62 已停止
# Thread-63 已停止
# Thread-64 已停止
# Thread-65 已停止
# Thread-66 已停止
# Thread-67 已停止
# Thread-68 已停止
# Thread-69 已停止
# Thread-70 已停止
# Thread-71 已停止
# Thread-72 已停止
# Thread-73 已停止
# tag组装完成!
# pack_tag() 运行时间: 107
#  getTag()中tag_list: ['3-4年经验', '本科', '招若干人', '07-18发布', '五险', '专业培训', '员工旅游', '交通补贴', '绩效奖金', '通讯补贴']
# ----------------------
# getTag() 运行时间: 31['3-4年经验', '本科', '招3人', '07-18发布', '五险一金', '餐饮补贴', '年终奖金', '绩效奖金']
# ----------------------
# getTag() 运行时间: 53
# Thread-50完成单页的时间: 114
#
# get_jobObjectList()当前处理链接: https://search.51job.com/list/000000,000000,0000,00,9,99,Java,2,6.html?lang=c&stype=&postchannel=0000&workyear=99&cotype=99&degreefrom=99&jobterm=99&companysize=99&providesalary=99&lonlat=0%2C0&radius=-1&ord_field=0&confirmdate=9&fromType=&dibiaoid=0&address=&line=&specialarea=00&from=&welfare=
# Thread-53完成单页的时间: 115
# getTag()中tag_list:get_jobObjectList()当前处理链接: https://search.51job.com/list/000000,000000,0000,00,9,99,Java,2,7.html?lang=c&stype=&postchannel=0000&workyear=99&cotype=99&degreefrom=99&jobterm=99&companysize=99&providesalary=99&lonlat=0%2C0&radius=-1&ord_field=0&confirmdate=9&fromType=&dibiaoid=0&address=&line=&specialarea=00&from=&welfare=
#  ['3-4年经验', '本科', '招若干人', '07-18发布', '五险一金', '周末双休', '交通补贴', '绩效奖金', '年终奖金', '大牛多多', '弹性工作', '员工旅游', '专业培训']
# ----------------------
# getTag() 运行时间: 39
# Thread-115 已停止getTag()中tag_list: ['2年经验', '本科', '招2人', '07-18发布', '五险一金', '补充医疗保险', '员工旅游', '交通补贴', '通讯补贴', '专业培训', '绩效奖金', '年终奖金', '股票期权', '弹性工作']
# ----------------------
# getTag() 运行时间: 26
#
# Thread-116 已停止
# Thread-117 已停止
# Thread-118 已停止
# Thread-119 已停止
# Thread-120 已停止
# getTag()中tag_list: ['3-4年经验', '大专', '招5人', '07-18发布', '五险一金', '免费班车', '弹性工作', '年终奖金', '免费食宿']
# ----------------------
# getTag() 运行时间: 19
# getTag()当前处理链接: https://jobs.51job.com/guangzhou-lwq/103434434.html?s=01&t=0
# getTag()获得的ip: {'http': '90.154.25.104:8080', 'https': '90.154.25.104:8080'}
# getTag()中tag_list: ['3-4年经验', '本科', '招1人', '07-18发布', '五险一金', '餐饮补贴', '弹性工作', '节日福利', '绩效奖金', '带薪年假']
# ----------------------
# getTag() 运行时间: 44
# getTag()中tag_list:

# %% [raw]
# 当清洗ip的代码清理出去之后，proxy变成全局变量，读取连接时都使用同一个ip来链接，知道这个ip不可用，才获取下一个ip，
# 跑了一下发现，清洗一次的ip就足够爬10页的数据，大大缩减了时间
#
# 之前的程序是每个线程读取新的一页，就自己清洗一遍ip,然后在开始处理单页，消耗很多时间，也浪费很多ip
# ------------------------------------------------------------------------------------
# 10页2线程300秒
# 10页4线程264秒
