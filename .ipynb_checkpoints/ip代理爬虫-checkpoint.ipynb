# %%
import requests

# %%
# 先要去free proxy list网站把ip爬下来先爬一页
# 但是看不到ajax发送请求，不知道怎么加载数据的
# 先爬单页的ip下来用着
# 我在重新刷新了网页之后，在chrome中查看Preview
# 发现原来所有的数据都在一页
# js把它们隐藏起来了

url = 'https://free-proxy-list.net/'
r = requests.get(url)
r.status_code
# Out:
# 200

# %%
from bs4 import BeautifulSoup

# %%
html = r.text
soup = BeautifulSoup(html, features='html5lib')

# %%
soup.prettify
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# <html lang="en"><head><meta charset="utf-8"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="width=device-width,initial-scale=1,maximum-scale=1" name="viewport"/><meta content="origin" name="referrer"/><link href="https://cdn.jsdelivr.net/bootstrap/3.3.7/css/bootstrap.min.css" rel="stylesheet"/><link href="https://cdn.datatables.net/1.10.15/css/dataTables.bootstrap.min.css" rel="stylesheet"/><link href="https://cdn.jsdelivr.net/fontawesome/4.5.0/css/font-awesome.min.css" rel="stylesheet"/><link href="https://free-proxy-list.net/css/fpl18613.css" rel="stylesheet"/><link href="https://fonts.googleapis.com/css?family=Montserrat:400,600" rel="stylesheet"/><link href="https://free-proxy-list.net/favicon.ico" rel="icon"/><meta content="Here are the latest 300 free proxies that are just checked and added into our proxy list. The proxy list is updated every 10 minutes to keep fresh." name="description"/><title>Free Proxy List - Just Checked Proxy List</title></head><body><script>(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
# ga('create', 'UA-158616-8', 'auto');</script><nav class="navbar navbar-default navbar-fixed-top"><div class="container"><div class="navbar-header"><button class="navbar-toggle" data-target="#main-menu" data-toggle="collapse" type="button"><span class="icon-bar"></span> <span class="icon-bar"></span> <span class="icon-bar"></span></button> <a class="logo" href="https://free-proxy-list.net/">Free Proxy List</a></div><div class="collapse navbar-collapse" id="main-menu"><ul class="nav navbar-nav navbar-right" id="menu-main-menu"><li class="dropdown" id="tab_home"><a class="dropdown-toggle" data-toggle="dropdown" href="#">Free Proxy <b class="caret"></b></a><ul class="dropdown-menu"><li><a href="https://free-proxy-list.net/">New Proxy</a></li><li><a href="https://free-proxy-list.net/uk-proxy.html">UK Proxy</a></li><li><a href="https://free-proxy-list.net/web-proxy.html">Web Proxy</a></li><li><a href="https://free-proxy-list.net/anonymous-proxy.html">Anonymous Proxy</a></li><li><a href="http://www.google-proxy.net/">Google Proxy</a></li></ul></li><li id="tab_us"><a href="https://www.us-proxy.org/">US Proxy</a></li><li id="tab_socks"><a href="https://www.socks-proxy.net/">Socks Proxy</a></li><li id="tab_ssl"><a href="https://www.sslproxies.org/">SSL Proxy</a></li><li class="dropdown" id="tab_buy"><a class="dropdown-toggle" data-toggle="dropdown" href="#">Buy Proxy <b class="caret"></b></a><ul class="dropdown-menu"><li><a href="https://myiphide.com/" onclick="gaEvent('outbound', 'myiphide/navmenu', 'My IP Hide');" target="_blank">My IP Hide</a></li><li><a href="https://www.us-proxy.org/buyproxy.html" onclick="gaEvent('click', 'buyproxy/navmenu', 'Http Proxy');">Http Proxy</a></li><li><a href="https://www.socks-proxy.net/buysocksproxy.html" onclick="gaEvent('click', 'buysocks/navmenu', 'Socks Proxy');">Socks Proxy</a></li></ul></li><li class="dropdown"><a class="dropdown-toggle" data-toggle="dropdown" href="#">Company <b class="caret"></b></a><ul class="dropdown-menu"><li><a href="https://www.didsoft.com/" target="_blank">Didsoft</a></li><li><a href="https://www.didsoft.com/contact.html" target="_blank">Contact Us</a></li><li><a href="https://www.didsoft.com/product.html" target="_blank">Products</a></li></ul></li></ul></div></div></nav><style>.mb30-left{margin:6px 0 0 20px}
# #screenshot .mb30-left{margin-left:0}
# #save td, #save th {text-align:left}</style><header id="header"><div class="container"><div class="row"><div class="col-md-6"><div class="intro-text"><h2 class="intro-lead-in">My<span class="mihsp"> </span>IP<span class="mihsp"> </span>Hide is better than Free Proxy</h2><span class="intro-heading">Hide IP address and unblock websites with lightning fast, stable, and encrypted proxies.</span><div class="header-buttons"><a class="primary-button" href="#screenshot" onclick="gaEvent('click', 'mihscreen/headerbtn', 'Learn More');">Learn More  <i class="fa fa-angle-double-down"></i></a> <a class="secondary-button hidden-xs" href="#list" onclick="gaEvent('click', 'proxylist/headerbtn', 'Free Proxy');">Free Proxy</a></div></div></div><div class="col-md-6"><div class="header-dashboard"><img alt="My IP Hide" class="dashboard img-responsive" src="https://myiphide.com/images/multi-devices.png"/></div></div></div></div><div id="particles-js"></div></header><section id="list"><div class="container"><div class="text-center"><h1 class="section-heading">Free Proxy List</h1><span class="separator"></span><p class="section-subheading">Free proxies that are just checked and updated every 10 minutes</p><ul class="share-buttons hidden-print"><li><a href="https://www.facebook.com/sharer/sharer.php?u=https%3A%2F%2Ffree-proxy-list.net%2F&amp;t=" onclick="window.open('https://www.facebook.com/sharer/sharer.php?u=' + encodeURIComponent(document.URL) + '&amp;t=' + encodeURIComponent(document.URL)); gaEvent('share', 'facebook', document.URL); return false;" target="_blank" title="Share on Facebook"><i class="fa fa-facebook"></i><span class="sr-only">Share on Facebook</span></a></li><li><a href="https://twitter.com/intent/tweet?source=https%3A%2F%2Ffree-proxy-list.net%2F&amp;text=:%20https%3A%2F%2Ffree-proxy-list.net%2F" onclick="window.open('https://twitter.com/intent/tweet?text=' + encodeURIComponent(document.title) + ':%20' + encodeURIComponent(document.URL)); gaEvent('share', 'twitter', document.URL); return false;" target="_blank" title="Tweet"><i class="fa fa-twitter"></i><span class="sr-only">Tweet</span></a></li><li><a class="skype-share" href="#" onclick="gaEvent('share', 'skype', document.URL); return false;" title="Share on Skype"><i class="fa fa-skype"></i><span class="sr-only">Skype</span></a></li><li><a href="#" onclick="window.open('mailto:?subject=' + encodeURIComponent(document.title) + '&amp;body=' +  encodeURIComponent(document.URL)); gaEvent('share', 'email', document.URL); return false;" title="Send email"><i class="fa fa-envelope"></i><span class="sr-only">Send email</span></a></li><li><a href="https://plus.google.com/share?url=https%3A%2F%2Ffree-proxy-list.net%2F" onclick="window.open('https://plus.google.com/share?url=' + encodeURIComponent(document.URL)); gaEvent('share', 'googleplus', document.URL); return false;" target="_blank" title="Share on Google+"><i class="fa fa-google-plus"></i><span class="sr-only">Share on Google+</span></a></li><li><a href="#" onclick="gaEvent('share', 'print', document.URL); window.print()" title="Print"><i class="fa fa-print"></i><span class="sr-only">Print</span></a></li></ul></div><div class="table-responsive"><table cellspacing="0" class="table table-striped table-bordered" id="proxylisttable" width="100%"><thead><tr><th>IP Address</th><th>Port</th><th>Code</th><th class="hm">Country</th><th>Anonymity</th><th class="hm">Google</th><th class="hx">Https</th><th class="hm">Last Checked</th></tr></thead><tbody><tr><td>83.142.126.147</td><td>41258</td><td>PL</td><td class="hm">Poland</td><td>elite proxy</td><td class="hm">no</td><td class="hx">yes</td><td class="hm">5 seconds ago</td></tr><tr><td>43.230.156.86</td><td>8080</td><td>IN</td><td class="hm">India</td><td>elite proxy</td><td class="hm">no</td><td class="hx">yes</td><td class="hm">5 seconds ago</td></tr><tr><td>80.94.30.234</td><td>8080</td><td>PL</td><td class="hm">Poland</td><td>elite proxy</td><td class="hm">no</td><td class="hx">yes</td>< ...

# %%
div_tag = soup.find('div', 'table-responsive')

# %%
div_tag.tbody
# Out:
# <tbody><tr><td>83.142.126.147</td><td>41258</td><td>PL</td><td class="hm">Poland</td><td>elite proxy</td><td class="hm">no</td><td class="hx">yes</td><td class="hm">5 seconds ago</td></tr><tr><td>43.230.156.86</td><td>8080</td><td>IN</td><td class="hm">India</td><td>elite proxy</td><td class="hm">no</td><td class="hx">yes</td><td class="hm">5 seconds ago</td></tr><tr><td>80.94.30.234</td><td>8080</td><td>PL</td><td class="hm">Poland</td><td>elite proxy</td><td class="hm">no</td><td class="hx">yes</td><td class="hm">5 seconds ago</td></tr><tr><td>103.205.177.44</td><td>53281</td><td>PK</td><td class="hm">Pakistan</td><td>elite proxy</td><td class="hm">no</td><td class="hx">yes</td><td class="hm">5 seconds ago</td></tr><tr><td>103.75.32.113</td><td>8080</td><td>IN</td><td class="hm">India</td><td>elite proxy</td><td class="hm">no</td><td class="hx">yes</td><td class="hm">5 seconds ago</td></tr><tr><td>143.255.3.111</td><td>53281</td><td>BR</td><td class="hm">Brazil</td><td>elite proxy</td><td class="hm">no</td><td class="hx">yes</td><td class="hm">5 seconds ago</td></tr><tr><td>78.189.25.202</td><td>8080</td><td>TR</td><td class="hm">Turkey</td><td>elite proxy</td><td class="hm">no</td><td class="hx">yes</td><td class="hm">5 seconds ago</td></tr><tr><td>200.90.8.82</td><td>53281</td><td>VE</td><td class="hm">Venezuela</td><td>elite proxy</td><td class="hm">no</td><td class="hx">yes</td><td class="hm">5 seconds ago</td></tr><tr><td>45.115.70.252</td><td>8080</td><td>AU</td><td class="hm">Australia</td><td>elite proxy</td><td class="hm">no</td><td class="hx">yes</td><td class="hm">5 seconds ago</td></tr><tr><td>194.24.240.133</td><td>8080</td><td>RU</td><td class="hm">Russian Federation</td><td>elite proxy</td><td class="hm">no</td><td class="hx">yes</td><td class="hm">5 seconds ago</td></tr><tr><td>164.115.241.50</td><td>53281</td><td>TH</td><td class="hm">Thailand</td><td>elite proxy</td><td class="hm">no</td><td class="hx">yes</td><td class="hm">5 seconds ago</td></tr><tr><td>58.181.39.182</td><td>80</td><td>KR</td><td class="hm">Korea</td><td>elite proxy</td><td class="hm">no</td><td class="hx">yes</td><td class="hm">5 seconds ago</td></tr><tr><td>103.76.53.22</td><td>53281</td><td>IN</td><td class="hm">India</td><td>elite proxy</td><td class="hm">no</td><td class="hx">yes</td><td class="hm">5 seconds ago</td></tr><tr><td>81.21.85.191</td><td>8080</td><td>AZ</td><td class="hm">Azerbaijan</td><td>elite proxy</td><td class="hm">no</td><td class="hx">yes</td><td class="hm">5 seconds ago</td></tr><tr><td>46.32.70.188</td><td>8080</td><td>RU</td><td class="hm">Russian Federation</td><td>elite proxy</td><td class="hm">no</td><td class="hx">yes</td><td class="hm">5 seconds ago</td></tr><tr><td>103.78.53.199</td><td>8080</td><td>BD</td><td class="hm">Bangladesh</td><td>elite proxy</td><td class="hm">no</td><td class="hx">yes</td><td class="hm">5 seconds ago</td></tr><tr><td>103.76.174.170</td><td>8080</td><td>ID</td><td class="hm">Indonesia</td><td>elite proxy</td><td class="hm">no</td><td class="hx">yes</td><td class="hm">5 seconds ago</td></tr><tr><td>217.112.214.62</td><td>41258</td><td>UA</td><td class="hm">Ukraine</td><td>elite proxy</td><td class="hm">no</td><td class="hx">yes</td><td class="hm">5 seconds ago</td></tr><tr><td>89.35.145.21</td><td>41258</td><td>PL</td><td class="hm">Poland</td><td>elite proxy</td><td class="hm">no</td><td class="hx">yes</td><td class="hm">5 seconds ago</td></tr><tr><td>140.227.71.55</td><td>3128</td><td>JP</td><td class="hm">Japan</td><td>elite proxy</td><td class="hm">no</td><td class="hx">yes</td><td class="hm">5 seconds ago</td></tr><tr><td>42.115.74.248</td><td>8080</td><td>KH</td><td class="hm">Cambodia</td><td>elite proxy</td><td class="hm">no</td><td class="hx">yes</td><td class="hm">5 seconds ago</td></tr><tr><td>137.74.254.242</td><td>3128</td><td>FR</td><td class="hm">France</td><td>elite proxy</td><td class="hm">no</td><td class="hx">yes</td><td class="hm">5 seconds ago</td></tr><tr><t ...

# %%
div_tag.tbody.tr
# Out:
# <tr><td>83.142.126.147</td><td>41258</td><td>PL</td><td class="hm">Poland</td><td>elite proxy</td><td class="hm">no</td><td class="hx">yes</td><td class="hm">5 seconds ago</td></tr>

# %%
tbody_list = div_tag.tbody.contents

# %%
ip = tbody_list[0].next_element.string

# %%
port = tbody_list[0].next_element.next_sibling.string

# %%
print('%s:%s' % (ip, port))
# Out:
# 83.142.126.147:41258

# %%
# 把所有ip写入文件
tbody_list = div_tag.tbody.contents
result = ''
for tr in tbody_list:
    ip = tr.next_element.string
    port = tr.next_element.next_sibling.string
    result += ip + ':' + port + '\n'
    

with open('ip_pool.txt', 'w') as f:
    f.write(result)
