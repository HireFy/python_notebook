# %%
import requests
from bs4 import BeautifulSoup
import queue
import threading
import re
import csv
import functools
import os
from time import time

# %%
class jobObject:
    'job描述对象'
    __slots__ = ('tag_href', 'job', 'company', 'address', 'salary', 'tag')

# %%
# 获取函数运行时间装饰器
def excute_time(func):
    @functools.wraps(func)
    def wrapper(*args, **kwargs):
        start = time()
        result = func(*args, **kwargs)
        spend = time() - start
        print('%s() 运行时间: %d' % (func.__name__, spend))
        thread_num = ''
        if 'thread_num' in kwargs:
            thread_num = kwargs['thread_num']
        
        # 运行时间写入文件
        headers = ['函数', '运行时间', '线程数']
        if os.path.isfile('运行时间统计.csv'):
            with open('运行时间统计.csv', 'a', newline='') as f:
                writer = csv.DictWriter(f, headers)
                data = {'函数':func.__name__, '运行时间':spend, '线程数':thread_num}
                writer.writerow(data)
        else:
            with open('运行时间统计.csv', 'a', newline='') as f:
                writer = csv.DictWriter(f, headers)
                writer.writeheader()
                data = {'函数':func.__name__, '运行时间':spend, '线程数':thread_num}
                writer.writerow(data)
            
        return result
    return wrapper

# %%
# 打印当前运行线程信息
def get_current_thread_info(func):
    @functools.wraps(func)
    def wrapper(*args, **kwargs):
        print('[%s()] %s processing!' % (func.__name__, threading.current_thread().name))
        #print('[%s()] processing!' % (func.__name__))
        return func(*args, **kwargs)
    return wrapper

# %%
# free-proxy-list.net上面的ip保存在本地ip_pool.txt文件
@excute_time
def ipToFile(file_name='ip_pool.txt'):
    url = 'https://free-proxy-list.net/'
    r = requests.get(url)
    html = r.text
    soup = BeautifulSoup(html, features='html5lib')
    div_tag = soup.find('div', 'table-responsive')
    tbody_list = div_tag.tbody.contents
    result = ''
    for tr in tbody_list:
        ip = tr.next_element.string
        port = tr.next_element.next_sibling.string
        result += ip + ':' + port + '\n'

    with open(file_name, 'w') as f:
        f.write(result)

# %%
# 从ip_pool读取ip信息
# 返回proxies(queue)
@excute_time
def getIPool(file_name='ip_pool.txt'):
    proxies = queue.Queue()

    with open(file_name, 'r') as f:
        ip_pool = f.read()

    ip_pool = ip_pool.split('\n')

    # 删除最后一个空值
    del ip_pool[-1]

    for ip in ip_pool:
        proxy = {'http': ip, 'https': ip}
        proxies.put(proxy)

    return proxies

# %%
# 获得清理过后的proxies
# 剔除不能连接网页的proxy
# 接收queue, 线程数
# 返回清洗之后的proxies(queue)
@excute_time
def getCleanProxies(proxies, **thread_num):
    #     url = 'http://www.baidu.com'
    url = 'https://jobs.51job.com/'

    # 有效的ip队列
    ok_proxies = queue.Queue()

    def check_proxy(thread_proxies):

        thread_proxies_size = thread_proxies.qsize()

        for i in range(thread_proxies_size):
            thread_proxies_size = thread_proxies.qsize()
            print('当前剩余处理的ip: ', thread_proxies_size)

            # 如果当前ip为0退出当前线程
            if (thread_proxies_size == 0):
                break

            proxy = thread_proxies.get()
            try:
                r = requests.get(url, proxies=proxy, timeout=5)
                print(threading.current_thread().name + ' is processing')
                print('r.status_code:', r.status_code)
                if (r.status_code != 200):
                    print('remove proxy:', proxy)
                else:
                    ok_proxies.put(proxy)

                print('-------------------------------------')

            except requests.Timeout as e:
                print(threading.current_thread().name + ' is processing')
                print(e)
                print('remove proxy:', proxy)
                print('-------------------------------------')
            except requests.ConnectionError as e:
                print(threading.current_thread().name + ' is processing')
                print(e)
                print('remove proxy:', proxy)
                print('-------------------------------------')
            except requests.InvalidHeader as e:
                print(threading.current_thread().name + ' is processing')
                print(e)
                print('remove proxy:', proxy)
                print('-------------------------------------')


    threads = []

    for i in range(thread_num.get('thread_num')):
        thread = threading.Thread(target=check_proxy, args=(proxies,))
        threads.append(thread)

    print('线程开始：')
    for thread in threads:
        print(thread.name + '开始运行')
        thread.start()

    # 每次在剩余处理ip为0之后，程序就会停住不动
    # 当当前线程检测到剩余ip为0后，调用join()方法
    print('线程开始停止运行：')
    for thread in threads:
        thread.join()
        print(thread.name + '已停止')

    return ok_proxies

# %%
# 获得指定链接中的jobObject
# 组装成jobObjectList
# 返回jobObjectList
##############################
# 要不要返回出来交给外面的函数处理？
# 还是就在内部处理？
# 在外面封装个函数吧还是
@excute_time
def get_jobObjectList(url, proxies):
    flag = True
    proxy = proxies.get()
    # TODO 查看信息
    print('get_jobObjectList()当前处理链接:', url)
    while flag:
        try:
            r = requests.get(url, proxies=proxy, timeout=5)
            # 报了异常的话捕捉了之后
            # 获得新的proxy之后就直接开始下次循环
        except requests.exceptions.Timeout as e:
            print(e)
            proxy = proxies.get()
            print('尝试新的proxy')
            #print('----------------------')
            continue
        except requests.exceptions.ProxyError as e:
            print(e)
            proxy = proxies.get()
            print('尝试新的proxy')
            #print('----------------------')
            continue
        except requests.exceptions.ConnectionError as e:
            print(e)
            proxy = proxies.get()
            print('尝试新的proxy')
            #print('----------------------')
            continue
        
        # 不报异常就取消循环
        flag = False

    
    
    r.encoding = 'gbk'
    html = r.text
    soup = BeautifulSoup(html, features='html5lib')
    # 找到了工作列表的开头
    title = soup.find('div', 'el title')
    # 找到每一个工作列，它们分别是一个div class='el'
    job_info_list = title.find_next_siblings('div', 'el')

    # 存放当前页jobObject对象到jobObjectList中
    jobObjectList = []
    for tag in job_info_list:
        object = jobObject()
        object.tag_href = tag.find('a').attrs['href']
        object.job = tag.find('a').attrs['title']

        infos = tag.find_all(class_=re.compile('t[2-4]'))
        object.company = infos[0].string
        object.address = infos[1].string
        object.salary = infos[2].string
        jobObjectList.append(object)
    
    print('get_jobObjectList处理完成!')

    return jobObjectList

# %%
# 获取一个jobObject的tag属性列表
# 获取一个详情页标签
# 接收详情页的链接， ip代理
# 返回一个包含有标签的list
# TODO 这个函数读取网页的tag时，耗费时间比较长
# @excute_time
@get_current_thread_info
def getTag(url, proxies):
    tag_url = url
    proxy = proxies.get()

    # 存储标签的List
    tag_list = []
    flag = True

    # TODO 查看信息
    print('getTag()当前处理链接:', tag_url)
    print('getTag()获得的ip:', proxy)
    while flag:
        #     headers = {'user-agent','Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/66.0.3359.181 Chrome/66.0.3359.181 Safari/537.36'}
        try:
            r_tag = requests.get(tag_url, timeout=5, proxies=proxy)

        # 报了异常的话捕捉了之后
        # 获得新的proxy之后就直接开始下次循环
        except requests.exceptions.Timeout as e:
            print(e)
            proxy = proxies.get()
            print('尝试新的proxy')
            #print('----------------------')
            continue
        except requests.exceptions.ProxyError as e:
            print(e)
            proxy = proxies.get()
            print('尝试新的proxy')
            #print('----------------------')
            continue
        except requests.exceptions.ConnectionError as e:
            print(e)
            proxy = proxies.get()
            print('尝试新的proxy')
            #print('----------------------')
            continue
        # 不报异常就取消循环
        flag = False

    r_tag.encoding = 'gbk'
    tag_html = r_tag.text
    tag_soup = BeautifulSoup(tag_html, features='html5lib')

    # 找到详情页第一行标签
    tag_1 = tag_soup.find_all('span', 'sp4')
    for i in tag_1:
        tag_list.append(i.contents[1])

    # 找到详情页第二行标签
    tag_2 = tag_soup.find('p', 't2')

    # 有些详情页没有第二行标签
    if tag_2 is None:
        print('getTag()中tag_list:', tag_list)
        print('----------------------')
        return tag_list

    ll = []
    for i in tag_2.strings:
        ll.append(i)

    # 清除ll中的空值
    def not_empty(s):
        return s and s.strip()

    for i in filter(not_empty, ll):
        tag_list.append(i)

    print('getTag()中tag_list:', tag_list)
    print('----------------------')

    return tag_list

# %%
# 组装jobObject的tag属性
@excute_time
def pack_tag(jobObjectList, proxies, **thread_num):
    # 用一个队列来存储特定的jobObject的详情链接
    #这里都可以不用写
    # tag_href_queue = queue.Queue()
    #
    # for i in jobObjectList:
    #     print(i.tag_href)
    #     tag_href_queue.put(i.tag_href)
    #
    # print('队列中的tag_href: ', tag_href_queue.qsize())
    
    # 用队列多线程来处理
    # 不在使用单线程取列表中一个值然后处理
    jobObject_queue = queue.Queue()
    
    for jobObject in jobObjectList:
        jobObject_queue.put(jobObject)
    
    def pack_object(jobObject_queue):
        flag = True
        while flag:
            jobObject = jobObject_queue.get()
            jobObject.tag = getTag(jobObject.tag_href, proxies)
            if jobObject_queue.qsize() == 0:
                flag = False
            
    
    threads = []
    
    print('thread_num.get(\'thread_num\'): ', thread_num.get('thread_num'))
    
    for i in range(thread_num.get('thread_num')):
        thread = threading.Thread(target=pack_object, args=(jobObject_queue,))
        threads.append(thread)
    
    for thread in threads:
        thread.start()
        
        
    for thread in threads:
        thread.join()
        print('%s 已停止' % thread.name)
    

    print('tag组装完成!')

# %%
# 写入csv
@excute_time
def save_to_csv(jobObjectList):
    headers = ['职位', '公司', '地址', '薪酬', '标签']
    datas = []

    for jobObject in jobObjectList:
        data = {headers[0]: jobObject.job,
                headers[1]: jobObject.company,
                headers[2]: jobObject.address,
                headers[3]: jobObject.salary,
                headers[4]: jobObject.tag}
        datas.append(data)
        
    if os.path.isfile('51job.csv'):
        with open('51job.csv', 'a', newline='') as f:
            writer = csv.DictWriter(f, headers)
            for row in datas:
                writer.writerow(row)
    else:
        with open('51job.csv', 'a', newline='') as f:
            writer = csv.DictWriter(f, headers)
            writer.writeheader()
            for row in datas:
                writer.writerow(row)

# %%
def handle_single(url, proxies):
#     # 先爬个10页看看
#     base_url = queue.Queue()
#     for i in range(10):
#         url_str = 'https://search.51job.com/list/000000,000000,0000,00,9,99,Java,2,{}.html?lang=c&stype=&postchannel=0000&workyear=99&cotype=99&degreefrom=99&jobterm=99&companysize=99&providesalary=99&lonlat=0%2C0&radius=-1&ord_field=0&confirmdate=9&fromType=&dibiaoid=0&address=&line=&specialarea=00&from=&welfare=' \
#             .format(i + 1)
#         base_url.put(url_str)

    # while base_url.not_empty:
    #     print(base_url.get())
    
    

#     print('当前队列中页链接数:', base_url.qsize())

    # 处理ip的代码应该放在其他地方，放在这里拉低了单页的处理速度
    #  获取可用的ip
#     ipToFile()
#     proxies = getIPool()
#     proxies = getCleanProxies(proxies, 25)
#     print('可用的ip: ', proxies.qsize())}
#     threads = []

#     proxy = proxies.get()
    jobObjectList = get_jobObjectList(url, proxies)
    pack_tag(jobObjectList, proxies, thread_num=20)
    save_to_csv(jobObjectList)

# %%
def main():
    url = 'https://search.51job.com/list/000000,000000,0000,00,9,99,Java,2,1.html?lang=c&stype=&postchannel=0000&workyear=99&cotype=99&degreefrom=99&jobterm=99&companysize=99&providesalary=99&lonlat=0%2C0&radius=-1&ord_field=0&confirmdate=9&fromType=&dibiaoid=0&address=&line=&specialarea=00&from=&welfare='
    # 获取ip 
    ipToFile()
    proxies = getIPool()
    proxies = getCleanProxies(proxies, thread_num=45)
    print('可用的ip: ', proxies.qsize())
    
    start_time = time()
    handle_single(url, proxies)
    end_time = time()
    finish_time = end_time - start_time
    print('完成写入单页jobObject!')
    print('完成时间: ', finish_time)
    
    # todo 分割运行时间统计
    with open('运行时间统计.csv', 'a', newline='') as f:
        headers = ['函数', '运行时间', '线程数']
        writer = csv.DictWriter(f, headers)
        data = {'函数':'', '运行时间':'', '线程数':''}
        writer.writerow(data)

main()
# Out:
# ipToFile() 运行时间: 1
# getIPool() 运行时间: 0
# 线程开始：
# Thread-272开始运行
# 当前剩余处理的ip: Thread-273开始运行
#  300
# 当前剩余处理的ip:  299
# Thread-274开始运行
# 当前剩余处理的ip: Thread-275开始运行
#  298
# 当前剩余处理的ip: Thread-276开始运行
#  297
# 当前剩余处理的ip: Thread-277开始运行
#  296
# 当前剩余处理的ip: Thread-278开始运行
#  295
# 当前剩余处理的ip: Thread-279开始运行
#  294
# 当前剩余处理的ip: Thread-280开始运行
#  293
# 当前剩余处理的ip: Thread-281开始运行
#  292
# 当前剩余处理的ip: Thread-282开始运行
#  291
# 当前剩余处理的ip: Thread-283开始运行
#  290
# 当前剩余处理的ip: Thread-284开始运行
#  289
# 当前剩余处理的ip: Thread-285开始运行
#  288
# 当前剩余处理的ip: Thread-286开始运行
#  287
# 当前剩余处理的ip: Thread-287开始运行
#  286
# 当前剩余处理的ip: Thread-288开始运行
#  285
# 当前剩余处理的ip: Thread-289开始运行
#  284
# 当前剩余处理的ip: Thread-290开始运行
#  283
# 当前剩余处理的ip: Thread-291开始运行
#  282
# 当前剩余处理的ip: Thread-292开始运行
#  281
# 当前剩余处理的ip: Thread-293开始运行
#  280
# 当前剩余处理的ip: Thread-294开始运行
#  279
# 当前剩余处理的ip: Thread-295开始运行
#  278
# 当前剩余处理的ip: Thread-296开始运行
#  277
# 当前剩余处理的ip: Thread-297开始运行
#  276
# 当前剩余处理的ip: Thread-298开始运行
#  275
# 当前剩余处理的ip: Thread-299开始运行
#  274
# 当前剩余处理的ip: Thread-300开始运行
#  273
# 当前剩余处理的ip: Thread-301开始运行
#  272
# 当前剩余处理的ip: Thread-302开始运行
#  271
# 当前剩余处理的ip: Thread-303开始运行
#  270
# 当前剩余处理的ip: Thread-304开始运行
#  269
# 当前剩余处理的ip: Thread-305开始运行
#  268
# 当前剩余处理的ip: Thread-306开始运行
#  267
# 当前剩余处理的ip: Thread-307开始运行
#  266
# 当前剩余处理的ip: Thread-308开始运行
#  265
# 当前剩余处理的ip: Thread-309开始运行
#  264
# 当前剩余处理的ip: Thread-310开始运行
# Thread-282 is processing
# ('Connection aborted.', BadStatusLine('<html>\r\n',))
# remove proxy: {'http': '50.93.200.237:2018', 'https': '50.93.200.237:2018'}
# -------------------------------------
# 当前剩余处理的ip:  263
#  263
# 当前剩余处理的ip: Thread-311开始运行
#  261
# 当前剩余处理的ip: Thread-312开始运行
#  260
# 当前剩余处理的ip: Thread-313开始运行
#  259
# Thread-300 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 400 Bad Request',)))
# remove proxy: {'http': '52.163.120.142:8080', 'https': '52.163.120.142:8080'}
# -------------------------------------
# 当前剩余处理的ip:  258
# 当前剩余处理的ip: Thread-314开始运行
#  257
# 当前剩余处理的ip: Thread-315开始运行
#  256
# 当前剩余处理的ip: Thread-316开始运行
#  255
# 当前剩余处理的ip: 线程开始停止运行：
#  254
# Thread-285 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response',)))
# remove proxy: {'http': '1.4.213.36:8080', 'https': '1.4.213.36:8080'}
# -------------------------------------
# 当前剩余处理的ip:  253
# Thread-290 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 500 Internal Server Error',)))
# remove proxy: {'http': '52.23.176.214:80', 'https': '52.23.176.214:80'}
# -------------------------------------
# 当前剩余处理的ip:  252
# Thread-311 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response',)))
# remove proxy: {'http': '125.25.45.92:8080', 'https': '125.25.45.92:8080'}
# -------------------------------------
# 当前剩余处理的ip:  251
# Thread-272 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLError("bad handshake: SysCallError(-1, 'Unexpected EOF')",),))
# remove proxy: {'http': '188.120.231.125:80', 'https': '188.120.231.125:80'}
# -------------------------------------
# 当前剩余处理的ip:  250
# Thread-279 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 400 Bad Request',)))
# remove proxy: {'http': '216.250.99.38:80', 'https': '216.250.99.38:80'}
# -------------------------------------
# 当前剩余处理的ip:  249
# Thread-285 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 404 Not Found',)))
# remove proxy: {'http': '198.1.122.29:80', 'https': '198.1.122.29:80'}
# -------------------------------------
# 当前剩余处理的ip:  248
# Thread-303 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '177.67.83.134:80', 'https': '177.67.83.134:80'}
# -------------------------------------
# 当前剩余处理的ip:  247
# Thread-314 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', ConnectionResetError(104, 'Connection reset by peer')))
# remove proxy: {'http': '91.214.31.41:8080', 'https': '91.214.31.41:8080'}
# -------------------------------------
# 当前剩余处理的ip:  246
# Thread-301 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 500 Internal Server Error',)))
# remove proxy: {'http': '178.49.139.13:80', 'https': '178.49.139.13:80'}
# -------------------------------------
# 当前剩余处理的ip:  245
# Thread-272 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '159.89.229.66:8080', 'https': '159.89.229.66:8080'}
# -------------------------------------
# 当前剩余处理的ip:  244
# Thread-301 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 400 Bad Request',)))
# remove proxy: {'http': '47.89.241.103:8080', 'https': '47.89.241.103:8080'}
# -------------------------------------
# 当前剩余处理的ip:  243
# Thread-311 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 400 Bad Request',)))
# remove proxy: {'http': '92.38.47.226:80', 'https': '92.38.47.226:80'}
# -------------------------------------
# 当前剩余处理的ip:  242
# Thread-303 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '178.128.181.222:80', 'https': '178.128.181.222:80'}
# -------------------------------------
# 当前剩余处理的ip:  241
# Thread-281 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  240
# Thread-276 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  239
# Thread-297 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  238
# Thread-277 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  237
# Thread-314 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 502 Bad Gateway',)))
# remove proxy: {'http': '109.70.186.247:8080', 'https': '109.70.186.247:8080'}
# -------------------------------------
# 当前剩余处理的ip:  236
# Thread-274 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  235
# Thread-316 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  234
# Thread-274 is processing
# ('Connection aborted.', BadStatusLine('<html>\r\n',))
# remove proxy: {'http': '47.90.87.225:88', 'https': '47.90.87.225:88'}
# -------------------------------------
# 当前剩余处理的ip:  233
# Thread-279 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip: Thread-293 is processing 232
#
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  231
# Thread-307 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  230
# Thread-296 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  229
# Thread-274 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '66.70.190.244:8080', 'https': '66.70.190.244:8080'}
# -------------------------------------
# 当前剩余处理的ip:  228
# Thread-278 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  227
# Thread-297 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '174.138.5.199:8080', 'https': '174.138.5.199:8080'}
# -------------------------------------
# 当前剩余处理的ip:  226
# Thread-293 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '178.128.189.253:3128', 'https': '178.128.189.253:3128'}
# -------------------------------------
# 当前剩余处理的ip:  225
# Thread-285 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  224
# Thread-296 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 400 Bad Request',)))
# remove proxy: {'http': '188.166.119.186:80', 'https': '188.166.119.186:80'}
# -------------------------------------
# 当前剩余处理的ip:  223
# Thread-280 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  222
# Thread-274 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response',)))
# remove proxy: {'http': '182.93.91.244:80', 'https': '182.93.91.244:80'}
# -------------------------------------
# 当前剩余处理的ip:  221
# Thread-279 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '191.252.100.125:80', 'https': '191.252.100.125:80'}
# -------------------------------------
# 当前剩余处理的ip:  220
# Thread-298 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  219
# Thread-290 is processingThread-308 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  218
#
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  217
# Thread-289 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  216
# Thread-273 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  215
# Thread-315 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  214
# Thread-300 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  213
# Thread-288 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response',)))
# remove proxy: {'http': '182.93.89.133:80', 'https': '182.93.89.133:80'}
# -------------------------------------
# 当前剩余处理的ip:  212
# Thread-306 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  211
# Thread-275 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '114.202.2.185:80', 'https': '114.202.2.185:80'}
# -------------------------------------
# 当前剩余处理的ip:  210
# Thread-304 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  209
# Thread-292 is processingThread-309 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  208
#
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  207
# Thread-316 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  206
# Thread-291 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '212.98.150.50:80', 'https': '212.98.150.50:80'}
# -------------------------------------
# 当前剩余处理的ip:  205
# Thread-294 is processingThread-295 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '179.235.141.8:31773', 'https': '179.235.141.8:31773'}
# -------------------------------------
# 当前剩余处理的ip:  204
# Thread-305 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '80.237.54.158:8080', 'https': '80.237.54.158:8080'}
# -------------------------------------
# 当前剩余处理的ip:  203
#
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  202
# Thread-272 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip: Thread-312 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '213.136.87.38:8118', 'https': '213.136.87.38:8118'}
# -------------------------------------
# 当前剩余处理的ip:  201
#  201
# Thread-303 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '58.97.81.11:80', 'https': '58.97.81.11:80'}
# -------------------------------------
# 当前剩余处理的ip:  199
# Thread-316 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 503 Service Temporarily Unavailable',)))
# remove proxy: {'http': '213.136.89.121:80', 'https': '213.136.89.121:80'}
# -------------------------------------
# 当前剩余处理的ip:  198
# Thread-301 is processingThread-286 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  197
# Thread-293 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  196
# Thread-281 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  195
#
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  194
# Thread-311 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  193
# Thread-312 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response',)))
# remove proxy: {'http': '103.112.63.242:53281', 'https': '103.112.63.242:53281'}
# -------------------------------------
# 当前剩余处理的ip:  192
# Thread-314 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  191
# Thread-284 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  190
# Thread-287 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  189
# Thread-297 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  188
# Thread-277 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  187
# Thread-308 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  186
# Thread-283 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  185
# Thread-298 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  184
# Thread-302 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  183
# Thread-276 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  182
# Thread-313 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  181
# Thread-278 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '165.90.60.133:80', 'https': '165.90.60.133:80'}
# -------------------------------------
# 当前剩余处理的ip:  180
# Thread-296 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  179
# Thread-294 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  178
# Thread-275 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  177
# Thread-316 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 502 Bad Gateway',)))
# remove proxy: {'http': '217.119.82.14:8080', 'https': '217.119.82.14:8080'}
# -------------------------------------
# 当前剩余处理的ip:  176
# Thread-293 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', ConnectionResetError(104, 'Connection reset by peer')))
# remove proxy: {'http': '103.106.239.2:8080', 'https': '103.106.239.2:8080'}
# -------------------------------------
# 当前剩余处理的ip:  175
# Thread-290 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '191.101.25.48:3128', 'https': '191.101.25.48:3128'}
# -------------------------------------
# 当前剩余处理的ip:  174
# Thread-295 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  173
# Thread-288 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f231fa41160>, 'Connection to 31.41.92.102 timed out. (connect timeout=5)'))
# remove proxy: {'http': '31.41.92.102:41258', 'https': '31.41.92.102:41258'}
# -------------------------------------
# 当前剩余处理的ip:  172
# Thread-279 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  171
# Thread-306 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  170
# Thread-310 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '41.169.142.178:8080', 'https': '41.169.142.178:8080'}
# -------------------------------------
# 当前剩余处理的ip:  169
# Thread-273 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  168
# Thread-304 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  167
# Thread-313 is processingThread-297 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  166
#
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  165
# Thread-307 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  164
# Thread-315 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  163
# Thread-284 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 434 Requested host unavailable',)))
# remove proxy: {'http': '188.128.1.37:8080', 'https': '188.128.1.37:8080'}
# -------------------------------------
# 当前剩余处理的ip:  162
# Thread-305 is processingThread-299 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  161
#
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  160
# Thread-309 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '88.250.220.22:8080', 'https': '88.250.220.22:8080'}
# -------------------------------------
# 当前剩余处理的ip:  159
# Thread-272 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  158
# Thread-310 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 502 Bad Gateway',)))
# remove proxy: {'http': '88.147.142.25:8080', 'https': '88.147.142.25:8080'}
# -------------------------------------
# 当前剩余处理的ip:  157
# Thread-291 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  156
# Thread-286 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  155
# Thread-303 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f231fa10390>, 'Connection to 83.219.142.227 timed out. (connect timeout=5)'))
# remove proxy: {'http': '83.219.142.227:41258', 'https': '83.219.142.227:41258'}
# -------------------------------------
# 当前剩余处理的ip:  154
# Thread-272 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 503 Too many open connections',)))
# remove proxy: {'http': '5.45.107.137:8118', 'https': '5.45.107.137:8118'}
# -------------------------------------
# 当前剩余处理的ip:  153
# Thread-291 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response',)))
# remove proxy: {'http': '108.35.4.138:80', 'https': '108.35.4.138:80'}
# -------------------------------------
# 当前剩余处理的ip:  152
# Thread-301 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f231f8fee10>, 'Connection to 186.47.100.170 timed out. (connect timeout=5)'))
# remove proxy: {'http': '186.47.100.170:53281', 'https': '186.47.100.170:53281'}
# -------------------------------------
# 当前剩余处理的ip:  151
# Thread-312 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f231fa9beb8>, 'Connection to 45.125.119.62 timed out. (connect timeout=5)'))
# remove proxy: {'http': '45.125.119.62:8080', 'https': '45.125.119.62:8080'}
# -------------------------------------
# 当前剩余处理的ip:  150
# Thread-309 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  149
# Thread-279 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  148
# Thread-292 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '203.223.190.156:53281', 'https': '203.223.190.156:53281'}
# -------------------------------------
# 当前剩余处理的ip:  147
# Thread-287 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '193.34.9.140:8080', 'https': '193.34.9.140:8080'}
# -------------------------------------
# 当前剩余处理的ip:  146
# Thread-308 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f231fb69d30>, 'Connection to 103.70.128.8 timed out. (connect timeout=5)'))
# remove proxy: {'http': '103.70.128.8:8080', 'https': '103.70.128.8:8080'}
# -------------------------------------
# 当前剩余处理的ip:  145
# Thread-281 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  144
# Thread-274 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  143
# Thread-285 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  142
# Thread-296 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  141
# Thread-302 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f231fc2aa90>, 'Connection to 125.209.88.46 timed out. (connect timeout=5)'))
# remove proxy: {'http': '125.209.88.46:8080', 'https': '125.209.88.46:8080'}
# -------------------------------------
# 当前剩余处理的ip:  140
# Thread-276 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f231fa7d668>, 'Connection to 103.214.77.34 timed out. (connect timeout=5)'))
# remove proxy: {'http': '103.214.77.34:8080', 'https': '103.214.77.34:8080'}
# -------------------------------------
# 当前剩余处理的ip:  139
# Thread-316 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  138
# Thread-283 is processingThread-282 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Read timed out. (read timeout=5)
# remove proxy: {'http': '81.162.238.73:53281', 'https': '81.162.238.73:53281'}
# -------------------------------------
# 当前剩余处理的ip:  137
#
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  136
# Thread-294 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  135
# Thread-306 is processingThread-298 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  134
#
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  133
# Thread-290 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '125.99.255.126:53281', 'https': '125.99.255.126:53281'}
# -------------------------------------
# 当前剩余处理的ip:  132
# Thread-288 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f231faca278>, 'Connection to 41.206.60.162 timed out. (connect timeout=5)'))
# remove proxy: {'http': '41.206.60.162:8080', 'https': '41.206.60.162:8080'}
# -------------------------------------
# 当前剩余处理的ip:  131
# Thread-287 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  130
# Thread-273 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f231faebef0>, 'Connection to 103.18.180.22 timed out. (connect timeout=5)'))
# remove proxy: {'http': '103.18.180.22:8080', 'https': '103.18.180.22:8080'}
# -------------------------------------
# 当前剩余处理的ip:  129
# Thread-301 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  128
# Thread-302 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  127
# Thread-284 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  126
# Thread-313 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '103.90.200.26:53281', 'https': '103.90.200.26:53281'}
# -------------------------------------
# 当前剩余处理的ip:  125
# Thread-295 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  124
# Thread-299 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f2320105c18>, 'Connection to 61.14.229.42 timed out. (connect timeout=5)'))
# remove proxy: {'http': '61.14.229.42:8080', 'https': '61.14.229.42:8080'}
# -------------------------------------
# 当前剩余处理的ip:  123
# Thread-310 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  122
# Thread-305 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '103.21.161.105:6666', 'https': '103.21.161.105:6666'}
# -------------------------------------
# 当前剩余处理的ip:  121
# Thread-283 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  120
# Thread-280 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Read timed out.
# remove proxy: {'http': '189.14.193.242:53281', 'https': '189.14.193.242:53281'}
# -------------------------------------
# 当前剩余处理的ip:  119
# Thread-311 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  118
# Thread-289 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  117
# Thread-290 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  116
# Thread-291 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f231fa49d30>, 'Connection to 189.126.77.120 timed out. (connect timeout=5)'))
# remove proxy: {'http': '189.126.77.120:20183', 'https': '189.126.77.120:20183'}
# -------------------------------------
# 当前剩余处理的ip:  115
# Thread-304 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  114
# Thread-292 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '43.228.126.175:80', 'https': '43.228.126.175:80'}
# -------------------------------------
# 当前剩余处理的ip:  113
# Thread-288 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  112
# Thread-281 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f2320130a90>, 'Connection to 212.200.126.13 timed out. (connect timeout=5)'))
# remove proxy: {'http': '212.200.126.13:8080', 'https': '212.200.126.13:8080'}
# -------------------------------------
# 当前剩余处理的ip:  111
# Thread-274 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f231fa727b8>, 'Connection to 70.184.179.116 timed out. (connect timeout=5)'))
# remove proxy: {'http': '70.184.179.116:8080', 'https': '70.184.179.116:8080'}
# -------------------------------------
# 当前剩余处理的ip:  110
# Thread-275 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  109
# Thread-272 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '103.12.161.191:53281', 'https': '103.12.161.191:53281'}
# -------------------------------------
# 当前剩余处理的ip:  108
# Thread-315 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  107
# Thread-304 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 ',)))
# remove proxy: {'http': '181.49.24.126:8081', 'https': '181.49.24.126:8081'}
# -------------------------------------
# 当前剩余处理的ip:  106
# Thread-286 is processingThread-282 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  105
#
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  104
# Thread-309 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '200.52.144.77:8080', 'https': '200.52.144.77:8080'}
# -------------------------------------
# 当前剩余处理的ip:  103
# Thread-279 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  102
# Thread-297 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '139.255.113.174:8080', 'https': '139.255.113.174:8080'}
# -------------------------------------
# 当前剩余处理的ip:  101
# Thread-298 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  100
# Thread-307 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '45.63.35.68:53281', 'https': '45.63.35.68:53281'}
# -------------------------------------
# 当前剩余处理的ip:  99
# Thread-303 is processingThread-277 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '103.220.29.244:8080', 'https': '103.220.29.244:8080'}
# -------------------------------------
# 当前剩余处理的ip:  98
#
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  97
# Thread-287 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  96
# Thread-309 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# remove proxy: {'http': '118.70.79.130:8080', 'https': '118.70.79.130:8080'}
# -------------------------------------
# 当前剩余处理的ip:  95
# Thread-302 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  94
# Thread-300 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  93
# Thread-294 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '13.66.242.205:80', 'https': '13.66.242.205:80'}
# -------------------------------------
# 当前剩余处理的ip:  92
# Thread-312 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '46.102.115.192:41258', 'https': '46.102.115.192:41258'}
# -------------------------------------
# 当前剩余处理的ip:  91
# Thread-316 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  90
# Thread-290 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  89
# Thread-291 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  88
# Thread-289 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  87
# Thread-284 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  86
# Thread-292 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  85
# Thread-310 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f2320411b00>, 'Connection to 187.110.64.92 timed out. (connect timeout=5)'))
# remove proxy: {'http': '187.110.64.92:53281', 'https': '187.110.64.92:53281'}
# -------------------------------------
# 当前剩余处理的ip:  84
# Thread-295 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '191.101.25.46:3128', 'https': '191.101.25.46:3128'}
# -------------------------------------
# 当前剩余处理的ip:  83
# Thread-280 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  82
# Thread-304 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 500 Internal Server Error',)))
# remove proxy: {'http': '195.201.138.167:80', 'https': '195.201.138.167:80'}
# -------------------------------------
# 当前剩余处理的ip:  81
# Thread-276 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '103.216.82.203:6666', 'https': '103.216.82.203:6666'}
# -------------------------------------
# 当前剩余处理的ip:  80
# Thread-298 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  79
# Thread-272 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  78
# Thread-315 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  77
# Thread-314 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Read timed out.
# remove proxy: {'http': '36.89.29.167:8080', 'https': '36.89.29.167:8080'}
# -------------------------------------
# 当前剩余处理的ip:  76
# Thread-278 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  75
# Thread-296 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '105.235.193.238:8080', 'https': '105.235.193.238:8080'}
# -------------------------------------
# 当前剩余处理的ip:  74
# Thread-274 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f231faca320>, 'Connection to 85.130.3.136 timed out. (connect timeout=5)'))
# remove proxy: {'http': '85.130.3.136:53281', 'https': '85.130.3.136:53281'}
# -------------------------------------
# 当前剩余处理的ip:  73
# Thread-306 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  72
# Thread-300 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  71
# Thread-286 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f231fb694e0>, 'Connection to 95.67.44.118 timed out. (connect timeout=5)'))
# remove proxy: {'http': '95.67.44.118:8080', 'https': '95.67.44.118:8080'}
# -------------------------------------
# 当前剩余处理的ip:  70
# Thread-294 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  69
# Thread-296 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 503 Too many open connections',)))
# remove proxy: {'http': '5.45.64.97:3128', 'https': '5.45.64.97:3128'}
# -------------------------------------
# 当前剩余处理的ip:  68
# Thread-307 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  67
# Thread-290 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  66
# Thread-293 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Read timed out. (read timeout=5)
# remove proxy: {'http': '36.67.7.33:45619', 'https': '36.67.7.33:45619'}
# -------------------------------------
# 当前剩余处理的ip:  65
# Thread-281 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  64
# Thread-273 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  63
# Thread-287 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '191.101.25.205:3128', 'https': '191.101.25.205:3128'}
# -------------------------------------
# 当前剩余处理的ip:  62
# Thread-309 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '191.101.25.138:3128', 'https': '191.101.25.138:3128'}
# -------------------------------------
# 当前剩余处理的ip:  61
# Thread-313 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  60
# Thread-276 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  59
# Thread-316 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '191.101.25.5:3128', 'https': '191.101.25.5:3128'}
# -------------------------------------
# 当前剩余处理的ip:  58
# Thread-301 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '27.133.130.156:3128', 'https': '27.133.130.156:3128'}
# -------------------------------------
# 当前剩余处理的ip:  57
# Thread-289 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f2320252c50>, 'Connection to 185.103.167.208 timed out. (connect timeout=5)'))
# remove proxy: {'http': '185.103.167.208:41258', 'https': '185.103.167.208:41258'}
# -------------------------------------
# 当前剩余处理的ip:  56
# Thread-297 is processingThread-298 is processing
# r.status_code: 200
# Thread-285 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '5.202.149.219:53281', 'https': '5.202.149.219:53281'}
# -------------------------------------
# 当前剩余处理的ip:  55
#
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  54
# -------------------------------------
# 当前剩余处理的ip:  53
# Thread-303 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  52
# Thread-282 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  51
# Thread-298 is processing
# ('Connection aborted.', BadStatusLine('<H1> ¿Â¶óÀÎ »ç¿ëÀÚ ¼ö°¡ ¶óÀÌ¼¾½º Çã°¡ ¼ö¸¦ ÃÊ°úÇß½À´Ï´Ù. ¶óÀÌ¼¾½º¸¦ ±¸ÀÔÇÏ°Å³ª ¾÷µ¥ÀÌÆ®ÇØ¾ßÇÕ´Ï´Ù.</H1>',))
# remove proxy: {'http': '119.202.157.223:808', 'https': '119.202.157.223:808'}
# -------------------------------------
# 当前剩余处理的ip:  50
# Thread-297 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f231fa7de80>: Failed to establish a new connection: [Errno 111] Connection refused',)))
# remove proxy: {'http': '171.100.92.117:8888', 'https': '171.100.92.117:8888'}
# -------------------------------------
# 当前剩余处理的ip:  49
# Thread-272 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  48
# Thread-296 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  47
# Thread-292 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f231fa51400>, 'Connection to 93.179.250.28 timed out. (connect timeout=5)'))
# remove proxy: {'http': '93.179.250.28:41258', 'https': '93.179.250.28:41258'}
# -------------------------------------
# 当前剩余处理的ip:  46
# Thread-311 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  45
# Thread-314 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  44
# Thread-292 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f231fa69080>: Failed to establish a new connection: [Errno 113] No route to host',)))
# remove proxy: {'http': '191.5.182.222:20183', 'https': '191.5.182.222:20183'}
# -------------------------------------
# 当前剩余处理的ip:  43
# Thread-279 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  42
# Thread-286 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  41
# Thread-291 is processingThread-277 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '168.194.152.102:53281', 'https': '168.194.152.102:53281'}
# -------------------------------------
# 当前剩余处理的ip:  40
# Thread-274 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  39
#
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  38
# Thread-294 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  37
# Thread-295 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  36
# Thread-283 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Read timed out.
# remove proxy: {'http': '139.5.26.27:53281', 'https': '139.5.26.27:53281'}
# -------------------------------------
# 当前剩余处理的ip:  35
# Thread-308 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  34
# Thread-314 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', ConnectionResetError(104, 'Connection reset by peer')))
# remove proxy: {'http': '103.41.147.14:8080', 'https': '103.41.147.14:8080'}
# -------------------------------------
# 当前剩余处理的ip:  33
# Thread-287 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  32
# Thread-306 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f231fabe9e8>, 'Connection to 138.186.172.200 timed out. (connect timeout=5)'))
# remove proxy: {'http': '138.186.172.200:53281', 'https': '138.186.172.200:53281'}
# -------------------------------------
# 当前剩余处理的ip:  31
# Thread-285 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  30
# Thread-300 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f23203da978>, 'Connection to 41.77.186.14 timed out. (connect timeout=5)'))
# remove proxy: {'http': '41.77.186.14:8080', 'https': '41.77.186.14:8080'}
# -------------------------------------
# 当前剩余处理的ip:  29
# Thread-313 is processing
# r.status_code: 200
# -------------------------------------
# 当前剩余处理的ip:  28
# Thread-307 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f232010feb8>, 'Connection to 14.102.103.129 timed out. (connect timeout=5)'))
# ...
#
# getTag()当前处理链接: https://jobs.51job.com/shanghai-pdxq/70496441.html?s=01&t=0
# getTag()获得的ip: {'http': '168.181.168.23:53281', 'https': '168.181.168.23:53281'}
# [getTag()] Thread-335 processing!
# getTag()当前处理链接: https://jobs.51job.com/nanjing-glq/104479434.html?s=01&t=0
# getTag()获得的ip: {'http': '190.244.30.116:53281', 'https': '190.244.30.116:53281'}
# [getTag()] Thread-336 processing!
# getTag()当前处理链接: https://jobs.51job.com/chongqing-ybq/104556994.html?s=01&t=0
# getTag()获得的ip: {'http': '169.255.5.174:53281', 'https': '169.255.5.174:53281'}
# getTag()中tag_list: ['2年经验', '本科', '招5人', '07-16发布', '五险一金', '周末双休', '包住']
# ----------------------
# [getTag()] Thread-319 processing!
# getTag()当前处理链接: https://jobs.51job.com/guangzhou-thq/104362395.html?s=01&t=0
# getTag()获得的ip: {'http': '41.193.238.225:8080', 'https': '41.193.238.225:8080'}
# getTag()中tag_list: ['1年经验', '大专', '招若干人', '07-16发布', '五险一金', '年终奖金', '弹性工作']
# ----------------------
# [getTag()] Thread-318 processing!
# getTag()当前处理链接: https://jobs.51job.com/shanghai-hkq/104557017.html?s=01&t=0
# getTag()获得的ip: {'http': '78.108.105.2:8888', 'https': '78.108.105.2:8888'}
# getTag()中tag_list: ['2年经验', '本科', '招13人', '07-16发布', '五险一金', '餐饮补贴', '弹性工作', '员工旅游', '专业培训', '员工生日会']
# ----------------------
# [getTag()] Thread-321 processing!
# getTag()当前处理链接: https://jobs.51job.com/shanghai-mhq/104556489.html?s=01&t=0
# getTag()获得的ip: {'http': '212.126.121.238:53281', 'https': '212.126.121.238:53281'}
# getTag()中tag_list: ['2年经验', '大专', '招3人', '07-16发布', '五险一金', '员工旅游', '餐饮补贴', '通讯补贴', '年终奖金', '绩效奖金', '专业培训', '出国机会', '定期体检', '免费班车']
# ----------------------
# [getTag()] Thread-317 processing!
# getTag()当前处理链接: https://jobs.51job.com/guangzhou-hzq/103715649.html?s=01&t=0
# getTag()获得的ip: {'http': '163.43.28.172:60088', 'https': '163.43.28.172:60088'}
# getTag()中tag_list: ['无工作经验', '本科', '招若干人', '07-16发布']
# ----------------------
# [getTag()] Thread-322 processing!
# getTag()当前处理链接: https://jobs.51job.com/shanghai-pdxq/103783625.html?s=01&t=0
# getTag()获得的ip: {'http': '5.2.229.173:8080', 'https': '5.2.229.173:8080'}
# getTag()中tag_list:HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /guangzhou-thq/104362395.html?s=01&t=0 (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f232c7f6eb8>, 'Connection to 41.193.238.225 timed out. (connect timeout=5)'))
# 尝试新的proxy
#  ['1年经验', '本科', '招4人', '07-16发布', '五险一金', '绩效奖金', '员工旅游', '年终奖金', '专业培训']
# ----------------------
# [getTag()] Thread-334 processing!
# getTag()当前处理链接: https://jobs.51job.com/hangzhou-jgq/98236114.html?s=01&t=0
# getTag()获得的ip: {'http': '41.75.4.208:53281', 'https': '41.75.4.208:53281'}
# getTag()中tag_list: ['无工作经验', '招若干人', '07-16发布', '五险一金', '餐饮补贴', '弹性工作', '定期体检', '补充医疗保险', '补充公积金', '专业培训', '年终奖金', '无限量下午茶']
# ----------------------
# [getTag()] Thread-324 processing!
# getTag()当前处理链接: https://jobs.51job.com/changsha-txq/104309514.html?s=01&t=0
# getTag()获得的ip: {'http': '83.219.134.250:44331', 'https': '83.219.134.250:44331'}
# getTag()中tag_list: ['无工作经验', '本科', '招2人', '07-16发布', '周末双休', '带薪年假', '五险一金', '节日福利', '加班补贴', '年终奖金']
# ----------------------
# [getTag()] Thread-330 processing!
# getTag()当前处理链接: https://jobs.51job.com/chengdu-jjq/92441308.html?s=01&t=0
# getTag()获得的ip: {'http': '45.77.150.231:8080', 'https': '45.77.150.231:8080'}
# getTag()中tag_list: ['2年经验', '招8人', '07-16发布']
# ----------------------
# [getTag()] Thread-333 processing!
# getTag()当前处理链接: https://jobs.51job.com/guangzhou/84889793.html?s=01&t=0
# getTag()获得的ip: {'http': '217.107.105.207:53281', 'https': '217.107.105.207:53281'}
# getTag()中tag_list:getTag()中tag_list: ['3-4年经验', '本科', '招1人', '07-16发布', '五险一金', '员工旅游', '餐饮补贴', '周末双休', '绩效奖金', '年终奖金', '股票期权', '定期体检']
# ----------------------
# [getTag()] Thread-328 processing!
# getTag()当前处理链接: https://jobs.51job.com/chongqing-ybq/102321472.html?s=01&t=0
# getTag()获得的ip: {'http': '190.152.182.150:53281', 'https': '190.152.182.150:53281'}
#  ['1年经验', '大专', '招若干人', '07-16发布', '五险一金', '餐饮补贴', '专业培训', '绩效奖金']
# ----------------------
# [getTag()] Thread-327 processing!
# getTag()当前处理链接: https://jobs.51job.com/shanghai-jaq/93650574.html?s=01&t=0
# getTag()获得的ip: {'http': '163.172.180.176:3128', 'https': '163.172.180.176:3128'}
# getTag()中tag_list: ['3-4年经验', '本科', '招2人', '07-16发布', '五险一金', '员工旅游', '定期体检']
# ----------------------
# [getTag()] Thread-325 processing!
# getTag()当前处理链接: https://jobs.51job.com/wuxi/90429369.html?s=01&t=0
# getTag()获得的ip: {'http': '94.130.20.85:31288', 'https': '94.130.20.85:31288'}
# getTag()中tag_list:getTag()中tag_list:getTag()中tag_list: ['3-4年经验', '本科', '招2人', '07-16发布', '五险一金', '员工旅游', '餐饮补贴', '定期体检', '年底双薪']
# ----------------------
# [getTag()] Thread-336 processing!
# getTag()当前处理链接: https://jobs.51job.com/haikou/104555842.html?s=01&t=0
# getTag()获得的ip: {'http': '91.222.17.135:53281', 'https': '91.222.17.135:53281'}
#  ['3-4年经验', '本科', '招3人', '07-16发布', '五险一金', '员工旅游', '绩效奖金', '股票期权']
# ----------------------
# [getTag()] Thread-326 processing!
# getTag()当前处理链接: https://jobs.51job.com/taiyuan/102890808.html?s=01&t=0
# getTag()获得的ip: {'http': '43.245.185.163:53281', 'https': '43.245.185.163:53281'}
# getTag()中tag_list:HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /guangzhou-hpq/103189237.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# 尝试新的proxy
#  ['3-4年经验', '大专', '招若干人', '07-16发布', '员工旅游', '弹性工作', '五险一金', '定期体检']
# ----------------------
# [getTag()] Thread-317 processing!
# getTag()当前处理链接: https://jobs.51job.com/guangzhou-thq/104508464.html?s=01&t=0
# getTag()获得的ip: {'http': '46.50.141.217:8080', 'https': '46.50.141.217:8080'}
#  ['3-4年经验', '大专', '招3人', '07-16发布', '五险一金', '补充医疗保险', '定期体检', '晋升空间', '补贴']
# ----------------------
# [getTag()] Thread-332 processing!
# getTag()当前处理链接: https://jobs.51job.com/hangzhou-jgq/99675112.html?s=01&t=0
# getTag()获得的ip: {'http': '186.194.183.255:53281', 'https': '186.194.183.255:53281'}
# getTag()中tag_list:getTag()中tag_list: ['3-4年经验', '本科', '招5人', '07-16发布', '员工旅游', '专业培训', '绩效奖金', '年终奖金', '五险', '提供住宿']
# ----------------------
# [getTag()] Thread-329 processing!
# getTag()当前处理链接: https://jobs.51job.com/zhengzhou/93001809.html?s=01&t=0
# getTag()获得的ip: {'http': '78.156.40.38:41258', 'https': '78.156.40.38:41258'}
#  ['2年经验', '大专', '招1人', '07-16发布', '五险一金', '餐饮补贴', '通讯补贴', '专业培训', '员工旅游', '定期体检', '股票期权', '年终奖金', '绩效奖金']
# ----------------------
# [getTag()] Thread-331 processing!
# getTag()当前处理链接: https://jobs.51job.com/shanghai-pdxq/41398609.html?s=01&t=0
# getTag()获得的ip: {'http': '178.252.119.88:53281', 'https': '178.252.119.88:53281'}
# getTag()中tag_list: ['1年经验', '本科', '招10人', '07-16发布', '五险一金', '周末双休', '定期体检', '员工旅游', '年终奖金']
# ----------------------
# [getTag()] Thread-320 processing!
# getTag()当前处理链接: https://jobs.51job.com/wuhan-jaq/104556148.html?s=01&t=0
# getTag()获得的ip: {'http': '185.94.89.224:41258', 'https': '185.94.89.224:41258'}
# getTag()中tag_list: ['2年经验', '本科', '招2人', '07-16发布', '五险一金', '补充医疗保险', '餐饮补贴', '交通补贴', '通讯补贴', '专业培训', '绩效奖金', '年终奖金', '定期体检']
# ----------------------
# [getTag()] Thread-335 processing!
# getTag()当前处理链接: https://jobs.51job.com/changsha-txq/104556115.html?s=01&t=0
# getTag()获得的ip: {'http': '31.41.90.80:41258', 'https': '31.41.90.80:41258'}
# getTag()中tag_list: ['无工作经验', '本科', '招若干人', '07-16发布', '五险一金', '补充医疗保险', '交通补贴', '餐饮补贴', '通讯补贴', '年终奖金', '定期体检']
# ----------------------
# [getTag()] Thread-318 processing!
# getTag()当前处理链接: https://jobs.51job.com/jinan/104058858.html?s=01&t=0
# getTag()获得的ip: {'http': '188.126.47.155:41258', 'https': '188.126.47.155:41258'}
# getTag()中tag_list: ['5-7年经验', '本科', '招2人', '07-16发布', '五险一金', '餐饮补贴', '弹性工作', '专业培训', '绩效奖金', '年终奖金']
# ----------------------
# [getTag()] Thread-321 processing!
# getTag()当前处理链接: https://jobs.51job.com/beijing/104556125.html?s=01&t=0
# getTag()获得的ip: {'http': '46.148.139.23:41258', 'https': '46.148.139.23:41258'}
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /changsha-txq/104556115.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response',)))
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /hangzhou-jgq/98236114.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))getTag()中tag_list:
# 尝试新的proxy
#  ['无工作经验', '本科', '招2人', '07-16发布', '五险一金', '员工旅游', '年终奖金', '专业培训']
# ----------------------
# [getTag()] Thread-330 processing!
# getTag()当前处理链接: https://jobs.51job.com/wuhan-jhq/102916253.html?s=01&t=0
# getTag()获得的ip: {'http': '190.145.181.214:53281', 'https': '190.145.181.214:53281'}
# getTag()中tag_list: ['2年经验', '大专', '招2人', '07-16发布', '五险一金', '专业培训', '绩效奖金', '餐饮补贴', '周末双休', '住宿', '年终奖金', '定期体检', '免费班车']
# ----------------------
# [getTag()] Thread-324 processing!
# getTag()当前处理链接: https://jobs.51job.com/wuhan-hsq/99360855.html?s=01&t=0
# getTag()获得的ip: {'http': '81.166.240.157:8080', 'https': '81.166.240.157:8080'}
# getTag()中tag_list: ['8-9年经验', '本科', '招1人', '07-16发布', '五险一金', '员工旅游', '专业培训', '年终奖金', '定期体检']
# ----------------------
# [getTag()] Thread-327 processing!
# getTag()当前处理链接: https://jobs.51job.com/shenzhen-ftq/104552550.html?s=01&t=0
# getTag()获得的ip: {'http': '109.194.17.181:8080', 'https': '109.194.17.181:8080'}
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /haikou/104555842.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# 尝试新的proxy
# getTag()中tag_list: ['1年经验', '大专', '招2人', '07-16发布', '五险一金', '餐饮补贴', '年终奖金', '弹性工作']
# ----------------------
# [getTag()] Thread-325 processing!
# getTag()当前处理链接: https://jobs.51job.com/shenzhen-nsq/104173092.html?s=01&t=0
# getTag()获得的ip: {'http': '82.202.68.26:8080', 'https': '82.202.68.26:8080'}
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /wuhan-jaq/104556148.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# 尝试新的proxy
# getTag()中tag_list: ['2年经验', '本科', '招1人', '07-16发布']
# ----------------------
# [getTag()] Thread-322 processing!
# getTag()当前处理链接: https://jobs.51job.com/guangzhou-yxq/78945462.html?s=01&t=0
# getTag()获得的ip: {'http': '217.175.37.197:53281', 'https': '217.175.37.197:53281'}
# getTag()中tag_list: ['1年经验', '大专', '招1人', '07-16发布', '五险一金', '员工旅游', '年终奖金', '绩效奖金']
# ----------------------
# [getTag()] Thread-317 processing!
# getTag()当前处理链接: https://jobs.51job.com/shenzhen-nsq/104556124.html?s=01&t=0
# getTag()获得的ip: {'http': '45.6.216.79:80', 'https': '45.6.216.79:80'}
# getTag()中tag_list: ['5-7年经验', '本科', '招3人', '07-16发布', '五险一金', '绩效奖金', '专业培训', '员工旅游']
# ----------------------
# [getTag()] Thread-326 processing!
# getTag()当前处理链接: https://jobs.51job.com/nanjing-yhtq/104533228.html?s=01&t=0
# getTag()获得的ip: {'http': '59.106.216.142:60088', 'https': '59.106.216.142:60088'}
# getTag()中tag_list: ['无工作经验', '本科', '招若干人', '07-16发布', '综合医疗', '提供住宿', '餐饮补贴', '转正机会']
# ----------------------
# [getTag()] Thread-321 processing!
# getTag()当前处理链接: https://jobs.51job.com/shenzhen-nsq/103777319.html?s=01&t=0
# getTag()获得的ip: {'http': '89.178.250.162:53281', 'https': '89.178.250.162:53281'}
# getTag()中tag_list: ['2年经验', '本科', '招若干人', '07-16发布', '五险一金', '员工旅游', '绩效奖金', '年终奖金', '定期体检']
# ----------------------
# getTag()中tag_list: ['无工作经验', '招3人', '07-16发布', '五险一金', '绩效奖金', '年终奖金', '股票期权', '弹性工作']
# ----------------------
# getTag()中tag_list: ['1年经验', '招2人', '07-16发布', '五险一金', '弹性工作', '年终奖金', '绩效奖金']
# ----------------------
# getTag()中tag_list: ['无工作经验', '招3人', '07-16发布', '五险一金', '补充公积金', '交通补贴', '餐饮补贴', '年终奖金']
# ----------------------
# getTag()中tag_list: ['3-4年经验', '招若干人', '07-16发布', '专业培训', '通讯补贴', '股票期权', '定期体检', '周末双休', '五险一金', '年终奖金', '员工旅游', '绩效奖金']
# ----------------------
# getTag()中tag_list:getTag()中tag_list: ['无工作经验', '招1人', '07-16发布', '做五休二', '专业培训', '五险一金', '节日福利', '带薪年假', '团队聚餐', '年度旅游', '出国旅游机会', '学习基金']
# ----------------------
#  ['3-4年经验', '本科', '招1人', '07-16发布', '员工旅游', '餐饮补贴', '绩效奖金', '年终奖金', '弹性工作', '定期体检', '五险']
# ----------------------
# getTag()中tag_list: ['2年经验', '大专', '招1人', '07-16发布', '五险一金', '交通补贴', '餐饮补贴', '年终奖金']
# ----------------------
# getTag()中tag_list: ['3-4年经验', '本科', '招1人', '07-16发布', '五险一金', '周末双休', '年终奖金', '员工旅游', '定期体检', '专业培训', '绩效奖金']
# ----------------------
# getTag()中tag_list: ['1年经验', '招若干人', '07-16发布', '五险一金', '补充医疗保险', '员工旅游', '通讯补贴', '绩效奖金', '年终奖金', '定期体检', '带薪年假', '年终双薪']
# ----------------------
# getTag()中tag_list:getTag()中tag_list: ['5-7年经验', '大专', '招2人', '07-16发布', '包住宿', '带薪年假', '五险一金', '餐饮补贴', '节日福利', '全勤奖', '专业培训', '加班补贴', '绩效奖金', '年终奖金']
# ----------------------
#  ['3-4年经验', '大专', '招2人', '07-16发布']
# ----------------------
# getTag()中tag_list: ['5-7年经验', '本科', '招1人', '07-16发布', '五险一金', '员工旅游', '周末双休', '年底双薪']
# ----------------------
# getTag()中tag_list: ['5-7年经验', '大专', '招2人', '07-16发布', '五险一金', '员工旅游', '交通补贴', '餐饮补贴', '专业培训', '绩效奖金', '年终奖金', '股票期权', '弹性工作']
# ----------------------
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /shenzhen-nsq/103777319.html?s=01&t=0 (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f23170c1518>, 'Connection to 89.178.250.162 timed out. (connect timeout=5)'))
# 尝试新的proxy
# getTag()中tag_list:getTag()中tag_list: ['3-4年经验', '大专', '招2人', '07-16发布', '五险一金', '弹性工作', '专业培训', '员工旅游', '年终奖金']
# ----------------------
#  ['无工作经验', '招1人', '07-16发布', '五险一金', '定期体检', '餐饮补贴']
# ----------------------
# getTag()中tag_list: ['3-4年经验', '本科', '招若干人', '07-16发布']
# ----------------------
# Thread-317 已停止
# Thread-318 已停止
# Thread-319 已停止
# Thread-320 已停止
# getTag()中tag_list: ['无工作经验', '大专', '招若干人', '07-16发布']
# ----------------------
# getTag()中tag_list: ['5-7年经验', '大专', '招3人', '07-16发布', '五险一金', '员工旅游', '餐饮补贴', '定期体检', '股票期权', '绩效奖金', '午餐补助', '年节福利']
# ----------------------
# getTag()中tag_list: ['3-4年经验', '本科', '招2人', '07-16发布', '五险一金', '专业培训', '年终奖金', '加班补贴']
# ----------------------
# Thread-321 已停止
# Thread-322 已停止
# Thread-323 已停止
# Thread-324 已停止
# Thread-325 已停止
# Thread-326 已停止
# Thread-327 已停止
# Thread-328 已停止
# Thread-329 已停止
# Thread-330 已停止
# Thread-331 已停止
# Thread-332 已停止
# Thread-333 已停止
# Thread-334 已停止
# Thread-335 已停止
# Thread-336 已停止
# tag组装完成!
# pack_tag() 运行时间: 31
# save_to_csv() 运行时间: 0
# 完成写入单页jobObject!
# 完成时间:  35.50054478645325
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /wuhan-jhq/102916253.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', ConnectionResetError(104, 'Connection reset by peer')))
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /fuzhou-glq/102497666.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /shenzhen-ftq/104552550.html?s=01&t=0 (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f231715eef0>, 'Connection to 171.97.25.121 timed out. (connect timeout=5)'))
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /guangzhou-yxq/78945462.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /shanghai-xhq/100145931.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /beijing-cyq/104549778.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /nanjing-yhtq/104533228.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: /changzhou/70909658.html?s=01&t=0 (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Read timed out. (read timeout=5)
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Read timed out. (read timeout=5)

# %% [raw]
# 单页完成最多需要7分钟，200页需要连续爬23小时左右

# %% [markdown]
# - 装饰器查看每个函数处理的时间，具体优化
# - 清洗ip的函数的代码不应该放在处理单页数据的函数里面
# ----
# 现在想的是多线程来处理，一个线程调用一个handle_single()，就是
# 一个线程执行完成一个页面的所有操作，不知道这样速度是不是会提升
#
# 可以写一个模拟程序，来看看是不是会提升速度
#
# ----
#
# 最耗时的操作是pack_tag，98%的时间在这里被消耗!

# %% [raw]
# pack_tag的线程数为5的时候，消耗时间65秒,之前单线程时224秒左右，下降了70%左右的时间！

# %% [raw]
# pack_tag线程数为10，消耗时间46秒，相比之前下降30%左右！完成处理单页需要48b秒时间,

# %% [raw]
# 运行时间统计.csv第一行的数据情况是getCleanProxies()的线程数是25, pack_tag()的线程数是10
# 第二行情况是getCleanProxies的线程数30, pack_tag()的线程数是20
# 最佳的配置是getCleanProxies线程45, pack_tag线程20
