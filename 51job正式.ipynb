# %%
import requests
from bs4 import BeautifulSoup
import queue
import threading
import re
import csv
import functools
import os
from time import time

# %%
class jobObject:
    'job描述对象'
    __slots__ = ('tag_href', 'job', 'company', 'address', 'salary', 'tag')

# %%
def ipToQueue():
    q = queue.Queue()
    url = 'https://free-proxy-list.net/'
    r = requests.get(url)
    html = r.text
    soup = BeautifulSoup(html, features='html5lib')
    div_tag = soup.find('div', 'table-responsive')
    tbody_list = div_tag.tbody.contents
    result = ''
    for tr in tbody_list:
        ip = tr.next_element.string
        port = tr.next_element.next_sibling.string
        result = ip + ':' + port
        q.put(result)

    return q

# %%
# q = ipToQueue()
# print(q.qsize())

# while q.qsize()!=0:
#     print(q.get())

# %%
def getIPool(ip_queue):
    proxies = queue.Queue()

    flag = True
    while flag:
        ip = ip_queue.get()
        proxy = {'http': ip, 'https': ip}
        proxies.put(proxy)
        if ip_queue.qsize()==0:
            flag = False

    return proxies

# %%
def getCleanProxies(proxies, **thread_num):
    #     url = 'http://www.baidu.com'
    url = 'https://jobs.51job.com/'

    # 有效的ip队列
    ok_proxies = queue.Queue()

    def check_proxy(thread_proxies):

        thread_proxies_size = thread_proxies.qsize()

        for i in range(thread_proxies_size):
            thread_proxies_size = thread_proxies.qsize()
            print('%s : 当前剩余处理的ip: %d' % (threading.current_thread().name, thread_proxies_size))

            # 如果当前ip为0退出当前线程
            if (thread_proxies_size == 0):
                break

            proxy = thread_proxies.get()
            try:
                r = requests.get(url, proxies=proxy, timeout=5)
                print(threading.current_thread().name + ' is processing')
                print('r.status_code:', r.status_code)
                if (r.status_code != 200):
                    print('remove proxy:', proxy)
                else:
                    ok_proxies.put(proxy)

                print('-------------------------------------')

            except requests.Timeout as e:
                print(threading.current_thread().name + ' is processing')
                print(e)
                print('remove proxy:', proxy)
                print('-------------------------------------')
            except requests.ConnectionError as e:
                print(threading.current_thread().name + ' is processing')
                print(e)
                print('remove proxy:', proxy)
                print('-------------------------------------')
            except requests.InvalidHeader as e:
                print(threading.current_thread().name + ' is processing')
                print(e)
                print('remove proxy:', proxy)
                print('-------------------------------------')


    threads = []

    for i in range(thread_num.get('thread_num')):
        thread = threading.Thread(target=check_proxy, args=(proxies,))
        threads.append(thread)

    print('线程开始：')
    for thread in threads:
        print(thread.name + '开始运行')
        thread.start()

    # 每次在剩余处理ip为0之后，程序就会停住不动
    # 当当前线程检测到剩余ip为0后，调用join()方法
    print('线程开始停止运行：')
    for thread in threads:
        thread.join()
        print(thread.name + '已停止')

    return ok_proxies

# %%
def get_jobObjectList(url, proxies):
    flag = True
    proxy = getProxy(proxies)
    # TODO 查看信息
    print('get_jobObjectList()当前处理链接:', url)
    while flag:
        try:
            r = requests.get(url, proxies=proxy, timeout=5)
            # 报了异常的话捕捉了之后
            # 获得新的proxy之后就直接开始下次循环
        except requests.exceptions.Timeout as e:
            print(e)
            proxy = getProxy(proxies)
            print('尝试新的proxy')
            #print('----------------------')
            continue
        except requests.exceptions.ProxyError as e:
            print(e)
            proxy = getProxy(proxies)
            print('尝试新的proxy')
            #print('----------------------')
            continue
        except requests.exceptions.ConnectionError as e:
            print(e)
            proxy = getProxy(proxies)
            print('尝试新的proxy')
            #print('----------------------')
            continue
        
        # 不报异常就取消循环
        flag = False

    
    
    r.encoding = 'gbk'
    html = r.text
    soup = BeautifulSoup(html, features='html5lib')
    # 找到了工作列表的开头
    title = soup.find('div', 'el title')
    # 找到每一个工作列，它们分别是一个div class='el'
    job_info_list = title.find_next_siblings('div', 'el')

    # 存放当前页jobObject对象到jobObjectList中
    jobObjectList = []
    for tag in job_info_list:
        object = jobObject()
        object.tag_href = tag.find('a').attrs['href']
        object.job = tag.find('a').attrs['title']

        infos = tag.find_all(class_=re.compile('t[2-4]'))
        object.company = infos[0].string
        object.address = infos[1].string
        object.salary = infos[2].string
        jobObjectList.append(object)
    
    print('get_jobObjectList处理完成!')

    return jobObjectList

# %%
def getTag(url, proxies):
    tag_url = url
    proxy = getProxy(proxies)

    # 存储标签的List
    tag_list = []
    flag = True

    # TODO 查看信息
    print('getTag()当前处理链接:', tag_url)
    print('getTag()获得的ip:', proxy)
    while flag:
        #     headers = {'user-agent','Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/66.0.3359.181 Chrome/66.0.3359.181 Safari/537.36'}
        try:
            r_tag = requests.get(tag_url, timeout=5, proxies=proxy)

        # 报了异常的话捕捉了之后
        # 获得新的proxy之后就直接开始下次循环
        except requests.exceptions.Timeout as e:
            print(e)
            proxy = getProxy(proxies)
            print('尝试新的proxy')
            #print('----------------------')
            continue
        except requests.exceptions.ProxyError as e:
            print(e)
            proxy = getProxy(proxies)
            print('尝试新的proxy')
            #print('----------------------')
            continue
        except requests.exceptions.ConnectionError as e:
            print(e)
            proxy = getProxy(proxies)
            print('尝试新的proxy')
            #print('----------------------')
            continue
        # 不报异常就取消循环
        flag = False

    r_tag.encoding = 'gbk'
    tag_html = r_tag.text
    tag_soup = BeautifulSoup(tag_html, features='html5lib')

    # 找到详情页第一行标签
    tag_1 = tag_soup.find_all('span', 'sp4')
    for i in tag_1:
        tag_list.append(i.contents[1])

    # 找到详情页第二行标签
    tag_2 = tag_soup.find('p', 't2')

    # 有些详情页没有第二行标签
    if tag_2 is None:
        print('getTag()中tag_list:', tag_list)
        print('----------------------')
        return tag_list

    ll = []
    for i in tag_2.strings:
        ll.append(i)

    # 清除ll中的空值
    def not_empty(s):
        return s and s.strip()

    for i in filter(not_empty, ll):
        tag_list.append(i)

    print('getTag()中tag_list:', tag_list)
    print('----------------------')

    return tag_list

# %%
def pack_tag(jobObjectList, proxies, **thread_num):
    jobObject_queue = queue.Queue()
    
    for jobObject in jobObjectList:
        jobObject_queue.put(jobObject)
    
    def pack_object(jobObject_queue):
        flag = True
        while flag:
            jobObject = jobObject_queue.get()
            jobObject.tag = getTag(jobObject.tag_href, proxies)
            if jobObject_queue.qsize() == 0:
                flag = False
            
    
    threads = []
    
#     print('thread_num.get(\'thread_num\'): ', thread_num.get('thread_num'))
    
    for i in range(thread_num.get('thread_num')):
        thread = threading.Thread(target=pack_object, args=(jobObject_queue,))
        threads.append(thread)
    
    for thread in threads:
        thread.start()
        
        
    for thread in threads:
        thread.join()
        print('%s 已停止' % thread.name)
    

    print('tag组装完成!')

# %%
def save_to_csv(jobObjectList):
    headers = ['职位', '公司', '地址', '薪酬', '标签']
    datas = []

    for jobObject in jobObjectList:
        data = {headers[0]: jobObject.job,
                headers[1]: jobObject.company,
                headers[2]: jobObject.address,
                headers[3]: jobObject.salary,
                headers[4]: jobObject.tag}
        datas.append(data)
        
    if os.path.isfile('51job.csv'):
        with open('51job.csv', 'a', newline='') as f:
            writer = csv.DictWriter(f, headers)
            for row in datas:
                writer.writerow(row)
    else:
        with open('51job.csv', 'a', newline='') as f:
            writer = csv.DictWriter(f, headers)
            writer.writeheader()
            for row in datas:
                writer.writerow(row)

# %%
def handle_single(url, proxies):
    jobObjectList = get_jobObjectList(url, proxies)
    pack_tag(jobObjectList, proxies, thread_num=20)
    save_to_csv(jobObjectList)

# %%
# 获取proxy
# 当队列中的proxy用完了的时候在获取新的proxies
# 不是每次线程启动就获取新的proxies
# 当一个proxy不能用了才能获取新的proxy
def getProxy(proxies):
    print('###当前proxies的ip数: ', proxies.qsize())
    if proxies.qsize()==0:
        proxies = getProxies()
        
    proxy = proxies.get()
    return proxy
    

def getProxies():
    # 多线程的话，就不保存在本地文件
    # 应该保存在各自线程的queue里面s
    ip_start = time()
    ip_queue = ipToQueue()
    proxies = getIPool(ip_queue)
    proxies = getCleanProxies(proxies, thread_num=45)
    ip_result = time() - ip_start
    print('可用的ip: ', proxies.qsize())
    print('%s清洗ip的时间: %d' % (threading.current_thread().name, ip_result))
    return proxies

# %%
def main():
    url_queue = queue.Queue()
    pages = 10
    thread_nums = 2
    
    for i in range(pages):
        url = 'https://search.51job.com/list/000000,000000,0000,00,9,99,Java,2,{}.html?lang=c&stype=&postchannel=0000&workyear=99&cotype=99&degreefrom=99&jobterm=99&companysize=99&providesalary=99&lonlat=0%2C0&radius=-1&ord_field=0&confirmdate=9&fromType=&dibiaoid=0&address=&line=&specialarea=00&from=&welfare='\
        .format(i+1)
        url_queue.put(url)
    
#     flag = True
#     while flag:

    proxies = getProxies()

    def go(url_queue, proxies):
        flag = True
        while flag:   
            url = url_queue.get()
            
            
            start = time()
            handle_single(url, proxies)
            result = time() - start
            print('%s完成单页的时间: %d' % (threading.current_thread().name, result))
            
            if url_queue.qsize()==0:
                flag = False
            
    
    threads = []
    
    for i in range(thread_nums):
        thread = threading.Thread(target=go, args=(url_queue,proxies))
        threads.append(thread)
    
    start = time()
    for thread in threads:
        thread.start()
        print('主线程%s开始' % thread.name)
        
    for thread in threads:
        thread.join()
        print('主线程%s停止' % thread.name)
    
    result = time()-start
    print('爬取时间:',result)

# %%
main()
# Out:
# 线程开始：
# Thread-4开始运行
# Thread-4 : 当前剩余处理的ip: 300Thread-5开始运行
#
# Thread-5 : 当前剩余处理的ip: 299Thread-6开始运行
#
# Thread-6 : 当前剩余处理的ip: 298Thread-7开始运行
#
# Thread-7 : 当前剩余处理的ip: 297Thread-8开始运行
#
# Thread-8 : 当前剩余处理的ip: 296Thread-9开始运行
#
# Thread-9 : 当前剩余处理的ip: 295Thread-10开始运行
#
# Thread-10 : 当前剩余处理的ip: 294Thread-11开始运行
#
# Thread-11 : 当前剩余处理的ip: 293Thread-12开始运行
#
# Thread-12 : 当前剩余处理的ip: 292Thread-13开始运行
#
# Thread-13 : 当前剩余处理的ip: 291Thread-14开始运行
#
# Thread-14 : 当前剩余处理的ip: 290Thread-15开始运行
#
# Thread-15 : 当前剩余处理的ip: 289Thread-16开始运行
#
# Thread-16 : 当前剩余处理的ip: 288Thread-17开始运行
#
# Thread-17 : 当前剩余处理的ip: 287Thread-18开始运行
#
# Thread-18 : 当前剩余处理的ip: 286Thread-19开始运行
#
# Thread-19 : 当前剩余处理的ip: 285Thread-20开始运行
#
# Thread-20 : 当前剩余处理的ip: 284Thread-21开始运行
#
# Thread-21 : 当前剩余处理的ip: 283Thread-22开始运行
#
# Thread-22 : 当前剩余处理的ip: 282Thread-23开始运行
#
# Thread-23 : 当前剩余处理的ip: 281Thread-24开始运行
#
# Thread-24 : 当前剩余处理的ip: 280Thread-25开始运行
#
# Thread-25 : 当前剩余处理的ip: 279Thread-26开始运行
#
# Thread-26 : 当前剩余处理的ip: 278Thread-27开始运行
#
# Thread-27 : 当前剩余处理的ip: 277Thread-28开始运行
#
# Thread-28 : 当前剩余处理的ip: 276Thread-29开始运行
#
# Thread-29 : 当前剩余处理的ip: 275Thread-30开始运行
#
# Thread-30 : 当前剩余处理的ip: 274Thread-31开始运行
#
# Thread-31 : 当前剩余处理的ip: 273Thread-32开始运行
#
# Thread-32 : 当前剩余处理的ip: 272Thread-33开始运行
#
# Thread-33 : 当前剩余处理的ip: 271Thread-34开始运行
#
# Thread-34 : 当前剩余处理的ip: 270Thread-35开始运行
#
# Thread-35 : 当前剩余处理的ip: 269Thread-36开始运行
#
# Thread-36 : 当前剩余处理的ip: 268Thread-37开始运行
#
# Thread-37 : 当前剩余处理的ip: 267Thread-38开始运行
#
# Thread-38 : 当前剩余处理的ip: 266Thread-39开始运行
#
# Thread-39 : 当前剩余处理的ip: 265Thread-40开始运行
#
# Thread-40 : 当前剩余处理的ip: 264Thread-41开始运行
#
# Thread-41 : 当前剩余处理的ip: 263Thread-42开始运行
#
# Thread-42 : 当前剩余处理的ip: 262Thread-43开始运行
#
# Thread-43 : 当前剩余处理的ip: 261Thread-44开始运行
#
# Thread-44 : 当前剩余处理的ip: 260Thread-45开始运行
#
# Thread-45 : 当前剩余处理的ip: 259Thread-46开始运行
#
# Thread-46 : 当前剩余处理的ip: 258Thread-47开始运行
#
# Thread-25 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 400 Bad Request',)))
# remove proxy: {'http': '47.75.119.61:80', 'https': '47.75.119.61:80'}
# -------------------------------------
# Thread-25 : 当前剩余处理的ip: 257
# Thread-47 : 当前剩余处理的ip: 256Thread-48开始运行
#
# Thread-48 : 当前剩余处理的ip: 255线程开始停止运行：
#
# Thread-28 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7fe4dc780160>: Failed to establish a new connection: [Errno 111] Connection refused',)))
# remove proxy: {'http': '80.94.174.55:3128', 'https': '80.94.174.55:3128'}
# -------------------------------------
# Thread-28 : 当前剩余处理的ip: 254
# Thread-22 is processing
# r.status_code: 200
# -------------------------------------
# Thread-22 : 当前剩余处理的ip: 253
# Thread-37 is processing
# r.status_code: 200
# -------------------------------------
# Thread-37 : 当前剩余处理的ip: 252
# Thread-23 is processing
# r.status_code: 200
# -------------------------------------
# Thread-23 : 当前剩余处理的ip: 251
# Thread-33 is processing
# r.status_code: 200
# -------------------------------------
# Thread-33 : 当前剩余处理的ip: 250
# Thread-46 is processing
# r.status_code: 200
# -------------------------------------
# Thread-46 : 当前剩余处理的ip: 249
# Thread-15 is processing
# r.status_code: 200
# -------------------------------------
# Thread-15 : 当前剩余处理的ip: 248
# Thread-16 is processing
# r.status_code: 200
# -------------------------------------
# Thread-16 : 当前剩余处理的ip: 247
# Thread-15 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 400 Bad Request',)))
# remove proxy: {'http': '47.75.144.201:80', 'https': '47.75.144.201:80'}
# -------------------------------------
# Thread-15 : 当前剩余处理的ip: 246
# Thread-44 is processingThread-35 is processing
# r.status_code: 200
# -------------------------------------
# Thread-44 : 当前剩余处理的ip: 245
#
# r.status_code: 200
# -------------------------------------
# Thread-35 : 当前剩余处理的ip: 244
# Thread-6 is processing
# r.status_code: 200
# -------------------------------------
# Thread-6 : 当前剩余处理的ip: 243
# Thread-8 is processing
# r.status_code: 200
# -------------------------------------
# Thread-8 : 当前剩余处理的ip: 242
# Thread-27 is processing
# r.status_code: 200
# -------------------------------------
# Thread-27 : 当前剩余处理的ip: 241
# Thread-13 is processing
# r.status_code: 200
# -------------------------------------
# Thread-13 : 当前剩余处理的ip: 240
# Thread-27 is processing
# ('Connection aborted.', BadStatusLine('<html>\r\n',))
# remove proxy: {'http': '47.90.87.225:88', 'https': '47.90.87.225:88'}
# -------------------------------------
# Thread-27 : 当前剩余处理的ip: 239
# Thread-41 is processing
# r.status_code: 200
# -------------------------------------
# Thread-41 : 当前剩余处理的ip: 238
# Thread-43 is processing
# r.status_code: 200
# -------------------------------------
# Thread-43 : 当前剩余处理的ip: 237
# Thread-11 is processing
# r.status_code: 200
# -------------------------------------
# Thread-11 : 当前剩余处理的ip: 236
# Thread-47 is processing
# r.status_code: 200
# -------------------------------------
# Thread-47 : 当前剩余处理的ip: 235
# Thread-47 is processing
# ('Connection aborted.', BadStatusLine('<html>\r\n',))
# remove proxy: {'http': '113.255.76.120:8380', 'https': '113.255.76.120:8380'}
# -------------------------------------
# Thread-47 : 当前剩余处理的ip: 234
# Thread-23 is processing
# r.status_code: 200
# -------------------------------------
# Thread-23 : 当前剩余处理的ip: 233
# Thread-17 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fe4dc7b45f8>, 'Connection to 43.252.103.210 timed out. (connect timeout=5)'))
# remove proxy: {'http': '43.252.103.210:8080', 'https': '43.252.103.210:8080'}
# -------------------------------------
# Thread-17 : 当前剩余处理的ip: 232
# Thread-39 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '204.133.187.66:3128', 'https': '204.133.187.66:3128'}
# -------------------------------------
# Thread-39 : 当前剩余处理的ip: 231
# Thread-26 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '79.212.11.50:80', 'https': '79.212.11.50:80'}
# -------------------------------------
# Thread-26 : 当前剩余处理的ip: 230
# Thread-25 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '154.236.165.34:53281', 'https': '154.236.165.34:53281'}
# -------------------------------------
# Thread-25 : 当前剩余处理的ip: 229
# Thread-23 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 500 Internal Server Error',)))
# remove proxy: {'http': '139.59.83.91:80', 'https': '139.59.83.91:80'}
# -------------------------------------
# Thread-23 : 当前剩余处理的ip: 228
# Thread-17 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response',)))
# remove proxy: {'http': '103.245.19.30:63909', 'https': '103.245.19.30:63909'}
# -------------------------------------
# Thread-17 : 当前剩余处理的ip: 227
# Thread-41 is processing
# r.status_code: 200
# -------------------------------------
# Thread-41 : 当前剩余处理的ip: 226
# Thread-33 is processing
# r.status_code: 200
# -------------------------------------
# Thread-33 : 当前剩余处理的ip: 225
# Thread-26 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '176.53.2.122:8080', 'https': '176.53.2.122:8080'}
# -------------------------------------
# Thread-26 : 当前剩余处理的ip: 224
# Thread-29 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '119.42.157.187:53281', 'https': '119.42.157.187:53281'}
# -------------------------------------
# Thread-29 : 当前剩余处理的ip: 223
# Thread-42 is processing
# r.status_code: 200
# -------------------------------------
# Thread-42 : 当前剩余处理的ip: 222
# Thread-48 is processing
# r.status_code: 200
# -------------------------------------
# Thread-48 : 当前剩余处理的ip: 221
# Thread-12 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '83.228.74.156:8080', 'https': '83.228.74.156:8080'}
# -------------------------------------
# Thread-12 : 当前剩余处理的ip: 220
# Thread-21 is processing
# r.status_code: 200
# -------------------------------------
# Thread-21 : 当前剩余处理的ip: 219
# Thread-16 is processing
# r.status_code: 200
# -------------------------------------
# Thread-16 : 当前剩余处理的ip: 218
# Thread-40 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '80.94.30.234:8080', 'https': '80.94.30.234:8080'}
# -------------------------------------
# Thread-40 : 当前剩余处理的ip: 217
# Thread-16 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '178.128.189.253:3128', 'https': '178.128.189.253:3128'}
# -------------------------------------
# Thread-16 : 当前剩余处理的ip: 216
# Thread-11 is processing
# r.status_code: 200
# -------------------------------------
# Thread-11 : 当前剩余处理的ip: 215
# Thread-32 is processing
# r.status_code: 200
# -------------------------------------
# Thread-32 : 当前剩余处理的ip: 214
# Thread-48 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '177.55.138.125:8080', 'https': '177.55.138.125:8080'}
# -------------------------------------
# Thread-48 : 当前剩余处理的ip: 213
# Thread-6 is processing
# r.status_code: 200
# -------------------------------------
# Thread-6 : 当前剩余处理的ip: 212
# Thread-37 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fe4dc705630>, 'Connection to 89.22.255.113 timed out. (connect timeout=5)'))
# remove proxy: {'http': '89.22.255.113:8080', 'https': '89.22.255.113:8080'}
# -------------------------------------
# Thread-37 : 当前剩余处理的ip: 211
# Thread-5 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '1.10.141.121:8080', 'https': '1.10.141.121:8080'}
# -------------------------------------
# Thread-5 : 当前剩余处理的ip: 210
# Thread-7 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '103.253.107.108:8080', 'https': '103.253.107.108:8080'}
# -------------------------------------
# Thread-7 : 当前剩余处理的ip: 209
# Thread-28 is processing
# r.status_code: 200
# -------------------------------------
# Thread-28 : 当前剩余处理的ip: 208
# Thread-44 is processing
# r.status_code: 200
# -------------------------------------
# Thread-44 : 当前剩余处理的ip: 207
# Thread-6 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 503 Service Temporarily Unavailable',)))
# remove proxy: {'http': '81.17.17.163:80', 'https': '81.17.17.163:80'}
# -------------------------------------
# Thread-6 : 当前剩余处理的ip: 206
# Thread-46 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '52.23.193.25:8080', 'https': '52.23.193.25:8080'}
# -------------------------------------
# Thread-46 : 当前剩余处理的ip: 205
# Thread-35 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fe4dc65d588>, 'Connection to 91.231.172.221 timed out. (connect timeout=5)'))
# remove proxy: {'http': '91.231.172.221:41258', 'https': '91.231.172.221:41258'}
# -------------------------------------
# Thread-35 : 当前剩余处理的ip: 204
# Thread-15 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fe4dc7a6668>, 'Connection to 81.163.60.88 timed out. (connect timeout=5)'))
# remove proxy: {'http': '81.163.60.88:41258', 'https': '81.163.60.88:41258'}
# -------------------------------------
# Thread-15 : 当前剩余处理的ip: 203
# Thread-31 is processing
# r.status_code: 200
# -------------------------------------
# Thread-31 : 当前剩余处理的ip: 202
# Thread-44 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '142.44.246.242:80', 'https': '142.44.246.242:80'}
# -------------------------------------
# Thread-44 : 当前剩余处理的ip: 201
# Thread-18 is processing
# r.status_code: 200
# -------------------------------------
# Thread-18 : 当前剩余处理的ip: 200
# Thread-5 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 500 Internal Server Error',)))
# remove proxy: {'http': '195.178.207.241:80', 'https': '195.178.207.241:80'}
# -------------------------------------
# Thread-5 : 当前剩余处理的ip: 199
# Thread-32 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 ',)))
# remove proxy: {'http': '190.199.221.196:8081', 'https': '190.199.221.196:8081'}
# -------------------------------------
# Thread-32 : 当前剩余处理的ip: 198
# Thread-31 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 500 Internal Server Error',)))
# remove proxy: {'http': '168.235.93.162:8080', 'https': '168.235.93.162:8080'}
# -------------------------------------
# Thread-31 : 当前剩余处理的ip: 197
# Thread-27 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '114.202.2.185:80', 'https': '114.202.2.185:80'}
# -------------------------------------
# Thread-27 : 当前剩余处理的ip: 196
# Thread-21 is processing
# r.status_code: 200
# -------------------------------------
# Thread-21 : 当前剩余处理的ip: 195
# Thread-44 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '167.99.153.225:3128', 'https': '167.99.153.225:3128'}
# -------------------------------------
# Thread-44 : 当前剩余处理的ip: 194
# Thread-36 is processing
# r.status_code: 200
# -------------------------------------
# Thread-36 : 当前剩余处理的ip: 193
# Thread-15 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 ',)))
# remove proxy: {'http': '170.82.228.42:8080', 'https': '170.82.228.42:8080'}
# -------------------------------------
# Thread-15 : 当前剩余处理的ip: 192
# Thread-35 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '174.138.5.199:8080', 'https': '174.138.5.199:8080'}
# -------------------------------------
# Thread-35 : 当前剩余处理的ip: 191
# Thread-17 is processing
# r.status_code: 200
# -------------------------------------
# Thread-17 : 当前剩余处理的ip: 190
# Thread-19 is processing
# r.status_code: 200
# -------------------------------------
# Thread-19 : 当前剩余处理的ip: 189
# Thread-25 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLError("bad handshake: SysCallError(-1, 'Unexpected EOF')",),))
# remove proxy: {'http': '180.254.185.140:80', 'https': '180.254.185.140:80'}
# -------------------------------------
# Thread-25 : 当前剩余处理的ip: 188
# Thread-5 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '177.67.83.134:80', 'https': '177.67.83.134:80'}
# -------------------------------------
# Thread-5 : 当前剩余处理的ip: 187
# Thread-24 is processing
# r.status_code: 200
# -------------------------------------
# Thread-24 : 当前剩余处理的ip: 186
# Thread-38 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '134.35.153.52:8080', 'https': '134.35.153.52:8080'}
# -------------------------------------
# Thread-38 : 当前剩余处理的ip: 185
# Thread-22 is processing
# r.status_code: 200
# -------------------------------------
# Thread-22 : 当前剩余处理的ip: 184
# Thread-43 is processing
# r.status_code: 200
# -------------------------------------
# Thread-43 : 当前剩余处理的ip: 183
# Thread-42 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLError("bad handshake: SysCallError(-1, 'Unexpected EOF')",),))
# remove proxy: {'http': '125.162.210.190:80', 'https': '125.162.210.190:80'}
# -------------------------------------
# Thread-42 : 当前剩余处理的ip: 182
# Thread-45 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '41.169.146.2:8080', 'https': '41.169.146.2:8080'}
# -------------------------------------
# Thread-45 : 当前剩余处理的ip: 181
# Thread-22 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 400 Bad Request',)))
# remove proxy: {'http': '87.233.77.52:80', 'https': '87.233.77.52:80'}
# -------------------------------------
# Thread-22 : 当前剩余处理的ip: 180
# Thread-44 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '41.190.33.162:8080', 'https': '41.190.33.162:8080'}
# -------------------------------------
# Thread-44 : 当前剩余处理的ip: 179
# Thread-13 is processing
# r.status_code: 200
# -------------------------------------
# Thread-13 : 当前剩余处理的ip: 178
# Thread-39 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fe4dc73fda0>, 'Connection to 96.9.83.23 timed out. (connect timeout=5)'))
# remove proxy: {'http': '96.9.83.23:53281', 'https': '96.9.83.23:53281'}
# -------------------------------------
# Thread-39 : 当前剩余处理的ip: 177
# Thread-23 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fe4dc6c4828>, 'Connection to 213.47.227.118 timed out. (connect timeout=5)'))
# remove proxy: {'http': '213.47.227.118:8080', 'https': '213.47.227.118:8080'}
# -------------------------------------
# Thread-23 : 当前剩余处理的ip: 176
# Thread-7 is processing
# r.status_code: 200
# -------------------------------------
# Thread-7 : 当前剩余处理的ip: 175
# Thread-47 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '110.235.249.146:53281', 'https': '110.235.249.146:53281'}
# -------------------------------------
# Thread-47 : 当前剩余处理的ip: 174
# Thread-37 is processing
# r.status_code: 200
# -------------------------------------
# Thread-37 : 当前剩余处理的ip: 173
# Thread-13 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 400 Bad Request',)))
# remove proxy: {'http': '31.186.71.46:8081', 'https': '31.186.71.46:8081'}
# -------------------------------------
# Thread-13 : 当前剩余处理的ip: 172
# Thread-12 is processing
# r.status_code: 200
# -------------------------------------
# Thread-12 : 当前剩余处理的ip: 171
# Thread-6 is processing
# r.status_code: 200
# -------------------------------------
# Thread-6 : 当前剩余处理的ip: 170
# Thread-28 is processing
# r.status_code: 200
# -------------------------------------
# Thread-28 : 当前剩余处理的ip: 169
# Thread-41 is processing
# r.status_code: 200
# -------------------------------------
# Thread-41 : 当前剩余处理的ip: 168
# Thread-46 is processingThread-17 is processing
# r.status_code:
#  r.status_code:200
# 200-------------------------------------
#
# Thread-46 : 当前剩余处理的ip: 167
# -------------------------------------
# Thread-17 : 当前剩余处理的ip: 166
# Thread-32 is processing
# r.status_code: 200
# -------------------------------------
# Thread-32 : 当前剩余处理的ip: 165
# Thread-40 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fe4dc6cb2e8>, 'Connection to 95.78.172.194 timed out. (connect timeout=5)'))
# remove proxy: {'http': '95.78.172.194:53281', 'https': '95.78.172.194:53281'}
# -------------------------------------
# Thread-40 : 当前剩余处理的ip: 164
# Thread-33 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '103.47.239.165:8080', 'https': '103.47.239.165:8080'}
# -------------------------------------
# Thread-33 : 当前剩余处理的ip: 163
# Thread-8 is processing
# r.status_code: 200
# -------------------------------------
# Thread-8 : 当前剩余处理的ip: 162
# Thread-11 is processing
# r.status_code: 200
# -------------------------------------
# Thread-11 : 当前剩余处理的ip: 161
# Thread-5 is processing
# r.status_code: 200
# -------------------------------------
# Thread-5 : 当前剩余处理的ip: 160
# Thread-16 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '103.56.206.236:3129', 'https': '103.56.206.236:3129'}
# -------------------------------------
# Thread-16 : 当前剩余处理的ip: 159
# Thread-26 is processing
# r.status_code: 200
# -------------------------------------
# Thread-26 : 当前剩余处理的ip: 158
# Thread-48 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fe4dc622b70>, 'Connection to 91.237.123.201 timed out. (connect timeout=5)'))
# remove proxy: {'http': '91.237.123.201:41258', 'https': '91.237.123.201:41258'}
# -------------------------------------
# Thread-48 : 当前剩余处理的ip: 157
# Thread-29 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '80.78.64.70:8080', 'https': '80.78.64.70:8080'}
# -------------------------------------
# Thread-29 : 当前剩余处理的ip: 156
# Thread-15 is processing
# r.status_code: 200
# -------------------------------------
# Thread-15 : 当前剩余处理的ip: 155
# Thread-4 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '186.0.205.196:53281', 'https': '186.0.205.196:53281'}
# -------------------------------------
# Thread-4 : 当前剩余处理的ip: 154
# Thread-18 is processing
# r.status_code: 200
# -------------------------------------
# Thread-18 : 当前剩余处理的ip: 153
# Thread-30 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Read timed out.
# remove proxy: {'http': '92.245.174.164:41258', 'https': '92.245.174.164:41258'}
# -------------------------------------
# Thread-30 : 当前剩余处理的ip: 152
# Thread-47 is processing
# r.status_code: 200
# -------------------------------------
# Thread-47 : 当前剩余处理的ip: 151
# Thread-35 is processing
# r.status_code: 200
# -------------------------------------
# Thread-35 : 当前剩余处理的ip: 150
# Thread-21 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fe4dc62a048>, 'Connection to 103.69.111.118 timed out. (connect timeout=5)'))
# remove proxy: {'http': '103.69.111.118:8080', 'https': '103.69.111.118:8080'}
# -------------------------------------
# Thread-21 : 当前剩余处理的ip: 149
# Thread-14 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Read timed out. (read timeout=5)
# remove proxy: {'http': '138.36.200.170:53281', 'https': '138.36.200.170:53281'}
# -------------------------------------
# Thread-14 : 当前剩余处理的ip: 148
# Thread-27 is processing
# r.status_code: 200
# -------------------------------------
# Thread-27 : 当前剩余处理的ip: 147
# Thread-25 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fe4dc765320>, 'Connection to 14.102.121.138 timed out. (connect timeout=5)'))
# remove proxy: {'http': '14.102.121.138:8080', 'https': '14.102.121.138:8080'}
# -------------------------------------
# Thread-25 : 当前剩余处理的ip: 146
# Thread-19 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '149.129.219.94:8888', 'https': '149.129.219.94:8888'}
# -------------------------------------
# Thread-19 : 当前剩余处理的ip: 145
# Thread-38 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fe4dc73f208>, 'Connection to 79.106.45.154 timed out. (connect timeout=5)'))
# remove proxy: {'http': '79.106.45.154:8080', 'https': '79.106.45.154:8080'}
# -------------------------------------
# Thread-38 : 当前剩余处理的ip: 144
# Thread-24 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '103.228.35.76:6666', 'https': '103.228.35.76:6666'}
# -------------------------------------
# Thread-24 : 当前剩余处理的ip: 143
# Thread-42 is processing
# r.status_code: 200
# -------------------------------------
# Thread-42 : 当前剩余处理的ip: 142
# Thread-7 is processing
# r.status_code: 200
# -------------------------------------
# Thread-7 : 当前剩余处理的ip: 141
# Thread-22 is processing
# r.status_code: 200
# -------------------------------------
# Thread-22 : 当前剩余处理的ip: 140
# Thread-44 is processing
# r.status_code: 200
# -------------------------------------
# Thread-44 : 当前剩余处理的ip: 139
# Thread-26 is processing
# r.status_code: 200
# -------------------------------------
# Thread-26 : 当前剩余处理的ip: 138
# Thread-46 is processing
# r.status_code: 200
# -------------------------------------
# Thread-46 : 当前剩余处理的ip: 137
# Thread-35 is processing
# r.status_code: 200
# -------------------------------------
# Thread-35 : 当前剩余处理的ip: 136
# Thread-31 is processing
# r.status_code: 200
# -------------------------------------
# Thread-31 : 当前剩余处理的ip: 135
# Thread-12 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fe4dc5f0400>, 'Connection to 101.109.210.5 timed out. (connect timeout=5)'))
# remove proxy: {'http': '101.109.210.5:8080', 'https': '101.109.210.5:8080'}
# -------------------------------------
# Thread-12 : 当前剩余处理的ip: 134
# Thread-48 is processing
# r.status_code: 200
# -------------------------------------
# Thread-48 : 当前剩余处理的ip: 133
# Thread-18 is processing
# r.status_code: 200
# -------------------------------------
# Thread-18 : 当前剩余处理的ip: 132
# Thread-8 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fe4df7f7da0>, 'Connection to 128.201.99.81 timed out. (connect timeout=5)'))
# remove proxy: {'http': '128.201.99.81:53281', 'https': '128.201.99.81:53281'}
# -------------------------------------
# Thread-8 : 当前剩余处理的ip: 131
# Thread-11 is processing
# r.status_code: 200
# -------------------------------------
# Thread-11 : 当前剩余处理的ip: 130
# Thread-33 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '200.123.5.77:80', 'https': '200.123.5.77:80'}
# -------------------------------------
# Thread-33 : 当前剩余处理的ip: 129
# Thread-13 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '173.193.90.210:3129', 'https': '173.193.90.210:3129'}
# -------------------------------------
# Thread-13 : 当前剩余处理的ip: 128
# Thread-37 is processing
# r.status_code: 200
# -------------------------------------
# Thread-37 : 当前剩余处理的ip: 127
# Thread-23 is processing
# r.status_code: 200
# -------------------------------------
# Thread-23 : 当前剩余处理的ip: 126
# Thread-18 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 501 Not Implemented',)))
# remove proxy: {'http': '92.206.100.180:8080', 'https': '92.206.100.180:8080'}
# -------------------------------------
# Thread-18 : 当前剩余处理的ip: 125
# Thread-32 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', ConnectionResetError(104, 'Connection reset by peer')))
# remove proxy: {'http': '187.32.243.30:80', 'https': '187.32.243.30:80'}
# -------------------------------------
# Thread-32 : 当前剩余处理的ip: 124
# Thread-5 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '185.119.57.172:53281', 'https': '185.119.57.172:53281'}
# -------------------------------------
# Thread-5 : 当前剩余处理的ip: 123
# Thread-29 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fe4dc780978>, 'Connection to 109.87.23.100 timed out. (connect timeout=5)'))
# remove proxy: {'http': '109.87.23.100:8080', 'https': '109.87.23.100:8080'}
# -------------------------------------
# Thread-29 : 当前剩余处理的ip: 122
# Thread-16 is processing
# r.status_code: 200
# -------------------------------------
# Thread-16 : 当前剩余处理的ip: 121
# Thread-7 is processing
# r.status_code: 200
# -------------------------------------
# Thread-7 : 当前剩余处理的ip: 120
# Thread-43 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '150.129.207.66:6666', 'https': '150.129.207.66:6666'}
# -------------------------------------
# Thread-43 : 当前剩余处理的ip: 119
# Thread-23 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 501 Not Implemented',)))
# remove proxy: {'http': '94.135.197.9:8080', 'https': '94.135.197.9:8080'}
# -------------------------------------
# Thread-23 : 当前剩余处理的ip: 118
# Thread-48 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '177.158.150.119:8080', 'https': '177.158.150.119:8080'}
# -------------------------------------
# Thread-48 : 当前剩余处理的ip: 117
# Thread-30 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fe4dc6f1ac8>, 'Connection to 83.175.166.234 timed out. (connect timeout=5)'))
# remove proxy: {'http': '83.175.166.234:8080', 'https': '83.175.166.234:8080'}
# -------------------------------------
# Thread-30 : 当前剩余处理的ip: 116
# Thread-47 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fe4dc675828>, 'Connection to 203.153.109.34 timed out. (connect timeout=5)'))
# remove proxy: {'http': '203.153.109.34:80', 'https': '203.153.109.34:80'}
# -------------------------------------
# Thread-47 : 当前剩余处理的ip: 115
# Thread-40 is processing
# r.status_code: 200
# -------------------------------------
# Thread-40 : 当前剩余处理的ip: 114
# Thread-17 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '89.189.87.132:8080', 'https': '89.189.87.132:8080'}
# -------------------------------------
# Thread-17 : 当前剩余处理的ip: 113
# Thread-14 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fe4dc780e10>, 'Connection to 84.0.81.157 timed out. (connect timeout=5)'))
# remove proxy: {'http': '84.0.81.157:8080', 'https': '84.0.81.157:8080'}
# -------------------------------------
# Thread-14 : 当前剩余处理的ip: 112
# Thread-40 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7fe4df7f76a0>: Failed to establish a new connection: [Errno 111] Connection refused',)))
# remove proxy: {'http': '95.31.29.209:3128', 'https': '95.31.29.209:3128'}
# -------------------------------------
# Thread-40 : 当前剩余处理的ip: 111
# Thread-27 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fe4dc65db70>, 'Connection to 94.75.70.66 timed out. (connect timeout=5)'))
# remove proxy: {'http': '94.75.70.66:8080', 'https': '94.75.70.66:8080'}
# -------------------------------------
# Thread-27 : 当前剩余处理的ip: 110
# Thread-34 is processing
# r.status_code: 200
# -------------------------------------
# Thread-34 : 当前剩余处理的ip: 109
# Thread-4 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '103.239.254.86:8080', 'https': '103.239.254.86:8080'}
# -------------------------------------
# Thread-4 : 当前剩余处理的ip: 108
# Thread-40 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7fe4dc6f1390>: Failed to establish a new connection: [Errno 111] Connection refused',)))
# remove proxy: {'http': '81.163.62.250:41258', 'https': '81.163.62.250:41258'}
# -------------------------------------
# Thread-40 : 当前剩余处理的ip: 107
# Thread-5 is processing
# r.status_code: 200
# -------------------------------------
# Thread-5 : 当前剩余处理的ip: 106
# Thread-13 is processing
# r.status_code: 200
# -------------------------------------
# Thread-13 : 当前剩余处理的ip: 105
# Thread-41 is processing
# r.status_code: 200
# -------------------------------------
# Thread-41 : 当前剩余处理的ip: 104
# Thread-19 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fe4dc5c6128>, 'Connection to 93.39.194.66 timed out. (connect timeout=5)'))
# remove proxy: {'http': '93.39.194.66:8080', 'https': '93.39.194.66:8080'}
# -------------------------------------
# Thread-19 : 当前剩余处理的ip: 103
# Thread-38 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fe4dc588d30>, 'Connection to 187.49.80.99 timed out. (connect timeout=5)'))
# remove proxy: {'http': '187.49.80.99:8080', 'https': '187.49.80.99:8080'}
# -------------------------------------
# Thread-38 : 当前剩余处理的ip: 102
# Thread-42 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fe4dc622a58>, 'Connection to 42.112.15.116 timed out. (connect timeout=5)'))
# remove proxy: {'http': '42.112.15.116:53281', 'https': '42.112.15.116:53281'}
# -------------------------------------
# Thread-42 : 当前剩余处理的ip: 101
# Thread-13 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '189.198.226.4:3128', 'https': '189.198.226.4:3128'}
# -------------------------------------
# Thread-13 : 当前剩余处理的ip: 100
# Thread-24 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '46.175.253.248:8080', 'https': '46.175.253.248:8080'}
# -------------------------------------
# Thread-24 : 当前剩余处理的ip: 99
# Thread-22 is processing
# r.status_code: 200
# -------------------------------------
# Thread-22 : 当前剩余处理的ip: 98
# Thread-9 is processing
# r.status_code: 200
# -------------------------------------
# Thread-9 : 当前剩余处理的ip: 97
# Thread-14 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '186.214.142.227:8080', 'https': '186.214.142.227:8080'}
# -------------------------------------
# Thread-14 : 当前剩余处理的ip: 96
# Thread-38 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLError("bad handshake: SysCallError(-1, 'Unexpected EOF')",),))
# remove proxy: {'http': '103.231.62.110:1080', 'https': '103.231.62.110:1080'}
# -------------------------------------
# Thread-38 : 当前剩余处理的ip: 95
# Thread-37 is processing
# r.status_code: 200
# -------------------------------------
# Thread-37 : 当前剩余处理的ip: 94
# Thread-44 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '103.249.251.242:84', 'https': '103.249.251.242:84'}
# -------------------------------------
# Thread-44 : 当前剩余处理的ip: 93
# Thread-36 is processing
# r.status_code: 200
# -------------------------------------
# Thread-36 : 当前剩余处理的ip: 92
# Thread-28 is processing
# r.status_code: 200
# -------------------------------------
# Thread-28 : 当前剩余处理的ip: 91
# Thread-46 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fe4dc60d0f0>, 'Connection to 103.239.252.230 timed out. (connect timeout=5)'))
# remove proxy: {'http': '103.239.252.230:8080', 'https': '103.239.252.230:8080'}
# -------------------------------------
# Thread-46 : 当前剩余处理的ip: 90
# Thread-35 is processing
# r.status_code: 200
# -------------------------------------
# Thread-35 : 当前剩余处理的ip: 89
# Thread-37 is processing
# r.status_code: 200
# -------------------------------------
# Thread-37 : 当前剩余处理的ip: 88
# Thread-10 is processing
# r.status_code: 200
# -------------------------------------
# Thread-10 : 当前剩余处理的ip: 87
# Thread-12 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fe4dc6a4e80>, 'Connection to 103.250.157.49 timed out. (connect timeout=5)'))
# remove proxy: {'http': '103.250.157.49:6666', 'https': '103.250.157.49:6666'}
# -------------------------------------
# Thread-12 : 当前剩余处理的ip: 86
# Thread-5 is processing
# r.status_code: 200
# -------------------------------------
# Thread-5 : 当前剩余处理的ip: 85
# Thread-11 is processing
# r.status_code: 200
# -------------------------------------
# Thread-11 : 当前剩余处理的ip: 84
# Thread-32 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fe4dc5d1fd0>, 'Connection to 189.112.92.139 timed out. (connect timeout=5)'))
# remove proxy: {'http': '189.112.92.139:53281', 'https': '189.112.92.139:53281'}
# -------------------------------------
# Thread-32 : 当前剩余处理的ip: 83
# Thread-33 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '187.32.4.66:8080', 'https': '187.32.4.66:8080'}
# -------------------------------------
# Thread-33 : 当前剩余处理的ip: 82
# Thread-18 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '204.44.64.253:80', 'https': '204.44.64.253:80'}
# -------------------------------------
# Thread-18 : 当前剩余处理的ip: 81
# Thread-29 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fe4df80b0f0>, 'Connection to 201.242.242.117 timed out. (connect timeout=5)'))
# remove proxy: {'http': '201.242.242.117:8080', 'https': '201.242.242.117:8080'}
# -------------------------------------
# Thread-29 : 当前剩余处理的ip: 80
# Thread-43 is processing
# r.status_code: 200
# -------------------------------------
# Thread-43 : 当前剩余处理的ip: 79
# Thread-41 is processing
# r.status_code: 200
# -------------------------------------
# Thread-41 : 当前剩余处理的ip: 78
# Thread-8 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '187.157.187.134:53281', 'https': '187.157.187.134:53281'}
# -------------------------------------
# Thread-8 : 当前剩余处理的ip: 77
# Thread-27 is processing
# r.status_code: 200
# -------------------------------------
# Thread-27 : 当前剩余处理的ip: 76
# Thread-7 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '103.70.146.226:53281', 'https': '103.70.146.226:53281'}
# -------------------------------------
# Thread-7 : 当前剩余处理的ip: 75
# Thread-33 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 501 Not Implemented',)))
# remove proxy: {'http': '88.215.99.176:8080', 'https': '88.215.99.176:8080'}
# -------------------------------------
# Thread-33 : 当前剩余处理的ip: 74
# Thread-47 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fe4dc63efd0>, 'Connection to 181.129.193.146 timed out. (connect timeout=5)'))
# remove proxy: {'http': '181.129.193.146:53281', 'https': '181.129.193.146:53281'}
# -------------------------------------
# Thread-47 : 当前剩余处理的ip: 73
# Thread-31 is processing
# r.status_code: 200
# -------------------------------------
# Thread-31 : 当前剩余处理的ip: 72
# Thread-13 is processing
# r.status_code: 200
# -------------------------------------
# Thread-13 : 当前剩余处理的ip: 71
# Thread-36 is processing
# r.status_code: 200
# -------------------------------------
# Thread-36 : 当前剩余处理的ip: 70
# Thread-4 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fe4df7deb00>, 'Connection to 88.204.178.138 timed out. (connect timeout=5)'))
# remove proxy: {'http': '88.204.178.138:8080', 'https': '88.204.178.138:8080'}
# -------------------------------------
# Thread-4 : 当前剩余处理的ip: 69
# Thread-14 is processing
# r.status_code: 200
# -------------------------------------
# Thread-14 : 当前剩余处理的ip: 68
# Thread-48 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '190.198.231.233:8080', 'https': '190.198.231.233:8080'}
# -------------------------------------
# Thread-48 : 当前剩余处理的ip: 67
# Thread-19 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '178.62.76.18:82', 'https': '178.62.76.18:82'}
# -------------------------------------
# Thread-19 : 当前剩余处理的ip: 66
# Thread-6 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Read timed out. (read timeout=5)
# remove proxy: {'http': '81.16.246.44:8080', 'https': '81.16.246.44:8080'}
# -------------------------------------
# Thread-6 : 当前剩余处理的ip: 65
# Thread-35 is processing
# r.status_code: 200
# -------------------------------------
# Thread-35 : 当前剩余处理的ip: 64
# Thread-42 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fe4dc6f10f0>, 'Connection to 125.162.89.136 timed out. (connect timeout=5)'))
# remove proxy: {'http': '125.162.89.136:8080', 'https': '125.162.89.136:8080'}
# -------------------------------------
# Thread-42 : 当前剩余处理的ip: 63
# Thread-15 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '134.35.220.179:8080', 'https': '134.35.220.179:8080'}
# -------------------------------------
# Thread-15 : 当前剩余处理的ip: 62
# Thread-17 is processing
# r.status_code: 200
# -------------------------------------
# Thread-17 : 当前剩余处理的ip: 61
# Thread-22 is processing
# ...
# Thread-260 : 当前剩余处理的ip: 284
#  ['无工作经验', '大专', '招2人', '07-17发布', '五险一金', '餐补补贴', '住房补贴', '专业培训', '绩效奖金', '年底双薪', '弹性工作', '员工旅游', '定期体检', '下午茶']
# ----------------------
# ###当前proxies的ip数:  0
# Thread-214开始运行
# Thread-307 : 当前剩余处理的ip: 282
# Thread-308开始运行
# Thread-308 : 当前剩余处理的ip: 281
# Thread-128开始运行
# Thread-173开始运行
# Thread-252 is processing
# r.status_code: 200
# -------------------------------------
# Thread-252 : 当前剩余处理的ip: 283
# Thread-309开始运行
# Thread-261开始运行
# Thread-309 : 当前剩余处理的ip: 280
# Thread-173 : 当前剩余处理的ip: 281
# Thread-114 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fe4c83b6438>, 'Connection to 190.14.249.98 timed out. (connect timeout=5)'))
# remove proxy: {'http': '190.14.249.98:80', 'https': '190.14.249.98:80'}
# -------------------------------------
# Thread-114 : 当前剩余处理的ip: 283
# Thread-174开始运行
# Thread-214 : 当前剩余处理的ip: 286
# Thread-261 : 当前剩余处理的ip: 282
# Thread-128 : 当前剩余处理的ip: 282
# getTag()中tag_list:Thread-215开始运行
# Thread-310开始运行
# Thread-115 is processingThread-215 : 当前剩余处理的ip: 285
# Thread-216开始运行
#
# r.status_code: 200
# -------------------------------------
# Thread-115 : 当前剩余处理的ip: 281
# Thread-112 is processingThread-216 : 当前剩余处理的ip: 284
# Thread-310 : 当前剩余处理的ip: 279
# Thread-311开始运行
# Thread-311 : 当前剩余处理的ip: 278
#
# r.status_code: 200
# -------------------------------------
# Thread-112 : 当前剩余处理的ip: 280
# Thread-129开始运行
# Thread-306 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '174.138.5.199:8080', 'https': '174.138.5.199:8080'}
# -------------------------------------
# Thread-306 : 当前剩余处理的ip: 277
# Thread-250 is processingThread-312开始运行
# Thread-262开始运行
# Thread-217开始运行
# Thread-174 : 当前剩余处理的ip: 280
# Thread-249 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fe4c8295940>, 'Connection to 190.14.249.98 timed out. (connect timeout=5)'))
# remove proxy: {'http': '190.14.249.98:80', 'https': '190.14.249.98:80'}
# -------------------------------------
# Thread-249 : 当前剩余处理的ip: 281
# Thread-262 : 当前剩余处理的ip: 280
# Thread-263开始运行
# Thread-217 : 当前剩余处理的ip: 283
# Thread-312 : 当前剩余处理的ip: 276
# Thread-313开始运行
# Thread-159 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '190.14.249.98:80', 'https': '190.14.249.98:80'}
# -------------------------------------
# Thread-159 : 当前剩余处理的ip: 279
# Thread-205 is processing
# r.status_code: 200
# -------------------------------------
# Thread-205 : 当前剩余处理的ip: 282
# Thread-129 : 当前剩余处理的ip: 279
# Thread-292 is processingThread-111 is processingThread-116 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fe4c82a62e8>, 'Connection to 95.67.67.54 timed out. (connect timeout=5)'))
# remove proxy: {'http': '95.67.67.54:53281', 'https': '95.67.67.54:53281'}
# -------------------------------------
# Thread-116 : 当前剩余处理的ip: 278
#
# r.status_code: 200
# -------------------------------------
# Thread-292 : 当前剩余处理的ip: 275
# Thread-297 is processing ['3-4年经验', '本科', '招1人', '07-17发布', '五险一金', '专业培训', '绩效奖金', '年终奖金', '股票期权', '弹性工作']
# ----------------------
# ###当前proxies的ip数:  0
# Thread-313 : 当前剩余处理的ip: 274
#
# r.status_code: 200
# -------------------------------------
# Thread-111 : 当前剩余处理的ip: 277
# Thread-314开始运行
#
# r.status_code: 200
# -------------------------------------
# Thread-250 : 当前剩余处理的ip: 279
# Thread-263 : 当前剩余处理的ip: 278
# Thread-294 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '190.14.249.98:80', 'https': '190.14.249.98:80'}
# -------------------------------------
# Thread-294 : 当前剩余处理的ip: 273
# Thread-117 is processing
# r.status_code: 200
# -------------------------------------
# Thread-117 : 当前剩余处理的ip: 276
# Thread-314 : 当前剩余处理的ip: 272
# Thread-130开始运行
# Thread-114 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '174.138.5.199:8080', 'https': '174.138.5.199:8080'}
# -------------------------------------
# Thread-114 : 当前剩余处理的ip: 275
# Thread-218开始运行
# Thread-167 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '174.138.5.199:8080', 'https': '174.138.5.199:8080'}
# -------------------------------------
# Thread-218 : 当前剩余处理的ip: 281
# Thread-130 : 当前剩余处理的ip: 274
# Thread-315开始运行
# Thread-167 : 当前剩余处理的ip: 278
# Thread-219开始运行
# Thread-131开始运行
# Thread-252 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '174.138.5.199:8080', 'https': '174.138.5.199:8080'}
# -------------------------------------
# Thread-252 : 当前剩余处理的ip: 277
# Thread-175开始运行
# Thread-175 : 当前剩余处理的ip: 277
# Thread-315 : 当前剩余处理的ip: 271
# Thread-264开始运行
# Thread-131 : 当前剩余处理的ip: 273
#
# r.status_code: 200
# -------------------------------------
# Thread-297 : 当前剩余处理的ip: 270
# Thread-247 is processing
# r.status_code: 200
# -------------------------------------
# Thread-247 : 当前剩余处理的ip: 276
# Thread-132开始运行
# Thread-316开始运行
# Thread-176开始运行
# Thread-264 : 当前剩余处理的ip: 275
# Thread-176 : 当前剩余处理的ip: 276
# Thread-121 is processingThread-202 is processing
# r.status_code: 200
# -------------------------------------
# Thread-202 : 当前剩余处理的ip: 280
# Thread-265开始运行
# Thread-316 : 当前剩余处理的ip: 269
# Thread-132 : 当前剩余处理的ip: 272
# Thread-165 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fe4a9e0da20>, 'Connection to 27.116.51.116 timed out. (connect timeout=5)'))
# remove proxy: {'http': '27.116.51.116:6666', 'https': '27.116.51.116:6666'}
# -------------------------------------
# Thread-165 : 当前剩余处理的ip: 275
# Thread-172 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '52.23.193.25:8080', 'https': '52.23.193.25:8080'}
# -------------------------------------
# Thread-172 : 当前剩余处理的ip: 274
# Thread-251 is processing
# r.status_code: 200
# -------------------------------------
# Thread-251 : 当前剩余处理的ip: 274
#
# r.status_code: 200
# -------------------------------------
# Thread-121 : 当前剩余处理的ip: 271
# Thread-317开始运行
# Thread-255 is processing
# r.status_code: 200
# -------------------------------------
# Thread-255 : 当前剩余处理的ip: 273
# Thread-208 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '154.119.52.168:9050', 'https': '154.119.52.168:9050'}
# -------------------------------------
# Thread-208 : 当前剩余处理的ip: 279
# Thread-177开始运行
# Thread-122 is processing
# r.status_code: 200
# -------------------------------------
# Thread-122 : 当前剩余处理的ip: 270
# Thread-317 : 当前剩余处理的ip: 268
# Thread-307 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '52.23.193.25:8080', 'https': '52.23.193.25:8080'}
# -------------------------------------
# Thread-307 : 当前剩余处理的ip: 267
# Thread-318开始运行
# Thread-133开始运行
# Thread-160 is processing
# r.status_code: 200
# -------------------------------------
# Thread-160 : 当前剩余处理的ip: 273
# Thread-295 is processing
# r.status_code: 200
# -------------------------------------
# Thread-295 : 当前剩余处理的ip: 266
# Thread-177 : 当前剩余处理的ip: 272
# Thread-133 : 当前剩余处理的ip: 269
# Thread-134开始运行
# Thread-113 is processing
# r.status_code: 200
# -------------------------------------
# Thread-113 : 当前剩余处理的ip: 268
# Thread-178开始运行
# Thread-120 is processing
# r.status_code: 200
# -------------------------------------
# Thread-120 : 当前剩余处理的ip: 267
# Thread-156 is processingThread-178 : 当前剩余处理的ip: 271
# Thread-179开始运行
#
# r.status_code: 200
# -------------------------------------
# Thread-156 : 当前剩余处理的ip: 270
# Thread-219 : 当前剩余处理的ip: 278
# Thread-261 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '52.23.193.25:8080', 'https': '52.23.193.25:8080'}
# -------------------------------------
# Thread-261 : 当前剩余处理的ip: 272
# Thread-265 : 当前剩余处理的ip: 271
# Thread-134 : 当前剩余处理的ip: 266
# Thread-318 : 当前剩余处理的ip: 265
# Thread-179 : 当前剩余处理的ip: 269
# Thread-180开始运行
# Thread-123 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response',)))
# remove proxy: {'http': '186.211.162.106:20183', 'https': '186.211.162.106:20183'}
# -------------------------------------
# Thread-123 : 当前剩余处理的ip: 265
# Thread-293 is processing
# r.status_code: 200
# -------------------------------------
# Thread-293 : 当前剩余处理的ip: 264
# Thread-180 : 当前剩余处理的ip: 268
# Thread-135开始运行
# Thread-212 is processing
# r.status_code: 200
# -------------------------------------
# Thread-212 : 当前剩余处理的ip: 277
# Thread-206 is processing
# r.status_code: 200
# -------------------------------------
# Thread-206 : 当前剩余处理的ip: 276
# Thread-295 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response',)))
# remove proxy: {'http': '182.253.130.245:53281', 'https': '182.253.130.245:53281'}
# -------------------------------------
# Thread-295 : 当前剩余处理的ip: 263
# Thread-266开始运行
# Thread-291 is processing
# r.status_code: 200
# -------------------------------------
# Thread-291 : 当前剩余处理的ip: 262
# Thread-296 is processing
# r.status_code: 200
# -------------------------------------
# Thread-296 : 当前剩余处理的ip: 261
# Thread-160 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response',)))
# remove proxy: {'http': '41.60.232.62:8080', 'https': '41.60.232.62:8080'}
# -------------------------------------
# Thread-160 : 当前剩余处理的ip: 267
# Thread-135 : 当前剩余处理的ip: 264
# Thread-128 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '52.23.193.25:8080', 'https': '52.23.193.25:8080'}
# -------------------------------------
# Thread-128 : 当前剩余处理的ip: 263
# Thread-204 is processingThread-210 is processing
# r.status_code: 200
# -------------------------------------
# Thread-210 : 当前剩余处理的ip: 275
# Thread-136开始运行
# Thread-136 : 当前剩余处理的ip: 262Thread-219 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response',)))
# remove proxy: {'http': '195.138.84.3:8080', 'https': '195.138.84.3:8080'}
# -------------------------------------
# Thread-219 : 当前剩余处理的ip: 274
# Thread-301 is processing
# r.status_code: 200
# -------------------------------------
# Thread-301 : 当前剩余处理的ip: 260
# Thread-203 is processing
# Thread-137开始运行
# Thread-266 : 当前剩余处理的ip: 270
# Thread-205 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '52.23.193.25:8080', 'https': '52.23.193.25:8080'}
# -------------------------------------
# Thread-205 : 当前剩余处理的ip: 273
#
# r.status_code: 200
# -------------------------------------
# Thread-203 : 当前剩余处理的ip: 272
# Thread-137 : 当前剩余处理的ip: 261
# Thread-319开始运行
# Thread-220开始运行
#
# r.status_code: 200
# -------------------------------------
# Thread-204 : 当前剩余处理的ip: 271
# Thread-217 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '174.138.5.199:8080', 'https': '174.138.5.199:8080'}
# -------------------------------------
# Thread-217 : 当前剩余处理的ip: 270
# Thread-319 : 当前剩余处理的ip: 259
# Thread-320开始运行
# Thread-291 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response',)))
# remove proxy: {'http': '80.48.119.28:8080', 'https': '80.48.119.28:8080'}
# -------------------------------------
# Thread-291 : 当前剩余处理的ip: 258
# Thread-220 : 当前剩余处理的ip: 269
# Thread-157 is processing
# r.status_code: 200
# -------------------------------------
# Thread-157 : 当前剩余处理的ip: 266
# Thread-315 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# remove proxy: {'http': '62.210.254.135:6666', 'https': '62.210.254.135:6666'}Thread-221开始运行
# Thread-138开始运行
#
# -------------------------------------
# Thread-315 : 当前剩余处理的ip: 257Thread-320 : 当前剩余处理的ip: 257
# Thread-158 is processingThread-296 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 500 Internal Server Error',)))
# remove proxy: {'http': '168.235.93.162:8080', 'https': '168.235.93.162:8080'}
# -------------------------------------
# Thread-296 : 当前剩余处理的ip: 256
# Thread-321开始运行
# Thread-248 is processing
# r.status_code: 200
# -------------------------------------
# Thread-248 : 当前剩余处理的ip: 269
# Thread-321 : 当前剩余处理的ip: 255
# Thread-322开始运行
# Thread-313 is processing
# r.status_code: 200
# -------------------------------------
# Thread-313 : 当前剩余处理的ip: 254
# Thread-138 : 当前剩余处理的ip: 260
# Thread-139开始运行
# Thread-136 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response',)))
# remove proxy: {'http': '80.48.119.28:8080', 'https': '80.48.119.28:8080'}
# -------------------------------------
# Thread-136 : 当前剩余处理的ip: 259
# Thread-121 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# remove proxy: {'http': '62.210.254.135:6666', 'https': '62.210.254.135:6666'}
# -------------------------------------
# Thread-157 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response',)))
# remove proxy: {'http': '182.253.130.245:53281', 'https': '182.253.130.245:53281'}
# -------------------------------------
# Thread-157 : 当前剩余处理的ip: 265
# Thread-221 : 当前剩余处理的ip: 268
# Thread-139 : 当前剩余处理的ip: 258

# %% [raw]
# 一个最影响速度的地方就是每个线程在开始运行handle_single前要进行ip清洗的操作

# %% [raw]
# 10页2线程
# getCleanProxy()45
# pack_tag()20
# ---
# 主线程Thread-4停止
# 主线程Thread-5停止
# 爬取时间: 540.9446504116058
