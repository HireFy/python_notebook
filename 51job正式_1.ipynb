# %%
import requests
from bs4 import BeautifulSoup
import queue
import threading
import re
import csv
import functools
import os
from time import time

# %%
lock = threading.Lock()

# %%
# 获取函数运行时间装饰器
def excute_time(func):
    @functools.wraps(func)
    def wrapper(*args, **kwargs):
        start = time()
        result = func(*args, **kwargs)
        spend = time() - start
        print('%s() 运行时间: %d' % (func.__name__, spend))
        thread_num = ''
        if 'thread_num' in kwargs:
            thread_num = kwargs['thread_num']
        
        # 运行时间写入文件
        headers = ['函数', '运行时间', '线程数']
        if os.path.isfile('运行时间统计.csv'):
            with open('运行时间统计.csv', 'a', newline='') as f:
                writer = csv.DictWriter(f, headers)
                data = {'函数':func.__name__, '运行时间':spend, '线程数':thread_num}
                writer.writerow(data)
        else:
            with open('运行时间统计.csv', 'a', newline='') as f:
                writer = csv.DictWriter(f, headers)
                writer.writeheader()
                data = {'函数':func.__name__, '运行时间':spend, '线程数':thread_num}
                writer.writerow(data)
            
        return result
    return wrapper

# %%
class jobObject:
    'job描述对象'
    __slots__ = ('tag_href', 'job', 'company', 'address', 'salary', 'tag')

# %%
def ipToQueue():
    q = queue.Queue()
    url = 'https://free-proxy-list.net/'
    r = requests.get(url)
    html = r.text
    soup = BeautifulSoup(html, features='html5lib')
    div_tag = soup.find('div', 'table-responsive')
    tbody_list = div_tag.tbody.contents
    result = ''
    for tr in tbody_list:
        ip = tr.next_element.string
        port = tr.next_element.next_sibling.string
        result = ip + ':' + port
        q.put(result)

    return q

# %%
def getIPool(ip_queue):
    proxies = queue.Queue()

    flag = True
    while flag:
        ip = ip_queue.get()
        proxy = {'http': ip, 'https': ip}
        proxies.put(proxy)
        if ip_queue.qsize()==0:
            flag = False

    return proxies

# %%
def getCleanProxies(proxies, **thread_num):
    #     url = 'http://www.baidu.com'
    url = 'https://jobs.51job.com/'

    # 有效的ip队列
    ok_proxies = queue.Queue()

    def check_proxy(thread_proxies):

        thread_proxies_size = thread_proxies.qsize()

        for i in range(thread_proxies_size):
            thread_proxies_size = thread_proxies.qsize()
            print('%s : 当前剩余处理的ip: %d' % (threading.current_thread().name, thread_proxies_size))

            # 如果当前ip为0退出当前线程
            if (thread_proxies_size == 0):
                break

            proxy = thread_proxies.get()
            try:
                r = requests.get(url, proxies=proxy, timeout=5)
                print(threading.current_thread().name + ' is processing')
                print('r.status_code:', r.status_code)
                if (r.status_code != 200):
                    print('remove proxy:', proxy)
                else:
                    ok_proxies.put(proxy)

                print('-------------------------------------')

            except requests.Timeout as e:
                print(threading.current_thread().name + ' is processing')
                print(e)
                print('remove proxy:', proxy)
                print('-------------------------------------')
            except requests.ConnectionError as e:
                print(threading.current_thread().name + ' is processing')
                print(e)
                print('remove proxy:', proxy)
                print('-------------------------------------')
            except requests.InvalidHeader as e:
                print(threading.current_thread().name + ' is processing')
                print(e)
                print('remove proxy:', proxy)
                print('-------------------------------------')


    threads = []

    for i in range(thread_num.get('thread_num')):
        thread = threading.Thread(target=check_proxy, args=(proxies,))
        threads.append(thread)

    print('线程开始：')
    for thread in threads:
        print(thread.name + '开始运行')
        thread.start()

    # 每次在剩余处理ip为0之后，程序就会停住不动
    # 当当前线程检测到剩余ip为0后，调用join()方法
    print('线程开始停止运行：')
    for thread in threads:
        thread.join()
        print(thread.name + '已停止')

    return ok_proxies

# %%
@excute_time
def get_jobObjectList(url):
    global proxy
    
    flag = True
    
    # TODO 查看信息
    print('get_jobObjectList()当前处理链接:', url)
    while flag:
        try:
            r = requests.get(url, proxies=proxy, timeout=5)
            # 报了异常的话捕捉了之后
            # 获得新的proxy之后就直接开始下次循环
        except requests.exceptions.Timeout as e:
            print(e)
            proxy = getProxy()
            print('尝试新的proxy')
            #print('----------------------')
            continue
        except requests.exceptions.ProxyError as e:
            print(e)
            proxy = getProxy()
            print('尝试新的proxy')
            #print('----------------------')
            continue
        except requests.exceptions.ConnectionError as e:
            print(e)
            proxy = getProxy()
            print('尝试新的proxy')
            #print('----------------------')
            continue
        
        # 不报异常就取消循环
        flag = False

    
    
    r.encoding = 'gbk'
    html = r.text
    soup = BeautifulSoup(html, features='html5lib')
    # 找到了工作列表的开头
    title = soup.find('div', 'el title')
    # 找到每一个工作列，它们分别是一个div class='el'
    job_info_list = title.find_next_siblings('div', 'el')

    # 存放当前页jobObject对象到jobObjectList中
    jobObjectList = []
    for tag in job_info_list:
        object = jobObject()
        object.tag_href = tag.find('a').attrs['href']
        object.job = tag.find('a').attrs['title']

        infos = tag.find_all(class_=re.compile('t[2-4]'))
        object.company = infos[0].string
        object.address = infos[1].string
        object.salary = infos[2].string
        jobObjectList.append(object)
    
    print('get_jobObjectList处理完成!')

    return jobObjectList

# %%
def getTag(url):
    tag_url = url
    global proxy
    
    # 存储标签的List
    tag_list = []
    flag = True

    # TODO 查看信息
    print('getTag()当前处理链接:', tag_url)
    print('getTag()获得的ip:', proxy)
    while flag:
        #     headers = {'user-agent','Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/66.0.3359.181 Chrome/66.0.3359.181 Safari/537.36'}
        try:
            r_tag = requests.get(tag_url, timeout=5, proxies=proxy)

        # 报了异常的话捕捉了之后
        # 获得新的proxy之后就直接开始下次循环
        except requests.exceptions.Timeout as e:
            print(e)
            proxy = getProxy()
            print('尝试新的proxy')
            #print('----------------------')
            continue
        except requests.exceptions.ProxyError as e:
            print(e)
            proxy = getProxy()
            print('尝试新的proxy')
            #print('----------------------')
            continue
        except requests.exceptions.ConnectionError as e:
            print(e)
            proxy = getProxy()
            print('尝试新的proxy')
            #print('----------------------')
            continue
        # 不报异常就取消循环
        flag = False

    r_tag.encoding = 'gbk'
    tag_html = r_tag.text
    tag_soup = BeautifulSoup(tag_html, features='html5lib')

    # 找到详情页第一行标签
    tag_1 = tag_soup.find_all('span', 'sp4')
    for i in tag_1:
        tag_list.append(i.contents[1])

    # 找到详情页第二行标签
    tag_2 = tag_soup.find('p', 't2')

    # 有些详情页没有第二行标签
    if tag_2 is None:
        print('getTag()中tag_list:', tag_list)
        print('----------------------')
        return tag_list

    ll = []
    for i in tag_2.strings:
        ll.append(i)

    # 清除ll中的空值
    def not_empty(s):
        return s and s.strip()

    for i in filter(not_empty, ll):
        tag_list.append(i)

    print('getTag()中tag_list:', tag_list)
    print('----------------------')

    return tag_list

# %%
@excute_time
def pack_tag(jobObjectList, **thread_num):
    jobObject_queue = queue.Queue()
    
    for jobObject in jobObjectList:
        jobObject_queue.put(jobObject)
    
    def pack_object(jobObject_queue):
        flag = True
        while flag:
            jobObject = jobObject_queue.get()
            jobObject.tag = getTag(jobObject.tag_href)
            if jobObject_queue.qsize() == 0:
                flag = False
            
    
    threads = []
    
#     print('thread_num.get(\'thread_num\'): ', thread_num.get('thread_num'))
    
    for i in range(thread_num.get('thread_num')):
        thread = threading.Thread(target=pack_object, args=(jobObject_queue,))
        threads.append(thread)
    
    for thread in threads:
        thread.start()
                
    for thread in threads:
        thread.join()
        print('%s 已停止' % thread.name)
    

    print('tag组装完成!')

# %%
def save_to_csv(jobObjectList):
    headers = ['职位', '公司', '地址', '薪酬', '标签']
    datas = []

    for jobObject in jobObjectList:
        data = {headers[0]: jobObject.job,
                headers[1]: jobObject.company,
                headers[2]: jobObject.address,
                headers[3]: jobObject.salary,
                headers[4]: jobObject.tag}
        datas.append(data)
        
    if os.path.isfile('51job.csv'):
        with open('51job.csv', 'a', newline='') as f:
            writer = csv.DictWriter(f, headers)
            for row in datas:
                writer.writerow(row)
    else:
        with open('51job.csv', 'a', newline='') as f:
            writer = csv.DictWriter(f, headers)
            writer.writeheader()
            for row in datas:
                writer.writerow(row)

# %%
def handle_single(url, proxy):
    jobObjectList = get_jobObjectList(url)
    pack_tag(jobObjectList, thread_num=20)
    save_to_csv(jobObjectList)

# %%
# 获取proxy
# 当队列中的proxy用完了的时候在获取新的proxies
# 不是每次线程启动就获取新的proxies
# 当一个proxy不能用了才能获取新的proxy
def getProxy():
    global proxies
    
    lock.acquire()
    if proxies.qsize()==0:
        proxies = getProxies()
    lock.release()
        
    proxy = proxies.get()
    print('###当前proxies的ip数: ', proxies.qsize())
    return proxy
    

def getProxies():
    # 多线程的话，就不保存在本地文件
    # 应该保存在各自线程的queue里面s
    ip_start = time()
    ip_queue = ipToQueue()
    proxies = getIPool(ip_queue)
    proxies = getCleanProxies(proxies, thread_num=45)
    ip_result = time() - ip_start
    print('可用的ip: ', proxies.qsize())
    print('%s清洗ip的时间: %d' % (threading.current_thread().name, ip_result))
    return proxies

# %%
# 全局变量
proxies = getProxies()
proxy= getProxy()
# Out:
# 线程开始：
# Thread-4开始运行
# Thread-4 : 当前剩余处理的ip: 300Thread-5开始运行
#
# Thread-5 : 当前剩余处理的ip: 299Thread-6开始运行
#
# Thread-6 : 当前剩余处理的ip: 298Thread-7开始运行
#
# Thread-7 : 当前剩余处理的ip: 297Thread-8开始运行
#
# Thread-8 : 当前剩余处理的ip: 296Thread-9开始运行
#
# Thread-9 : 当前剩余处理的ip: 295
# Thread-10开始运行
# Thread-10 : 当前剩余处理的ip: 294Thread-11开始运行
#
# Thread-11 : 当前剩余处理的ip: 293Thread-12开始运行
#
# Thread-12 : 当前剩余处理的ip: 292Thread-13开始运行
#
# Thread-13 : 当前剩余处理的ip: 291Thread-14开始运行
#
# Thread-14 : 当前剩余处理的ip: 290Thread-15开始运行
#
# Thread-15 : 当前剩余处理的ip: 289Thread-16开始运行
#
# Thread-16 : 当前剩余处理的ip: 288Thread-17开始运行
#
# Thread-17 : 当前剩余处理的ip: 287
# Thread-18开始运行
# Thread-18 : 当前剩余处理的ip: 286Thread-19开始运行
#
# Thread-19 : 当前剩余处理的ip: 285
# Thread-20开始运行
# Thread-20 : 当前剩余处理的ip: 284Thread-21开始运行
#
# Thread-21 : 当前剩余处理的ip: 283Thread-22开始运行
#
# Thread-22 : 当前剩余处理的ip: 282Thread-23开始运行
#
# Thread-23 : 当前剩余处理的ip: 281Thread-24开始运行
#
# Thread-24 : 当前剩余处理的ip: 280Thread-25开始运行
#
# Thread-25 : 当前剩余处理的ip: 279Thread-26开始运行
#
# Thread-26 : 当前剩余处理的ip: 278Thread-27开始运行
#
# Thread-27 : 当前剩余处理的ip: 277Thread-28开始运行
#
# Thread-28 : 当前剩余处理的ip: 276Thread-29开始运行
#
# Thread-29 : 当前剩余处理的ip: 275Thread-30开始运行
#
# Thread-30 : 当前剩余处理的ip: 274Thread-31开始运行
#
# Thread-31 : 当前剩余处理的ip: 273Thread-32开始运行
#
# Thread-32 : 当前剩余处理的ip: 272Thread-33开始运行
#
# Thread-33 : 当前剩余处理的ip: 271Thread-34开始运行
#
# Thread-34 : 当前剩余处理的ip: 270Thread-35开始运行
#
# Thread-35 : 当前剩余处理的ip: 269Thread-36开始运行
#
# Thread-36 : 当前剩余处理的ip: 268Thread-37开始运行
#
# Thread-37 : 当前剩余处理的ip: 267Thread-38开始运行
#
# Thread-38 : 当前剩余处理的ip: 266Thread-39开始运行
#
# Thread-39 : 当前剩余处理的ip: 265
# Thread-40开始运行
# Thread-8 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f8da7eb8668>: Failed to establish a new connection: [Errno 111] Connection refused',)))
# remove proxy: {'http': '212.174.143.89:8080', 'https': '212.174.143.89:8080'}
# -------------------------------------
# Thread-8 : 当前剩余处理的ip: 264
# Thread-31 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f8da45c9550>: Failed to establish a new connection: [Errno 111] Connection refused',)))
# remove proxy: {'http': '35.184.109.90:3128', 'https': '35.184.109.90:3128'}
# -------------------------------------
# Thread-31 : 当前剩余处理的ip: 263
# Thread-40 : 当前剩余处理的ip: 262Thread-41开始运行
#
# Thread-24 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 400 Bad Request',)))
# remove proxy: {'http': '149.129.132.93:80', 'https': '149.129.132.93:80'}
# -------------------------------------
# Thread-24 : 当前剩余处理的ip: 261
# Thread-16 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f8da4659f60>: Failed to establish a new connection: [Errno 111] Connection refused',)))
# remove proxy: {'http': '212.174.143.91:3128', 'https': '212.174.143.91:3128'}
# -------------------------------------
# Thread-16 : 当前剩余处理的ip: 260
# Thread-18 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f8da4673908>: Failed to establish a new connection: [Errno 111] Connection refused',)))
# remove proxy: {'http': '212.174.143.8:8080', 'https': '212.174.143.8:8080'}
# -------------------------------------
# Thread-18 : 当前剩余处理的ip: 259
# Thread-41 : 当前剩余处理的ip: 258Thread-42开始运行
#
# Thread-42 : 当前剩余处理的ip: 257Thread-43开始运行
#
# Thread-43 : 当前剩余处理的ip: 256
# Thread-44开始运行
# Thread-44 : 当前剩余处理的ip: 255Thread-45开始运行
#
# Thread-45 : 当前剩余处理的ip: 254Thread-46开始运行
#
# Thread-46 : 当前剩余处理的ip: 253Thread-47开始运行
#
# Thread-25 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '178.128.189.253:3128', 'https': '178.128.189.253:3128'}
# -------------------------------------
# Thread-25 : 当前剩余处理的ip: 252
# Thread-47 : 当前剩余处理的ip: 251Thread-48开始运行
#
# Thread-48 : 当前剩余处理的ip: 250线程开始停止运行：
#
# Thread-13 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# remove proxy: {'http': '211.222.0.95:8080', 'https': '211.222.0.95:8080'}
# -------------------------------------
# Thread-13 : 当前剩余处理的ip: 249
# Thread-30 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '66.70.190.244:8080', 'https': '66.70.190.244:8080'}
# -------------------------------------
# Thread-30 : 当前剩余处理的ip: 248
# Thread-39 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f8da4584390>: Failed to establish a new connection: [Errno 111] Connection refused',)))
# remove proxy: {'http': '212.174.143.28:8080', 'https': '212.174.143.28:8080'}
# -------------------------------------
# Thread-39 : 当前剩余处理的ip: 247
# Thread-35 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '167.99.153.225:3128', 'https': '167.99.153.225:3128'}
# -------------------------------------
# Thread-35 : 当前剩余处理的ip: 246
# Thread-39 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f8da454f978>: Failed to establish a new connection: [Errno 111] Connection refused',)))
# remove proxy: {'http': '159.89.184.107:80', 'https': '159.89.184.107:80'}
# -------------------------------------
# Thread-39 : 当前剩余处理的ip: 245
# Thread-30 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 500 Internal Server Error',)))
# remove proxy: {'http': '202.162.68.78:80', 'https': '202.162.68.78:80'}
# -------------------------------------
# Thread-30 : 当前剩余处理的ip: 244
# Thread-37 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 ',)))
# remove proxy: {'http': '190.94.102.4:8081', 'https': '190.94.102.4:8081'}
# -------------------------------------
# Thread-37 : 当前剩余处理的ip: 243
# Thread-18 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '159.203.33.72:3128', 'https': '159.203.33.72:3128'}
# -------------------------------------
# Thread-18 : 当前剩余处理的ip: 242
# Thread-14 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', ConnectionResetError(104, 'Connection reset by peer')))
# remove proxy: {'http': '182.253.100.136:3129', 'https': '182.253.100.136:3129'}
# -------------------------------------
# Thread-14 : 当前剩余处理的ip: 241
# Thread-15 is processing
# r.status_code: 200
# -------------------------------------
# Thread-15 : 当前剩余处理的ip: 240
# Thread-30 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', ConnectionResetError(104, 'Connection reset by peer')))
# remove proxy: {'http': '80.48.119.28:8080', 'https': '80.48.119.28:8080'}
# -------------------------------------
# Thread-30 : 当前剩余处理的ip: 239
# Thread-13 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', ConnectionResetError(104, 'Connection reset by peer')))
# remove proxy: {'http': '109.194.17.181:8080', 'https': '109.194.17.181:8080'}
# -------------------------------------
# Thread-13 : 当前剩余处理的ip: 238
# Thread-24 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', ConnectionResetError(104, 'Connection reset by peer')))
# remove proxy: {'http': '217.174.187.74:41258', 'https': '217.174.187.74:41258'}
# -------------------------------------
# Thread-24 : 当前剩余处理的ip: 237
# Thread-46 is processing
# r.status_code: 200
# -------------------------------------
# Thread-46 : 当前剩余处理的ip: 236
# Thread-19 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response',)))
# remove proxy: {'http': '79.133.80.47:8080', 'https': '79.133.80.47:8080'}
# -------------------------------------
# Thread-19 : 当前剩余处理的ip: 235
# Thread-15 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '89.40.119.252:80', 'https': '89.40.119.252:80'}
# -------------------------------------
# Thread-15 : 当前剩余处理的ip: 234
# Thread-32 is processing
# r.status_code: 200
# -------------------------------------
# Thread-32 : 当前剩余处理的ip: 233
# Thread-24 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 500 Internal Server Error',)))
# remove proxy: {'http': '104.131.77.10:80', 'https': '104.131.77.10:80'}
# -------------------------------------
# Thread-24 : 当前剩余处理的ip: 232
# Thread-23 is processing
# r.status_code: 200
# -------------------------------------
# Thread-23 : 当前剩余处理的ip: 231
# Thread-45 is processing
# r.status_code: 200
# -------------------------------------
# Thread-45 : 当前剩余处理的ip: 230
# Thread-45 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 400 Bad Request',)))
# remove proxy: {'http': '13.115.179.194:80', 'https': '13.115.179.194:80'}
# -------------------------------------
# Thread-45 : 当前剩余处理的ip: 229
# Thread-12 is processing
# r.status_code: 200
# -------------------------------------
# Thread-12 : 当前剩余处理的ip: 228
# Thread-14 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '52.23.193.25:8080', 'https': '52.23.193.25:8080'}
# -------------------------------------
# Thread-14 : 当前剩余处理的ip: 227
# Thread-44 is processing
# r.status_code: 200
# -------------------------------------
# Thread-44 : 当前剩余处理的ip: 226
# Thread-33 is processing
# r.status_code: 200
# -------------------------------------
# Thread-33 : 当前剩余处理的ip: 225
# Thread-29 is processing
# r.status_code: 200
# -------------------------------------
# Thread-29 : 当前剩余处理的ip: 224
# Thread-25 is processing
# r.status_code: 200
# -------------------------------------
# Thread-25 : 当前剩余处理的ip: 223
# Thread-18 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 502 Bad Gateway',)))
# remove proxy: {'http': '78.25.98.114:8080', 'https': '78.25.98.114:8080'}
# -------------------------------------
# Thread-18 : 当前剩余处理的ip: 222
# Thread-39 is processing
# r.status_code: 200
# -------------------------------------
# Thread-39 : 当前剩余处理的ip: 221
# Thread-20 is processing
# r.status_code: 200
# -------------------------------------
# Thread-20 : 当前剩余处理的ip: 220
# Thread-29 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '159.65.45.64:8080', 'https': '159.65.45.64:8080'}
# -------------------------------------
# Thread-29 : 当前剩余处理的ip: 219
# Thread-26 is processing
# r.status_code: 200
# -------------------------------------
# Thread-26 : 当前剩余处理的ip: 218
# Thread-48 is processing
# r.status_code: 200
# -------------------------------------
# Thread-48 : 当前剩余处理的ip: 217
# Thread-12 is processing
# r.status_code: 200
# -------------------------------------
# Thread-12 : 当前剩余处理的ip: 216
# Thread-19 is processing
# r.status_code: 200
# -------------------------------------
# Thread-19 : 当前剩余处理的ip: 215
# Thread-43 is processing
# r.status_code: 200
# -------------------------------------
# Thread-43 : 当前剩余处理的ip: 214
# Thread-39 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '206.189.26.105:8080', 'https': '206.189.26.105:8080'}
# -------------------------------------
# Thread-39 : 当前剩余处理的ip: 213
# Thread-17 is processing
# r.status_code: 200
# -------------------------------------
# Thread-17 : 当前剩余处理的ip: 212
# Thread-19 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# remove proxy: {'http': '61.220.65.151:8080', 'https': '61.220.65.151:8080'}
# -------------------------------------
# Thread-19 : 当前剩余处理的ip: 211
# Thread-5 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '91.231.115.34:8080', 'https': '91.231.115.34:8080'}
# -------------------------------------
# Thread-5 : 当前剩余处理的ip: 210
# Thread-21 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '24.230.251.39:53281', 'https': '24.230.251.39:53281'}
# -------------------------------------
# Thread-21 : 当前剩余处理的ip: 209
# Thread-27 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '188.120.227.20:80', 'https': '188.120.227.20:80'}
# -------------------------------------
# Thread-27 : 当前剩余处理的ip: 208
# Thread-11 is processing
# r.status_code: 200
# -------------------------------------
# Thread-11 : 当前剩余处理的ip: 207
# Thread-47 is processing
# r.status_code: 200
# -------------------------------------
# Thread-47 : 当前剩余处理的ip: 206
# Thread-48 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '177.67.83.134:80', 'https': '177.67.83.134:80'}
# -------------------------------------
# Thread-48 : 当前剩余处理的ip: 205
# Thread-18 is processing
# r.status_code: 200
# -------------------------------------
# Thread-18 : 当前剩余处理的ip: 204
# Thread-27 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '159.89.145.94:8080', 'https': '159.89.145.94:8080'}
# -------------------------------------
# Thread-27 : 当前剩余处理的ip: 203
# Thread-39 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 502 Bad Gateway',)))
# remove proxy: {'http': '188.120.227.28:10004', 'https': '188.120.227.28:10004'}
# -------------------------------------
# Thread-39 : 当前剩余处理的ip: 202
# Thread-42 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '81.211.23.6:3128', 'https': '81.211.23.6:3128'}
# -------------------------------------
# Thread-42 : 当前剩余处理的ip: 201
# Thread-43 is processing
# r.status_code: 200
# -------------------------------------
# Thread-43 : 当前剩余处理的ip: 200
# Thread-39 is processing
# ('Connection aborted.', BadStatusLine('<html>\r\n',))
# remove proxy: {'http': '47.90.87.225:88', 'https': '47.90.87.225:88'}
# -------------------------------------
# Thread-39 : 当前剩余处理的ip: 199
# Thread-20 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '196.223.232.46:8085', 'https': '196.223.232.46:8085'}
# -------------------------------------
# Thread-20 : 当前剩余处理的ip: 198
# Thread-37 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f8da45ed7f0>, 'Connection to 62.69.253.227 timed out. (connect timeout=5)'))
# remove proxy: {'http': '62.69.253.227:8080', 'https': '62.69.253.227:8080'}
# -------------------------------------
# Thread-37 : 当前剩余处理的ip: 197
# Thread-48 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '142.44.246.242:80', 'https': '142.44.246.242:80'}
# -------------------------------------
# Thread-48 : 当前剩余处理的ip: 196
# Thread-40 is processing
# r.status_code: 200
# -------------------------------------
# Thread-40 : 当前剩余处理的ip: 195
# Thread-42 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '54.39.98.138:8080', 'https': '54.39.98.138:8080'}
# -------------------------------------
# Thread-42 : 当前剩余处理的ip: 194
# Thread-9 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '110.232.76.50:53281', 'https': '110.232.76.50:53281'}
# -------------------------------------
# Thread-9 : 当前剩余处理的ip: 193
# Thread-39 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '167.99.157.10:3128', 'https': '167.99.157.10:3128'}
# -------------------------------------
# Thread-39 : 当前剩余处理的ip: 192
# Thread-28 is processing
# r.status_code: 200
# -------------------------------------
# Thread-28 : 当前剩余处理的ip: 191
# Thread-36 is processing
# r.status_code: 200
# -------------------------------------
# Thread-36 : 当前剩余处理的ip: 190
# Thread-45 is processing
# r.status_code: 200
# -------------------------------------
# Thread-45 : 当前剩余处理的ip: 189
# Thread-16 is processing
# r.status_code: 200
# -------------------------------------
# Thread-16 : 当前剩余处理的ip: 188
# Thread-33 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 502 Bad Gateway',)))
# remove proxy: {'http': '83.169.244.38:8080', 'https': '83.169.244.38:8080'}
# -------------------------------------
# Thread-33 : 当前剩余处理的ip: 187
# Thread-10 is processing
# r.status_code: 200
# -------------------------------------
# Thread-10 : 当前剩余处理的ip: 186
# Thread-6 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '149.56.66.84:53281', 'https': '149.56.66.84:53281'}
# -------------------------------------
# Thread-45 is processing
# ('Connection aborted.', BadStatusLine('<html>\r\n',))
# remove proxy: {'http': '50.93.200.237:2018', 'https': '50.93.200.237:2018'}
# -------------------------------------
# Thread-45 : 当前剩余处理的ip: 185
# Thread-6 : 当前剩余处理的ip: 184
# Thread-4 is processing
# r.status_code: 200
# -------------------------------------
# Thread-4 : 当前剩余处理的ip: 183
# Thread-24 is processing
# r.status_code: 200
# -------------------------------------
# Thread-24 : 当前剩余处理的ip: 182
# Thread-18 is processing
# r.status_code: 200
# -------------------------------------
# Thread-18 : 当前剩余处理的ip: 181
# Thread-30 is processing
# r.status_code: 200
# -------------------------------------
# Thread-30 : 当前剩余处理的ip: 180
# Thread-8 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '167.114.56.171:80', 'https': '167.114.56.171:80'}
# -------------------------------------
# Thread-8 : 当前剩余处理的ip: 179
# Thread-16 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '80.211.181.37:3128', 'https': '80.211.181.37:3128'}
# -------------------------------------
# Thread-16 : 当前剩余处理的ip: 178
# Thread-30 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '159.203.77.130:8080', 'https': '159.203.77.130:8080'}
# -------------------------------------
# Thread-30 : 当前剩余处理的ip: 177
# Thread-13 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '110.232.86.52:53281', 'https': '110.232.86.52:53281'}
# -------------------------------------
# Thread-13 : 当前剩余处理的ip: 176
# Thread-34 is processing
# r.status_code: 200
# -------------------------------------
# Thread-34 : 当前剩余处理的ip: 175
# Thread-41 is processing
# r.status_code: 200
# -------------------------------------
# Thread-41 : 当前剩余处理的ip: 174
# Thread-43 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 502 Bad Gateway',)))
# remove proxy: {'http': '217.71.131.116:8080', 'https': '217.71.131.116:8080'}
# -------------------------------------
# Thread-43 : 当前剩余处理的ip: 173
# Thread-30 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '159.89.229.66:8080', 'https': '159.89.229.66:8080'}
# -------------------------------------
# Thread-30 : 当前剩余处理的ip: 172
# Thread-13 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 503 Service Temporarily Unavailable',)))
# remove proxy: {'http': '213.136.77.246:80', 'https': '213.136.77.246:80'}
# -------------------------------------
# Thread-13 : 当前剩余处理的ip: 171
# Thread-7 is processing
# r.status_code: 200
# -------------------------------------
# Thread-7 : 当前剩余处理的ip: 170
# Thread-15 is processing
# r.status_code: 200
# -------------------------------------
# Thread-15 : 当前剩余处理的ip: 169
# Thread-36 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 502 Bad Gateway',)))
# remove proxy: {'http': '217.119.82.14:8080', 'https': '217.119.82.14:8080'}
# -------------------------------------
# Thread-36 : 当前剩余处理的ip: 168
# Thread-18 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# remove proxy: {'http': '49.212.129.44:3128', 'https': '49.212.129.44:3128'}
# -------------------------------------
# Thread-18 : 当前剩余处理的ip: 167
# Thread-22 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '36.66.169.18:8080', 'https': '36.66.169.18:8080'}
# -------------------------------------
# Thread-22 : 当前剩余处理的ip: 166
# Thread-35 is processing
# r.status_code: 200
# -------------------------------------
# Thread-35 : 当前剩余处理的ip: 165
# Thread-25 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '74.209.243.116:3128', 'https': '74.209.243.116:3128'}
# -------------------------------------
# Thread-25 : 当前剩余处理的ip: 164
# Thread-43 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 502 Bad Gateway',)))
# remove proxy: {'http': '176.62.77.212:8080', 'https': '176.62.77.212:8080'}
# -------------------------------------
# Thread-43 : 当前剩余处理的ip: 163
# Thread-46 is processing
# r.status_code: 200
# -------------------------------------
# Thread-46 : 当前剩余处理的ip: 162
# Thread-23 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '81.162.238.73:53281', 'https': '81.162.238.73:53281'}
# -------------------------------------
# Thread-23 : 当前剩余处理的ip: 161
# Thread-12 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f8da463fe48>, 'Connection to 173.212.202.65 timed out. (connect timeout=5)'))
# remove proxy: {'http': '173.212.202.65:443', 'https': '173.212.202.65:443'}
# -------------------------------------
# Thread-12 : 当前剩余处理的ip: 160
# Thread-24 is processing
# r.status_code: 200
# -------------------------------------
# Thread-24 : 当前剩余处理的ip: 159
# Thread-43 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# remove proxy: {'http': '182.72.74.51:3128', 'https': '182.72.74.51:3128'}
# -------------------------------------
# Thread-43 : 当前剩余处理的ip: 158
# Thread-14 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '81.214.120.116:8080', 'https': '81.214.120.116:8080'}
# -------------------------------------
# Thread-14 : 当前剩余处理的ip: 157
# Thread-35 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 ',)))
# remove proxy: {'http': '181.49.24.126:8081', 'https': '181.49.24.126:8081'}
# -------------------------------------
# Thread-35 : 当前剩余处理的ip: 156
# Thread-12 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '159.203.172.125:8080', 'https': '159.203.172.125:8080'}
# -------------------------------------
# Thread-12 : 当前剩余处理的ip: 155
# Thread-17 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '138.68.95.116:3128', 'https': '138.68.95.116:3128'}
# -------------------------------------
# Thread-17 : 当前剩余处理的ip: 154
# Thread-32 is processing
# r.status_code: 200
# -------------------------------------
# Thread-32 : 当前剩余处理的ip: 153
# Thread-4 is processing
# r.status_code: 200
# -------------------------------------
# Thread-4 : 当前剩余处理的ip: 152
# Thread-14 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '201.16.148.145:80', 'https': '201.16.148.145:80'}
# -------------------------------------
# Thread-14 : 当前剩余处理的ip: 151
# Thread-4 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response',)))
# remove proxy: {'http': '113.53.151.228:8080', 'https': '113.53.151.228:8080'}
# -------------------------------------
# Thread-4 : 当前剩余处理的ip: 150
# Thread-12 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '174.138.5.199:8080', 'https': '174.138.5.199:8080'}
# -------------------------------------
# Thread-12 : 当前剩余处理的ip: 149
# Thread-8 is processing
# r.status_code: 200
# -------------------------------------
# Thread-8 : 当前剩余处理的ip: 148
# Thread-42 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f8da45a6080>, 'Connection to 78.189.25.202 timed out. (connect timeout=5)'))
# remove proxy: {'http': '78.189.25.202:8080', 'https': '78.189.25.202:8080'}
# -------------------------------------
# Thread-42 : 当前剩余处理的ip: 147
# Thread-9 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f8da7eb8550>, 'Connection to 188.95.30.118 timed out. (connect timeout=5)'))
# remove proxy: {'http': '188.95.30.118:41258', 'https': '188.95.30.118:41258'}
# -------------------------------------
# Thread-9 : 当前剩余处理的ip: 146
# Thread-10 is processing
# r.status_code: 200
# -------------------------------------
# Thread-10 : 当前剩余处理的ip: 145
# Thread-28 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f8da45e3518>, 'Connection to 95.140.195.154 timed out. (connect timeout=5)'))
# remove proxy: {'http': '95.140.195.154:8080', 'https': '95.140.195.154:8080'}
# -------------------------------------
# Thread-28 : 当前剩余处理的ip: 144
# Thread-21 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '95.221.141.192:44331', 'https': '95.221.141.192:44331'}
# -------------------------------------
# Thread-21 : 当前剩余处理的ip: 143
# Thread-39 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '5.196.205.139:3128', 'https': '5.196.205.139:3128'}
# -------------------------------------
# Thread-39 : 当前剩余处理的ip: 142
# Thread-6 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f8da4535dd8>, 'Connection to 177.47.236.61 timed out. (connect timeout=5)'))
# remove proxy: {'http': '177.47.236.61:53281', 'https': '177.47.236.61:53281'}
# -------------------------------------
# Thread-6 : 当前剩余处理的ip: 141
# Thread-29 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '41.169.142.178:8080', 'https': '41.169.142.178:8080'}
# -------------------------------------
# Thread-29 : 当前剩余处理的ip: 140
# Thread-33 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '185.93.3.123:8080', 'https': '185.93.3.123:8080'}
# -------------------------------------
# Thread-33 : 当前剩余处理的ip: 139
# Thread-41 is processing
# r.status_code: 200
# -------------------------------------
# Thread-41 : 当前剩余处理的ip: 138
# Thread-5 is processing
# r.status_code: 200
# -------------------------------------
# Thread-5 : 当前剩余处理的ip: 137
# Thread-20 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '62.210.151.46:8080', 'https': '62.210.151.46:8080'}
# -------------------------------------
# Thread-20 : 当前剩余处理的ip: 136
# Thread-45 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '36.66.255.114:8080', 'https': '36.66.255.114:8080'}
# -------------------------------------
# Thread-45 : 当前剩余处理的ip: 135
# Thread-19 is processing
# r.status_code: 200
# -------------------------------------
# Thread-19 : 当前剩余处理的ip: 134
# Thread-18 is processing
# r.status_code: 200
# -------------------------------------
# Thread-18 : 当前剩余处理的ip: 133
# Thread-11 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '5.189.162.175:3128', 'https': '5.189.162.175:3128'}
# -------------------------------------
# Thread-11 : 当前剩余处理的ip: 132
# Thread-40 is processing
# r.status_code: 200
# -------------------------------------
# Thread-40 : 当前剩余处理的ip: 131
# Thread-13 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '113.161.90.156:3128', 'https': '113.161.90.156:3128'}
# -------------------------------------
# Thread-13 : 当前剩余处理的ip: 130
# Thread-47 is processing
# r.status_code: 200
# -------------------------------------
# Thread-47 : 当前剩余处理的ip: 129
# Thread-22 is processing
# r.status_code: 200
# -------------------------------------
# Thread-22 : 当前剩余处理的ip: 128
# Thread-34 is processing
# r.status_code: 200
# -------------------------------------
# Thread-34 : 当前剩余处理的ip: 127
# Thread-27 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '62.176.114.233:8080', 'https': '62.176.114.233:8080'}
# -------------------------------------
# Thread-27 : 当前剩余处理的ip: 126
# Thread-17 is processing
# r.status_code: 200
# -------------------------------------
# Thread-17 : 当前剩余处理的ip: 125
# Thread-43 is processing
# r.status_code: 200
# -------------------------------------
# Thread-43 : 当前剩余处理的ip: 124
# Thread-30 is processing
# r.status_code: 200
# -------------------------------------
# Thread-30 : 当前剩余处理的ip: 123
# Thread-7 is processing
# r.status_code: 200
# -------------------------------------
# Thread-7 : 当前剩余处理的ip: 122
# Thread-33 is processing
# r.status_code: 200
# -------------------------------------
# Thread-33 : 当前剩余处理的ip: 121
# Thread-10 is processing
# r.status_code: 200
# -------------------------------------
# Thread-10 : 当前剩余处理的ip: 120
# Thread-23 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '185.93.3.70:8080', 'https': '185.93.3.70:8080'}
# -------------------------------------
# Thread-23 : 当前剩余处理的ip: 119
# Thread-24 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '80.211.189.165:3128', 'https': '80.211.189.165:3128'}
# -------------------------------------
# Thread-24 : 当前剩余处理的ip: 118
# Thread-48 is processing
# r.status_code: 200
# -------------------------------------
# Thread-48 : 当前剩余处理的ip: 117
# Thread-36 is processing
# r.status_code: 200
# -------------------------------------
# Thread-36 : 当前剩余处理的ip: 116
# Thread-46 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '91.109.38.219:8080', 'https': '91.109.38.219:8080'}
# -------------------------------------
# Thread-46 : 当前剩余处理的ip: 115
# Thread-32 is processing
# r.status_code: 200
# -------------------------------------
# Thread-32 : 当前剩余处理的ip: 114
# Thread-37 is processing
# r.status_code: 200
# -------------------------------------
# Thread-37 : 当前剩余处理的ip: 113
# Thread-14 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f8da44f1f28>, 'Connection to 92.241.86.146 timed out. (connect timeout=5)'))
# remove proxy: {'http': '92.241.86.146:8080', 'https': '92.241.86.146:8080'}
# -------------------------------------
# Thread-14 : 当前剩余处理的ip: 112
# Thread-5 is processing
# r.status_code: 200
# -------------------------------------
# Thread-5 : 当前剩余处理的ip: 111
# Thread-41 is processing
# r.status_code: 200
# -------------------------------------
# Thread-41 : 当前剩余处理的ip: 110
# Thread-9 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f8da4479e48>, 'Connection to 37.144.154.98 timed out. (connect timeout=5)'))
# remove proxy: {'http': '37.144.154.98:8080', 'https': '37.144.154.98:8080'}
# -------------------------------------
# Thread-9 : 当前剩余处理的ip: 109
# Thread-11 is processing
# r.status_code: 200
# -------------------------------------
# Thread-11 : 当前剩余处理的ip: 108
# Thread-12 is processing
# r.status_code: 200
# -------------------------------------
# Thread-12 : 当前剩余处理的ip: 107
# Thread-21 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f8da45fd470>, 'Connection to 177.47.238.113 timed out. (connect timeout=5)'))
# remove proxy: {'http': '177.47.238.113:53281', 'https': '177.47.238.113:53281'}
# -------------------------------------
# Thread-21 : 当前剩余处理的ip: 106
# Thread-39 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f8da4507940>, 'Connection to 81.30.216.147 timed out. (connect timeout=5)'))
# remove proxy: {'http': '81.30.216.147:41258', 'https': '81.30.216.147:41258'}
# -------------------------------------
# Thread-39 : 当前剩余处理的ip: 105
# Thread-31 is processing
# r.status_code: 200
# -------------------------------------
# Thread-31 : 当前剩余处理的ip: 104
# Thread-42 is processing
# r.status_code: 200
# -------------------------------------
# Thread-42 : 当前剩余处理的ip: 103
# Thread-28 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '41.193.222.58:3128', 'https': '41.193.222.58:3128'}
# -------------------------------------
# Thread-28 : 当前剩余处理的ip: 102
# Thread-5 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden',)))
# remove proxy: {'http': '191.252.100.125:80', 'https': '191.252.100.125:80'}
# -------------------------------------
# Thread-5 : 当前剩余处理的ip: 101
# Thread-20 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f8da4511ac8>, 'Connection to 43.227.135.204 timed out. (connect timeout=5)'))
# remove proxy: {'http': '43.227.135.204:8080', 'https': '43.227.135.204:8080'}
# -------------------------------------
# Thread-20 : 当前剩余处理的ip: 100
# Thread-45 is processing
# r.status_code: 200
# -------------------------------------
# Thread-45 : 当前剩余处理的ip: 99
# Thread-26 is processing
# r.status_code: 200
# -------------------------------------
# Thread-26 : 当前剩余处理的ip: 98
# Thread-43 is processing
# r.status_code: 200
# -------------------------------------
# Thread-43 : 当前剩余处理的ip: 97
# Thread-4 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '194.0.91.146:8080', 'https': '194.0.91.146:8080'}
# -------------------------------------
# Thread-4 : 当前剩余处理的ip: 96
# Thread-34 is processing
# r.status_code: 200
# -------------------------------------
# Thread-34 : 当前剩余处理的ip: 95
# Thread-47 is processing
# r.status_code: 200
# -------------------------------------
# Thread-47 : 当前剩余处理的ip: 94
# Thread-38 is processing
# r.status_code: 200
# -------------------------------------
# Thread-38 : 当前剩余处理的ip: 93
# Thread-6 is processing
# r.status_code: 200
# -------------------------------------
# Thread-6 : 当前剩余处理的ip: 92
# Thread-48 is processing
# r.status_code: 200
# -------------------------------------
# Thread-48 : 当前剩余处理的ip: 91
# Thread-21 is processing
# r.status_code: 200
# -------------------------------------
# Thread-21 : 当前剩余处理的ip: 90
# Thread-27 is processing
# r.status_code: 200
# -------------------------------------
# Thread-27 : 当前剩余处理的ip: 89
# Thread-23 is processing
# r.status_code: 200
# -------------------------------------
# Thread-23 : 当前剩余处理的ip: 88
# Thread-40 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '95.221.171.153:44331', 'https': '95.221.171.153:44331'}
# -------------------------------------
# Thread-40 : 当前剩余处理的ip: 87
# Thread-10 is processing
# r.status_code: 200
# -------------------------------------
# Thread-10 : 当前剩余处理的ip: 86
# Thread-36 is processing
# r.status_code: 200
# -------------------------------------
# Thread-36 : 当前剩余处理的ip: 85
# Thread-12 is processing
# r.status_code: 200
# -------------------------------------
# Thread-12 : 当前剩余处理的ip: 84
# Thread-33 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f8da4507c18>, 'Connection to 31.173.185.118 timed out. (connect timeout=5)'))
# remove proxy: {'http': '31.173.185.118:8080', 'https': '31.173.185.118:8080'}
# -------------------------------------
# Thread-33 : 当前剩余处理的ip: 83
# Thread-30 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '85.113.38.169:8080', 'https': '85.113.38.169:8080'}
# -------------------------------------
# Thread-30 : 当前剩余处理的ip: 82
# Thread-7 is processing
# r.status_code: 200
# -------------------------------------
# Thread-7 : 当前剩余处理的ip: 81
# Thread-19 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '89.23.19.143:8080', 'https': '89.23.19.143:8080'}
# -------------------------------------
# Thread-19 : 当前剩余处理的ip: 80
# Thread-8 is processing
# r.status_code: 200
# -------------------------------------
# Thread-8 : 当前剩余处理的ip: 79
# Thread-29 is processing
# r.status_code: 200
# -------------------------------------
# Thread-29 : 当前剩余处理的ip: 78
# Thread-15 is processing
# r.status_code: 200
# -------------------------------------
# Thread-15 : 当前剩余处理的ip: 77
# Thread-8 is processing
# r.status_code: 200
# -------------------------------------
# Thread-8 : 当前剩余处理的ip: 76
# Thread-16 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Read timed out. (read timeout=5)
# remove proxy: {'http': '208.126.235.26:55444', 'https': '208.126.235.26:55444'}
# -------------------------------------
# Thread-16 : 当前剩余处理的ip: 75
# Thread-41 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f8da459b7f0>, 'Connection to 103.217.237.170 timed out. (connect timeout=5)'))
# remove proxy: {'http': '103.217.237.170:53281', 'https': '103.217.237.170:53281'}
# -------------------------------------
# Thread-41 : 当前剩余处理的ip: 74
# Thread-14 is processing
# r.status_code: 200
# -------------------------------------
# Thread-14 : 当前剩余处理的ip: 73
# Thread-31 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f8da4440828>, 'Connection to 217.171.86.51 timed out. (connect timeout=5)'))
# remove proxy: {'http': '217.171.86.51:53281', 'https': '217.171.86.51:53281'}
# -------------------------------------
# Thread-31 : 当前剩余处理的ip: 72
# Thread-13 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '190.186.58.207:53281', 'https': '190.186.58.207:53281'}
# -------------------------------------
# Thread-13 : 当前剩余处理的ip: 71
# Thread-25 is processing
# r.status_code: 200
# -------------------------------------
# Thread-25 : 当前剩余处理的ip: 70
# Thread-42 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f8da44797b8>, 'Connection to 95.53.254.198 timed out. (connect timeout=5)'))
# remove proxy: {'http': '95.53.254.198:53281', 'https': '95.53.254.198:53281'}
# -------------------------------------
# Thread-42 : 当前剩余处理的ip: 69
# Thread-28 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f8da4486978>, 'Connection to 103.211.152.65 timed out. (connect timeout=5)'))
# remove proxy: {'http': '103.211.152.65:53281', 'https': '103.211.152.65:53281'}
# -------------------------------------
# Thread-28 : 当前剩余处理的ip: 68
# Thread-45 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '103.16.165.226:53281', 'https': '103.16.165.226:53281'}
# -------------------------------------
# Thread-45 : 当前剩余处理的ip: 67
# Thread-17 is processing
# ...
# Thread-33 : 当前剩余处理的ip: 17
# Thread-32 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f8da4535668>: Failed to establish a new connection: [Errno 113] No route to host',)))
# remove proxy: {'http': '103.36.9.102:53281', 'https': '103.36.9.102:53281'}
# -------------------------------------
# Thread-32 : 当前剩余处理的ip: 16
# Thread-10 is processing
# r.status_code: 200
# -------------------------------------
# Thread-10 : 当前剩余处理的ip: 15
# Thread-13 is processing
# r.status_code: 200
# -------------------------------------
# Thread-13 : 当前剩余处理的ip: 14
# Thread-39 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Read timed out. (read timeout=5)
# remove proxy: {'http': '95.67.220.209:44331', 'https': '95.67.220.209:44331'}
# -------------------------------------
# Thread-39 : 当前剩余处理的ip: 13
# Thread-24 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '86.127.69.58:53281', 'https': '86.127.69.58:53281'}
# -------------------------------------
# Thread-24 : 当前剩余处理的ip: 12
# Thread-48 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', ConnectionResetError(104, 'Connection reset by peer')))
# remove proxy: {'http': '212.174.143.35:8080', 'https': '212.174.143.35:8080'}
# -------------------------------------
# Thread-48 : 当前剩余处理的ip: 11
# Thread-45 is processing
# r.status_code: 200
# -------------------------------------
# Thread-45 : 当前剩余处理的ip: 10
# Thread-11 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f8da4530dd8>, 'Connection to 187.243.251.30 timed out. (connect timeout=5)'))
# remove proxy: {'http': '187.243.251.30:65103', 'https': '187.243.251.30:65103'}
# -------------------------------------
# Thread-11 : 当前剩余处理的ip: 9
# Thread-26 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Read timed out.
# remove proxy: {'http': '36.89.192.91:8080', 'https': '36.89.192.91:8080'}
# -------------------------------------
# Thread-26 : 当前剩余处理的ip: 8
# Thread-34 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '212.19.22.193:8080', 'https': '212.19.22.193:8080'}
# -------------------------------------
# Thread-34 : 当前剩余处理的ip: 7
# Thread-12 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '78.156.40.38:41258', 'https': '78.156.40.38:41258'}
# -------------------------------------
# Thread-12 : 当前剩余处理的ip: 6
# Thread-38 is processing
# r.status_code: 200
# -------------------------------------
# Thread-38 : 当前剩余处理的ip: 5
# Thread-46 is processing
# r.status_code: 200
# -------------------------------------
# Thread-46 : 当前剩余处理的ip: 4
# Thread-15 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '91.240.97.69:8080', 'https': '91.240.97.69:8080'}
# -------------------------------------
# Thread-15 : 当前剩余处理的ip: 3
# Thread-14 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f8da44cd5f8>, 'Connection to 185.231.15.4 timed out. (connect timeout=5)'))
# remove proxy: {'http': '185.231.15.4:53281', 'https': '185.231.15.4:53281'}
# -------------------------------------
# Thread-14 : 当前剩余处理的ip: 2
# Thread-36 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f8da454f400>, 'Connection to 150.129.114.194 timed out. (connect timeout=5)'))
# remove proxy: {'http': '150.129.114.194:6666', 'https': '150.129.114.194:6666'}
# -------------------------------------
# Thread-36 : 当前剩余处理的ip: 1
# Thread-9 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '89.251.32.44:8080', 'https': '89.251.32.44:8080'}
# -------------------------------------
# Thread-9 : 当前剩余处理的ip: 0
# Thread-5 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f8da45bd128>, 'Connection to 220.247.168.163 timed out. (connect timeout=5)'))
# remove proxy: {'http': '220.247.168.163:53281', 'https': '220.247.168.163:53281'}
# -------------------------------------
# Thread-5 : 当前剩余处理的ip: 0
# Thread-30 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f8da4547eb8>, 'Connection to 157.119.207.134 timed out. (connect timeout=5)'))
# remove proxy: {'http': '157.119.207.134:6666', 'https': '157.119.207.134:6666'}
# -------------------------------------
# Thread-30 : 当前剩余处理的ip: 0
# Thread-41 is processing
# r.status_code: 200
# -------------------------------------
# Thread-41 : 当前剩余处理的ip: 0
# Thread-37 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f8da4479978>, 'Connection to 41.180.1.155 timed out. (connect timeout=5)'))
# remove proxy: {'http': '41.180.1.155:53281', 'https': '41.180.1.155:53281'}
# -------------------------------------
# Thread-37 : 当前剩余处理的ip: 0
# Thread-7 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response',)))
# remove proxy: {'http': '182.93.89.133:80', 'https': '182.93.89.133:80'}
# -------------------------------------
# Thread-7 : 当前剩余处理的ip: 0
# Thread-27 is processing
# r.status_code: 200
# -------------------------------------
# Thread-27 : 当前剩余处理的ip: 0
# Thread-21 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Read timed out. (read timeout=5)
# remove proxy: {'http': '84.40.127.18:8080', 'https': '84.40.127.18:8080'}
# -------------------------------------
# Thread-21 : 当前剩余处理的ip: 0
# Thread-22 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '35.230.34.45:80', 'https': '35.230.34.45:80'}
# -------------------------------------
# Thread-22 : 当前剩余处理的ip: 0
# Thread-17 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f8da46665c0>, 'Connection to 83.18.150.55 timed out. (connect timeout=5)'))
# remove proxy: {'http': '83.18.150.55:3128', 'https': '83.18.150.55:3128'}
# -------------------------------------
# Thread-17 : 当前剩余处理的ip: 0
# Thread-19 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '37.17.170.150:8080', 'https': '37.17.170.150:8080'}
# -------------------------------------
# Thread-19 : 当前剩余处理的ip: 0
# Thread-20 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '36.89.193.133:53281', 'https': '36.89.193.133:53281'}
# -------------------------------------
# Thread-20 : 当前剩余处理的ip: 0
# Thread-35 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Read timed out.
# remove proxy: {'http': '103.86.155.230:53281', 'https': '103.86.155.230:53281'}
# -------------------------------------
# Thread-35 : 当前剩余处理的ip: 0
# Thread-10 is processing
# r.status_code: 200
# -------------------------------------
# Thread-10 : 当前剩余处理的ip: 0
# Thread-23 is processing
# r.status_code: 200
# -------------------------------------
# Thread-23 : 当前剩余处理的ip: 0
# Thread-43 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f8da4440e48>, 'Connection to 110.44.122.198 timed out. (connect timeout=5)'))
# remove proxy: {'http': '110.44.122.198:53281', 'https': '110.44.122.198:53281'}
# -------------------------------------
# Thread-43 : 当前剩余处理的ip: 0
# Thread-25 is processing
# r.status_code: 200
# -------------------------------------
# Thread-25 : 当前剩余处理的ip: 0
# Thread-29 is processing
# r.status_code: 200
# -------------------------------------
# Thread-29 : 当前剩余处理的ip: 0
# Thread-18 is processing
# r.status_code: 200
# -------------------------------------
# Thread-18 : 当前剩余处理的ip: 0
# Thread-31 is processing
# r.status_code: 200
# -------------------------------------
# Thread-31 : 当前剩余处理的ip: 0
# Thread-32 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '94.240.59.59:53281', 'https': '94.240.59.59:53281'}
# -------------------------------------
# Thread-32 : 当前剩余处理的ip: 0
# Thread-33 is processing
# r.status_code: 200
# -------------------------------------
# Thread-33 : 当前剩余处理的ip: 0
# Thread-24 is processing
# r.status_code: 200
# -------------------------------------
# Thread-24 : 当前剩余处理的ip: 0
# Thread-48 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '51.15.132.75:8118', 'https': '51.15.132.75:8118'}
# -------------------------------------
# Thread-48 : 当前剩余处理的ip: 0
# Thread-8 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Read timed out. (read timeout=5)
# remove proxy: {'http': '138.118.85.155:53281', 'https': '138.118.85.155:53281'}
# -------------------------------------
# Thread-8 : 当前剩余处理的ip: 0
# Thread-16 is processing
# r.status_code: 200
# -------------------------------------
# Thread-16 : 当前剩余处理的ip: 0
# Thread-11 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f8da7e909e8>, 'Connection to 190.12.54.34 timed out. (connect timeout=5)'))
# remove proxy: {'http': '190.12.54.34:6666', 'https': '190.12.54.34:6666'}
# -------------------------------------
# Thread-11 : 当前剩余处理的ip: 0
# Thread-45 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out',)))
# remove proxy: {'http': '41.190.139.134:8080', 'https': '41.190.139.134:8080'}
# -------------------------------------
# Thread-45 : 当前剩余处理的ip: 0
# Thread-28 is processing
# r.status_code: 200
# -------------------------------------
# Thread-28 : 当前剩余处理的ip: 0
# Thread-12 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f8da449dc88>, 'Connection to 24.252.160.238 timed out. (connect timeout=5)'))
# remove proxy: {'http': '24.252.160.238:53281', 'https': '24.252.160.238:53281'}
# -------------------------------------
# Thread-12 : 当前剩余处理的ip: 0
# Thread-38 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f8da7ec9eb8>, 'Connection to 52.33.44.103 timed out. (connect timeout=5)'))
# remove proxy: {'http': '52.33.44.103:80', 'https': '52.33.44.103:80'}
# -------------------------------------
# Thread-38 : 当前剩余处理的ip: 0
# Thread-14 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f8da44cdac8>, 'Connection to 109.72.236.16 timed out. (connect timeout=5)'))
# remove proxy: {'http': '109.72.236.16:53281', 'https': '109.72.236.16:53281'}
# -------------------------------------
# Thread-14 : 当前剩余处理的ip: 0
# Thread-4 is processing
# r.status_code: 200
# -------------------------------------
# Thread-4 : 当前剩余处理的ip: 0
# Thread-4已停止
# Thread-5已停止
# Thread-42 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '92.50.251.14:8080', 'https': '92.50.251.14:8080'}
# -------------------------------------
# Thread-42 : 当前剩余处理的ip: 0
# Thread-46 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '185.20.64.201:41258', 'https': '185.20.64.201:41258'}
# -------------------------------------
# Thread-46 : 当前剩余处理的ip: 0
# Thread-44 is processing
# r.status_code: 200
# -------------------------------------
# Thread-44 : 当前剩余处理的ip: 0
# Thread-6 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Read timed out. (read timeout=5)
# remove proxy: {'http': '103.70.144.121:8080', 'https': '103.70.144.121:8080'}
# -------------------------------------
# Thread-6 : 当前剩余处理的ip: 0
# Thread-6已停止
# Thread-7已停止
# Thread-8已停止
# Thread-9已停止
# Thread-10已停止
# Thread-11已停止
# Thread-12已停止
# Thread-13 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '77.85.169.74:8080', 'https': '77.85.169.74:8080'}
# -------------------------------------
# Thread-13 : 当前剩余处理的ip: 0
# Thread-13已停止
# Thread-14已停止
# Thread-34 is processing
# r.status_code: 200
# -------------------------------------
# Thread-34 : 当前剩余处理的ip: 0
# Thread-26 is processing
# r.status_code: 200
# -------------------------------------
# Thread-26 : 当前剩余处理的ip: 0
# Thread-40 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Read timed out.
# remove proxy: {'http': '175.184.248.231:53281', 'https': '175.184.248.231:53281'}
# -------------------------------------
# Thread-40 : 当前剩余处理的ip: 0
# Thread-47 is processing
# r.status_code: 200
# -------------------------------------
# Thread-47 : 当前剩余处理的ip: 0
# Thread-15 is processing
# HTTPSConnectionPool(host='jobs.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', timeout('select timed out',)))
# remove proxy: {'http': '185.231.208.226:8080', 'https': '185.231.208.226:8080'}
# -------------------------------------
# Thread-15 : 当前剩余处理的ip: 0
# Thread-15已停止
# Thread-16已停止
# Thread-17已停止
# Thread-18已停止
# Thread-19已停止
# Thread-20已停止
# Thread-21已停止
# Thread-22已停止
# Thread-23已停止
# Thread-24已停止
# Thread-25已停止
# Thread-26已停止
# Thread-27已停止
# Thread-28已停止
# Thread-29已停止
# Thread-30已停止
# Thread-31已停止
# Thread-32已停止
# Thread-33已停止
# Thread-34已停止
# Thread-35已停止
# Thread-36 is processing
# r.status_code: 200
# -------------------------------------
# Thread-36 : 当前剩余处理的ip: 0
# Thread-36已停止
# Thread-37已停止
# Thread-38已停止
# Thread-39 is processing
# r.status_code: 200
# -------------------------------------
# Thread-39 : 当前剩余处理的ip: 0
# Thread-39已停止
# Thread-40已停止
# Thread-41已停止
# Thread-42已停止
# Thread-43已停止
# Thread-44已停止
# Thread-45已停止
# Thread-46已停止
# Thread-47已停止
# Thread-48已停止
# 可用的ip:  132
# MainThread清洗ip的时间: 48
# ###当前proxies的ip数:  131

# %%
def main():
    url_queue = queue.Queue()
    pages = 10
    thread_nums = 5
    
    for i in range(pages):
        url = 'https://search.51job.com/list/000000,000000,0000,00,9,99,Java,2,{}.html?lang=c&stype=&postchannel=0000&workyear=99&cotype=99&degreefrom=99&jobterm=99&companysize=99&providesalary=99&lonlat=0%2C0&radius=-1&ord_field=0&confirmdate=9&fromType=&dibiaoid=0&address=&line=&specialarea=00&from=&welfare='\
        .format(i+1)
        url_queue.put(url)
    
#     flag = True
#     while flag:
 
    def go(url_queue, proxy):
        flag = True
        while flag:   
            url = url_queue.get()
            start = time()
            handle_single(url, proxy)
            result = time() - start
            print('%s完成单页的时间: %d' % (threading.current_thread().name, result))
            
            if url_queue.qsize()==0:
                flag = False
            
    
    threads = []
    
    for i in range(thread_nums):
        thread = threading.Thread(target=go, args=(url_queue,proxy))
        threads.append(thread)
    try:
        start = time()
        for thread in threads:
            thread.start()
            print('主线程%s开始' % thread.name)

        for thread in threads:
            thread.join()
            print('主线程%s停止' % thread.name)
    except RuntimeError as e:
        print(e)
        print('当前线程数:', threading.active_count())
    
    result = time()-start
    print('爬取时间:',result)
    
    # todo 分割运行时间统计
    with open('运行时间统计.csv', 'a', newline='') as f:
        headers = ['函数', '运行时间', '线程数']
        writer = csv.DictWriter(f, headers)
        data = {'函数':'', '运行时间':'', '线程数':''}
        writer.writerow(data)

# %%
main()
# Out:
# 主线程Thread-49开始
# get_jobObjectList()当前处理链接: https://search.51job.com/list/000000,000000,0000,00,9,99,Java,2,1.html?lang=c&stype=&postchannel=0000&workyear=99&cotype=99&degreefrom=99&jobterm=99&companysize=99&providesalary=99&lonlat=0%2C0&radius=-1&ord_field=0&confirmdate=9&fromType=&dibiaoid=0&address=&line=&specialarea=00&from=&welfare=
# get_jobObjectList()当前处理链接: https://search.51job.com/list/000000,000000,0000,00,9,99,Java,2,2.html?lang=c&stype=&postchannel=0000&workyear=99&cotype=99&degreefrom=99&jobterm=99&companysize=99&providesalary=99&lonlat=0%2C0&radius=-1&ord_field=0&confirmdate=9&fromType=&dibiaoid=0&address=&line=&specialarea=00&from=&welfare=
# 主线程Thread-50开始
# get_jobObjectList()当前处理链接:主线程Thread-51开始
html?s=01&t=0
# getTag()获得的ip: {'http': '45.76.247.122:3128', 'https': '45.76.247.122:3128'}
# getTag()中tag_list: getTag()中tag_list:getTag()中tag_list:['3-4年经验', '本科', '招2人', '07-18发布']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/hangzhou-bjq/99555111.html?s=01&t=0
# getTag()获得的ip: {'http': '45.76.247.122:3128', 'https': '45.76.247.122:3128'}
#  ['无工作经验', '本科', '招若干人', '07-18发布']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/shanghai-xhq/85523985.html?s=01&t=0
# getTag()获得的ip: {'http': '45.76.247.122:3128', 'https': '45.76.247.122:3128'}
# getTag()中tag_list: ['3-4年经验', '本科', '招若干人', '07-18发布', '五险一金', '弹性工作', '定期体检', '年终奖金', '绩效奖金', '员工旅游', '专业培训']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/shenzhen-lhxq/69207758.html?s=01&t=0
# getTag()获得的ip: {'http': '45.76.247.122:3128', 'https': '45.76.247.122:3128'}
#  ['3-4年经验', '本科', '招1人', '07-18发布', '五险一金', '餐饮补贴', '弹性工作', '节日福利', '绩效奖金', '带薪年假']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/dalian-zsq/104179970.html?s=01&t=0
# getTag()获得的ip: {'http': '45.76.247.122:3128', 'https': '45.76.247.122:3128'}
# getTag()中tag_list:getTag()中tag_list: ['无工作经验', '本科', '招1人', '07-18发布', '五险一金', '补充医疗保险', '员工旅游', '交通补贴', '年终奖金', '绩效奖金', '通讯补贴', '定期体检']
# ...
# getTag()中tag_list:getTag()中tag_list: ['无工作经验', '招5人', '07-18发布']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/shanghai-hpq/104664775.html?s=01&t=0
# getTag()获得的ip: {'http': '45.76.247.122:3128', 'https': '45.76.247.122:3128'}
#  ['3-4年经验', '本科', '招1人', '07-18发布']
# ----------------------
# getTag()中tag_list:getTag()中tag_list:getTag()中tag_list: ['3-4年经验', '大专', '招2人', '07-18发布', '五险一金', '绩效奖金', '员工下午茶', '员工活动', '员工旅游', '专业培训']
# ----------------------
#  ['1年经验', '大专', '招1人', '07-18发布', '带薪年假', '五险一金', '专业培训', '节日福利', '绩效奖金']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/guangzhou-hzq/101299889.html?s=01&t=0
# getTag()获得的ip: {'http': '45.76.247.122:3128', 'https': '45.76.247.122:3128'}
#  ['无工作经验', '大专', '招若干人', '07-18发布']
# ----------------------
#  ['2年经验', '大专', '招3人', '07-18发布', '五险一金', '补充医疗保险', '员工旅游', '餐饮补贴', '通讯补贴', '专业培训', '绩效奖金', '年终奖金', '定期体检']
# ----------------------
# getTag()中tag_list:getTag()中tag_list: ['2年经验', '大专', '招3人', '07-18发布', '五险一金', '补充医疗保险', '餐饮补贴', '绩效奖金', '年终奖金', '股票期权', '弹性工作', '定期体检']
# ----------------------
#  ['3-4年经验', '本科', '招10人', '07-18发布', '五险一金', '餐饮补贴', '专业培训', '定期体检', '通讯补贴', '年终奖金']
# ----------------------
# getTag()中tag_list: ['3-4年经验', '大专', '招1人', '07-18发布', '专业培训', '餐饮补贴', '通讯补贴', '员工旅游', '绩效奖金', '年终奖金', '定期体检']
# ----------------------
# getTag()中tag_list:getTag()中tag_list:getTag()中tag_list: ['无工作经验', '本科', '招2人', '07-18发布', '五险一金', '餐饮补贴', '专业培训', '免费班车', '定期体检', '加班补贴', '带薪年假', '周末双休', '节日福利', '住房补贴']
# ----------------------
# getTag()中tag_list: ['3-4年经验', '大专', '招5人', '07-18发布', '周末双休', '弹性工作', '带薪年假', '包吃', '五险一金', '节日福利']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/xian-ytq/104662286.html?s=01&t=0
# getTag()获得的ip: {'http': '45.76.247.122:3128', 'https': '45.76.247.122:3128'}
#  ['1年经验', '大专', '招4人', '07-18发布', '五险一金', '免费班车', '年终奖金', '绩效奖金', '周末双休', '员工旅游']
# ----------------------
# getTag()中tag_list: ['3-4年经验', '大专', '招3人', '07-18发布']
# ----------------------
# getTag()中tag_list: ['3-4年经验', '本科', '招5人', '07-18发布', '五险一金', '绩效奖金', '带薪年假', '定期体检', '员工旅游', '节日福利']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/shenyang/104092281.html?s=01&t=0
# getTag()获得的ip: {'http': '45.76.247.122:3128', 'https': '45.76.247.122:3128'}
#  ['1年经验', '本科', '招若干人', '07-18发布', '餐饮补贴', '五险一金', '年终奖金']
# ----------------------
# getTag()中tag_list: ['2年经验', '本科', '招1人', '07-18发布', '五险一金', '员工旅游', '年终奖金', '绩效奖金', '股票期权', '专业培训']
# ----------------------
# getTag()中tag_list:getTag()中tag_list: ['3-4年经验', '本科', '招2人', '07-18发布', '五险一金', '员工旅游', '出国机会', '专业培训', '绩效奖金', '年终奖金', '弹性工作', '定期体检']
# ----------------------
# getTag()中tag_list: ['1年经验', '大专', '招10人', '07-18发布', '五险一金', '年终奖金', '定期体检', '节日福利']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/shanghai-ypq/104662725.html?s=01&t=0
# getTag()获得的ip: {'http': '45.76.247.122:3128', 'https': '45.76.247.122:3128'}
# getTag()中tag_list: ['3-4年经验', '大专', '招7人', '07-18发布']
# ----------------------
#  ['无工作经验', '本科', '招若干人', '07-18发布', '五险一金', '定期体检', '绩效奖金', '餐饮补贴', '股票期权', '年终奖金']
# ----------------------
# getTag()中tag_list:getTag()中tag_list:getTag()中tag_list: ['无工作经验', '本科', '招若干人', '07-18发布', '五险一金', '专业培训', '年终奖金', '绩效奖金']
# ----------------------
# getTag()中tag_list: ['无工作经验', '大专', '招1人', '07-18发布', '五险一金', '员工旅游', '专业培训', '通讯补贴', '定期体检', '餐饮补贴', '绩效奖金', '年终奖金']
# ----------------------
# getTag()中tag_list: ['3-4年经验', '大专', '招3人', '07-18发布', '五险一金', '员工旅游', '绩效奖金', '年终奖金', '全勤奖', '带薪休假', '升迁机会']
# ----------------------
# getTag()当前处理链接: https://jobs.51job.com/shanghai-xhq/101939176.html?s=01&t=0
# getTag()获得的ip: {'http': '45.76.247.122:3128', 'https': '45.76.247.122:3128'}
#  ['5-7年经验', '本科', '招1人', '07-18发布', '做五休二', '周末双休', '带薪年假', '五险一金', '绩效奖金', '节日福利', '餐饮补贴', '通讯补贴']
# ----------------------
#  ['3-4年经验', '大专', '招2人', '07-18发布']
# ----------------------
# getTag()中tag_list: ['3-4年经验', '大专', '招10人', '07-18发布', '员工旅游', '餐饮补贴', '通讯补贴', '专业培训', '绩效奖金', '年终奖金', '定期体检', '股票期权']
# ----------------------
# getTag()中tag_list:getTag()中tag_list: ['3-4年经验', '本科', '招2人', '07-18发布', '五险一金', '定期体检', '交通补贴', '通讯补贴', '员工旅游', '专业培训', '弹性工作', '年终奖金', '绩效奖金']
# ----------------------
#  ['3-4年经验', '大专', '招若干人', '07-18发布']
# ----------------------
# getTag()中tag_list:getTag()中tag_list:getTag()中tag_list:getTag()中tag_list: ['1年经验', '大专', '招1人', '07-18发布', '五险一金', '餐饮补贴', '绩效奖金', '定期体检'] ['5-7年经验', '大专', '招5人', '07-18发布', '五险一金', '免费班车', '员工旅游', '弹性工作', '绩效奖金', '年终奖金']
# ----------------------
#  ['3-4年经验', '本科', '招3人', '07-18发布', '五险一金', '交通补贴', '通讯补贴', '做五休二']
# ----------------------
#
# ----------------------
# Thread-94 已停止
# Thread-95 已停止
# getTag()中tag_list: ['1年经验', '大专', '招1人', '07-18发布', '五险一金', '专业培训', '绩效奖金', '年终奖金']
# ----------------------
# getTag()中tag_list: ['无工作经验', '本科', '招3人', '07-18发布', '五险一金', '餐饮补贴', '通讯补贴', '定期体检', '补充公积金', '员工旅游', '专业培训', '年终奖金', '绩效奖金', '商业保险']
# ----------------------
#  ['3-4年经验', '大专', '招6人', '07-18发布', '五险一金', '补充医疗保险', '员工旅游', '专业培训', '定期体检', '12天带薪年假']
# ----------------------
# getTag()中tag_list:getTag()中tag_list: ['无工作经验', '大专', '招4人', '07-18发布']
# ----------------------
# getTag()中tag_list:getTag()中tag_list: ['5-7年经验', '大专', '招1人', '07-18发布', '五险一金', '餐饮补贴']
# ----------------------
#  ['2年经验', '本科', '招若干人', '07-18发布', '五险一金', '专业培训', '免费班车', '年终奖金', '绩效奖金', '员工旅游', '股票期权']
# ----------------------
# Thread-74 已停止
# Thread-75 已停止
# Thread-96 已停止
# getTag()中tag_list: ['5-7年经验', '本科', '招5人', '07-18发布', '五险一金', '专业培训']
# ----------------------
# getTag()中tag_list:getTag()中tag_list:getTag()中tag_list: ['5-7年经验', '本科', '招3人', '07-18发布', '五险一金', '采暖补贴', '高温补贴', '餐饮补贴', '定期体检', '绩效奖金', '专业培训']
# ----------------------
# getTag()中tag_list: ['无工作经验', '招4人', '07-18发布', '五险一金', '补充医疗保险', '年终奖金', '定期体检']
# ----------------------
# getTag()中tag_list: ['2年经验', '本科', '招若干人', '07-18发布', '五险一金', '绩效奖金', '定期体检', '交通补贴', '项目工作奖', '弹性工作', '股票期权']
# ----------------------
# getTag()中tag_list: ['3-4年经验', '本科', '招1人', '07-18发布']
# ----------------------
#  ['无工作经验', '大专', '招若干人', '07-18发布', '五险一金', '绩效奖金', '餐饮补贴', '专业培训', '年终奖金', '定期体检', '员工旅游', '交通补贴']
# ----------------------
# getTag()中tag_list: ['2年经验', '大专', '招2人', '07-18发布', '五险一金', '交通补贴', '年终奖金']
# ----------------------
#  ['3-4年经验', '本科', '招1人', '07-18发布']
# ----------------------
# getTag()中tag_list: ['无工作经验', '高中', '招6人', '07-18发布', '五险一金', '员工旅游', '交通补贴', '餐饮补贴', '专业培训', '出国机会', '绩效奖金', '年终奖金', '弹性工作', '定期体检']
# ----------------------
# getTag()中tag_list:getTag()中tag_list: ['3-4年经验', '本科', '招6人', '07-18发布', '五险一金', '餐饮补贴', '绩效奖金', '年终奖金']
# ----------------------
# getTag()中tag_list:getTag()中tag_list:getTag()中tag_list: ['3-4年经验', '本科', '招10人', '07-18发布', '五险一金', '餐饮补贴', '定期体检', '专业培训', '免费班车', '员工旅游', '交通补贴', '年终奖金', '股票期权', '绩效奖金']
# ----------------------
# getTag()中tag_list: ['3-4年经验', '本科', '招5人', '07-18发布', '五险一金', '交通补贴', '餐饮补贴', '绩效奖金', '年终奖金', '定期体检', '节日福利']
# ----------------------
#  ['2年经验', '大专', '招2人', '07-18发布', '五险一金', '年终奖金', '股票期权']
# ----------------------
#  getTag()中tag_list: ['1年经验', '本科', '招1人', '07-18发布', '五险一金', '餐饮补贴', '年终奖金']
# ----------------------
# getTag()中tag_list: ['3-4年经验', '招若干人', '07-18发布', '做五休二', '周末双休', '弹性工作', '五险一金', '绩效奖金']
# ----------------------
# ['3-4年经验', '本科', '招2人', '07-18发布', '员工旅游', '绩效奖金', '年终奖金', '专业培训', '股票期权', '弹性工作', '定期体检', '出国机会', '五险一金']
# ----------------------
# getTag()中tag_list:getTag()中tag_list: ['3-4年经验', '本科', '招1人', '07-18发布', '周末双休', '五险一金', '通讯补贴', '餐饮补贴', '节日福利', '做五休二', '年终奖金', '电脑补贴']
# ----------------------
# Thread-114 已停止
#  ['2年经验', '本科', '招2人', '07-18发布', '五险一金', '补充医疗保险', '年终奖金', '定期体检', '餐饮补贴', '通讯补贴']
# ----------------------
# getTag()中tag_list: ['3-4年经验', '大专', '招若干人', '07-18发布', '五险一金', '交通补贴', '员工旅游', '餐饮补贴', '出国机会', '弹性工作', '定期体检', '周末双休']
# ----------------------
#  ['无工作经验', '大专', '招5人', '07-18发布', '五险一金', '专业培训', '绩效奖金', '年终奖金', '弹性工作', '定期体检', '员工旅游', '出国机会', '通讯补贴', '餐饮补贴']
# ----------------------
# getTag()中tag_list:getTag()中tag_list: ['无工作经验', '大专', '招8人', '07-18发布', '节日福利', '五险一金', '带薪年假', '补充医疗保险', '员工旅游', '年终奖金', '周末双休'] ['5-7年经验', '本科', '招若干人', '07-18发布']
# ----------------------
#  ['无工作经验', '招1人', '07-18发布', '五险一金']
# ----------------------
# getTag()中tag_list: ['5-7年经验', '本科', '招若干人', '07-18发布', '五险一金', '补充医疗保险', '补充公积金', '交通补贴', '餐饮补贴', '通讯补贴', '年终奖金', '绩效奖金', '定期体检']
# ----------------------
# getTag()中tag_list:getTag()中tag_list: ['5-7年经验', '大专', '招2人', '07-18发布', '五险一金', '免费班车', '餐饮补贴', '年终奖金', '弹性工作', '过节福利', '员工旅游']
# ----------------------
# getTag()中tag_list: ['3-4年经验', '大专', '招1人', '07-18发布', '五险一金', '餐饮补贴', '通讯补贴', '绩效奖金']
# ----------------------
#
# ----------------------
# ['5-7年经验', '本科', '招若干人', '07-18发布', '五险一金', '补充医疗保险', '补充公积金', '员工旅游', '餐饮补贴', '通讯补贴', '专业培训', '绩效奖金', '年终奖金', '弹性工作']
# getTag()中tag_list:getTag()中tag_list:----------------------
#  ['2年经验', '本科', '招10人', '07-18发布', '餐饮补贴', '五险一金', '年终奖金', '定期体检', '绩效奖金']
# ----------------------
# getTag()中tag_list:getTag()中tag_list: ['3-4年经验', '大专', '招4人', '07-18发布', '五险一金', '餐饮补贴', '通讯补贴', '绩效奖金', '年终奖金', '股票期权', '员工旅游']
# ----------------------
# getTag()中tag_list: ['3-4年经验', '大专', '招2人', '07-18发布', '五险一金', '年终奖金', '股票期权', '弹性工作', '餐饮补贴']
# ----------------------
#  getTag()中tag_list:['3-4年经验', '本科', '招2人', '07-18发布']
# ----------------------
# getTag()中tag_list: ['无工作经验', '硕士', '招若干人', '07-18发布', '五险一金', '交通补贴', '餐饮补贴', '通讯补贴', '年终奖金', '专业培训', '节假日福利', '住房补贴', '工龄补贴']
# ----------------------
# getTag()中tag_list: getTag()中tag_list:getTag()中tag_list:  ['3-4年经验', '本科', '招若干人', '07-18发布']
# ----------------------
# ['无工作经验', '本科', '招2人', '07-18发布', '五险一金', '餐饮补贴', '专业培训', '出国机会', '绩效奖金', '年终奖金', '员工旅游', '定期体检']
# ----------------------
#  ['1年经验', '大专', '招2人', '07-18发布']
# ----------------------
# ['3-4年经验', '本科', '招2人', '07-18发布', '五险一金', '员工旅游', '年终奖金', '绩效奖金', '定期体检', '弹性工作', '周末双休', '项目奖金']
# ----------------------
# getTag()中tag_list: getTag()中tag_list: ['3-4年经验', '本科', '招若干人', '07-18发布', '五险一金', '定期体检', '通讯补贴', '十三薪'] ['3-4年经验', '大专', '招3人', '07-18发布', '通讯补贴', '弹性工作', '员工旅游', '股票期权', '年终奖金', '绩效奖金', '五险']
# ----------------------
# Thread-54 已停止
#
# ----------------------
# getTag()中tag_list: ['3-4年经验', '招2人', '07-18发布', '做五休二', '五险一金', '周末双休', '全勤奖', '绩效奖金', '专业培训']
# ----------------------
# getTag()中tag_list:['1年经验', '大专', '招1人', '07-18发布', '五险一金', '员工旅游', '定期体检', '绩效奖金', '年终奖金']
# ----------------------
# getTag()中tag_list: ['2年经验', '本科', '招若干人', '07-18发布', '五险一金', '绩效奖金', '年终奖金']
# ----------------------
# getTag()中tag_list: ['3-4年经验', '大专', '招3人', '07-18发布', '五险一金', '餐饮补贴', '通讯补贴', '绩效奖金', '年终奖金', '股票期权', '员工旅游']getTag()中tag_list: Thread-134 已停止
# ['无工作经验', '招1人', '07-18发布', '餐饮补贴', '五险一金', '高温补贴']
# ----------------------getTag()中tag_list: ['3-4年经验', '大专', '招5人', '07-18发布', '五险一金', '补充医疗保险', '年终奖金', '定期体检'] ['3-4年经验', '本科', '招1人', '07-18发布', '五险一金', '免费班车', '员工旅游', '绩效奖金', '专业培训', '周末双休']
# ----------------------
#
# getTag()中tag_list: ['3-4年经验', '本科', '招2人', '07-18发布']
#
# getTag()中tag_list: ----------------------['3-4年经验', '本科', '招1人', '07-18发布', '周末双休', '带薪年假', '专业培训', '全勤奖', '六险']
# ----------------------
#
# ----------------------
# ----------------------getTag()中tag_list:
# getTag()中tag_list: ['3-4年经验', '本科', '招2人', '07-18发布', '五险一金', '餐饮补贴', '定期体检', '绩效奖金', '年终奖金', '员工旅游', '节日福利', '带薪年假']
# ----------------------
#
# getTag()中tag_list:  ['1年经验', '本科', '招若干人', '07-18发布', '五险一金', '年终奖金', '员工旅游', '定期体检']
# ----------------------
# ['5-7年经验', '本科', '招1人', '07-18发布', '五险一金', '绩效奖金', '年终奖金']getTag()中tag_list: ['3-4年经验', '大专', '招2人', '07-18发布', '五险一金', '员工旅游', '餐饮补贴', '绩效奖金', '年终奖金', '定期体检']
# ----------------------
# Thread-97 已停止
# Thread-98 已停止
# Thread-99 已停止
# Thread-100 已停止
# Thread-101 已停止
#
# ----------------------
# getTag()中tag_list: ['3-4年经验', '大专', '招2人', '07-18发布', '五险一金', '节日福利', '专业培训', '餐饮补贴', '房补', '周末双休']
# ----------------------
# getTag()中tag_list: ['无工作经验', '招8人', '07-18发布']
# ----------------------
# Thread-102 已停止
# Thread-103 已停止
# Thread-104 已停止
# Thread-105 已停止
# getTag()中tag_list: ['3-4年经验', '大专', '招若干人', '07-18发布', '五险一金', '绩效奖金', '年终奖金', '生日福利']
# ----------------------
# Thread-76 已停止
# Thread-77 已停止
# Thread-78 已停止
# Thread-79 已停止
# Thread-80 已停止
# Thread-81 已停止
# Thread-82 已停止
# Thread-83 已停止
# Thread-84 已停止
# Thread-85 已停止
# Thread-86 已停止
# Thread-87 已停止
# Thread-88 已停止
# Thread-89 已停止
# Thread-90 已停止
# Thread-91 已停止
# Thread-92 已停止
# Thread-93 已停止
# tag组装完成!
# pack_tag() 运行时间: 126
# getTag()中tag_list: ['3-4年经验', '本科', '招7人', '07-18发布']getTag()中tag_list:
# ----------------------
# Thread-135 已停止['8-9年经验', '本科', '招3人', '07-18发布', '弹性工作', '全勤奖', '绩效奖金', '节日福利', '专业培训', '五险一金', '带薪年假']
# ----------------------
#
# Thread-136 已停止
# Thread-137 已停止
# Thread-138 已停止
# Thread-139 已停止
# Thread-140 已停止
# Thread-141 已停止
# Thread-142 已停止
# Thread-143 已停止
# Thread-144 已停止
# Thread-145 已停止
# Thread-146 已停止
# Thread-147 已停止
# Thread-148 已停止
# Thread-149 已停止
# Thread-150 已停止
# Thread-151 已停止
# Thread-152 已停止
# Thread-153 已停止
# tag组装完成!
# pack_tag() 运行时间: 125
# Thread-53完成单页的时间: 133
# get_jobObjectList()当前处理链接: https://search.51job.com/list/000000,000000,0000,00,9,99,Java,2,6.html?lang=c&stype=&postchannel=0000&workyear=99&cotype=99&degreefrom=99&jobterm=99&companysize=99&providesalary=99&lonlat=0%2C0&radius=-1&ord_field=0&confirmdate=9&fromType=&dibiaoid=0&address=&line=&specialarea=00&from=&welfare=
# Thread-50完成单页的时间: 134
# get_jobObjectList()当前处理链接: https://search.51job.com/list/000000,000000,0000,00,9,99,Java,2,7.html?lang=c&stype=&postchannel=0000&workyear=99&cotype=99&degreefrom=99&jobterm=99&companysize=99&providesalary=99&lonlat=0%2C0&radius=-1&ord_field=0&confirmdate=9&fromType=&dibiaoid=0&address=&line=&specialarea=00&from=&welfare=
# getTag()中tag_list: ['无工作经验', '本科', '招4人', '07-18发布', '交通补贴', '餐饮补贴', '年终奖金']getTag()中tag_list: ['1年经验', '本科', '招若干人', '07-18发布', '五险一金', '员工旅游', '通讯补贴', '出国机会', '绩效奖金', '年终奖金', '弹性工作']
# ----------------------
#
# ----------------------
# Thread-55 已停止
# Thread-56 已停止
# Thread-57 已停止
# Thread-58 已停止
# Thread-59 已停止
# Thread-60 已停止
# Thread-61 已停止
# Thread-62 已停止
# Thread-63 已停止
# Thread-64 已停止
# Thread-65 已停止
# Thread-66 已停止
# Thread-67 已停止
# Thread-68 已停止
# Thread-69 已停止
# Thread-70 已停止
# Thread-71 已停止
# Thread-72 已停止
# Thread-73 已停止
# tag组装完成!
# pack_tag() 运行时间: 128
# Thread-49完成单页的时间: 134
# get_jobObjectList()当前处理链接: https://search.51job.com/list/000000,000000,0000,00,9,99,Java,2,8.html?lang=c&stype=&postchannel=0000&workyear=99&cotype=99&degreefrom=99&jobterm=99&companysize=99&providesalary=99&lonlat=0%2C0&radius=-1&ord_field=0&confirmdate=9&fromType=&dibiaoid=0&address=&line=&specialarea=00&from=&welfare=
# getTag()中tag_list:getTag()中tag_list:  ['5-7年经验', '大专', '招2人', '07-18发布', '周末双休', '弹性工作', '带薪年假', '五险一金', '全勤奖', '节日福利', '专业培训', '餐饮补贴', '交通补贴', '通讯补贴']
# ----------------------
# ['5-7年经验', '本科', '招4人', '07-18发布', '五险一金', '员工旅游', '餐饮补贴', '通讯补贴', '专业培训', '绩效奖金', '年终奖金', '定期体检']
# ----------------------
# Thread-115 已停止
# Thread-116 已停止
# Thread-117 已停止
# Thread-118 已停止
# getTag()中tag_list: ['无工作经验', '大专', '招5人', '07-18发布', '五险一金', '绩效奖金', '年终奖金', '员工旅游']
# ----------------------
# Thread-106 已停止
# Thread-107 已停止
# Thread-108 已停止
# getTag()中tag_list: ['3-4年经验', '本科', '招2人', '07-18发布', '五险一金', '弹性工作', '绩效奖金', '年终奖金', '员工旅游', '股票期权']
# ----------------------
# Thread-119 已停止
# Thread-120 已停止
# Thread-121 已停止
# Thread-122 已停止
# Thread-123 已停止
# Thread-124 已停止
# Thread-125 已停止
# Thread-126 已停止
# Thread-127 已停止
# Thread-128 已停止
# Thread-129 已停止
# Thread-130 已停止
# Thread-131 已停止
# Thread-132 已停止
# Thread-133 已停止
# tag组装完成!
# pack_tag() 运行时间: 129
# Thread-52完成单页的时间: 135
# get_jobObjectList()当前处理链接: https://search.51job.com/list/000000,000000,0000,00,9,99,Java,2,9.html?lang=c&stype=&postchannel=0000&workyear=99&cotype=99&degreefrom=99&jobterm=99&companysize=99&providesalary=99&lonlat=0%2C0&radius=-1&ord_field=0&confirmdate=9&fromType=&dibiaoid=0&address=&line=&specialarea=00&from=&welfare=
# getTag()中tag_list: ['无工作经验', '招若干人', '07-18发布']
# ----------------------
# Thread-109 已停止
# Thread-110 已停止
# Thread-111 已停止
# Thread-112 已停止
# Thread-113 已停止
# tag组装完成!
# pack_tag() 运行时间: 130
# Thread-51完成单页的时间: 137
# get_jobObjectList()当前处理链接: https://search.51job.com/list/000000,000000,0000,00,9,99,Java,2,10.html?lang=c&stype=&postchannel=0000&workyear=99&cotype=99&degreefrom=99&jobterm=99&companysize=99&providesalary=99&lonlat=0%2C0&radius=-1&ord_field=0&confirmdate=9&fromType=&dibiaoid=0&address=&line=&specialarea=00&from=&welfare=
# get_jobObjectList处理完成!
# get_jobObjectList() 运行时间: 86

# %% [raw]
# 当清洗ip的代码清理出去之后，proxy变成全局变量，读取连接时都使用同一个ip来链接，知道这个ip不可用，才获取下一个ip，
# 跑了一下发现，清洗一次的ip就足够爬10页的数据，大大缩减了时间
#
# 之前的程序是每个线程读取新的一页，就自己清洗一遍ip,然后在开始处理单页，消耗很多时间，也浪费很多ip
# ------------------------------------------------------------------------------------
# 10页2线程300秒
# 10页4线程264秒
